# %%
import sys, os
sys.path.append('../..')
import json
import requests
from brokerapis.ebestOpenAPI import Ebest

# %%
# %load_ext autoreload
# %aimport brokerapis.ebestOpenAPI
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
ebest = Ebest()

# %%
ebest.login()
# Out:
# login succeeded
# True

# %%
res = ebest.transactions()
# Out:
# login succeeded

# %%
res.json()
# Out:
# {'CIDBQ02400OutBlock1': {'RecCnt': 1,
#   'AcntNo': '20010617901',
#   'Pwd': '********',
#   'IsuCodeVal': '',
#   'QrySrtDt': '20230516',
#   'QryEndDt': '20230717',
#   'ThdayTpCode': '0',
#   'OrdStatCode': '1',
#   'BnsTpCode': '0',
#   'QryTpCode': '2',
#   'OrdPtnCode': '00',
#   'OvrsDrvtFnoTpCode': 'A'},
#  'CIDBQ02400OutBlock2': [{'OrdDt': '20230516',
#    'OvrsFutsOrdNo': '0000024214',
#    'OvrsFutsOrgOrdNo': '0000000000',
#    'FcmOrdNo': '58169104025408',
#    'ExecDt': '20230516',
#    'OvrsFutsExecNo': '0000010661',
#    'FcmAcntNo': 'EBK8000',
#    'IsuCodeVal': '3ZNM23_1140',
#    'IsuNm': '10Y US T-Note P114.0 (2306)',
#    'AbrdFutsXrcPrc': '0.00000000000',
#    'BnsTpCode': '1',
#    'BnsTpNm': '매도',
#    'FutsOrdStatCode': '4',
#    'TpCodeNm': '신규',
#    'FutsOrdTpCode': '1',
#    'TrdTpNm': '체결',
#    'AbrdFutsOrdPtnCode': '2',
#    'OrdPtnNm': '지정가',
#    'OrdPtnTermTpCode': '01',
#    'CmnCodeNm': '일반',
#    'AppSrtDt': '',
#    'AppEndDt': '',
# ...

# %%
BASE_URL = "https://openapi.ebestsec.co.kr:8080"
PATH = "oauth2/token"
URL = f"{BASE_URL}/{PATH}"
ACCESS_TOKEN = "APP_KEY, APP_SECRET를 이용하여 발급받은 접근토큰"

# %%
headers = {  
    "content-type":"application/x-www-form-urlencoded",
}

# %%
body = {
    
    "appkey": "PSGFKbQVRJQiKbmIGRGF4z2ylNuszB5aGfYe",
    "appsecretkey": "f8n4bANxKzrdmnvJzvoNBVKPcCzPw62b",
    "grant_type":"client_credentials",
    "scope":"oob"
}

# %%
res = requests.post(URL, headers=headers, data=body)

# %%
res.json()
# Out:
# {'access_token': 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzUxMiJ9..xB5suT4WOEHrYi8NZKvEGgFMRkxw9nmIQgLJxGNxwz2gtkOD8575Na9OVZ8NjGXry753tMq85ILHiio_9QuwqQ',
#  'scope': 'oob',
#  'token_type': 'Bearer',
#  'expires_in': 56987}

# %%
URL
# Out:
# 'https://openapi.ebestsec.co.kr:8080//oauth2/token'

# %%
url= "https://openapi.ebestsec.co.kr:8080/oauth2/token?appkey=PSGFKbQVRJQiKbmIGRGF4z2ylNuszB5aGfYe&appsecretkey=f8n4bANxKzrdmnvJzvoNBVKPcCzPw62b&grant_type=client_credentials&scope=oob"

# %%
os.path.curdir
# Out:
# '.'
