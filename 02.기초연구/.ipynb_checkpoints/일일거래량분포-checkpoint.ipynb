# %%
import os, sys, pickle
sys.path.append('../')
sys.path.append('../scripts')
import tables as tb
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from models import OHLC, Products, Product
from tools import ohlc_chart, view_ohlc

# %%
DATADIR = os.path.join(os.getcwd(), '..', 'data')
ohlcfile = os.path.join(DATADIR,'futures.db')
products = pickle.load(open(os.path.join(DATADIR, 'products.pkl'),'rb')) #파일 로드

# %%
df =  products['LC'].dataframe()

# %%
view_ohlc(df, size=(9,7))
