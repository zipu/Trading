# %%
import sys, imp, os
from functools import reduce
import pandas as pd
import numpy as np
import h5py
import matplotlib.pyplot as plt
import nasdaqdatalink as ndl
import yaml
from tools.instruments import instruments, Quotes
from tools.constants import SRF_CONTINUOUS_BO_DB_PATH
from tools.display import ohlc_chart, view, oi_chart, metrics_chart, index_chart
import backtesting as bt
import re
from tools.display import MyFormatter

# %%
with open('03.전략연구/systems/system2.yaml', encoding='utf-8') as f:
    system1 = yaml.load(f, Loader=yaml.FullLoader)
    print(system1)
# Out:
# {'name': None, 'description': '시스템 설명', 'quotes_style': 'bo', 'sectors': 'default', 'instruments': ['AD', 'CL', 'C', 'LC'], 'from_date': '2015-01-01', 'to_date': '2017-05-01', 'principal': 1000000, 'heat_system': 'DefaultHeat', 'max_system_heat': 0.4, 'max_sector_heat': 0.4, 'max_trade_heat': 0.1, 'max_lots': 2, 'commission': 2.99, 'skid': 0.25, 'metrics': [['ema200', 'EMA', 'window=200'], ['ema20', 'EMA', 'window=20'], ['volatility', 'ATR', 'window=30'], ['min20', 'MIN', 'window=20'], ['max20', 'MAX', 'window=20']], 'entry_rule': {'long': 'ema200<ema20', 'short': 'ema200>ema20'}, 'exit_rule': {'long': 'ema200>ema20', 'short': 'ema200<ema20'}, 'stop_rule': {'long': 'min20', 'short': 'max20'}}

# %%
trader = bt.Trader(quotes_style='bo', systems=[system1])
system = trader.systems[0]

# %%
# %%time
trader.run()
# Out:
# 매매시작
# 거래일: 2015-01-02 00:00:00, 시스템: None 3.339082717895508sec
# 거래일: 2015-01-05 00:00:00, 시스템: None 0.006978034973144531sec
# 거래일: 2015-01-06 00:00:00, 시스템: None 0.006956577301025391sec
# 거래일: 2015-01-07 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2015-01-08 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2015-01-09 00:00:00, 시스템: None 0.006981372833251953sec
# 거래일: 2015-01-12 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2015-01-13 00:00:00, 시스템: None 0.005984306335449219sec
# 거래일: 2015-01-14 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2015-01-15 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2015-01-16 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2015-01-19 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2015-01-20 00:00:00, 시스템: None 0.002024412155151367sec
# 거래일: 2015-01-21 00:00:00, 시스템: None 0.005954265594482422sec
# 거래일: 2015-01-22 00:00:00, 시스템: None 0.006981372833251953sec
# 거래일: 2015-01-23 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2015-01-26 00:00:00, 시스템: None 0.005983591079711914sec
# 거래일: 2015-01-27 00:00:00, 시스템: None 0.00800180435180664sec
# 거래일: 2015-01-28 00:00:00, 시스템: None 0.005961179733276367sec
# 거래일: 2015-01-29 00:00:00, 시스템: None 0.007978439331054688sec
# 거래일: 2015-01-30 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2015-02-02 00:00:00, 시스템: None 0.006981372833251953sec
# 거래일: 2015-02-03 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2015-02-04 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2015-02-05 00:00:00, 시스템: None 0.006981372833251953sec
# 거래일: 2015-02-06 00:00:00, 시스템: None 0.005983591079711914sec
# 거래일: 2015-02-09 00:00:00, 시스템: None 0.005984306335449219sec
# 거래일: 2015-02-10 00:00:00, 시스템: None 0.005984306335449219sec
# 거래일: 2015-02-11 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2015-02-12 00:00:00, 시스템: None 0.0069811344146728516sec
# 거래일: 2015-02-13 00:00:00, 시스템: None 0.005984306335449219sec
# 거래일: 2015-02-16 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2015-02-17 00:00:00, 시스템: None 0.000997304916381836sec
# 거래일: 2015-02-18 00:00:00, 시스템: None 0.006981372833251953sec
# 거래일: 2015-02-19 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2015-02-20 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2015-02-23 00:00:00, 시스템: None 0.0059833526611328125sec
# 거래일: 2015-02-24 00:00:00, 시스템: None 0.005983591079711914sec
# 거래일: 2015-02-25 00:00:00, 시스템: None 0.006981372833251953sec
# 거래일: 2015-02-26 00:00:00, 시스템: None 0.0069811344146728516sec
# 거래일: 2015-02-27 00:00:00, 시스템: None 0.005984306335449219sec
# 거래일: 2015-03-02 00:00:00, 시스템: None 0.006981372833251953sec
# 거래일: 2015-03-03 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2015-03-04 00:00:00, 시스템: None 0.006981611251831055sec
# 거래일: 2015-03-05 00:00:00, 시스템: None 0.005983591079711914sec
# 거래일: 2015-03-06 00:00:00, 시스템: None 0.006981372833251953sec
# 거래일: 2015-03-09 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2015-03-10 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2015-03-11 00:00:00, 시스템: None 0.006981611251831055sec
# 거래일: 2015-03-12 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2015-03-13 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2015-03-16 00:00:00, 시스템: None 0.00698089599609375sec
# 거래일: 2015-03-17 00:00:00, 시스템: None 0.005984306335449219sec
# 거래일: 2015-03-18 00:00:00, 시스템: None 0.006981611251831055sec
# 거래일: 2015-03-19 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2015-03-20 00:00:00, 시스템: None 0.005983591079711914sec
# 거래일: 2015-03-23 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2015-03-24 00:00:00, 시스템: None 0.005984306335449219sec
# 거래일: 2015-03-25 00:00:00, 시스템: None 0.0069811344146728516sec
# 거래일: 2015-03-26 00:00:00, 시스템: None 0.006981611251831055sec
# 거래일: 2015-03-27 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2015-03-30 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2015-03-31 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2015-04-01 00:00:00, 시스템: None 0.004986763000488281sec
# 거래일: 2015-04-02 00:00:00, 시스템: None 0.006981611251831055sec
# 거래일: 2015-04-03 00:00:00, 시스템: None 0.006981372833251953sec
# 거래일: 2015-04-06 00:00:00, 시스템: None 0.00498652458190918sec
# 거래일: 2015-04-07 00:00:00, 시스템: None 0.006981372833251953sec
# 거래일: 2015-04-08 00:00:00, 시스템: None 0.004986763000488281sec
# 거래일: 2015-04-09 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2015-04-10 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2015-04-13 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2015-04-14 00:00:00, 시스템: None 0.005984306335449219sec
# 거래일: 2015-04-15 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2015-04-16 00:00:00, 시스템: None 0.005983591079711914sec
# 거래일: 2015-04-17 00:00:00, 시스템: None 0.005984306335449219sec
# 거래일: 2015-04-20 00:00:00, 시스템: None 0.0069811344146728516sec
# 거래일: 2015-04-21 00:00:00, 시스템: None 0.005984306335449219sec
# 거래일: 2015-04-22 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2015-04-23 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2015-04-24 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2015-04-27 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2015-04-28 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2015-04-29 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2015-04-30 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2015-05-01 00:00:00, 시스템: None 0.005984306335449219sec
# 거래일: 2015-05-04 00:00:00, 시스템: None 0.0059833526611328125sec
# 거래일: 2015-05-05 00:00:00, 시스템: None 0.005984306335449219sec
# 거래일: 2015-05-06 00:00:00, 시스템: None 0.005984306335449219sec
# 거래일: 2015-05-07 00:00:00, 시스템: None 0.005983591079711914sec
# 거래일: 2015-05-08 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2015-05-11 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2015-05-12 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2015-05-13 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2015-05-14 00:00:00, 시스템: None 0.005983591079711914sec
# 거래일: 2015-05-15 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2015-05-18 00:00:00, 시스템: None 0.006981611251831055sec
# 거래일: 2015-05-19 00:00:00, 시스템: None 0.0069811344146728516sec
# 거래일: 2015-05-20 00:00:00, 시스템: None 0.006981372833251953sec
# 거래일: 2015-05-21 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2015-05-22 00:00:00, 시스템: None 0.006981611251831055sec
# 거래일: 2015-05-25 00:00:00, 시스템: None 0.005983591079711914sec
# 거래일: 2015-05-26 00:00:00, 시스템: None 0.0019948482513427734sec
# 거래일: 2015-05-27 00:00:00, 시스템: None 0.005983591079711914sec
# 거래일: 2015-05-28 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2015-05-29 00:00:00, 시스템: None 0.0059833526611328125sec
# 거래일: 2015-06-01 00:00:00, 시스템: None 0.005984306335449219sec
# 거래일: 2015-06-02 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2015-06-03 00:00:00, 시스템: None 0.006981372833251953sec
# 거래일: 2015-06-04 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2015-06-05 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2015-06-08 00:00:00, 시스템: None 0.005983591079711914sec
# 거래일: 2015-06-09 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2015-06-10 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2015-06-11 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2015-06-12 00:00:00, 시스템: None 0.006981372833251953sec
# 거래일: 2015-06-15 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2015-06-16 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2015-06-17 00:00:00, 시스템: None 0.006981372833251953sec
# 거래일: 2015-06-18 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2015-06-19 00:00:00, 시스템: None 0.005983591079711914sec
# 거래일: 2015-06-22 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2015-06-23 00:00:00, 시스템: None 0.0069811344146728516sec
# 거래일: 2015-06-24 00:00:00, 시스템: None 0.005984306335449219sec
# 거래일: 2015-06-25 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2015-06-26 00:00:00, 시스템: None 0.006993293762207031sec
# 거래일: 2015-06-29 00:00:00, 시스템: None 0.005972146987915039sec
# 거래일: 2015-06-30 00:00:00, 시스템: None 0.004986763000488281sec
# 거래일: 2015-07-01 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2015-07-02 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2015-07-03 00:00:00, 시스템: None 0.00498652458190918sec
# 거래일: 2015-07-06 00:00:00, 시스템: None 0.004986763000488281sec
# 거래일: 2015-07-07 00:00:00, 시스템: None 0.00698089599609375sec
# 거래일: 2015-07-08 00:00:00, 시스템: None 0.00598454475402832sec
# 거래일: 2015-07-09 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2015-07-10 00:00:00, 시스템: None 0.004986286163330078sec
# 거래일: 2015-07-13 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2015-07-14 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2015-07-15 00:00:00, 시스템: None 0.00498652458190918sec
# 거래일: 2015-07-16 00:00:00, 시스템: None 0.006981372833251953sec
# 거래일: 2015-07-17 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2015-07-20 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2015-07-21 00:00:00, 시스템: None 0.005984306335449219sec
# 거래일: 2015-07-22 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2015-07-23 00:00:00, 시스템: None 0.005984306335449219sec
# 거래일: 2015-07-24 00:00:00, 시스템: None 0.00698089599609375sec
# 거래일: 2015-07-27 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2015-07-28 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2015-07-29 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2015-07-30 00:00:00, 시스템: None 0.005983591079711914sec
# 거래일: 2015-07-31 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2015-08-03 00:00:00, 시스템: None 0.006981849670410156sec
# 거래일: 2015-08-04 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2015-08-05 00:00:00, 시스템: None 0.00698089599609375sec
# 거래일: 2015-08-06 00:00:00, 시스템: None 0.005984306335449219sec
# 거래일: 2015-08-07 00:00:00, 시스템: None 0.005982875823974609sec
# 거래일: 2015-08-10 00:00:00, 시스템: None 0.006981372833251953sec
# 거래일: 2015-08-11 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2015-08-12 00:00:00, 시스템: None 0.0069811344146728516sec
# 거래일: 2015-08-13 00:00:00, 시스템: None 0.006981372833251953sec
# 거래일: 2015-08-14 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2015-08-17 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2015-08-18 00:00:00, 시스템: None 0.006981372833251953sec
# 거래일: 2015-08-19 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2015-08-20 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2015-08-21 00:00:00, 시스템: None 0.006981372833251953sec
# 거래일: 2015-08-24 00:00:00, 시스템: None 0.005983591079711914sec
# 거래일: 2015-08-25 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2015-08-26 00:00:00, 시스템: None 0.005983591079711914sec
# 거래일: 2015-08-27 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2015-08-28 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2015-08-31 00:00:00, 시스템: None 0.0059833526611328125sec
# 거래일: 2015-09-01 00:00:00, 시스템: None 0.005984306335449219sec
# 거래일: 2015-09-02 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2015-09-03 00:00:00, 시스템: None 0.006981611251831055sec
# 거래일: 2015-09-04 00:00:00, 시스템: None 0.0069811344146728516sec
# 거래일: 2015-09-07 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2015-09-08 00:00:00, 시스템: None 0.0019948482513427734sec
# 거래일: 2015-09-09 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2015-09-10 00:00:00, 시스템: None 0.005983591079711914sec
# 거래일: 2015-09-11 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2015-09-14 00:00:00, 시스템: None 0.005984306335449219sec
# 거래일: 2015-09-15 00:00:00, 시스템: None 0.006981372833251953sec
# 거래일: 2015-09-16 00:00:00, 시스템: None 0.005983591079711914sec
# 거래일: 2015-09-17 00:00:00, 시스템: None 0.0069811344146728516sec
# 거래일: 2015-09-18 00:00:00, 시스템: None 0.005984306335449219sec
# 거래일: 2015-09-21 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2015-09-22 00:00:00, 시스템: None 0.006981372833251953sec
# 거래일: 2015-09-23 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2015-09-24 00:00:00, 시스템: None 0.006981372833251953sec
# 거래일: 2015-09-25 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2015-09-28 00:00:00, 시스템: None 0.006981372833251953sec
# 거래일: 2015-09-29 00:00:00, 시스템: None 0.0069811344146728516sec
# 거래일: 2015-09-30 00:00:00, 시스템: None 0.0069811344146728516sec
# 거래일: 2015-10-01 00:00:00, 시스템: None 0.006981849670410156sec
# 거래일: 2015-10-02 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2015-10-05 00:00:00, 시스템: None 0.005984306335449219sec
# 거래일: 2015-10-06 00:00:00, 시스템: None 0.00698089599609375sec
# 거래일: 2015-10-07 00:00:00, 시스템: None 0.004986763000488281sec
# 거래일: 2015-10-08 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2015-10-09 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2015-10-12 00:00:00, 시스템: None 0.005983591079711914sec
# 거래일: 2015-10-13 00:00:00, 시스템: None 0.005984306335449219sec
# 거래일: 2015-10-14 00:00:00, 시스템: None 0.006981372833251953sec
# 거래일: 2015-10-15 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2015-10-16 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2015-10-19 00:00:00, 시스템: None 0.0069811344146728516sec
# 거래일: 2015-10-20 00:00:00, 시스템: None 0.00498652458190918sec
# 거래일: 2015-10-21 00:00:00, 시스템: None 0.005983591079711914sec
# 거래일: 2015-10-22 00:00:00, 시스템: None 0.005984306335449219sec
# 거래일: 2015-10-23 00:00:00, 시스템: None 0.004987001419067383sec
# 거래일: 2015-10-26 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2015-10-27 00:00:00, 시스템: None 0.006981611251831055sec
# 거래일: 2015-10-28 00:00:00, 시스템: None 0.005983591079711914sec
# 거래일: 2015-10-29 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2015-10-30 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2015-11-02 00:00:00, 시스템: None 0.006981372833251953sec
# 거래일: 2015-11-03 00:00:00, 시스템: None 0.006981611251831055sec
# 거래일: 2015-11-04 00:00:00, 시스템: None 0.0069811344146728516sec
# 거래일: 2015-11-05 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2015-11-06 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2015-11-09 00:00:00, 시스템: None 0.006981372833251953sec
# 거래일: 2015-11-10 00:00:00, 시스템: None 0.005983591079711914sec
# 거래일: 2015-11-11 00:00:00, 시스템: None 0.006981372833251953sec
# 거래일: 2015-11-12 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2015-11-13 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2015-11-16 00:00:00, 시스템: None 0.006981372833251953sec
# 거래일: 2015-11-17 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2015-11-18 00:00:00, 시스템: None 0.00698089599609375sec
# 거래일: 2015-11-19 00:00:00, 시스템: None 0.005984306335449219sec
# 거래일: 2015-11-20 00:00:00, 시스템: None 0.006981611251831055sec
# 거래일: 2015-11-23 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2015-11-24 00:00:00, 시스템: None 0.005984306335449219sec
# 거래일: 2015-11-25 00:00:00, 시스템: None 0.004986763000488281sec
# 거래일: 2015-11-26 00:00:00, 시스템: None 0.005983591079711914sec
# 거래일: 2015-11-27 00:00:00, 시스템: None 0.0009975433349609375sec
# 거래일: 2015-11-30 00:00:00, 시스템: None 0.0069811344146728516sec
# 거래일: 2015-12-01 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2015-12-02 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2015-12-03 00:00:00, 시스템: None 0.0069811344146728516sec
# 거래일: 2015-12-04 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2015-12-07 00:00:00, 시스템: None 0.006981372833251953sec
# 거래일: 2015-12-08 00:00:00, 시스템: None 0.006981372833251953sec
# 거래일: 2015-12-09 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2015-12-10 00:00:00, 시스템: None 0.0069811344146728516sec
# 거래일: 2015-12-11 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2015-12-14 00:00:00, 시스템: None 0.006981611251831055sec
# 거래일: 2015-12-15 00:00:00, 시스템: None 0.005983591079711914sec
# 거래일: 2015-12-16 00:00:00, 시스템: None 0.006981611251831055sec
# 거래일: 2015-12-17 00:00:00, 시스템: None 0.005983591079711914sec
# 거래일: 2015-12-18 00:00:00, 시스템: None 0.006981372833251953sec
# 거래일: 2015-12-21 00:00:00, 시스템: None 0.006981849670410156sec
# 거래일: 2015-12-22 00:00:00, 시스템: None 0.005983591079711914sec
# 거래일: 2015-12-23 00:00:00, 시스템: None 0.006981611251831055sec
# 거래일: 2015-12-24 00:00:00, 시스템: None 0.005983591079711914sec
# 거래일: 2015-12-28 00:00:00, 시스템: None 0.00598454475402832sec
# 거래일: 2015-12-29 00:00:00, 시스템: None 0.005983591079711914sec
# 거래일: 2015-12-30 00:00:00, 시스템: None 0.006981372833251953sec
# 거래일: 2015-12-31 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2016-01-04 00:00:00, 시스템: None 0.006981372833251953sec
# 거래일: 2016-01-05 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2016-01-06 00:00:00, 시스템: None 0.006981611251831055sec
# 거래일: 2016-01-07 00:00:00, 시스템: None 0.005983591079711914sec
# 거래일: 2016-01-08 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2016-01-11 00:00:00, 시스템: None 0.006981611251831055sec
# 거래일: 2016-01-12 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2016-01-13 00:00:00, 시스템: None 0.0069811344146728516sec
# 거래일: 2016-01-14 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2016-01-15 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2016-01-18 00:00:00, 시스템: None 0.006981372833251953sec
# 거래일: 2016-01-19 00:00:00, 시스템: None 0.0009975433349609375sec
# 거래일: 2016-01-20 00:00:00, 시스템: None 0.0069811344146728516sec
# 거래일: 2016-01-21 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2016-01-22 00:00:00, 시스템: None 0.006981611251831055sec
# 거래일: 2016-01-25 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2016-01-26 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2016-01-27 00:00:00, 시스템: None 0.0069811344146728516sec
# 거래일: 2016-01-28 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2016-01-29 00:00:00, 시스템: None 0.006981849670410156sec
# 거래일: 2016-02-01 00:00:00, 시스템: None 0.005983591079711914sec
# 거래일: 2016-02-02 00:00:00, 시스템: None 0.006981372833251953sec
# 거래일: 2016-02-03 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2016-02-04 00:00:00, 시스템: None 0.005983591079711914sec
# 거래일: 2016-02-05 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2016-02-08 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2016-02-09 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2016-02-10 00:00:00, 시스템: None 0.006995677947998047sec
# 거래일: 2016-02-11 00:00:00, 시스템: None 0.005969524383544922sec
# 거래일: 2016-02-12 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2016-02-15 00:00:00, 시스템: None 0.006981372833251953sec
# 거래일: 2016-02-16 00:00:00, 시스템: None 0.0009970664978027344sec
# 거래일: 2016-02-17 00:00:00, 시스템: None 0.006981611251831055sec
# 거래일: 2016-02-18 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2016-02-19 00:00:00, 시스템: None 0.006981372833251953sec
# 거래일: 2016-02-22 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2016-02-23 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2016-02-24 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2016-02-25 00:00:00, 시스템: None 0.006981372833251953sec
# 거래일: 2016-02-26 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2016-02-29 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2016-03-01 00:00:00, 시스템: None 0.006981611251831055sec
# 거래일: 2016-03-02 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2016-03-03 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2016-03-04 00:00:00, 시스템: None 0.006981372833251953sec
# 거래일: 2016-03-07 00:00:00, 시스템: None 0.00498652458190918sec
# 거래일: 2016-03-08 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2016-03-09 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2016-03-10 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2016-03-11 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2016-03-14 00:00:00, 시스템: None 0.005983591079711914sec
# 거래일: 2016-03-15 00:00:00, 시스템: None 0.005984306335449219sec
# 거래일: 2016-03-16 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2016-03-17 00:00:00, 시스템: None 0.005984306335449219sec
# 거래일: 2016-03-18 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2016-03-21 00:00:00, 시스템: None 0.006981372833251953sec
# 거래일: 2016-03-22 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2016-03-23 00:00:00, 시스템: None 0.006981372833251953sec
# 거래일: 2016-03-24 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2016-03-28 00:00:00, 시스템: None 0.006981372833251953sec
# 거래일: 2016-03-29 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2016-03-30 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2016-03-31 00:00:00, 시스템: None 0.005983591079711914sec
# 거래일: 2016-04-01 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2016-04-04 00:00:00, 시스템: None 0.005984306335449219sec
# 거래일: 2016-04-05 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2016-04-06 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2016-04-07 00:00:00, 시스템: None 0.005983591079711914sec
# 거래일: 2016-04-08 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2016-04-11 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2016-04-12 00:00:00, 시스템: None 0.006981372833251953sec
# 거래일: 2016-04-13 00:00:00, 시스템: None 0.005983591079711914sec
# 거래일: 2016-04-14 00:00:00, 시스템: None 0.005984306335449219sec
# 거래일: 2016-04-15 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2016-04-18 00:00:00, 시스템: None 0.005984306335449219sec
# 거래일: 2016-04-19 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2016-04-20 00:00:00, 시스템: None 0.006981372833251953sec
# 거래일: 2016-04-21 00:00:00, 시스템: None 0.004986763000488281sec
# 거래일: 2016-04-22 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2016-04-25 00:00:00, 시스템: None 0.00698089599609375sec
# 거래일: 2016-04-26 00:00:00, 시스템: None 0.006981372833251953sec
# 거래일: 2016-04-27 00:00:00, 시스템: None 0.004986763000488281sec
# 거래일: 2016-04-28 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2016-04-29 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2016-05-02 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2016-05-03 00:00:00, 시스템: None 0.0059833526611328125sec
# 거래일: 2016-05-04 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2016-05-05 00:00:00, 시스템: None 0.005984306335449219sec
# 거래일: 2016-05-06 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2016-05-09 00:00:00, 시스템: None 0.005983591079711914sec
# 거래일: 2016-05-10 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2016-05-11 00:00:00, 시스템: None 0.005984306335449219sec
# 거래일: 2016-05-12 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2016-05-13 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2016-05-16 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2016-05-17 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2016-05-18 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2016-05-19 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2016-05-20 00:00:00, 시스템: None 0.0069811344146728516sec
# 거래일: 2016-05-23 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2016-05-24 00:00:00, 시스템: None 0.005984306335449219sec
# 거래일: 2016-05-25 00:00:00, 시스템: None 0.004986286163330078sec
# 거래일: 2016-05-26 00:00:00, 시스템: None 0.005984306335449219sec
# 거래일: 2016-05-27 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2016-05-30 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2016-05-31 00:00:00, 시스템: None 0.001994609832763672sec
# 거래일: 2016-06-01 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2016-06-02 00:00:00, 시스템: None 0.006981611251831055sec
# 거래일: 2016-06-03 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2016-06-06 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2016-06-07 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2016-06-08 00:00:00, 시스템: None 0.005983591079711914sec
# 거래일: 2016-06-09 00:00:00, 시스템: None 0.00598454475402832sec
# 거래일: 2016-06-10 00:00:00, 시스템: None 0.005983591079711914sec
# 거래일: 2016-06-13 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2016-06-14 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2016-06-15 00:00:00, 시스템: None 0.006981611251831055sec
# 거래일: 2016-06-16 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2016-06-17 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2016-06-20 00:00:00, 시스템: None 0.006981372833251953sec
# 거래일: 2016-06-21 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2016-06-22 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2016-06-23 00:00:00, 시스템: None 0.006981372833251953sec
# 거래일: 2016-06-24 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2016-06-27 00:00:00, 시스템: None 0.006981372833251953sec
# 거래일: 2016-06-28 00:00:00, 시스템: None 0.0069811344146728516sec
# 거래일: 2016-06-29 00:00:00, 시스템: None 0.005984306335449219sec
# 거래일: 2016-06-30 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2016-07-01 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2016-07-04 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2016-07-05 00:00:00, 시스템: None 0.000997304916381836sec
# 거래일: 2016-07-06 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2016-07-07 00:00:00, 시스템: None 0.006981611251831055sec
# 거래일: 2016-07-08 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2016-07-11 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2016-07-12 00:00:00, 시스템: None 0.006981849670410156sec
# 거래일: 2016-07-13 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2016-07-14 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2016-07-15 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2016-07-18 00:00:00, 시스템: None 0.0069811344146728516sec
# 거래일: 2016-07-19 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2016-07-20 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2016-07-21 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2016-07-22 00:00:00, 시스템: None 0.005983591079711914sec
# 거래일: 2016-07-25 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2016-07-26 00:00:00, 시스템: None 0.005983114242553711sec
# 거래일: 2016-07-27 00:00:00, 시스템: None 0.00598454475402832sec
# 거래일: 2016-07-28 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2016-07-29 00:00:00, 시스템: None 0.005983591079711914sec
# 거래일: 2016-08-01 00:00:00, 시스템: None 0.006981372833251953sec
# 거래일: 2016-08-02 00:00:00, 시스템: None 0.005984306335449219sec
# 거래일: 2016-08-03 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2016-08-04 00:00:00, 시스템: None 0.005983591079711914sec
# 거래일: 2016-08-05 00:00:00, 시스템: None 0.005984306335449219sec
# 거래일: 2016-08-08 00:00:00, 시스템: None 0.006982088088989258sec
# 거래일: 2016-08-09 00:00:00, 시스템: None 0.0059833526611328125sec
# 거래일: 2016-08-10 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2016-08-11 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2016-08-12 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2016-08-15 00:00:00, 시스템: None 0.005983591079711914sec
# 거래일: 2016-08-16 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2016-08-17 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2016-08-18 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2016-08-19 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2016-08-22 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2016-08-23 00:00:00, 시스템: None 0.005983591079711914sec
# 거래일: 2016-08-24 00:00:00, 시스템: None 0.006981611251831055sec
# 거래일: 2016-08-25 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2016-08-26 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2016-08-29 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2016-08-30 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2016-08-31 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2016-09-01 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2016-09-02 00:00:00, 시스템: None 0.00698089599609375sec
# 거래일: 2016-09-05 00:00:00, 시스템: None 0.00598454475402832sec
# 거래일: 2016-09-06 00:00:00, 시스템: None 0.0009970664978027344sec
# 거래일: 2016-09-07 00:00:00, 시스템: None 0.005984306335449219sec
# 거래일: 2016-09-08 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2016-09-09 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2016-09-12 00:00:00, 시스템: None 0.00598454475402832sec
# 거래일: 2016-09-13 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2016-09-14 00:00:00, 시스템: None 0.0069811344146728516sec
# 거래일: 2016-09-15 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2016-09-16 00:00:00, 시스템: None 0.006981372833251953sec
# 거래일: 2016-09-19 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2016-09-20 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2016-09-21 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2016-09-22 00:00:00, 시스템: None 0.006981611251831055sec
# 거래일: 2016-09-23 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2016-09-26 00:00:00, 시스템: None 0.005983591079711914sec
# 거래일: 2016-09-27 00:00:00, 시스템: None 0.006981849670410156sec
# 거래일: 2016-09-28 00:00:00, 시스템: None 0.005983591079711914sec
# 거래일: 2016-09-29 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2016-09-30 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2016-10-03 00:00:00, 시스템: None 0.006981611251831055sec
# 거래일: 2016-10-04 00:00:00, 시스템: None 0.00498652458190918sec
# 거래일: 2016-10-05 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2016-10-06 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2016-10-07 00:00:00, 시스템: None 0.006981372833251953sec
# 거래일: 2016-10-10 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2016-10-11 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2016-10-12 00:00:00, 시스템: None 0.006981611251831055sec
# 거래일: 2016-10-13 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2016-10-14 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2016-10-17 00:00:00, 시스템: None 0.005983591079711914sec
# 거래일: 2016-10-18 00:00:00, 시스템: None 0.005984306335449219sec
# 거래일: 2016-10-19 00:00:00, 시스템: None 0.006981372833251953sec
# 거래일: 2016-10-20 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2016-10-21 00:00:00, 시스템: None 0.004998207092285156sec
# 거래일: 2016-10-24 00:00:00, 시스템: None 0.0069696903228759766sec
# 거래일: 2016-10-25 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2016-10-26 00:00:00, 시스템: None 0.006981372833251953sec
# 거래일: 2016-10-27 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2016-10-28 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2016-10-31 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2016-11-01 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2016-11-02 00:00:00, 시스템: None 0.005984306335449219sec
# 거래일: 2016-11-03 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2016-11-04 00:00:00, 시스템: None 0.00698089599609375sec
# 거래일: 2016-11-07 00:00:00, 시스템: None 0.005984306335449219sec
# 거래일: 2016-11-08 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2016-11-09 00:00:00, 시스템: None 0.006981611251831055sec
# 거래일: 2016-11-10 00:00:00, 시스템: None 0.006981372833251953sec
# 거래일: 2016-11-11 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2016-11-14 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2016-11-15 00:00:00, 시스템: None 0.00498652458190918sec
# 거래일: 2016-11-16 00:00:00, 시스템: None 0.006981372833251953sec
# 거래일: 2016-11-17 00:00:00, 시스템: None 0.005983591079711914sec
# 거래일: 2016-11-18 00:00:00, 시스템: None 0.005984306335449219sec
# 거래일: 2016-11-21 00:00:00, 시스템: None 0.00498652458190918sec
# 거래일: 2016-11-22 00:00:00, 시스템: None 0.004986286163330078sec
# 거래일: 2016-11-23 00:00:00, 시스템: None 0.006981372833251953sec
# 거래일: 2016-11-24 00:00:00, 시스템: None 0.005984306335449219sec
# 거래일: 2016-11-25 00:00:00, 시스템: None 0.0019943714141845703sec
# 거래일: 2016-11-28 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2016-11-29 00:00:00, 시스템: None 0.004986763000488281sec
# 거래일: 2016-11-30 00:00:00, 시스템: None 0.005983591079711914sec
# 거래일: 2016-12-01 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2016-12-02 00:00:00, 시스템: None 0.004986763000488281sec
# 거래일: 2016-12-05 00:00:00, 시스템: None 0.006981372833251953sec
# 거래일: 2016-12-06 00:00:00, 시스템: None 0.0069675445556640625sec
# 거래일: 2016-12-07 00:00:00, 시스템: None 0.006981611251831055sec
# 거래일: 2016-12-08 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2016-12-09 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2016-12-12 00:00:00, 시스템: None 0.006981611251831055sec
# 거래일: 2016-12-13 00:00:00, 시스템: None 0.004986763000488281sec
# 거래일: 2016-12-14 00:00:00, 시스템: None 0.004986763000488281sec
# 거래일: 2016-12-15 00:00:00, 시스템: None 0.005983591079711914sec
# 거래일: 2016-12-16 00:00:00, 시스템: None 0.0069811344146728516sec
# 거래일: 2016-12-19 00:00:00, 시스템: None 0.005984306335449219sec
# 거래일: 2016-12-20 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2016-12-21 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2016-12-22 00:00:00, 시스템: None 0.006981372833251953sec
# 거래일: 2016-12-23 00:00:00, 시스템: None 0.00498652458190918sec
# 거래일: 2016-12-27 00:00:00, 시스템: None 0.005984306335449219sec
# 거래일: 2016-12-28 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2016-12-29 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2016-12-30 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2017-01-02 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2017-01-03 00:00:00, 시스템: None 0.001994609832763672sec
# 거래일: 2017-01-04 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2017-01-05 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2017-01-06 00:00:00, 시스템: None 0.006981372833251953sec
# 거래일: 2017-01-09 00:00:00, 시스템: None 0.005983591079711914sec
# 거래일: 2017-01-10 00:00:00, 시스템: None 0.005984306335449219sec
# 거래일: 2017-01-11 00:00:00, 시스템: None 0.004986763000488281sec
# 거래일: 2017-01-12 00:00:00, 시스템: None 0.005983591079711914sec
# 거래일: 2017-01-13 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2017-01-16 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2017-01-17 00:00:00, 시스템: None 0.001994609832763672sec
# 거래일: 2017-01-18 00:00:00, 시스템: None 0.00498652458190918sec
# 거래일: 2017-01-19 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2017-01-20 00:00:00, 시스템: None 0.006981611251831055sec
# 거래일: 2017-01-23 00:00:00, 시스템: None 0.006981611251831055sec
# 거래일: 2017-01-24 00:00:00, 시스템: None 0.005983591079711914sec
# 거래일: 2017-01-25 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2017-01-26 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2017-01-27 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2017-01-30 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2017-01-31 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2017-02-01 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2017-02-02 00:00:00, 시스템: None 0.004986286163330078sec
# 거래일: 2017-02-03 00:00:00, 시스템: None 0.005984306335449219sec
# 거래일: 2017-02-06 00:00:00, 시스템: None 0.0049860477447509766sec
# 거래일: 2017-02-07 00:00:00, 시스템: None 0.00598454475402832sec
# 거래일: 2017-02-08 00:00:00, 시스템: None 0.0069811344146728516sec
# 거래일: 2017-02-09 00:00:00, 시스템: None 0.004987001419067383sec
# 거래일: 2017-02-10 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2017-02-13 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2017-02-14 00:00:00, 시스템: None 0.004986763000488281sec
# 거래일: 2017-02-15 00:00:00, 시스템: None 0.0069811344146728516sec
# 거래일: 2017-02-16 00:00:00, 시스템: None 0.006981611251831055sec
# 거래일: 2017-02-17 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2017-02-20 00:00:00, 시스템: None 0.004986763000488281sec
# 거래일: 2017-02-21 00:00:00, 시스템: None 0.0019943714141845703sec
# 거래일: 2017-02-22 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2017-02-23 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2017-02-24 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2017-02-27 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2017-02-28 00:00:00, 시스템: None 0.004986763000488281sec
# 거래일: 2017-03-01 00:00:00, 시스템: None 0.004986286163330078sec
# 거래일: 2017-03-02 00:00:00, 시스템: None 0.005983591079711914sec
# 거래일: 2017-03-03 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2017-03-06 00:00:00, 시스템: None 0.005984306335449219sec
# 거래일: 2017-03-07 00:00:00, 시스템: None 0.0059833526611328125sec
# 거래일: 2017-03-08 00:00:00, 시스템: None 0.005984306335449219sec
# 거래일: 2017-03-09 00:00:00, 시스템: None 0.004987001419067383sec
# 거래일: 2017-03-10 00:00:00, 시스템: None 0.003989219665527344sec
# 거래일: 2017-03-13 00:00:00, 시스템: None 0.004987001419067383sec
# 거래일: 2017-03-14 00:00:00, 시스템: None 0.0069811344146728516sec
# 거래일: 2017-03-15 00:00:00, 시스템: None 0.006981372833251953sec
# 거래일: 2017-03-16 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2017-03-17 00:00:00, 시스템: None 0.006981372833251953sec
# 거래일: 2017-03-20 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2017-03-21 00:00:00, 시스템: None 0.006981849670410156sec
# 거래일: 2017-03-22 00:00:00, 시스템: None 0.005983591079711914sec
# 거래일: 2017-03-23 00:00:00, 시스템: None 0.005983591079711914sec
# 거래일: 2017-03-24 00:00:00, 시스템: None 0.006981611251831055sec
# 거래일: 2017-03-27 00:00:00, 시스템: None 0.005984306335449219sec
# 거래일: 2017-03-28 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2017-03-29 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2017-03-30 00:00:00, 시스템: None 0.0059833526611328125sec
# 거래일: 2017-03-31 00:00:00, 시스템: None 0.005984306335449219sec
# 거래일: 2017-04-03 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2017-04-04 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2017-04-05 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2017-04-06 00:00:00, 시스템: None 0.0049860477447509766sec
# 거래일: 2017-04-07 00:00:00, 시스템: None 0.005984306335449219sec
# 거래일: 2017-04-10 00:00:00, 시스템: None 0.004986763000488281sec
# 거래일: 2017-04-11 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2017-04-12 00:00:00, 시스템: None 0.004986763000488281sec
# 거래일: 2017-04-13 00:00:00, 시스템: None 0.004986763000488281sec
# 거래일: 2017-04-17 00:00:00, 시스템: None 0.005984306335449219sec
# 거래일: 2017-04-18 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2017-04-19 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2017-04-20 00:00:00, 시스템: None 0.005983829498291016sec
# 거래일: 2017-04-21 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2017-04-24 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2017-04-25 00:00:00, 시스템: None 0.006981372833251953sec
# 거래일: 2017-04-26 00:00:00, 시스템: None 0.005984067916870117sec
# 거래일: 2017-04-27 00:00:00, 시스템: None 0.005984306335449219sec
# 거래일: 2017-04-28 00:00:00, 시스템: None 0.005983114242553711sec
# 거래일: 2017-05-01 00:00:00, 시스템: None 0.005984306335449219sec
# CPU times: total: 7.42 s
# Wall time: 7.36 s

# %%
system.summary(level=0)
# Out:
# <style type="text/css">
# </style>
# <table id="T_f3629">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f3629_level0_col0" class="col_heading level0 col0" >투자금</th>
#       <th id="T_f3629_level0_col1" class="col_heading level0 col1" >최종자산</th>
#       <th id="T_f3629_level0_col2" class="col_heading level0 col2" >총손익</th>
#       <th id="T_f3629_level0_col3" class="col_heading level0 col3" >Bliss</th>
#       <th id="T_f3629_level0_col4" class="col_heading level0 col4" >CAGR</th>
#       <th id="T_f3629_level0_col5" class="col_heading level0 col5" >MDD</th>
#       <th id="T_f3629_level0_col6" class="col_heading level0 col6" >손익비</th>
#       <th id="T_f3629_level0_col7" class="col_heading level0 col7" >승률</th>
#       <th id="T_f3629_level0_col8" class="col_heading level0 col8" >위험대비손익</th>
#       <th id="T_f3629_level0_col9" class="col_heading level0 col9" >평균손익</th>
#       <th id="T_f3629_level0_col10" class="col_heading level0 col10" >평균수익</th>
#       <th id="T_f3629_level0_col11" class="col_heading level0 col11" >평균손실</th>
#       <th id="T_f3629_level0_col12" class="col_heading level0 col12" >보유기간</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f3629_level0_row0" class="row_heading level0 row0" >Result</th>
#       <td id="T_f3629_row0_col0" class="data row0 col0" >1,000,000</td>
#       <td id="T_f3629_row0_col1" class="data row0 col1" >1,236,044</td>
#       <td id="T_f3629_row0_col2" class="data row0 col2" >23.6%</td>
#       <td id="T_f3629_row0_col3" class="data row0 col3" >0.008</td>
#       <td id="T_f3629_row0_col4" class="data row0 col4" >9.5%</td>
#       <td id="T_f3629_row0_col5" class="data row0 col5" >12.1%</td>
#       <td id="T_f3629_row0_col6" class="data row0 col6" >-2.37</td>
#       <td id="T_f3629_row0_col7" class="data row0 col7" >88.7%</td>
#       <td id="T_f3629_row0_col8" class="data row0 col8" >56.6%</td>
#       <td id="T_f3629_row0_col9" class="data row0 col9" >790</td>
#       <td id="T_f3629_row0_col10" class="data row0 col10" >1,540</td>
#       <td id="T_f3629_row0_col11" class="data row0 col11" >-5,087</td>
#       <td id="T_f3629_row0_col12" class="data row0 col12" >11 일</td>
#     </tr>
#   </tbody>
# </table>

# %%
start = system.from_date#'2015-02-28'
end = system.to_date#'2020-05-01'
symbol = 'AD'
name = instruments[symbol].name
quotes = instruments.quotes()[symbol].loc[start:end]
quotes.dropna(subset=['open','high','low','close'], inplace=True)

datesindex = quotes.index
quotes = quotes.reset_index()

metrics = system.metrics[symbol].loc[datesindex]

trades = system.trades.log(symbol=symbol)
trades = pd.DataFrame(trades, columns=['entrydate','exitdate','position', 'entryprice', 'entrylots','entryrisk','#exits', 'profit','profit_ticks','duration','result'])
trades = trades[(trades.entrydate>=start) & (trades.entrydate<=end)]

# %%
cumprofit = trades.profit.cumsum()
num_trades = len(trades)
       
index_rows = sum([1 for i in metrics.attrs['type'].values() if i == 'index'])
xsize = 15
ysize = 12*(1 + 0.2*index_rows)
linewidth = 1

fig, (ax) = plt.subplots(2+index_rows, 1, figsize=(xsize, ysize),
       gridspec_kw = {'height_ratios':[3,1]+[1]*index_rows})

win_masks = []
lose_masks =[]

for idx, row in trades.iterrows():
    
    mask = (quotes['date'] >= row['entrydate']) & (quotes['date'] <= row['exitdate'])
    if row['result'] == 'WIN':
        win_masks.append(mask)
    elif row['result'] == 'LOSE':
        lose_masks.append(mask)
        
win_mask = reduce(np.logical_or, win_masks)
lose_mask = reduce(np.logical_or, lose_masks)


win_dates = quotes[win_mask].index
lose_dates = quotes[lose_mask].index
neutral_dates = quotes[~win_mask & ~lose_mask].index
dates = [win_dates, lose_dates, neutral_dates]
colors = ['r', 'b', 'k']

offset = 0.3

#1. Trade Performance Chart
for date, color in zip(dates, colors):
    o = quotes.loc[date, 'open'].values
    h = quotes.loc[date, 'high'].values
    l = quotes.loc[date, 'low'].values
    c = quotes.loc[date, 'close'].values
    
    ax[0].vlines(date, l, h, linewidth=linewidth, color=color)
    ax[0].hlines(o, date-offset, date, linewidth=linewidth, color=color)
    ax[0].hlines(c, date, date+offset, linewidth=linewidth, color=color)
    
#2. Metric Chart
metric_type = {
    'price':[k for k, v in metrics.attrs['type'].items() if v=='price' ],
    'index':[k for k, v in metrics.attrs['type'].items() if v=='index' ]
}

for metric in metric_type['price']:
    ax[0].plot(quotes.index, metrics[metric], label=metric)


title = f"Trade Performance: {name} ({symbol})"
ax[0].set_title(title, fontsize=20)
ax[0].set_ylabel('Price', fontsize=15)
ax[0].legend(loc=2)
#ax[0].grid(linestyle='--')
#ax[0].set_facecolor('lightgoldenrodyellow')
#ax[0].yaxis.tick_right()

#3.Index Chart
for axis, name in zip(ax[1:-1], metric_type['index']):
    axis.set_title(name, loc='left')
    #axis.set_ylabel(name, fontsize=15)
    axis.plot(quotes.index, metrics[name], name=)
    


#4. Tick-Profit Chart
#tick profit chart
ax[-1].bar(np.arange(1,num_trades+1), np.where(trades.position=='Long', trades.profit_ticks, 0), 0.3, color='red', alpha=0.6 )
ax[-1].bar(np.arange(1,num_trades+1), np.where(trades.position=='Short', trades.profit_ticks, 0), 0.3, color='blue', alpha=0.6 )
ax[-1].set_ylabel('Profit (tick)', fontsize=15)
ax[-1].axhline(y=0, linewidth=1, color='k')
#labels



#x축 fomatter
myformatter = MyFormatter(datesindex)
ax[0].xaxis.set_major_formatter(myformatter)

#common styles
for axis in ax:
    axis.yaxis.tick_right()
    axis.set_facecolor('lightgoldenrodyellow')
    #ax[1].set_xticks(range(1,num_trades+1))
    axis.grid(linestyle='--')

# %%
metrics
# Out:
#               ema200     ema20  volatility   min20   max20
# date
# 2015-01-02  0.858010  0.799535    0.491041  0.7862  0.8197
# 2015-01-05  0.857295  0.798408    0.477090  0.7821  0.8168
# 2015-01-06  0.856604  0.797544    0.449257  0.7821  0.8147
# 2015-01-07  0.855894  0.796514    0.422973  0.7820  0.8147
# 2015-01-08  0.855221  0.795862    0.340945  0.7820  0.8147
# ...              ...       ...         ...     ...     ...
# 2017-04-25  0.758310  0.762913   -1.930890  0.7543  0.7748
# 2017-04-26  0.758265  0.762053   -1.508882  0.7526  0.7748
# 2017-04-27  0.758224  0.761314   -1.546569  0.7512  0.7748
# 2017-04-28  0.758196  0.760760   -1.651090  0.7512  0.7731
# 2017-05-01  0.758222  0.760754   -1.568544  0.7512  0.7709
#
# [588 rows x 5 columns]

# %%
list(ax[1:-1]), metric_type['index']
# Out:
# [<AxesSubplot:>]

# %%
for i in map(list(ax[1:-1]), metric_type['index']):
    print(i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [69], in <cell line: 1>()
# ----> 1 for i in map(list(ax[1:-1]), metric_type['index']):
#       2     print(i)
#
# TypeError: 'list' object is not callable

# %%
metric_type = {
    'price':[k for k, v in metrics.attrs['type'].items() if v=='price' ],
    'index':[k for k, v in metrics.attrs['type'].items() if v=='index' ]
}

# %%
metric_type
# Out:
# {'price': ['ema200', 'ema20', 'min20', 'max20'], 'index': ['volatility']}

# %%
a=ax[1]

# %%
a.sharex?

# %%
win_masks = []
lose_masks =[]
for idx, row in trades.iterrows():
    
    mask = (quotes['date'] >= row['entrydate']) & (quotes['date'] <= row['exitdate'])
    if row['result'] == 'WIN':
        win_masks.append(mask)
    elif row['result'] == 'LOSE':
        lose_masks.append(mask)
        
win_mask = reduce(np.logical_or, win_masks)
lose_mask = reduce(np.logical_or, lose_masks)

# %%
quotes
# Out:
# field       date    open    high     low   close    volume        oi
# 0     2015-01-02  0.7954  0.7970  0.7862  0.7899   58971.0  119037.0
# 1     2015-01-05  0.7861  0.7894  0.7821  0.7878   70446.0  123921.0
# 2     2015-01-06  0.7874  0.7944  0.7870  0.7894   90245.0  124545.0
# 3     2015-01-07  0.7864  0.7878  0.7820  0.7868   79610.0  121806.0
# 4     2015-01-08  0.7864  0.7920  0.7862  0.7897   74891.0  122717.0
# ..           ...     ...     ...     ...     ...       ...       ...
# 597   2017-04-25  0.7640  0.7643  0.7592  0.7608   73095.0  104088.0
# 598   2017-04-26  0.7608  0.7638  0.7526  0.7539  125555.0  106783.0
# 599   2017-04-27  0.7547  0.7565  0.7512  0.7543   81406.0  111616.0
# 600   2017-04-28  0.7543  0.7563  0.7520  0.7555   78817.0  110052.0
# 601   2017-05-01  0.7554  0.7613  0.7546  0.7607   50876.0  108737.0
#
# [602 rows x 7 columns]

# %%
trades[trades['entrydate'].duplicated()]
# Out:
# Empty DataFrame
# Columns: [entrydate, exitdate, position, entryprice, entrylots, entryrisk, #exits, profit, profit_ticks, duration, result]
# Index: []

# %%
len(quotes[lose_mask])
# Out:
# 349

# %%
794+195+349
# Out:
# 1338

# %%
len(quotes)
# Out:
# 1336

# %%
quotes = instruments.quotes()['MD'].loc['2011-05-01': '2011-07-01']
metrics = system.metrics['MD'].loc['2011-05-01': '2011-07-01']

# %%
view(quotes, metrics=metrics)

# %%
system.summary(level=2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_ea659">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ea659_level0_col0" class="col_heading level0 col0" >총손익</th>
#       <th id="T_ea659_level0_col1" class="col_heading level0 col1" >평균손익</th>
#       <th id="T_ea659_level0_col2" class="col_heading level0 col2" >표준편차</th>
#       <th id="T_ea659_level0_col3" class="col_heading level0 col3" >위험대비손익</th>
#       <th id="T_ea659_level0_col4" class="col_heading level0 col4" >승률</th>
#       <th id="T_ea659_level0_col5" class="col_heading level0 col5" >보유기간</th>
#       <th id="T_ea659_level0_col6" class="col_heading level0 col6" >매매회수</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >구분</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ea659_level0_row0" class="row_heading level0 row0" >CBOT 10-year US Treasury Note</th>
#       <td id="T_ea659_row0_col0" class="data row0 col0" >413580</td>
#       <td id="T_ea659_row0_col1" class="data row0 col1" >547</td>
#       <td id="T_ea659_row0_col2" class="data row0 col2" >1652.07</td>
#       <td id="T_ea659_row0_col3" class="data row0 col3" >27.96%</td>
#       <td id="T_ea659_row0_col4" class="data row0 col4" >76.1%</td>
#       <td id="T_ea659_row0_col5" class="data row0 col5" >14.738095</td>
#       <td id="T_ea659_row0_col6" class="data row0 col6" >756</td>
#     </tr>
#     <tr>
#       <th id="T_ea659_level0_row1" class="row_heading level0 row1" >CBOT 2-year US Treasury Note</th>
#       <td id="T_ea659_row1_col0" class="data row1 col0" >235613</td>
#       <td id="T_ea659_row1_col1" class="data row1 col1" >251</td>
#       <td id="T_ea659_row1_col2" class="data row1 col2" >545.63</td>
#       <td id="T_ea659_row1_col3" class="data row1 col3" >47.35%</td>
#       <td id="T_ea659_row1_col4" class="data row1 col4" >83.2%</td>
#       <td id="T_ea659_row1_col5" class="data row1 col5" >14.323749</td>
#       <td id="T_ea659_row1_col6" class="data row1 col6" >939</td>
#     </tr>
#     <tr>
#       <th id="T_ea659_level0_row2" class="row_heading level0 row2" >CBOT 30-year US Treasury Bond</th>
#       <td id="T_ea659_row2_col0" class="data row2 col0" >830366</td>
#       <td id="T_ea659_row2_col1" class="data row2 col1" >1147</td>
#       <td id="T_ea659_row2_col2" class="data row2 col2" >5798.76</td>
#       <td id="T_ea659_row2_col3" class="data row2 col3" >30.53%</td>
#       <td id="T_ea659_row2_col4" class="data row2 col4" >76.5%</td>
#       <td id="T_ea659_row2_col5" class="data row2 col5" >13.803867</td>
#       <td id="T_ea659_row2_col6" class="data row2 col6" >724</td>
#     </tr>
#     <tr>
#       <th id="T_ea659_level0_row3" class="row_heading level0 row3" >CBOT 5-year US Treasury Note</th>
#       <td id="T_ea659_row3_col0" class="data row3 col0" >528927</td>
#       <td id="T_ea659_row3_col1" class="data row3 col1" >491</td>
#       <td id="T_ea659_row3_col2" class="data row3 col2" >1020.96</td>
#       <td id="T_ea659_row3_col3" class="data row3 col3" >43.00%</td>
#       <td id="T_ea659_row3_col4" class="data row3 col4" >79.0%</td>
#       <td id="T_ea659_row3_col5" class="data row3 col5" >14.271123</td>
#       <td id="T_ea659_row3_col6" class="data row3 col6" >1077</td>
#     </tr>
#     <tr>
#       <th id="T_ea659_level0_row4" class="row_heading level0 row4" >CBOT Corn</th>
#       <td id="T_ea659_row4_col0" class="data row4 col0" >380544</td>
#       <td id="T_ea659_row4_col1" class="data row4 col1" >338</td>
#       <td id="T_ea659_row4_col2" class="data row4 col2" >2491.26</td>
#       <td id="T_ea659_row4_col3" class="data row4 col3" >25.15%</td>
#       <td id="T_ea659_row4_col4" class="data row4 col4" >74.8%</td>
#       <td id="T_ea659_row4_col5" class="data row4 col5" >17.531972</td>
#       <td id="T_ea659_row4_col6" class="data row4 col6" >1126</td>
#     </tr>
#     <tr>
#       <th id="T_ea659_level0_row5" class="row_heading level0 row5" >CBOT Oats</th>
#       <td id="T_ea659_row5_col0" class="data row5 col0" >59592</td>
#       <td id="T_ea659_row5_col1" class="data row5 col1" >298</td>
#       <td id="T_ea659_row5_col2" class="data row5 col2" >778.20</td>
#       <td id="T_ea659_row5_col3" class="data row5 col3" >32.38%</td>
#       <td id="T_ea659_row5_col4" class="data row5 col4" >67.5%</td>
#       <td id="T_ea659_row5_col5" class="data row5 col5" >12.440000</td>
#       <td id="T_ea659_row5_col6" class="data row5 col6" >200</td>
#     </tr>
#     <tr>
#       <th id="T_ea659_level0_row6" class="row_heading level0 row6" >CBOT Soybean Meal</th>
#       <td id="T_ea659_row6_col0" class="data row6 col0" >-456620</td>
#       <td id="T_ea659_row6_col1" class="data row6 col1" >-603</td>
#       <td id="T_ea659_row6_col2" class="data row6 col2" >4168.55</td>
#       <td id="T_ea659_row6_col3" class="data row6 col3" >-17.41%</td>
#       <td id="T_ea659_row6_col4" class="data row6 col4" >67.2%</td>
#       <td id="T_ea659_row6_col5" class="data row6 col5" >16.109643</td>
#       <td id="T_ea659_row6_col6" class="data row6 col6" >757</td>
#     </tr>
#     <tr>
#       <th id="T_ea659_level0_row7" class="row_heading level0 row7" >CBOT Soybean Oil</th>
#       <td id="T_ea659_row7_col0" class="data row7 col0" >575940</td>
#       <td id="T_ea659_row7_col1" class="data row7 col1" >504</td>
#       <td id="T_ea659_row7_col2" class="data row7 col2" >1792.48</td>
#       <td id="T_ea659_row7_col3" class="data row7 col3" >29.57%</td>
#       <td id="T_ea659_row7_col4" class="data row7 col4" >77.0%</td>
#       <td id="T_ea659_row7_col5" class="data row7 col5" >18.162730</td>
#       <td id="T_ea659_row7_col6" class="data row7 col6" >1143</td>
#     </tr>
#     <tr>
#       <th id="T_ea659_level0_row8" class="row_heading level0 row8" >CBOT Soybeans</th>
#       <td id="T_ea659_row8_col0" class="data row8 col0" >390504</td>
#       <td id="T_ea659_row8_col1" class="data row8 col1" >492</td>
#       <td id="T_ea659_row8_col2" class="data row8 col2" >4443.07</td>
#       <td id="T_ea659_row8_col3" class="data row8 col3" >24.46%</td>
#       <td id="T_ea659_row8_col4" class="data row8 col4" >77.4%</td>
#       <td id="T_ea659_row8_col5" class="data row8 col5" >16.750315</td>
#       <td id="T_ea659_row8_col6" class="data row8 col6" >793</td>
#     </tr>
#     <tr>
#       <th id="T_ea659_level0_row9" class="row_heading level0 row9" >CBOT Wheat</th>
#       <td id="T_ea659_row9_col0" class="data row9 col0" >-297468</td>
#       <td id="T_ea659_row9_col1" class="data row9 col1" >-416</td>
#       <td id="T_ea659_row9_col2" class="data row9 col2" >4175.54</td>
#       <td id="T_ea659_row9_col3" class="data row9 col3" >0.41%</td>
#       <td id="T_ea659_row9_col4" class="data row9 col4" >71.6%</td>
#       <td id="T_ea659_row9_col5" class="data row9 col5" >16.881119</td>
#       <td id="T_ea659_row9_col6" class="data row9 col6" >715</td>
#     </tr>
#     <tr>
#       <th id="T_ea659_level0_row10" class="row_heading level0 row10" >CME Australian Dollar AUD</th>
#       <td id="T_ea659_row10_col0" class="data row10 col0" >816560</td>
#       <td id="T_ea659_row10_col1" class="data row10 col1" >711</td>
#       <td id="T_ea659_row10_col2" class="data row10 col2" >3611.95</td>
#       <td id="T_ea659_row10_col3" class="data row10 col3" >31.26%</td>
#       <td id="T_ea659_row10_col4" class="data row10 col4" >76.6%</td>
#       <td id="T_ea659_row10_col5" class="data row10 col5" >15.370209</td>
#       <td id="T_ea659_row10_col6" class="data row10 col6" >1148</td>
#     </tr>
#     <tr>
#       <th id="T_ea659_level0_row11" class="row_heading level0 row11" >CME British Pound GBP</th>
#       <td id="T_ea659_row11_col0" class="data row11 col0" >603084</td>
#       <td id="T_ea659_row11_col1" class="data row11 col1" >533</td>
#       <td id="T_ea659_row11_col2" class="data row11 col2" >2809.70</td>
#       <td id="T_ea659_row11_col3" class="data row11 col3" >30.77%</td>
#       <td id="T_ea659_r

# %%
system.summary(level=1)
# Out:
# <style type="text/css">
# </style>
# <table id="T_f25e7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f25e7_level0_col0" class="col_heading level0 col0" >총손익</th>
#       <th id="T_f25e7_level0_col1" class="col_heading level0 col1" >평균손익</th>
#       <th id="T_f25e7_level0_col2" class="col_heading level0 col2" >표준편차</th>
#       <th id="T_f25e7_level0_col3" class="col_heading level0 col3" >위험대비손익</th>
#       <th id="T_f25e7_level0_col4" class="col_heading level0 col4" >승률</th>
#       <th id="T_f25e7_level0_col5" class="col_heading level0 col5" >보유기간</th>
#       <th id="T_f25e7_level0_col6" class="col_heading level0 col6" >매매회수</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >구분</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f25e7_level0_row0" class="row_heading level0 row0" >currency</th>
#       <td id="T_f25e7_row0_col0" class="data row0 col0" >7089184</td>
#       <td id="T_f25e7_row0_col1" class="data row0 col1" >867</td>
#       <td id="T_f25e7_row0_col2" class="data row0 col2" >3612.36</td>
#       <td id="T_f25e7_row0_col3" class="data row0 col3" >35.07%</td>
#       <td id="T_f25e7_row0_col4" class="data row0 col4" >78.2%</td>
#       <td id="T_f25e7_row0_col5" class="data row0 col5" >15.516090</td>
#       <td id="T_f25e7_row0_col6" class="data row0 col6" >8173</td>
#     </tr>
#     <tr>
#       <th id="T_f25e7_level0_row1" class="row_heading level0 row1" >equity</th>
#       <td id="T_f25e7_row1_col0" class="data row1 col0" >1308275</td>
#       <td id="T_f25e7_row1_col1" class="data row1 col1" >321</td>
#       <td id="T_f25e7_row1_col2" class="data row1 col2" >6471.86</td>
#       <td id="T_f25e7_row1_col3" class="data row1 col3" >17.50%</td>
#       <td id="T_f25e7_row1_col4" class="data row1 col4" >76.5%</td>
#       <td id="T_f25e7_row1_col5" class="data row1 col5" >14.338900</td>
#       <td id="T_f25e7_row1_col6" class="data row1 col6" >4072</td>
#     </tr>
#     <tr>
#       <th id="T_f25e7_level0_row2" class="row_heading level0 row2" >fiber</th>
#       <td id="T_f25e7_row2_col0" class="data row2 col0" >85945</td>
#       <td id="T_f25e7_row2_col1" class="data row2 col1" >79</td>
#       <td id="T_f25e7_row2_col2" class="data row2 col2" >5227.10</td>
#       <td id="T_f25e7_row2_col3" class="data row2 col3" >4.26%</td>
#       <td id="T_f25e7_row2_col4" class="data row2 col4" >68.4%</td>
#       <td id="T_f25e7_row2_col5" class="data row2 col5" >17.782810</td>
#       <td id="T_f25e7_row2_col6" class="data row2 col6" >1082</td>
#     </tr>
#     <tr>
#       <th id="T_f25e7_level0_row3" class="row_heading level0 row3" >grain</th>
#       <td id="T_f25e7_row3_col0" class="data row3 col0" >652492</td>
#       <td id="T_f25e7_row3_col1" class="data row3 col1" >138</td>
#       <td id="T_f25e7_row3_col2" class="data row3 col2" >3344.14</td>
#       <td id="T_f25e7_row3_col3" class="data row3 col3" >15.86%</td>
#       <td id="T_f25e7_row3_col4" class="data row3 col4" >73.8%</td>
#       <td id="T_f25e7_row3_col5" class="data row3 col5" >17.012463</td>
#       <td id="T_f25e7_row3_col6" class="data row3 col6" >4734</td>
#     </tr>
#     <tr>
#       <th id="T_f25e7_level0_row4" class="row_heading level0 row4" >interest-rate</th>
#       <td id="T_f25e7_row4_col0" class="data row4 col0" >2008486</td>
#       <td id="T_f25e7_row4_col1" class="data row4 col1" >575</td>
#       <td id="T_f25e7_row4_col2" class="data row4 col2" >2836.33</td>
#       <td id="T_f25e7_row4_col3" class="data row4 col3" >38.33%</td>
#       <td id="T_f25e7_row4_col4" class="data row4 col4" >79.0%</td>
#       <td id="T_f25e7_row4_col5" class="data row4 col5" >14.289474</td>
#       <td id="T_f25e7_row4_col6" class="data row4 col6" >3496</td>
#     </tr>
#     <tr>
#       <th id="T_f25e7_level0_row5" class="row_heading level0 row5" >meat</th>
#       <td id="T_f25e7_row5_col0" class="data row5 col0" >816870</td>
#       <td id="T_f25e7_row5_col1" class="data row5 col1" >435</td>
#       <td id="T_f25e7_row5_col2" class="data row5 col2" >2934.21</td>
#       <td id="T_f25e7_row5_col3" class="data row5 col3" >10.72%</td>
#       <td id="T_f25e7_row5_col4" class="data row5 col4" >68.9%</td>
#       <td id="T_f25e7_row5_col5" class="data row5 col5" >17.094199</td>
#       <td id="T_f25e7_row5_col6" class="data row5 col6" >1879</td>
#     </tr>
#     <tr>
#       <th id="T_f25e7_level0_row6" class="row_heading level0 row6" >metal</th>
#       <td id="T_f25e7_row6_col0" class="data row6 col0" >3026561</td>
#       <td id="T_f25e7_row6_col1" class="data row6 col1" >689</td>
#       <td id="T_f25e7_row6_col2" class="data row6 col2" >9448.22</td>
#       <td id="T_f25e7_row6_col3" class="data row6 col3" >14.27%</td>
#       <td id="T_f25e7_row6_col4" class="data row6 col4" >72.8%</td>
#       <td id="T_f25e7_row6_col5" class="data row6 col5" >16.844596</td>
#       <td id="T_f25e7_row6_col6" class="data row6 col6" >4395</td>
#     </tr>
#     <tr>
#       <th id="T_f25e7_level0_row7" class="row_heading level0 row7" >petroleum</th>
#       <td id="T_f25e7_row7_col0" class="data row7 col0" >3291064</td>
#       <td id="T_f25e7_row7_col1" class="data row7 col1" >881</td>
#       <td id="T_f25e7_row7_col2" class="data row7 col2" >7932.77</td>
#       <td id="T_f25e7_row7_col3" class="data row7 col3" >23.18%</td>
#       <td id="T_f25e7_row7_col4" class="data row7 col4" >74.5%</td>
#       <td id="T_f25e7_row7_col5" class="data row7 col5" >14.011780</td>
#       <td id="T_f25e7_row7_col6" class="data row7 col6" >3735</td>
#     </tr>
#     <tr>
#       <th id="T_f25e7_level0_row8" class="row_heading level0 row8" >tropical</th>
#       <td id="T_f25e7_row8_col0" class="data row8 col0" >1214033</td>
#       <td id="T_f25e7_row8_col1" class="data row8 col1" >324</td>
#       <td id="T_f25e7_row8_col2" class="data row8 col2" >5037.25</td>
#       <td id="T_f25e7_row8_col3" class="data row8 col3" >5.87%</td>
#       <td id="T_f25e7_row8_col4" class="data row8 col4" >72.7%</td>
#       <td id="T_f25e7_row8_col5" class="data row8 col5" >16.090933</td>
#       <td id="T_f25e7_row8_col6" class="data row8 col6" >3750</td>
#     </tr>
#   </tbody>
# </table>

# %%
t = system.trades.log(symbol='MP')

# %%
s = [tr for tr in t if tr['profit']>0]

# %%
s
# Out:
# [{'id': 143453,
#   'entrydate': Timestamp('2017-04-10 00:00:00'),
#   'name': 'CME Mexican Peso',
#   'symbol': 'MP',
#   'sector': 'currency',
#   'position': -1,
#   'entryprice': 39817.5,
#   'entrylots': 1,
#   'entryrisk': 7125000.0,
#   'entryrisk_ticks': 1425000,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2017-04-10 00:00:00'),
#     'exitprice': 39960.0,
#     'exitlots': 1,
#     'profit': 7125000.0,
#     'profit_tick': 1425000,
#     'duration': 0,
#     'result': 'WIN'}],
#   'currentprice': 39960.0,
#   'stopprice': 39960.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 7125000.0,
#   'duration': 0,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 143573,
#   'entrydate': Timestamp('2017-04-13 00:00:00'),
#   'name': 'CME Mexican Peso',
#   'symbol': 'MP',
#   'sector': 'currency',
#   'position': -1,
#   'entryprice': 40145.0,
#   'entrylots': 1,
#   'entryrisk': 7750000.0,
#   'entryrisk_ticks': 1550000,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2017-04-13 00:00:00'),
#     'exitprice': 40300.0,
#     'exitlots': 1,
#     'profit': 7750000.0,
#     'profit_tick': 1550000,
#     'duration': 0,
#     'result': 'WIN'}],
#   'currentprice': 40300.0,
#   'stopprice': 40300.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 7750000.0,
#   'duration': 0,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 145175,
#   'entrydate': Timestamp('2017-06-12 00:00:00'),
#   'name': 'CME Mexican Peso',
#   'symbol': 'MP',
#   'sector': 'currency',
#   'position': -1,
#   'entryprice': 41837.5,
#   'entrylots': 1,
#   'entryrisk': 6125000.0,
#   'entryrisk_ticks': 1225000,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2017-06-12 00:00:00'),
#     'exitprice': 41960.0,
#     'exitlots': 1,
#     'profit': 6125000.0,
#     'profit_tick': 1225000,
#     'duration': 0,
#     'result': 'WIN'}],
#   'currentprice': 41960.0,
#   'stopprice': 41960.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 6125000.0,
#   'duration': 0,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 145295,
#   'entrydate': Timestamp('2017-06-15 00:00:00'),
#   'name': 'CME Mexican Peso',
#   'symbol': 'MP',
#   'sector': 'currency',
#   'position': -1,
#   'entryprice': 42427.5,
#   'entrylots': 1,
#   'entryrisk': 10125000.0,
#   'entryrisk_ticks': 2025000,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2017-06-16 00:00:00'),
#     'exitprice': 42630.0,
#     'exitlots': 1,
#     'profit': 10125000.0,
#     'profit_tick': 2025000,
#     'duration': 1,
#     'result': 'WIN'}],
#   'currentprice': 42630.0,
#   'stopprice': 42630.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 10125000.0,
#   'duration': 1,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 145375,
#   'entrydate': Timestamp('2017-06-19 00:00:00'),
#   'name': 'CME Mexican Peso',
#   'symbol': 'MP',
#   'sector': 'currency',
#   'position': -1,
#   'entryprice': 42572.5,
#   'entrylots': 2,
#   'entryrisk': 8750000.0,
#   'entryrisk_ticks': 875000,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2017-06-26 00:00:00'),
#     'exitprice': 42660.0,
#     'exitlots': 2,
#     'profit': 8750000.0,
#     'profit_tick': 875000,
#     'duration': 7,
#     'result': 'WIN'}],
#   'currentprice': 42660.0,
#   'stopprice': 42660.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 8750000.0,
#   'duration': 7,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 146137,
#   'entrydate': Timestamp('2017-07-17 00:00:00'),
#   'name': 'CME Mexican Peso',
#   'symbol': 'MP',
#   'sector': 'currency',
#   'position': -1,
#   'entryprice': 43870.0,
#   'entrylots': 1,
#   'entryrisk': 9000000.0,
#   'entryrisk_ticks': 1800000,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2017-07-17 00:00:00'),
#     'exitprice': 44050.0,
#     'exitlots': 1,
#     'profit': 9000000.0,
#     'profit_tick': 1800000,
#     'duration': 0,
#     'result': 'WIN'}],
#   'currentprice': 44050.0,
#   'stopprice': 44050.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 9000000.0,
#   'duration': 0,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 146217,
#   'entrydate': Timestamp('2017-07-19 00:00:00'),
#   'name': 'CME Mexican Peso',
#   'symbol': 'MP',
#   'sector': 'currency',
#   'position': -1,
#   'entryprice': 44175.0,
#   'entrylots': 1,
#   'entryrisk': 7750000.0,
#   'entryrisk_ticks': 1550000,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2017-07-19 00:00:00'),
#     'exitprice': 44330.0,
#     'exitlots': 1,
#     'profit': 7750000.0,
#     'profit_tick': 1550000,
#     'duration': 0,
#     'result': 'WIN'}],
#   'currentprice': 44330.0,
#   'stopprice': 44330.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 7750000.0,
#   'duration': 0,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 147177,
#   'entrydate': Timestamp('2017-08-22 00:00:00'),
#   'name': 'CME Mexican Peso',
#   'symbol': 'MP',
#   'sector': 'currency',
#   'position': -1,
#   'entryprice': 43917.5,
#   'entrylots': 1,
#   'entryrisk': 10125000.0,
#   'entryrisk_ticks': 2025000,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2017-08-22 00:00:00'),
#     'exitprice': 44120.0,
#     'exitlots': 1,
#     'profit': 10125000.0,
#     'profit_tick': 2025000,
#     'duration': 0,
#     'result': 'WIN'}],
#   'currentprice': 44120.0,
#   'stopprice': 44120.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 10125000.0,
#   'duration': 0,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 147257,
#   'entrydate': Timestamp('2017-08-24 00:00:00'),
#   'name': 'CME Mexican Peso',
#   'symbol': 'MP',
#   'sector': 'currency',
#   'position': -1,
#   'entryprice': 43877.5,
#   'entrylots': 1,
#   'entryrisk': 12125000.0,
#   'entryrisk_ticks': 2425000,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2017-08-25 00:00:00'),
#     'exitprice': 44120.0,
#     'exitlots': 1,
#     'profit': 12125000.0,
#     'profit_tick': 2425000,
#     'duration': 1,
#     'result': 'WIN'}],
#   'currentprice': 44120.0,
#   'stopprice': 44120.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 12125000.0,
#   'duration': 1,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 147864,
#   'entrydate': Timestamp('2017-09-15 00:00:00'),
#   'name': 'CME Mexican Peso',
#   'symbol': 'MP',
#   'sector': 'currency',
#   'position': -1,
#   'entryprice': 44125.0,
#   'entrylots': 1,
#   'entryrisk': 8250000.0,
#   'entryrisk_ticks': 1650000,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2017-09-15 00:00:00'),
#     'exitprice': 44290.0,
#     'exitlots': 1,
#     'profit': 8250000.0,
#     'profit_tick': 1650000,
#     'duration': 0,
#     'result': 'WIN'}],
#   'currentprice': 44290.0,
#   'stopprice': 44290.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 8250000.0,
#   'duration': 0,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 147904,
#   'entrydate': Timestamp('2017-09-18 00:00:00'),
#   'name': 'CME Mexican Peso',
#   'symbol': 'MP',
#   'sector': 'currency',
#   'position': -1,
#   'entryprice': 44095.0,
#   'entrylots': 1,
#   'entryrisk': 12250000.0,
#   'entryrisk_ticks': 2450000,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2017-09-18 00:00:00'),
#     'exitprice': 44340.0,
#     'exitlots': 1,
#     'profit': 12250000.0,
#     'profit_tick': 2450000,
#     'duration': 0,
#     'result': 'WIN'}],
#   'currentprice': 44340.0,
#   'stopprice': 44340.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 12250000.0,
#   'duration': 0,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 148224,
#   'entrydate': Timestamp('2017-09-28 00:00:00'),
#   'name': 'CME Mexican Peso',
#   'symbol': 'MP',
#   'sector': 'currency',
#   'position': 1,
#   'entryprice': 42552.5,
#   'entrylots': 1,
#   'entryrisk': 13625000.0,
#   'entryrisk_ticks': 2725000,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2017-09-28 00:00:00'),
#     'exitprice': 42280.0,
#     'exitlots': 1,
#     'profit': 13625000.0,
#     'profit_tick': 2725000,
#     'duration': 0,
#     'result': 'WIN'}],
#   'currentprice': 42280.0,
#   'stopprice': 42280.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 13625000.0,
#   'duration': 0,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 148304,
#   'entrydate': Timestamp('2017-10-02 00:00:00'),
#   'name': 'CME Mexican Peso',
#   'symbol': 'MP',
#   'sector': 'currency',
#   'position': 1,
#   'entryprice': 42477.5,
#   'entrylots': 1,
#   'entryrisk': 13375000.0,
#   'entryrisk_ticks': 2675000,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2017-10-02 00:00:00'),
#     'exitprice': 42210.0,
#     'exitlots': 1,
#     'profit': 13375000.0,
#     'profit_tick': 2675000,
#     'duration': 0,
#     'result': 'WIN'}],
#   'currentprice': 42210.0,
#   'stopprice': 42210.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 13375000.0,
#   'duration': 0,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 148344,
#   'entrydate': Timestamp('2017-10-03 00:00:00'),
#   'name': 'CME Mexican Peso',
#   'symbol': 'MP',
#   'sector': 'currency',
#   'position': 1,
#   'entryprice': 42487.5,
#   'entrylots': 1,
#   'entryrisk': 13875000.0,
#   'entryrisk_ticks': 2775000,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2017-10-05 00:00:00'),
#     'exitprice': 42210.0,
#     'exitlots': 1,
#     'profit': 13875000.0,
#     'profit_tick': 2775000,
#     'duration': 2,
#     'result': 'WIN'}],
#   'currentprice': 42210.0,
#   'stopprice': 42210.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 13875000.0,
#   'duration': 2,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 148464,
#   'entrydate': Timestamp('2017-10-06 00:00:00'),
#   'name': 'CME Mexican Peso',
#   'symbol': 'MP',
#   'sector': 'currency',
#   'position': 1,
#   'entryprice': 41760.0,
#   'entrylots': 1,
#   'entryrisk': 19000000.0,
#   'entryrisk_ticks': 3800000,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2017-10-06 00:00:00'),
#     'exitprice': 41380.0,
#     'exitlots': 1,
#     'profit': 19000000.0,
#     'profit_tick': 3800000,
#     'duration': 0,
#     'result': 'WIN'}],
#   'currentprice': 41380.0,
#   'stopprice': 41380.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 19000000.0,
#   'duration': 0,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 148504,
#   'entrydate': Timestamp('2017-10-09 00:00:00'),
#   'name': 'CME Mexican Peso',
#   'symbol': 'MP',
#   'sector': 'currency',
#   'position': 1,
#   'entryprice': 41575.0,
#   'entrylots': 1,
#   'entryrisk': 20250000.0,
#   'entryrisk_ticks': 4050000,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2017-10-09 00:00:00'),
#     'exitprice': 41170.0,
#     'exitlots': 1,
#     'profit': 20250000.0,
#     'profit_tick': 4050000,
#     'duration': 0,
#     'result': 'WIN'}],
#   'currentprice': 41170.0,
#   'stopprice': 41170.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 20250000.0,
#   'duration': 0,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 148584,
#   'entrydate': Timestamp('2017-10-11 00:00:00'),
#   'name': 'CME Mexican Peso',
#   'symbol': 'MP',
#   'sector': 'currency',
#   'position': 1,
#   'entryprice': 41002.5,
#   'entrylots': 1,
#   'entryrisk': 12125000.0,
#   'entryrisk_ticks': 2425000,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2017-10-12 00:00:00'),
#     'exitprice': 40760.0,
#     'exitlots': 1,
#     'profit': 12125000.0,
#     'profit_tick': 2425000,
#     'duration': 1,
#     'result': 'WIN'}],
#   'currentprice': 40760.0,
#   'stopprice': 40760.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 12125000.0,
#   'duration': 1,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 148664,
#   'entrydate': Timestamp('2017-10-13 00:00:00'),
#   'name': 'CME Mexican Peso',
#   'symbol': 'MP',
#   'sector': 'currency',
#   'position': 1,
#   'entryprice': 40712.5,
#   'entrylots': 1,
#   'entryrisk': 14625000.0,
#   'entryrisk_ticks': 2925000,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2017-10-13 00:00:00'),
#     'exitprice': 40420.0,
#     'exitlots': 1,
#     'profit': 14625000.0,
#     'profit_tick': 2925000,
#     'duration': 0,
#     'result': 'WIN'}],
#   'currentprice': 40420.0,
#   'stopprice': 40420.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 14625000.0,
#   'duration': 0,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 148704,
#   'entrydate': Timestamp('2017-10-16 00:00:00'),
#   'name': 'CME Mexican Peso',
#   'symbol': 'MP',
#   'sector': 'currency',
#   'position': 1,
#   'entryprice': 40527.5,
#   'entrylots': 1,
#   'entryrisk': 25875000.0,
#   'entryrisk_ticks': 5175000,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2017-10-16 00:00:00'),
#     'exitprice': 40010.0,
#     'exitlots': 1,
#     'profit': 25875000.0,
#     'profit_tick': 5175000,
#     'duration': 0,
#     'result': 'WIN'}],
#   'currentprice': 40010.0,
#   'stopprice': 40010.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 25875000.0,
#   'duration': 0,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 148744,
#   'entrydate': Timestamp('2017-10-17 00:00:00'),
#   'name': 'CME Mexican Peso',
#   'symbol': 'MP',
#   'sector': 'currency',
#   'position': 1,
#   'entryprice': 40497.5,
#   'entrylots': 1,
#   'entryrisk': 25375000.0,
#   'entryrisk_ticks': 5075000,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2017-10-17 00:00:00'),
#     'exitprice': 39990.0,
#     'exitlots': 1,
#     'profit': 25375000.0,
#     'profit_tick': 5075000,
#     'duration': 0,
#     'result': 'WIN'}],
#   'currentprice': 39990.0,
#   'stopprice': 39990.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 25375000.0,
#   'duration': 0,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 148904,
#   'entrydate': Timestamp('2017-10-23 00:00:00'),
#   'name': 'CME Mexican Peso',
#   'symbol': 'MP',
#   'sector': 'currency',
#   'position': 1,
#   'entryprice': 40465.0,
#   'entrylots': 1,
#   'entryrisk': 23750000.0,
#   'entryrisk_ticks': 4750000,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2017-10-24 00:00:00'),
#     'exitprice': 39990.0,
#     'exitlots': 1,
#     'profit': 23750000.0,
#     'profit_tick': 4750000,
#     'duration': 1,
#     'result': 'WIN'}],
#   'currentprice': 39990.0,
#   'stopprice': 39990.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 23750000.0,
#   'duration': 1,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 148944,
#   'entrydate': Timestamp('2017-10-24 00:00:00'),
#   'name': 'CME Mexican Peso',
#   'symbol': 'MP',
#   'sector': 'currency',
#   'position': 1,
#   'entryprice': 40215.0,
#   'entrylots': 1,
#   'entryrisk': 23750000.0,
#   'entryrisk_ticks': 4750000,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2017-10-24 00:00:00'),
#     'exitprice': 39740.0,
#     'exitlots': 1,
#     'profit': 23750000.0,
#     'profit_tick': 4750000,
#     'duration': 0,
#     'result': 'WIN'}],
#   'currentprice': 39740.0,
#   'stopprice': 39740.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 23750000.0,
#   'duration': 0,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 148984,
#   'entrydate': Timestamp('2017-10-25 00:00:00'),
#   'name': 'CME Mexican Peso',
#   'symbol': 'MP',
#   'sector': 'currency',
#   'position': 1,
#   'entryprice': 39977.5,
#   'entrylots': 2,
#   'entryrisk': 28750000.0,
#   'entryrisk_ticks': 2875000,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2017-10-25 00:00:00'),
#     'exitprice': 39690.0,
#     'exitlots': 2,
#     'profit': 28750000.0,
#     'profit_tick': 2875000,
#     'duration': 0,
#     'result': 'WIN'}],
#   'currentprice': 39690.0,
#   'stopprice': 39690.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 28750000.0,
#   'duration': 0,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 149024,
#   'entrydate': Timestamp('2017-10-26 00:00:00'),
#   'name': 'CME Mexican Peso',
#   'symbol': 'MP',
#   'sector': 'currency',
#   'position': 1,
#   'entryprice': 40397.5,
#   'entrylots': 1,
#   'entryrisk': 35375000.0,
#   'entryrisk_ticks': 7075000,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2017-10-27 00:00:00'),
#     'exitprice': 39690.0,
#     'exitlots': 1,
#     'profit': 35375000.0,
#     'profit_tick': 7075000,
#     'duration': 1,
#     'result': 'WIN'}],
#   'currentprice': 39690.0,
#   'stopprice': 39690.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 35375000.0,
#   'duration': 1,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 149064,
#   'entrydate': Timestamp('2017-10-27 00:00:00'),
#   'name': 'CME Mexican Peso',
#   'symbol': 'MP',
#   'sector': 'currency',
#   'position': 1,
#   'entryprice': 39997.5,
#   'entrylots': 1,
#   'entryrisk': 19875000.0,
#   'entryrisk_ticks': 3975000,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2017-10-27 00:00:00'),
#     'exitprice': 39600.0,
#     'exitlots': 1,
#     'profit': 19875000.0,
#     'profit_tick': 3975000,
#     'duration': 0,
#     'result': 'WIN'}],
#   'currentprice': 39600.0,
#   'stopprice': 39600.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 19875000.0,
#   'duration': 0,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 149704,
#   'entrydate': Timestamp('2017-11-20 00:00:00'),
#   'name': 'CME Mexican Peso',
#   'symbol': 'MP',
#   'sector': 'currency',
#   'position': -1,
#   'entryprice': 40805.0,
#   'entrylots': 2,
#   'entryrisk': 17500000.0,
#   'entryrisk_ticks': 1750000,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2017-11-21 00:00:00'),
#     'exitprice': 40980.0,
#     'exitlots': 2,
#     'profit': 17500000.0,
#     'profit_tick': 1750000,
#     'duration': 1,
#     'result': 'WIN'}],
#   'currentprice': 40980.0,
#   'stopprice': 40980.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 17500000.0,
#   'duration': 1,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 149826,
#   'entrydate': Timestamp('2017-11-24 00:00:00'),
#   'name': 'CME Mexican Peso',
#   'symbol': 'MP',
#   'sector': 'currency',
#   'position': -1,
#   'entryprice': 41710.0,
#   'entrylots': 1,
#   'entryrisk': 20000000.0,
#   'entryrisk_ticks': 4000000,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2017-11-24 00:00:00'),
#     'exitprice': 42110.0,
#     'exitlots': 1,
#     'profit': 20000000.0,
#     'profit_tick': 4000000,
#     'duration': 0,
#     'result': 'WIN'}],
#   'currentprice': 42110.0,
#   'stopprice': 42110.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 20000000.0,
#   'duration': 0,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 149866,
#   'entrydate': Timestamp('2017-11-27 00:00:00'),
#   'name': 'CME Mexican Peso',
#   'symbol': 'MP',
#   'sector': 'currency',
#   'position': -1,
#   'entryprice': 41982.5,
#   'entrylots': 1,
#   'entryrisk': 16875000.0,
#   'entryrisk_ticks': 3375000,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2017-11-27 00:00:00'),
#     'exitprice': 42320.0,
#     'exitlots': 1,
#     'profit': 16875000.0,
#     'profit_tick': 3375000,
#     'duration': 0,
#     'result': 'WIN'}],
#   'currentprice': 42320.0,
#   'stopprice': 42320.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 16875000.0,
#   'duration': 0,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 150546,
#   'entrydate': Timestamp('2017-12-20 00:00:00'),
#   'name': 'CME Mexican Peso',
#   'symbol': 'MP',
#   'sector': 'currency',
#   'position': 1,
#   'entryprice': 40420.0,
#   'entrylots': 1,
#   'entryrisk': 10000000.0,
#   'entryrisk_ticks': 2000000,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2017-12-20 00:00:00'),
#     'exitprice': 40220.0,
#     'exitlots': 1,
#     'profit': 10000000.0,
#     'profit_tick': 2000000,
#     'duration': 0,
#     'result': 'WIN'}],
#   'currentprice': 40220.0,
#   'stopprice': 40220.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 10000000.0,
#   'duration': 0,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 163676,
#   'entrydate': Timestamp('2019-04-11 00:00:00'),
#   'name': 'CME Mexican Peso',
#   'symbol': 'MP',
#   'sector': 'currency',
#   'position': -1,
#   'entryprice': 45175.0,
#   'entrylots': 1,
#   'entryrisk': 5250000.0,
#   'entryrisk_ticks': 1050000,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2019-04-11 00:00:00'),
#     'exitprice': 45280.0,
#     'exitlots': 1,
#     'profit': 5250000.0,
#     'profit_tick': 1050000,
#     'duration': 0,
#     'result': 'WIN'}],
#   'currentprice': 45280.0,
#   'stopprice': 45280.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 5250000.0,
#   'duration': 0,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 167894,
#   'entrydate': Timestamp('2019-09-11 00:00:00'),
#   'name': 'CME Mexican Peso',
#   'symbol': 'MP',
#   'sector': 'currency',
#   'position': -1,
#   'entryprice': 44600.0,
#   'entrylots': 1,
#   'entryrisk': 6000000.0,
#   'entryrisk_ticks': 1200000,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2019-09-11 00:00:00'),
#     'exitprice': 44720.0,
#     'exitlots': 1,
#     'profit': 6000000.0,
#     'profit_tick': 1200000,
#     'duration': 0,
#     'result': 'WIN'}],
#   'currentprice': 44720.0,
#   'stopprice': 44720.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 6000000.0,
#   'duration': 0,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 169014,
#   'entrydate': Timestamp('2019-10-21 00:00:00'),
#   'name': 'CME Mexican Peso',
#   'symbol': 'MP',
#   'sector': 'currency',
#   'position': -1,
#   'entryprice': 45920.0,
#   'entrylots': 1,
#   'entryrisk': 6000000.0,
#   'entryrisk_ticks': 1200000,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2019-10-22 00:00:00'),
#     'exitprice': 46040.0,
#     'exitlots': 1,
#     'profit': 6000000.0,
#     'profit_tick': 1200000,
#     'duration': 1,
#     'result': 'WIN'}],
#   'currentprice': 46040.0,
#   'stopprice': 46040.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 6000000.0,
#   'duration': 1,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 169214,
#   'entrydate': Timestamp('2019-10-28 00:00:00'),
#   'name': 'CME Mexican Peso',
#   'symbol': 'MP',
#   'sector': 'currency',
#   'position': -1,
#   'entryprice': 46207.5,
#   'entrylots': 1,
#   'entryrisk': 6125000.0,
#   'entryrisk_ticks': 1225000,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2019-10-28 00:00:00'),
#     'exitprice': 46330.0,
#     'exitlots': 1,
#     'profit': 6125000.0,
#     'profit_tick': 1225000,
#     'duration': 0,
#     'result': 'WIN'}],
#   'currentprice': 46330.0,
#   'stopprice': 46330.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 6125000.0,
#   'duration': 0,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 170420,
#   'entrydate': Timestamp('2019-12-10 00:00:00'),
#   'name': 'CME Mexican Peso',
#   'symbol': 'MP',
#   'sector': 'currency',
#   'position': -1,
#   'entryprice': 46082.5,
#   'entrylots': 1,
#   'entryrisk': 5375000.0,
#   'entryrisk_ticks': 1075000,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2019-12-10 00:00:00'),
#     'exitprice': 46190.0,
#     'exitlots': 1,
#     'profit': 5375000.0,
#     'profit_tick': 1075000,
#     'duration': 0,
#     'result': 'WIN'}],
#   'currentprice': 46190.0,
#   'stopprice': 46190.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 5375000.0,
#   'duration': 0,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 170620,
#   'entrydate': Timestamp('2019-12-17 00:00:00'),
#   'name': 'CME Mexican Peso',
#   'symbol': 'MP',
#   'sector': 'currency',
#   'position': -1,
#   'entryprice': 46925.0,
#   'entrylots': 1,
#   'entryrisk': 5250000.0,
#   'entryrisk_ticks': 1050000,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2019-12-17 00:00:00'),
#     'exitprice': 47030.0,
#     'exitlots': 1,
#     'profit': 5250000.0,
#     'profit_tick': 1050000,
#     'duration': 0,
#     'result': 'WIN'}],
#   'currentprice': 47030.0,
#   'stopprice': 47030.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 5250000.0,
#   'duration': 0,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 170660,
#   'entrydate': Timestamp('2019-12-18 00:00:00'),
#   'name': 'CME Mexican Peso',
#   'symbol': 'MP',
#   'sector': 'currency',
#   'position': -1,
#   'entryprice': 46900.0,
#   'entrylots': 1,
#   'entryrisk': 6500000.0,
#   'entryrisk_ticks': 1300000,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2019-12-20 00:00:00'),
#     'exitprice': 47030.0,
#     'exitlots': 1,
#     'profit': 6500000.0,
#     'profit_tick': 1300000,
#     'duration': 2,
#     'result': 'WIN'}],
#   'currentprice': 47030.0,
#   'stopprice': 47030.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 6500000.0,
#   'duration': 2,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 170740,
#   'entrydate': Timestamp('2019-12-20 00:00:00'),
#   'name': 'CME Mexican Peso',
#   'symbol': 'MP',
#   'sector': 'currency',
#   'position': -1,
#   'entryprice': 46895.0,
#   'entrylots': 1,
#   'entryrisk': 7250000.0,
#   'entryrisk_ticks': 1450000,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2019-12-20 00:00:00'),
#     'exitprice': 47040.0,
#     'exitlots': 1,
#     'profit': 7250000.0,
#     'profit_tick': 1450000,
#     'duration': 0,
#     'result': 'WIN'}],
#   'currentprice': 47040.0,
#   'stopprice': 47040.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 7250000.0,
#   'duration': 0,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 170780,
#   'entrydate': Timestamp('2019-12-23 00:00:00'),
#   'name': 'CME Mexican Peso',
#   'symbol': 'MP',
#   'sector': 'currency',
#   'position': -1,
#   'entryprice': 46865.0,
#   'entrylots': 1,
#   'entryrisk': 8750000.0,
#   'entryrisk_ticks': 1750000,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2019-12-23 00:00:00'),
#     'exitprice': 47040.0,
#     'exitlots': 1,
#     'profit': 8750000.0,
#     'profit_tick': 1750000,
#     'duration': 0,
#     'result': 'WIN'}],
#   'currentprice': 47040.0,
#   'stopprice': 47040.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 8750000.0,
#   'duration': 0,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 170820,
#   'entrydate': Timestamp('2019-12-24 00:00:00'),
#   'name': 'CME Mexican Peso',
#   'symbol': 'MP',
#   'sector': 'currency',
#   'position': -1,
#   'entryprice': 46877.5,
#   'entrylots': 1,
#   'entryrisk': 8125000.0,
#   'entryrisk_ticks': 1625000,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2019-12-27 00:00:00'),
#     'exitprice': 47040.0,
#     'exitlots': 1,
#     'profit': 8125000.0,
#     'profit_tick': 1625000,
#     'duration': 3,
#     'result': 'WIN'}],
#   'currentprice': 47040.0,
#   'stopprice': 47040.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 8125000.0,
#   'duration': 3,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 170860,
#   'entrydate': Timestamp('2019-12-26 00:00:00'),
#   'name': 'CME Mexican Peso',
#   'symbol': 'MP',
#   'sector': 'currency',
#   'position': -1,
#   'entryprice': 46840.0,
#   'entrylots': 1,
#   'entryrisk': 10000000.0,
#   'entryrisk_ticks': 2000000,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2019-12-27 00:00:00'),
#     'exitprice': 47040.0,
#     'exitlots': 1,
#     'profit': 10000000.0,
#     'profit_tick': 2000000,
#     'duration': 1,
#     'result': 'WIN'}],
#   'currentprice': 47040.0,
#   'stopprice': 47040.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 10000000.0,
#   'duration': 1,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 170940,
#   'entrydate': Timestamp('2019-12-30 00:00:00'),
#   'name': 'CME Mexican Peso',
#   'symbol': 'MP',
#   'sector': 'currency',
#   'position': -1,
#   'entryprice': 47160.0,
#   'entrylots': 1,
#   'entryrisk': 9500000.0,
#   'entryrisk_ticks': 1900000,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2019-12-30 00:00:00'),
#     'exitprice': 47350.0,
#     'exitlots': 1,
#     'profit': 9500000.0,
#     'profit_tick': 1900000,
#     'duration': 0,
#     'result': 'WIN'}],
#   'currentprice': 47350.0,
#   'stopprice': 47350.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 9500000.0,
#   'duration': 0,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 171060,
#   'entrydate': Timestamp('2020-01-03 00:00:00'),
#   'name': 'CME Mexican Peso',
#   'symbol': 'MP',
#   'sector': 'currency',
#   'position': -1,
#   'entryprice': 47127.5,
#   'entrylots': 1,
#   'entryrisk': 11125000.0,
#   'entryrisk_ticks': 2225000,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2020-01-06 00:00:00'),
#     'exitprice': 47350.0,
#     'exitlots': 1,
#     'profit': 11125000.0,
#     'profit_tick': 2225000,
#     'duration': 3,
#     'result': 'WIN'}],
#   'currentprice': 47350.0,
#   'stopprice': 47350.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 11125000.0,
#   'duration': 3,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 171140,
#   'entrydate': Timestamp('2020-01-07 00:00:00'),
#   'name': 'CME Mexican Peso',
#   'symbol': 'MP',
#   'sector': 'currency',
#   'position': -1,
#   'entryprice': 47215.0,
#   'entrylots': 1,
#   'entryrisk': 9750000.0,
#   'entryrisk_ticks': 1950000,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2020-01-08 00:00:00'),
#     'exitprice': 47410.0,
#     'exitlots': 1,
#     'profit': 9750000.0,
#     'profit_tick': 1950000,
#     'duration': 1,
#     'result': 'WIN'}],
#   'currentprice': 47410.0,
#   'stopprice': 47410.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 9750000.0,
#   'duration': 1,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 171220,
#   'entrydate': Timestamp('2020-01-09 00:00:00'),
#   'name': 'CME Mexican Peso',
#   'symbol': 'MP',
#   'sector': 'currency',
#   'position': -1,
#   'entryprice': 47335.0,
#   'entrylots': 1,
#   'entryrisk': 10250000.0,
#   'entryrisk_ticks': 2050000,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2020-01-09 00:00:00'),
#     'exitprice': 47540.0,
#     'exitlots': 1,
#     'profit': 10250000.0,
#     'profit_tick': 2050000,
#     'duration': 0,
#     'result': 'WIN'}],
#   'currentprice': 47540.0,
#   'stopprice': 47540.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 10250000.0,
#   'duration': 0,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 171260,
#   'entrydate': Timestamp('2020-01-10 00:00:00'),
#   'name': 'CME Mexican Peso',
#   'symbol': 'MP',
#   'sector': 'currency',
#   'position': -1,
#   'entryprice': 47327.5,
#   'entrylots': 1,
#   'entryrisk': 13625000.0,
#   'entryrisk_ticks': 2725000,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2020-01-10 00:00:00'),
#     'exitprice': 47600.0,
#     'exitlots': 1,
#     'profit': 13625000.0,
#     'profit_tick': 2725000,
#     'duration': 0,
#     'result': 'WIN'}],
#   'currentprice': 47600.0,
#   'stopprice': 47600.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 13625000.0,
#   'duration': 0,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 171300,
#   'entrydate': Timestamp('2020-01-13 00:00:00'),
#   'name': 'CME Mexican Peso',
#   'symbol': 'MP',
#   'sector': 'currency',
#   'position': -1,
#   'entryprice': 47432.5,
#   'entrylots': 2,
#   'entryrisk': 16750000.0,
#   'entryrisk_ticks': 1675000,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2020-01-16 00:00:00'),
#     'exitprice': 47600.0,
#     'exitlots': 2,
#     'profit': 16750000.0,
#     'profit_tick': 1675000,
#     'duration': 3,
#     'result': 'WIN'}],
#   'currentprice': 47600.0,
#   'stopprice': 47600.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 16750000.0,
#   'duration': 3,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 171340,
#   'entrydate': Timestamp('2020-01-14 00:00:00'),
#   'name': 'CME Mexican Peso',
#   'symbol': 'MP',
#   'sector': 'currency',
#   'position': -1,
#   'entryprice': 47410.0,
#   'entrylots': 1,
#   'entryrisk': 9500000.0,
#   'entryrisk_ticks': 1900000,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2020-01-16 00:00:00'),
#     'exitprice': 47600.0,
#     'exitlots': 1,
#     'profit': 9500000.0,
#     'profit_tick': 1900000,
#     'duration': 2,
#     'result': 'WIN'}],
#   'currentprice': 47600.0,
#   'stopprice': 47600.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 9500000.0,
#   'duration': 2,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 171380,
#   'entrydate': Timestamp('2020-01-15 00:00:00'),
#   'name': 'CME Mexican Peso',
#   'symbol': 'MP',
#   'sector': 'currency',
#   'position': -1,
#   'entryprice': 47450.0,
#   'entrylots': 2,
#   'entryrisk': 15000000.0,
#   'entryrisk_ticks': 1500000,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2020-01-16 00:00:00'),
#     'exitprice': 47600.0,
#     'exitlots': 2,
#     'profit': 15000000.0,
#     'profit_tick': 1500000,
#     'duration': 1,
#     'result': 'WIN'}],
#   'currentprice': 47600.0,
#   'stopprice': 47600.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 15000000.0,
#   'duration': 1,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 171420,
#   'entrydate': Timestamp('2020-01-16 00:00:00'),
#   'name': 'CME Mexican Peso',
#   'symbol': 'MP',
#   'sector': 'currency',
#   'position': -1,
#   'entryprice': 47450.0,
#   'entrylots': 2,
#   'entryrisk': 17000000.0,
#   'entryrisk_ticks': 1700000,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2020-01-16 00:00:00'),
#     'exitprice': 47620.0,
#     'exitlots': 2,
#     'profit': 17000000.0,
#     'profit_tick': 1700000,
#     'duration': 0,
#     'result': 'WIN'}],
#   'currentprice': 47620.0,
#   'stopprice': 47620.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 17000000.0,
#   'duration': 0,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 171460,
#   'entrydate': Timestamp('2020-01-17 00:00:00'),
#   'name': 'CME Mexican Peso',
#   'symbol': 'MP',
#   'sector': 'currency',
#   'position': -1,
#   'entryprice': 47552.5,
#   'entrylots': 1,
#   'entryrisk': 18375000.0,
#   'entryrisk_ticks': 3675000,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2020-01-17 00:00:00'),
#     'exitprice': 47920.0,
#     'exitlots': 1,
#     'profit': 18375000.0,
#     'profit_tick': 3675000,
#     'duration': 0,
#     'result': 'WIN'}],
#   'currentprice': 47920.0,
#   'stopprice': 47920.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 18375000.0,
#   'duration': 0,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 171506,
#   'entrydate': Timestamp('2020-01-21 00:00:00'),
#   'name': 'CME Mexican Peso',
#   'symbol': 'MP',
#   'sector': 'currency',
#   'position': -1,
#   'entryprice': 47797.5,
#   'entrylots': 2,
#   'entryrisk': 13250000.0,
#   'entryrisk_ticks': 1325000,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2020-01-21 00:00:00'),
#     'exitprice': 47930.0,
#     'exitlots': 2,
#     'profit': 13250000.0,
#     'profit_tick': 1325000,
#     'duration': 0,
#     'result': 'WIN'}],
#   'currentprice': 47930.0,
#   'stopprice': 47930.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 13250000.0,
#   'duration': 0,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 171546,
#   'entrydate': Timestamp('2020-01-22 00:00:00'),
#   'name': 'CME Mexican Peso',
#   'symbol': 'MP',
#   'sector': 'currency',
#   'position': -1,
#   'entryprice': 47562.5,
#   'entrylots': 1,
#   'entryrisk': 18375000.0,
#   'entryrisk_ticks': 3675000,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2020-01-29 00:00:00'),
#     'exitprice': 47930.0,
#     'exitlots': 1,
#     'profit': 18375000.0,
#     'profit_tick': 3675000,
#     'duration': 7,
#     'result': 'WIN'}],
#   'currentprice': 47930.0,
#   'stopprice': 47930.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 18375000.0,
#   'duration': 7,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 171586,
#   'entrydate': Timestamp('2020-01-23 00:00:00'),
#   'name': 'CME Mexican Peso',
#   'symbol': 'MP',
#   'sector': 'currency',
#   'position': -1,
#   'entryprice': 47755.0,
#   'entrylots': 2,
#   'entryrisk': 17500000.0,
#   'entryrisk_ticks': 1750000,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2020-01-29 00:00:00'),
#     'exitprice': 47930.0,
#     'exitlots': 2,
#     'profit': 17500000.0,
#     'profit_tick': 1750000,
#     'duration': 6,
#     'result': 'WIN'}],
#   'currentprice': 47930.0,
#   'stopprice': 47930.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 17500000.0,
#   'duration': 6,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 171626,
#   'entrydate': Timestamp('2020-01-24 00:00:00'),
#   'name': 'CME Mexican Peso',
#   'symbol': 'MP',
#   'sector': 'currency',
#   'position': -1,
#   'entryprice': 47610.0,
#   'entrylots': 1,
#   'entryrisk': 16000000.0,
#   'entryrisk_ticks': 3200000,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2020-01-29 00:00:00'),
#     'exitprice': 47930.0,
#     'exitlots': 1,
#     'profit': 16000000.0,
#     'profit_tick': 3200000,
#     'duration': 5,
#     'result': 'WIN'}],
#   'currentprice': 47930.0,
#   'stopprice': 47930.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 16000000.0,
#   'duration': 5,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 171666,
#   'entrydate': Timestamp('2020-01-27 00:00:00'),
#   'name': 'CME Mexican Peso',
#   'symbol': 'MP',
#   'sector': 'currency',
#   'position': -1,
#   'entryprice': 47345.0,
#   'entrylots': 1,
#   'entryrisk': 29250000.0,
#   'entryrisk_ticks': 5850000,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2020-01-29 00:00:00'),
#     'exitprice': 47930.0,
#     'exitlots': 1,
#     'profit': 29250000.0,
#     'profit_tick': 5850000,
#     'duration': 2,
#     'result': 'WIN'}],
#   'currentprice': 47930.0,
#   'stopprice': 47930.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 29250000.0,
#   'duration': 2,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 171746,
#   'entrydate': Timestamp('2020-01-29 00:00:00'),
#   'name': 'CME Mexican Peso',
#   'symbol': 'MP',
#   'sector': 'currency',
#   'position': -1,
#   'entryprice': 47745.0,
#   'entrylots': 2,
#   'entryrisk': 20500000.0,
#   'entryrisk_ticks': 2050000,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2020-01-29 00:00:00'),
#     'exitprice': 47950.0,
#     'exitlots': 2,
#     'profit': 20500000.0,
#     'profit_tick': 2050000,
#     'duration': 0,
#     'result': 'WIN'}],
#   'currentprice': 47950.0,
#   'stopprice': 47950.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 20500000.0,
#   'duration': 0,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 171786,
#   'entrydate': Timestamp('2020-01-30 00:00:00'),
#   'name': 'CME Mexican Peso',
#   'symbol': 'MP',
#   'sector': 'currency',
#   'position': -1,
#   'entryprice': 47777.5,
#   'entrylots': 2,
#   'entryrisk': 17250000.0,
#   'entryrisk_ticks': 1725000,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2020-02-04 00:00:00'),
#     'exitprice': 47950.0,
#     'exitlots': 2,
#     'profit': 17250000.0,
#     'profit_tick': 1725000,
#     'duration': 5,
#     'result': 'WIN'}],
#   'currentprice': 47950.0,
#   'stopprice': 47950.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 17250000.0,
#   'duration': 5,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 171826,
#   'entrydate': Timestamp('2020-01-31 00:00:00'),
#   'name': 'CME Mexican Peso',
#   'symbol': 'MP',
#   'sector': 'currency',
#   'position': -1,
#   'entryprice': 47527.5,
#   'entrylots': 1,
#   'entryrisk': 21125000.0,
#   'entryrisk_ticks': 4225000,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2020-02-04 00:00:00'),
#     'exitprice': 47950.0,
#     'exitlots': 1,
#     'profit': 21125000.0,
#     'profit_tick': 4225000,
#     'duration': 4,
#     'result': 'WIN'}],
#   'currentprice': 47950.0,
#   'stopprice': 47950.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 21125000.0,
#   'duration': 4,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 171866,
#   'entrydate': Timestamp('2020-02-03 00:00:00'),
#   'name': 'CME Mexican Peso',
#   'symbol': 'MP',
#   'sector': 'currency',
#   'position': -1,
#   'entryprice': 47317.5,
#   'entrylots': 1,
#   'entryrisk': 31625000.0,
#   'entryrisk_ticks': 6325000,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2020-02-04 00:00:00'),
#     'exitprice': 47950.0,
#     'exitlots': 1,
#     'profit': 31625000.0,
#     'profit_tick': 6325000,
#     'duration': 1,
#     'result': 'WIN'}],
#   'currentprice': 47950.0,
#   'stopprice': 47950.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 31625000.0,
#   'duration': 1,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 171906,
#   'entrydate': Timestamp('2020-02-04 00:00:00'),
#   'name': 'CME Mexican Peso',
#   'symbol': 'MP',
#   'sector': 'currency',
#   'position': -1,
#   'entryprice': 47555.0,
#   'entrylots': 1,
#   'entryrisk': 24250000.0,
#   'entryrisk_ticks': 4850000,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2020-02-04 00:00:00'),
#     'exitprice': 48040.0,
#     'exitlots': 1,
#     'profit': 24250000.0,
#     'profit_tick': 4850000,
#     'duration': 0,
#     'result': 'WIN'}],
#   'currentprice': 48040.0,
#   'stopprice': 48040.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 24250000.0,
#   'duration': 0,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 171946,
#   'entrydate': Timestamp('2020-02-05 00:00:00'),
#   'name': 'CME Mexican Peso',
#   'symbol': 'MP',
#   'sector': 'currency',
#   'position': -1,
#   'entryprice': 48005.0,
#   'entrylots': 2,
#   'entryrisk': 26500000.0,
#   'entryrisk_ticks': 2650000,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2020-02-05 00:00:00'),
#     'exitprice': 48270.0,
#     'exitlots': 2,
#     'profit': 26500000.0,
#     'profit_tick': 2650000,
#     'duration': 0,
#     'result': 'WIN'}],
#   'currentprice': 48270.0,
#   'stopprice': 48270.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 26500000.0,
#   'duration': 0,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 171986,
#   'entrydate': Timestamp('2020-02-06 00:00:00'),
#   'name': 'CME Mexican Peso',
#   'symbol': 'MP',
#   'sector': 'currency',
#   'position': -1,
#   'entryprice': 48197.5,
#   'entrylots': 2,
#   'entryrisk': 14250000.0,
#   'entryrisk_ticks': 1425000,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2020-02-06 00:00:00'),
#     'exitprice': 48340.0,
#     'exitlots': 2,
#     'profit': 14250000.0,
#     'profit_tick': 1425000,
#     'duration': 0,
#     'result': 'WIN'}],
#   'currentprice': 48340.0,
#   'stopprice': 48340.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 14250000.0,
#   'duration': 0,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 172026,
#   'entrydate': Timestamp('2020-02-07 00:00:00'),
#   'name': 'CME Mexican Peso',
#   'symbol': 'MP',
#   'sector': 'currency',
#   'position': -1,
#   'entryprice': 47962.5,
#   'entrylots': 2,
#   'entryrisk': 37750000.0,
#   'entryrisk_ticks': 3775000,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2020-02-13 00:00:00'),
#     'exitprice': 48340.0,
#     'exitlots': 2,
#     'profit': 37750000.0,
#     'profit_tick': 3775000,
#     'duration': 6,
#     'result': 'WIN'}],
#   'currentprice': 48340.0,
#   'stopprice': 48340.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 37750000.0,
#   'duration': 6,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 172066,
#   'entrydate': Timestamp('2020-02-10 00:00:00'),
#   'name': 'CME Mexican Peso',
#   'symbol': 'MP',
#   'sector': 'currency',
#   'position': -1,
#   'entryprice': 47687.5,
#   'entrylots': 1,
#   'entryrisk': 32625000.0,
#   'entryrisk_ticks': 6525000,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2020-02-13 00:00:00'),
#     'exitprice': 48340.0,
#     'exitlots': 1,
#     'profit': 32625000.0,
#     'profit_tick': 6525000,
#     'duration': 3,
#     'result': 'WIN'}],
#   'currentprice': 48340.0,
#   'stopprice': 48340.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 32625000.0,
#   'duration': 3,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 172106,
#   'entrydate': Timestamp('2020-02-11 00:00:00'),
#   'name': 'CME Mexican Peso',
#   'symbol': 'MP',
#   'sector': 'currency',
#   'position': -1,
#   'entryprice': 47925.0,
#   'entrylots': 2,
#   'entryrisk': 41500000.0,
#   'entryrisk_ticks': 4150000,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2020-02-13 00:00:00'),
#     'exitprice': 48340.0,
#     'exitlots': 2,
#     'profit': 41500000.0,
#     'profit_tick': 4150000,
#     'duration': 2,
#     'result': 'WIN'}],
#   'currentprice': 48340.0,
#   'stopprice': 48340.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 41500000.0,
#   'duration': 2,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 172146,
#   'entrydate': Timestamp('2020-02-12 00:00:00'),
#   'name': 'CME Mexican Peso',
#   'symbol': 'MP',
#   'sector': 'currency',
#   'position': -1,
#   'entryprice': 48065.0,
#   'entrylots': 2,
#   'entryrisk': 27500000.0,
#   'entryrisk_ticks': 2750000,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2020-02-13 00:00:00'),
#     'exitprice': 48340.0,
#     'exitlots': 2,
#     'profit': 27500000.0,
#     'profit_tick': 2750000,
#     'duration': 1,
#     'result': 'WIN'}],
#   'currentprice': 48340.0,
#   'stopprice': 48340.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 27500000.0,
#   'duration': 1,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 172186,
#   'entrydate': Timestamp('2020-02-13 00:00:00'),
#   'name': 'CME Mexican Peso',
#   'symbol': 'MP',
#   'sector': 'currency',
#   'position': -1,
#   'entryprice': 48165.0,
#   'entrylots': 2,
#   'entryrisk': 18500000.0,
#   'entryrisk_ticks': 1850000,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2020-02-13 00:00:00'),
#     'exitprice': 48350.0,
#     'exitlots': 2,
#     'profit': 18500000.0,
#     'profit_tick': 1850000,
#     'duration': 0,
#     'result': 'WIN'}],
#   'currentprice': 48350.0,
#   'stopprice': 48350.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 18500000.0,
#   'duration': 0,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 172226,
#   'entrydate': Timestamp('2020-02-14 00:00:00'),
#   'name': 'CME Mexican Peso',
#   'symbol': 'MP',
#   'sector': 'currency',
#   'position': -1,
#   'entryprice': 48282.5,
#   'entrylots': 2,
#   'entryrisk': 19750000.0,
#   'entryrisk_ticks': 1975000,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2020-02-14 00:00:00'),
#     'exitprice': 48480.0,
#     'exitlots': 2,
#     'profit': 19750000.0,
#     'profit_tick': 1975000,
#     'duration': 0,
#     'result': 'WIN'}],
#   'currentprice': 48480.0,
#   'stopprice': 48480.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 19750000.0,
#   'duration': 0,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 172272,
#   'entrydate': Timestamp('2020-02-18 00:00:00'),
#   'name': 'CME Mexican Peso',
#   'symbol': 'MP',
#   'sector': 'currency',
#   'position': -1,
#   'entryprice': 48362.5,
#   'entrylots': 2,
#   'entryrisk': 14750000.0,
#   'entryrisk_ticks': 1475000,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2020-02-18 00:00:00'),
#     'exitprice': 48510.0,
#     'exitlots': 2,
#     'profit': 14750000.0,
#     'profit_tick': 1475000,
#     'duration': 0,
#     'result': 'WIN'}],
#   'currentprice': 48510.0,
#   'stopprice': 48510.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 14750000.0,
#   'duration': 0,
#   'exittype': 'stop',
#   'result': 'WIN',
# ...
#   'name': 'CME Mexican Peso',
#   'symbol': 'MP',
#   'sector': 'currency',
#   'position': -1,
#   'entryprice': 48325.0,
#   'entrylots': 2,
#   'entryrisk': 35500000.0,
#   'entryrisk_ticks': 3550000,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2022-03-23 00:00:00'),
#     'exitprice': 48680.0,
#     'exitlots': 2,
#     'profit': 35500000.0,
#     'profit_tick': 3550000,
#     'duration': 1,
#     'result': 'WIN'}],
#   'currentprice': 48680.0,
#   'stopprice': 48680.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 35500000.0,
#   'duration': 1,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 193540,
#   'entrydate': Timestamp('2022-03-23 00:00:00'),
#   'name': 'CME Mexican Peso',
#   'symbol': 'MP',
#   'sector': 'currency',
#   'position': -1,
#   'entryprice': 48557.5,
#   'entrylots': 2,
#   'entryrisk': 32250000.0,
#   'entryrisk_ticks': 3225000,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2022-03-23 00:00:00'),
#     'exitprice': 48880.0,
#     'exitlots': 2,
#     'profit': 32250000.0,
#     'profit_tick': 3225000,
#     'duration': 0,
#     'result': 'WIN'}],
#   'currentprice': 48880.0,
#   'stopprice': 48880.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 32250000.0,
#   'duration': 0,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 193580,
#   'entrydate': Timestamp('2022-03-24 00:00:00'),
#   'name': 'CME Mexican Peso',
#   'symbol': 'MP',
#   'sector': 'currency',
#   'position': -1,
#   'entryprice': 48725.0,
#   'entrylots': 2,
#   'entryrisk': 38500000.0,
#   'entryrisk_ticks': 3850000,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2022-03-24 00:00:00'),
#     'exitprice': 49110.0,
#     'exitlots': 2,
#     'profit': 38500000.0,
#     'profit_tick': 3850000,
#     'duration': 0,
#     'result': 'WIN'}],
#   'currentprice': 49110.0,
#   'stopprice': 49110.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 38500000.0,
#   'duration': 0,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 193620,
#   'entrydate': Timestamp('2022-03-25 00:00:00'),
#   'name': 'CME Mexican Peso',
#   'symbol': 'MP',
#   'sector': 'currency',
#   'position': -1,
#   'entryprice': 49075.0,
#   'entrylots': 2,
#   'entryrisk': 45500000.0,
#   'entryrisk_ticks': 4550000,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2022-03-25 00:00:00'),
#     'exitprice': 49530.0,
#     'exitlots': 2,
#     'profit': 45500000.0,
#     'profit_tick': 4550000,
#     'duration': 0,
#     'result': 'WIN'}],
#   'currentprice': 49530.0,
#   'stopprice': 49530.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 45500000.0,
#   'duration': 0,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 193660,
#   'entrydate': Timestamp('2022-03-28 00:00:00'),
#   'name': 'CME Mexican Peso',
#   'symbol': 'MP',
#   'sector': 'currency',
#   'position': -1,
#   'entryprice': 49120.0,
#   'entrylots': 2,
#   'entryrisk': 41000000.0,
#   'entryrisk_ticks': 4100000,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2022-03-29 00:00:00'),
#     'exitprice': 49530.0,
#     'exitlots': 2,
#     'profit': 41000000.0,
#     'profit_tick': 4100000,
#     'duration': 1,
#     'result': 'WIN'}],
#   'currentprice': 49530.0,
#   'stopprice': 49530.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 41000000.0,
#   'duration': 1,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 193700,
#   'entrydate': Timestamp('2022-03-29 00:00:00'),
#   'name': 'CME Mexican Peso',
#   'symbol': 'MP',
#   'sector': 'currency',
#   'position': -1,
#   'entryprice': 49015.0,
#   'entrylots': 2,
#   'entryrisk': 53500000.0,
#   'entryrisk_ticks': 5350000,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2022-03-29 00:00:00'),
#     'exitprice': 49550.0,
#     'exitlots': 2,
#     'profit': 53500000.0,
#     'profit_tick': 5350000,
#     'duration': 0,
#     'result': 'WIN'}],
#   'currentprice': 49550.0,
#   'stopprice': 49550.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 53500000.0,
#   'duration': 0,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 193740,
#   'entrydate': Timestamp('2022-03-30 00:00:00'),
#   'name': 'CME Mexican Peso',
#   'symbol': 'MP',
#   'sector': 'currency',
#   'position': -1,
#   'entryprice': 49442.5,
#   'entrylots': 2,
#   'entryrisk': 36750000.0,
#   'entryrisk_ticks': 3675000,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2022-03-30 00:00:00'),
#     'exitprice': 49810.0,
#     'exitlots': 2,
#     'profit': 36750000.0,
#     'profit_tick': 3675000,
#     'duration': 0,
#     'result': 'WIN'}],
#   'currentprice': 49810.0,
#   'stopprice': 49810.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 36750000.0,
#   'duration': 0,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 193780,
#   'entrydate': Timestamp('2022-03-31 00:00:00'),
#   'name': 'CME Mexican Peso',
#   'symbol': 'MP',
#   'sector': 'currency',
#   'position': -1,
#   'entryprice': 49615.0,
#   'entrylots': 2,
#   'entryrisk': 22500000.0,
#   'entryrisk_ticks': 2250000,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2022-03-31 00:00:00'),
#     'exitprice': 49840.0,
#     'exitlots': 2,
#     'profit': 22500000.0,
#     'profit_tick': 2250000,
#     'duration': 0,
#     'result': 'WIN'}],
#   'currentprice': 49840.0,
#   'stopprice': 49840.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 22500000.0,
#   'duration': 0,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 193820,
#   'entrydate': Timestamp('2022-04-01 00:00:00'),
#   'name': 'CME Mexican Peso',
#   'symbol': 'MP',
#   'sector': 'currency',
#   'position': -1,
#   'entryprice': 49652.5,
#   'entrylots': 2,
#   'entryrisk': 36750000.0,
#   'entryrisk_ticks': 3675000,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2022-04-01 00:00:00'),
#     'exitprice': 50020.0,
#     'exitlots': 2,
#     'profit': 36750000.0,
#     'profit_tick': 3675000,
#     'duration': 0,
#     'result': 'WIN'}],
#   'currentprice': 50020.0,
#   'stopprice': 50020.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 36750000.0,
#   'duration': 0,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 193860,
#   'entrydate': Timestamp('2022-04-04 00:00:00'),
#   'name': 'CME Mexican Peso',
#   'symbol': 'MP',
#   'sector': 'currency',
#   'position': -1,
#   'entryprice': 49612.5,
#   'entrylots': 2,
#   'entryrisk': 46750000.0,
#   'entryrisk_ticks': 4675000,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2022-04-04 00:00:00'),
#     'exitprice': 50080.0,
#     'exitlots': 2,
#     'profit': 46750000.0,
#     'profit_tick': 4675000,
#     'duration': 0,
#     'result': 'WIN'}],
#   'currentprice': 50080.0,
#   'stopprice': 50080.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 46750000.0,
#   'duration': 0,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 193900,
#   'entrydate': Timestamp('2022-04-05 00:00:00'),
#   'name': 'CME Mexican Peso',
#   'symbol': 'MP',
#   'sector': 'currency',
#   'position': -1,
#   'entryprice': 49745.0,
#   'entrylots': 2,
#   'entryrisk': 33500000.0,
#   'entryrisk_ticks': 3350000,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2022-04-13 00:00:00'),
#     'exitprice': 50080.0,
#     'exitlots': 2,
#     'profit': 33500000.0,
#     'profit_tick': 3350000,
#     'duration': 8,
#     'result': 'WIN'}],
#   'currentprice': 50080.0,
#   'stopprice': 50080.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 33500000.0,
#   'duration': 8,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 193940,
#   'entrydate': Timestamp('2022-04-06 00:00:00'),
#   'name': 'CME Mexican Peso',
#   'symbol': 'MP',
#   'sector': 'currency',
#   'position': -1,
#   'entryprice': 49282.5,
#   'entrylots': 2,
#   'entryrisk': 79750000.0,
#   'entryrisk_ticks': 7975000,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2022-04-13 00:00:00'),
#     'exitprice': 50080.0,
#     'exitlots': 2,
#     'profit': 79750000.0,
#     'profit_tick': 7975000,
#     'duration': 7,
#     'result': 'WIN'}],
#   'currentprice': 50080.0,
#   'stopprice': 50080.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 79750000.0,
#   'duration': 7,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 193980,
#   'entrydate': Timestamp('2022-04-07 00:00:00'),
#   'name': 'CME Mexican Peso',
#   'symbol': 'MP',
#   'sector': 'currency',
#   'position': -1,
#   'entryprice': 48977.5,
#   'entrylots': 2,
#   'entryrisk': 110250000.0,
#   'entryrisk_ticks': 11025000,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2022-04-13 00:00:00'),
#     'exitprice': 50080.0,
#     'exitlots': 2,
#     'profit': 110250000.0,
#     'profit_tick': 11025000,
#     'duration': 6,
#     'result': 'WIN'}],
#   'currentprice': 50080.0,
#   'stopprice': 50080.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 110250000.0,
#   'duration': 6,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 194020,
#   'entrydate': Timestamp('2022-04-08 00:00:00'),
#   'name': 'CME Mexican Peso',
#   'symbol': 'MP',
#   'sector': 'currency',
#   'position': -1,
#   'entryprice': 49067.5,
#   'entrylots': 2,
#   'entryrisk': 101250000.0,
#   'entryrisk_ticks': 10125000,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2022-04-13 00:00:00'),
#     'exitprice': 50080.0,
#     'exitlots': 2,
#     'profit': 101250000.0,
#     'profit_tick': 10125000,
#     'duration': 5,
#     'result': 'WIN'}],
#   'currentprice': 50080.0,
#   'stopprice': 50080.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 101250000.0,
#   'duration': 5,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 194060,
#   'entrydate': Timestamp('2022-04-11 00:00:00'),
#   'name': 'CME Mexican Peso',
#   'symbol': 'MP',
#   'sector': 'currency',
#   'position': -1,
#   'entryprice': 49310.0,
#   'entrylots': 2,
#   'entryrisk': 77000000.0,
#   'entryrisk_ticks': 7700000,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2022-04-13 00:00:00'),
#     'exitprice': 50080.0,
#     'exitlots': 2,
#     'profit': 77000000.0,
#     'profit_tick': 7700000,
#     'duration': 2,
#     'result': 'WIN'}],
#   'currentprice': 50080.0,
#   'stopprice': 50080.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 77000000.0,
#   'duration': 2,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 194100,
#   'entrydate': Timestamp('2022-04-12 00:00:00'),
#   'name': 'CME Mexican Peso',
#   'symbol': 'MP',
#   'sector': 'currency',
#   'position': -1,
#   'entryprice': 49637.5,
#   'entrylots': 2,
#   'entryrisk': 44250000.0,
#   'entryrisk_ticks': 4425000,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2022-04-13 00:00:00'),
#     'exitprice': 50080.0,
#     'exitlots': 2,
#     'profit': 44250000.0,
#     'profit_tick': 4425000,
#     'duration': 1,
#     'result': 'WIN'}],
#   'currentprice': 50080.0,
#   'stopprice': 50080.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 44250000.0,
#   'duration': 1,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 194140,
#   'entrydate': Timestamp('2022-04-13 00:00:00'),
#   'name': 'CME Mexican Peso',
#   'symbol': 'MP',
#   'sector': 'currency',
#   'position': -1,
#   'entryprice': 49935.0,
#   'entrylots': 2,
#   'entryrisk': 20500000.0,
#   'entryrisk_ticks': 2050000,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2022-04-13 00:00:00'),
#     'exitprice': 50140.0,
#     'exitlots': 2,
#     'profit': 20500000.0,
#     'profit_tick': 2050000,
#     'duration': 0,
#     'result': 'WIN'}],
#   'currentprice': 50140.0,
#   'stopprice': 50140.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 20500000.0,
#   'duration': 0,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 194180,
#   'entrydate': Timestamp('2022-04-14 00:00:00'),
#   'name': 'CME Mexican Peso',
#   'symbol': 'MP',
#   'sector': 'currency',
#   'position': -1,
#   'entryprice': 49870.0,
#   'entrylots': 2,
#   'entryrisk': 30000000.0,
#   'entryrisk_ticks': 3000000,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2022-04-14 00:00:00'),
#     'exitprice': 50170.0,
#     'exitlots': 2,
#     'profit': 30000000.0,
#     'profit_tick': 3000000,
#     'duration': 0,
#     'result': 'WIN'}],
#   'currentprice': 50170.0,
#   'stopprice': 50170.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 30000000.0,
#   'duration': 0,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 194380,
#   'entrydate': Timestamp('2022-04-22 00:00:00'),
#   'name': 'CME Mexican Peso',
#   'symbol': 'MP',
#   'sector': 'currency',
#   'position': -1,
#   'entryprice': 48975.0,
#   'entrylots': 2,
#   'entryrisk': 119500000.0,
#   'entryrisk_ticks': 11950000,
#   'exits': [{'exittype': 'exit',
#     'exitdate': Timestamp('2022-04-25 00:00:00'),
#     'exitprice': 48982.5,
#     'exitlots': 2,
#     'profit': 750000.0,
#     'profit_tick': 75000,
#     'duration': 3,
#     'result': 'WIN'}],
#   'currentprice': 48982.5,
#   'stopprice': 50170.0,
#   'risk': 0.0,
#   'risk_ticks': 11875000,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 750000.0,
#   'duration': 3,
#   'exittype': 'exit',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 194420,
#   'entrydate': Timestamp('2022-04-25 00:00:00'),
#   'name': 'CME Mexican Peso',
#   'symbol': 'MP',
#   'sector': 'currency',
#   'position': 1,
#   'entryprice': 48982.5,
#   'entrylots': 2,
#   'entryrisk': 64250000.0,
#   'entryrisk_ticks': 6425000,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2022-04-25 00:00:00'),
#     'exitprice': 48340.0,
#     'exitlots': 2,
#     'profit': 64250000.0,
#     'profit_tick': 6425000,
#     'duration': 0,
#     'result': 'WIN'}],
#   'currentprice': 48340.0,
#   'stopprice': 48340.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 64250000.0,
#   'duration': 0,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 194460,
#   'entrydate': Timestamp('2022-04-26 00:00:00'),
#   'name': 'CME Mexican Peso',
#   'symbol': 'MP',
#   'sector': 'currency',
#   'position': 1,
#   'entryprice': 49002.5,
#   'entrylots': 2,
#   'entryrisk': 66250000.0,
#   'entryrisk_ticks': 6625000,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2022-04-27 00:00:00'),
#     'exitprice': 48340.0,
#     'exitlots': 2,
#     'profit': 66250000.0,
#     'profit_tick': 6625000,
#     'duration': 1,
#     'result': 'WIN'}],
#   'currentprice': 48340.0,
#   'stopprice': 48340.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 66250000.0,
#   'duration': 1,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 194500,
#   'entrydate': Timestamp('2022-04-27 00:00:00'),
#   'name': 'CME Mexican Peso',
#   'symbol': 'MP',
#   'sector': 'currency',
#   'position': 1,
#   'entryprice': 48552.5,
#   'entrylots': 2,
#   'entryrisk': 30250000.0,
#   'entryrisk_ticks': 3025000,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2022-04-27 00:00:00'),
#     'exitprice': 48250.0,
#     'exitlots': 2,
#     'profit': 30250000.0,
#     'profit_tick': 3025000,
#     'duration': 0,
#     'result': 'WIN'}],
#   'currentprice': 48250.0,
#   'stopprice': 48250.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 30250000.0,
#   'duration': 0,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 194540,
#   'entrydate': Timestamp('2022-04-28 00:00:00'),
#   'name': 'CME Mexican Peso',
#   'symbol': 'MP',
#   'sector': 'currency',
#   'position': 1,
#   'entryprice': 48642.5,
#   'entrylots': 2,
#   'entryrisk': 61250000.0,
#   'entryrisk_ticks': 6125000,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2022-04-28 00:00:00'),
#     'exitprice': 48030.0,
#     'exitlots': 2,
#     'profit': 61250000.0,
#     'profit_tick': 6125000,
#     'duration': 0,
#     'result': 'WIN'}],
#   'currentprice': 48030.0,
#   'stopprice': 48030.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 61250000.0,
#   'duration': 0,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False}]

# %%
equitylog = pd.DataFrame(system.equity.log()).set_index('date')
equity = equitylog.groupby(by='date').last()

# %%
trader.quotes['JY'].loc['2017-04-01':]['close'].plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
instruments['JY'].tickunit
# Out:
# 0.5

# %%
trades = system.trades.log()

# %%
trades
# Out:
# [{'id': 1,
#   'entrydate': Timestamp('2011-01-03 00:00:00'),
#   'name': 'CME Australian Dollar AUD',
#   'symbol': 'AD',
#   'sector': 'currency',
#   'position': -1,
#   'entryprice': 0.8676005442619323,
#   'entrylots': 2,
#   'entryrisk': 1060.0,
#   'entryrisk_ticks': 106,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2011-02-01 00:00:00'),
#     'exitprice': 0.8645004034042358,
#     'exitlots': 2,
#     'profit': -620.0,
#     'profit_tick': -62,
#     'duration': 29,
#     'result': 'LOSE'}],
#   'currentprice': 0.8645004034042358,
#   'stopprice': 0.8645004034042358,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': 0.0,
#   'profit': -620.0,
#   'duration': 29,
#   'exittype': 'stop',
#   'result': 'LOSE',
#   'on_fire': False},
#  {'id': 2,
#   'entrydate': Timestamp('2011-01-03 00:00:00'),
#   'name': 'CBOT Soybean Oil',
#   'symbol': 'BO',
#   'sector': 'grain',
#   'position': -1,
#   'entryprice': 64.96999389648437,
#   'entrylots': 2,
#   'entryrisk': 1404.0,
#   'entryrisk_ticks': 117,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2011-01-03 00:00:00'),
#     'exitprice': 66.13999938964844,
#     'exitlots': 2,
#     'profit': 1404.0,
#     'profit_tick': 117,
#     'duration': 0,
#     'result': 'WIN'}],
#   'currentprice': 66.13999938964844,
#   'stopprice': 66.13999938964844,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 1404.0,
#   'duration': 0,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 3,
#   'entrydate': Timestamp('2011-01-03 00:00:00'),
#   'name': 'CME British Pound GBP',
#   'symbol': 'BP',
#   'sector': 'currency',
#   'position': 1,
#   'entryprice': 1.6021996435165404,
#   'entrylots': 2,
#   'entryrisk': 2520.0,
#   'entryrisk_ticks': 210,
#   'exits': [{'exittype': 'exit',
#     'exitdate': Timestamp('2011-01-18 00:00:00'),
#     'exitprice': 1.6336997022628785,
#     'exitlots': 2,
#     'profit': -3780.0,
#     'profit_tick': -315,
#     'duration': 15,
#     'result': 'LOSE'}],
#   'currentprice': 1.6336997022628785,
#   'stopprice': 1.5811996459960938,
#   'risk': 0.0,
#   'risk_ticks': 525,
#   'lots': 0,
#   'flame': 0.0,
#   'profit': -3780.0,
#   'duration': 15,
#   'exittype': 'exit',
#   'result': 'LOSE',
#   'on_fire': False},
#  {'id': 4,
#   'entrydate': Timestamp('2011-01-03 00:00:00'),
#   'name': 'CBOT Corn',
#   'symbol': 'C',
#   'sector': 'grain',
#   'position': -1,
#   'entryprice': 549.75,
#   'entrylots': 2,
#   'entryrisk': 888.0,
#   'entryrisk_ticks': 37,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2011-01-03 00:00:00'),
#     'exitprice': 559.0,
#     'exitlots': 2,
#     'profit': 888.0,
#     'profit_tick': 37,
#     'duration': 0,
#     'result': 'WIN'}],
#   'currentprice': 559.0,
#   'stopprice': 559.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 888.0,
#   'duration': 0,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 5,
#   'entrydate': Timestamp('2011-01-03 00:00:00'),
#   'name': 'CME Canadian Dollar CAD',
#   'symbol': 'CD',
#   'sector': 'currency',
#   'position': -1,
#   'entryprice': 0.9851999267578125,
#   'entrylots': 2,
#   'entryrisk': 1010.0,
#   'entryrisk_ticks': 101,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2011-01-03 00:00:00'),
#     'exitprice': 0.9902498722076416,
#     'exitlots': 2,
#     'profit': 1010.0,
#     'profit_tick': 101,
#     'duration': 0,
#     'result': 'WIN'}],
#   'currentprice': 0.9902498722076416,
#   'stopprice': 0.9902498722076416,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 1010.0,
#   'duration': 0,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 6,
#   'entrydate': Timestamp('2011-01-03 00:00:00'),
#   'name': 'NYMEX WTI Crude Oil',
#   'symbol': 'CL',
#   'sector': 'petroleum',
#   'position': -1,
#   'entryprice': 131.8099560546875,
#   'entrylots': 2,
#   'entryrisk': 2580.0,
#   'entryrisk_ticks': 129,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2011-01-03 00:00:00'),
#     'exitprice': 133.0999755859375,
#     'exitlots': 2,
#     'profit': 2580.0,
#     'profit_tick': 129,
#     'duration': 0,
#     'result': 'WIN'}],
#   'currentprice': 133.0999755859375,
#   'stopprice': 133.0999755859375,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 2580.0,
#   'duration': 0,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 7,
#   'entrydate': Timestamp('2011-01-03 00:00:00'),
#   'name': 'ICE Cotton',
#   'symbol': 'CT',
#   'sector': 'fiber',
#   'position': -1,
#   'entryprice': 98.83998260498046,
#   'entrylots': 2,
#   'entryrisk': 15050.0,
#   'entryrisk_ticks': 1505,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2011-01-21 00:00:00'),
#     'exitprice': 107.7099838256836,
#     'exitlots': 2,
#     'profit': 8870.0,
#     'profit_tick': 887,
#     'duration': 18,
#     'result': 'WIN'}],
#   'currentprice': 107.7099838256836,
#   'stopprice': 107.7099838256836,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 8870.0,
#   'duration': 18,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 8,
#   'entrydate': Timestamp('2011-01-03 00:00:00'),
#   'name': 'ICE US Dollar Index',
#   'symbol': 'DX',
#   'sector': 'currency',
#   'position': 1,
#   'entryprice': 80.1420101928711,
#   'entrylots': 2,
#   'entryrisk': 780.0,
#   'entryrisk_ticks': 78,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2011-01-14 00:00:00'),
#     'exitprice': 79.75201416015625,
#     'exitlots': 2,
#     'profit': 780.0,
#     'profit_tick': 78,
#     'duration': 11,
#     'result': 'WIN'}],
#   'currentprice': 79.75201416015625,
#   'stopprice': 79.75201416015625,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 780.0,
#   'duration': 11,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 9,
#   'entrydate': Timestamp('2011-01-03 00:00:00'),
#   'name': 'CME Euro FX',
#   'symbol': 'EC',
#   'sector': 'currency',
#   'position': 1,
#   'entryprice': 1.4732498836517334,
#   'entrylots': 2,
#   'entryrisk': 7356.0,
#   'entryrisk_ticks': 613,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2011-01-06 00:00:00'),
#     'exitprice': 1.4425997734069824,
#     'exitlots': 2,
#     'profit': 7356.0,
#     'profit_tick': 613,
#     'duration': 3,
#     'result': 'WIN'}],
#   'currentprice': 1.4425997734069824,
#   'stopprice': 1.4425997734069824,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 7356.0,
#   'duration': 3,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 10,
#   'entrydate': Timestamp('2011-01-03 00:00:00'),
#   'name': 'CME S&P 500 Index E-Mini',
#   'symbol': 'ES',
#   'sector': 'equity',
#   'position': -1,
#   'entryprice': 1034.75,
#   'entrylots': 2,
#   'entryrisk': 1608.0,
#   'entryrisk_ticks': 67,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2011-01-03 00:00:00'),
#     'exitprice': 1051.5,
#     'exitlots': 2,
#     'profit': 1608.0,
#     'profit_tick': 67,
#     'duration': 0,
#     'result': 'WIN'}],
#   'currentprice': 1051.5,
#   'stopprice': 1051.5,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 1608.0,
#   'duration': 0,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 11,
#   'entrydate': Timestamp('2011-01-03 00:00:00'),
#   'name': 'CBOT 5-year US Treasury Note',
#   'symbol': 'FV',
#   'sector': 'interest-rate',
#   'position': -1,
#   'entryprice': 101.3046875,
#   'entrylots': 2,
#   'entryrisk': 3934.0,
#   'entryrisk_ticks': 281,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2011-01-07 00:00:00'),
#     'exitprice': 101.8515625,
#     'exitlots': 2,
#     'profit': 980.0,
#     'profit_tick': 70,
#     'duration': 4,
#     'result': 'WIN'}],
#   'currentprice': 101.8515625,
#   'stopprice': 101.8515625,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 980.0,
#   'duration': 4,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 12,
#   'entrydate': Timestamp('2011-01-03 00:00:00'),
#   'name': 'NYMEX Gold',
#   'symbol': 'GC',
#   'sector': 'metal',
#   'position': -1,
#   'entryprice': 1637.40068359375,
#   'entrylots': 2,
#   'entryrisk': 2780.0,
#   'entryrisk_ticks': 139,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2011-02-16 00:00:00'),
#     'exitprice': 1597.70068359375,
#     'exitlots': 2,
#     'profit': -7940.0,
#     'profit_tick': -397,
#     'duration': 44,
#     'result': 'LOSE'}],
#   'currentprice': 1597.70068359375,
#   'stopprice': 1597.70068359375,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': 0.0,
#   'profit': -7940.0,
#   'duration': 44,
#   'exittype': 'stop',
#   'result': 'LOSE',
#   'on_fire': False},
#  {'id': 13,
#   'entrydate': Timestamp('2011-01-03 00:00:00'),
#   'name': 'COMEX Copper',
#   'symbol': 'HG',
#   'sector': 'metal',
#   'position': -1,
#   'entryprice': 4.995001415252686,
#   'entrylots': 2,
#   'entryrisk': 2472.0,
#   'entryrisk_ticks': 103,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2011-01-03 00:00:00'),
#     'exitprice': 5.046501636505127,
#     'exitlots': 2,
#     'profit': 2472.0,
#     'profit_tick': 103,
#     'duration': 0,
#     'result': 'WIN'}],
#   'currentprice': 5.046501636505127,
#   'stopprice': 5.046501636505127,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 2472.0,
#   'duration': 0,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 14,
#   'entrydate': Timestamp('2011-01-03 00:00:00'),
#   'name': 'NYMEX Heating Oil',
#   'symbol': 'HO',
#   'sector': 'petroleum',
#   'position': -1,
#   'entryprice': 2.571001758956909,
#   'entrylots': 2,
#   'entryrisk': 3824.0,
#   'entryrisk_ticks': 478,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2011-01-03 00:00:00'),
#     'exitprice': 2.6188018321990967,
#     'exitlots': 2,
#     'profit': 3824.0,
#     'profit_tick': 478,
#     'duration': 0,
#     'result': 'WIN'}],
#   'currentprice': 2.6188018321990967,
#   'stopprice': 2.6188018321990967,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 3824.0,
#   'duration': 0,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 15,
#   'entrydate': Timestamp('2011-01-03 00:00:00'),
#   'name': 'CME Japanese Yen JPY',
#   'symbol': 'JY',
#   'sector': 'currency',
#   'position': -1,
#   'entryprice': 13418.5,
#   'entrylots': 2,
#   'entryrisk': 1137.5,
#   'entryrisk_ticks': 91,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2011-02-01 00:00:00'),
#     'exitprice': 13362.0,
#     'exitlots': 2,
#     'profit': -1412.5,
#     'profit_tick': -113,
#     'duration': 29,
#     'result': 'LOSE'}],
#   'currentprice': 13362.0,
#   'stopprice': 13362.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': 0.0,
#   'profit': -1412.5,
#   'duration': 29,
#   'exittype': 'stop',
#   'result': 'LOSE',
#   'on_fire': False},
#  {'id': 16,
#   'entrydate': Timestamp('2011-01-03 00:00:00'),
#   'name': 'CME Live Cattle',
#   'symbol': 'LC',
#   'sector': 'meat',
#   'position': -1,
#   'entryprice': 166.99994506835938,
#   'entrylots': 2,
#   'entryrisk': 780.0,
#   'entryrisk_ticks': 39,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2011-01-11 00:00:00'),
#     'exitprice': 167.97494506835938,
#     'exitlots': 2,
#     'profit': 780.0,
#     'profit_tick': 39,
#     'duration': 8,
#     'result': 'WIN'}],
#   'currentprice': 167.97494506835938,
#   'stopprice': 167.97494506835938,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 780.0,
#   'duration': 8,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 17,
#   'entrydate': Timestamp('2011-01-03 00:00:00'),
#   'name': 'CME Lean Hogs',
#   'symbol': 'LN',
#   'sector': 'meat',
#   'position': 1,
#   'entryprice': 169.69998779296876,
#   'entrylots': 2,
#   'entryrisk': 4340.0,
#   'entryrisk_ticks': 217,
#   'exits': [{'exittype': 'exit',
#     'exitdate': Timestamp('2011-01-14 00:00:00'),
#     'exitprice': 171.4250061035156,
#     'exitlots': 2,
#     'profit': -1380.0,
#     'profit_tick': -69,
#     'duration': 11,
#     'result': 'LOSE'}],
#   'currentprice': 171.4250061035156,
#   'stopprice': 164.67498779296875,
#   'risk': 0.0,
#   'risk_ticks': 270,
#   'lots': 0,
#   'flame': 0.0,
#   'profit': -1380.0,
#   'duration': 11,
#   'exittype': 'exit',
#   'result': 'LOSE',
#   'on_fire': False},
#  {'id': 18,
#   'entrydate': Timestamp('2011-01-03 00:00:00'),
#   'name': 'CME S&P 400 Midcap Index',
#   'symbol': 'MD',
#   'sector': 'equity',
#   'position': -1,
#   'entryprice': 808.7498779296875,
#   'entrylots': 2,
#   'entryrisk': 1800.0,
#   'entryrisk_ticks': 90,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2011-01-03 00:00:00'),
#     'exitprice': 817.7498779296875,
#     'exitlots': 2,
#     'profit': 1800.0,
#     'profit_tick': 90,
#     'duration': 0,
#     'result': 'WIN'}],
#   'currentprice': 817.7498779296875,
#   'stopprice': 817.7498779296875,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 1800.0,
#   'duration': 0,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 19,
#   'entrydate': Timestamp('2011-01-03 00:00:00'),
#   'name': 'CME New Zealand Dollar NZD',
#   'symbol': 'NE',
#   'sector': 'currency',
#   'position': -1,
#   'entryprice': 0.6383498514175415,
#   'entrylots': 2,
#   'entryrisk': 1080.0,
#   'entryrisk_ticks': 108,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2011-02-01 00:00:00'),
#     'exitprice': 0.6432498693466187,
#     'exitlots': 2,
#     'profit': 980.0,
#     'profit_tick': 98,
#     'duration': 29,
#     'result': 'WIN'}],
#   'currentprice': 0.6432498693466187,
#   'stopprice': 0.6432498693466187,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 980.0,
#   'duration': 29,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 20,
#   'entrydate': Timestamp('2011-01-03 00:00:00'),
#   'name': 'NYMEX Natural Gas',
#   'symbol': 'NG',
#   'sector': 'petroleum',
#   'position': 1,
#   'entryprice': 12.272000869750977,
#   'entrylots': 2,
#   'entryrisk': 11260.0,
#   'entryrisk_ticks': 563,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2011-01-28 00:00:00'),
#     'exitprice': 12.031000137329102,
#     'exitlots': 2,
#     'profit': 4820.0,
#     'profit_tick': 241,
#     'duration': 25,
#     'result': 'WIN'}],
#   'currentprice': 12.031000137329102,
#   'stopprice': 12.031000137329102,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 4820.0,
#   'duration': 25,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 21,
#   'entrydate': Timestamp('2011-01-03 00:00:00'),
#   'name': 'CME Nikkei 225',
#   'symbol': 'NK',
#   'sector': 'equity',
#   'position': -1,
#   'entryprice': 9660.0,
#   'entrylots': 2,
#   'entryrisk': 2150.0,
#   'entryrisk_ticks': 43,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2011-01-04 00:00:00'),
#     'exitprice': 9875.0,
#     'exitlots': 2,
#     'profit': 2150.0,
#     'profit_tick': 43,
#     'duration': 1,
#     'result': 'WIN'}],
#   'currentprice': 9875.0,
#   'stopprice': 9875.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 2150.0,
#   'duration': 1,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 22,
#   'entrydate': Timestamp('2011-01-03 00:00:00'),
#   'name': 'CME NASDAQ 100 Index Mini',
#   'symbol': 'NQ',
#   'sector': 'equity',
#   'position': -1,
#   'entryprice': 2276.75,
#   'entrylots': 2,
#   'entryrisk': 1920.0,
#   'entryrisk_ticks': 192,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2011-01-03 00:00:00'),
#     'exitprice': 2324.75,
#     'exitlots': 2,
#     'profit': 1920.0,
#     'profit_tick': 192,
#     'duration': 0,
#     'result': 'WIN'}],
#   'currentprice': 2324.75,
#   'stopprice': 2324.75,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 1920.0,
#   'duration': 0,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 23,
#   'entrydate': Timestamp('2011-01-03 00:00:00'),
#   'name': 'ICE Orange Juice',
#   'symbol': 'OJ',
#   'sector': 'tropical',
#   'position': -1,
#   'entryprice': 161.35001220703126,
#   'entrylots': 2,
#   'entryrisk': 2422.0,
#   'entryrisk_ticks': 173,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2011-01-03 00:00:00'),
#     'exitprice': 170.0,
#     'exitlots': 2,
#     'profit': 2422.0,
#     'profit_tick': 173,
#     'duration': 0,
#     'result': 'WIN'}],
#   'currentprice': 170.0,
#   'stopprice': 170.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 2422.0,
#   'duration': 0,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 24,
#   'entrydate': Timestamp('2011-01-03 00:00:00'),
#   'name': 'NYMEX Palladium',
#   'symbol': 'PA',
#   'sector': 'metal',
#   'position': -1,
#   'entryprice': 848.3504028320312,
#   'entrylots': 2,
#   'entryrisk': 1700.0,
#   'entryrisk_ticks': 17,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2011-01-03 00:00:00'),
#     'exitprice': 856.9505004882812,
#     'exitlots': 2,
#     'profit': 1700.0,
#     'profit_tick': 17,
#     'duration': 0,
#     'result': 'WIN'}],
#   'currentprice': 856.9505004882812,
#   'stopprice': 856.9505004882812,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 1700.0,
#   'duration': 0,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 25,
#   'entrydate': Timestamp('2011-01-03 00:00:00'),
#   'name': 'NYMEX Platinum',
#   'symbol': 'PL',
#   'sector': 'metal',
#   'position': -1,
#   'entryprice': 1919.9994140625,
#   'entrylots': 2,
#   'entryrisk': 1620.0,
#   'entryrisk_ticks': 162,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2011-01-03 00:00:00'),
#     'exitprice': 1936.199462890625,
#     'exitlots': 2,
#     'profit': 1620.0,
#     'profit_tick': 162,
#     'duration': 0,
#     'result': 'WIN'}],
#   'currentprice': 1936.199462890625,
#   'stopprice': 1936.199462890625,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 1620.0,
#   'duration': 0,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 26,
#   'entrydate': Timestamp('2011-01-03 00:00:00'),
#   'name': 'NYMEX Gasoline',
#   'symbol': 'RB',
#   'sector': 'petroleum',
#   'position': -1,
#   'entryprice': 1.527701918029785,
#   'entrylots': 2,
#   'entryrisk': 3152.0,
#   'entryrisk_ticks': 394,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2011-01-03 00:00:00'),
#     'exitprice': 1.5671017169952393,
#     'exitlots': 2,
#     'profit': 3152.0,
#     'profit_tick': 394,
#     'duration': 0,
#     'result': 'WIN'}],
#   'currentprice': 1.5671017169952393,
#   'stopprice': 1.5671017169952393,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 3152.0,
#   'duration': 0,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 27,
#   'entrydate': Timestamp('2011-01-03 00:00:00'),
#   'name': 'CBOT Soybeans',
#   'symbol': 'S',
#   'sector': 'grain',
#   'position': -1,
#   'entryprice': 897.75,
#   'entrylots': 2,
#   'entryrisk': 1752.0,
#   'entryrisk_ticks': 73,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2011-01-03 00:00:00'),
#     'exitprice': 916.0,
#     'exitlots': 2,
#     'profit': 1752.0,
#     'profit_tick': 73,
#     'duration': 0,
#     'result': 'WIN'}],
#   'currentprice': 916.0,
#   'stopprice': 916.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 1752.0,
#   'duration': 0,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 28,
#   'entrydate': Timestamp('2011-01-03 00:00:00'),
#   'name': 'CME Swiss Franc CHF',
#   'symbol': 'SF',
#   'sector': 'currency',
#   'position': -1,
#   'entryprice': 1.2429001104354858,
#   'entrylots': 2,
#   'entryrisk': 1416.0,
#   'entryrisk_ticks': 59,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2011-02-02 00:00:00'),
#     'exitprice': 1.2442001104354858,
#     'exitlots': 2,
#     'profit': 312.0,
#     'profit_tick': 13,
#     'duration': 30,
#     'result': 'WIN'}],
#   'currentprice': 1.2442001104354858,
#   'stopprice': 1.2442001104354858,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 312.0,
#   'duration': 30,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 29,
#   'entrydate': Timestamp('2011-01-03 00:00:00'),
#   'name': 'NYMEX Silver',
#   'symbol': 'SI',
#   'sector': 'metal',
#   'position': -1,
#   'entryprice': 34.849007263183594,
#   'entrylots': 2,
#   'entryrisk': 4550.0,
#   'entryrisk_ticks': 91,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2011-01-03 00:00:00'),
#     'exitprice': 35.30400085449219,
#     'exitlots': 2,
#     'profit': 4550.0,
#     'profit_tick': 91,
#     'duration': 0,
#     'result': 'WIN'}],
#   'currentprice': 35.30400085449219,
#   'stopprice': 35.30400085449219,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 4550.0,
#   'duration': 0,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 30,
#   'entrydate': Timestamp('2011-01-03 00:00:00'),
#   'name': 'CBOT Soybean Meal',
#   'symbol': 'SM',
#   'sector': 'grain',
#   'position': -1,
#   'entryprice': 217.6000244140625,
#   'entrylots': 2,
#   'entryrisk': 960.0,
#   'entryrisk_ticks': 48,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2011-01-03 00:00:00'),
#     'exitprice': 222.4000244140625,
#     'exitlots': 2,
#     'profit': 960.0,
#     'profit_tick': 48,
#     'duration': 0,
#     'result': 'WIN'}],
#   'currentprice': 222.4000244140625,
#   'stopprice': 222.4000244140625,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 960.0,
#   'duration': 0,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 31,
#   'entrydate': Timestamp('2011-01-03 00:00:00'),
#   'name': 'CBOT 2-year US Treasury Note',
#   'symbol': 'TU',
#   'sector': 'interest-rate',
#   'position': -1,
#   'entryprice': 104.1820297241211,
#   'entrylots': 2,
#   'entryrisk': 1148.0,
#   'entryrisk_ticks': 82,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2011-01-10 00:00:00'),
#     'exitprice': 104.2601547241211,
#     'exitlots': 2,
#     'profit': 280.0,
#     'profit_tick': 20,
#     'duration': 7,
#     'result': 'WIN'}],
#   'currentprice': 104.2601547241211,
#   'stopprice': 104.2601547241211,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 280.0,
#   'duration': 7,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 32,
#   'entrydate': Timestamp('2011-01-03 00:00:00'),
#   'name': 'CBOT 10-year US Treasury Note',
#   'symbol': 'TY',
#   'sector': 'interest-rate',
#   'position': 1,
#   'entryprice': 95.015625,
#   'entrylots': 2,
#   'entryrisk': 2712.0,
#   'entryrisk_ticks': 113,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2011-02-03 00:00:00'),
#     'exitprice': 94.046875,
#     'exitlots': 2,
#     'profit': 1488.0,
#     'profit_tick': 62,
#     'duration': 31,
#     'result': 'WIN'}],
#   'currentprice': 94.046875,
#   'stopprice': 94.046875,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 1488.0,
#   'duration': 31,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 33,
#   'entrydate': Timestamp('2011-01-03 00:00:00'),
#   'name': 'CBOT 30-year US Treasury Bond',
#   'symbol': 'US',
#   'sector': 'interest-rate',
#   'position': 1,
#   'entryprice': 92.15625,
#   'entrylots': 2,
#   'entryrisk': 6758.0,
#   'entryrisk_ticks': 109,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2011-02-02 00:00:00'),
#     'exitprice': 89.34375,
#     'exitlots': 2,
#     'profit': 5580.0,
#     'profit_tick': 90,
#     'duration': 30,
#     'result': 'WIN'}],
#   'currentprice': 89.34375,
#   'stopprice': 89.34375,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 5580.0,
#   'duration': 30,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 34,
#   'entrydate': Timestamp('2011-01-03 00:00:00'),
#   'name': 'CBOT Wheat',
#   'symbol': 'W',
#   'sector': 'grain',
#   'position': -1,
#   'entryprice': 1434.5,
#   'entrylots': 2,
#   'entryrisk': 3048.0,
#   'entryrisk_ticks': 127,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2011-01-03 00:00:00'),
#     'exitprice': 1466.25,
#     'exitlots': 2,
#     'profit': 3048.0,
#     'profit_tick': 127,
#     'duration': 0,
#     'result': 'WIN'}],
#   'currentprice': 1466.25,
#   'stopprice': 1466.25,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 3048.0,
#   'duration': 0,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 35,
#   'entrydate': Timestamp('2011-01-04 00:00:00'),
#   'name': 'CME Australian Dollar AUD',
#   'symbol': 'AD',
#   'sector': 'currency',
#   'position': -1,
#   'entryprice': 0.8601004592895508,
#   'entrylots': 2,
#   'entryrisk': 2560.0,
#   'entryrisk_ticks': 256,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2011-02-01 00:00:00'),
#     'exitprice': 0.8645004034042358,
#     'exitlots': 2,
#     'profit': 880.0,
#     'profit_tick': 88,
#     'duration': 28,
#     'result': 'WIN'}],
#   'currentprice': 0.8645004034042358,
#   'stopprice': 0.8645004034042358,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 880.0,
#   'duration': 28,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 36,
#   'entrydate': Timestamp('2011-01-04 00:00:00'),
#   'name': 'CBOT Soybean Oil',
#   'symbol': 'BO',
#   'sector': 'grain',
#   'position': -1,
#   'entryprice': 64.36000244140625,
#   'entrylots': 2,
#   'entryrisk': 2136.0,
#   'entryrisk_ticks': 178,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2011-02-02 00:00:00'),
#     'exitprice': 65.88999938964844,
#     'exitlots': 2,
#     'profit': 1836.0,
#     'profit_tick': 153,
#     'duration': 29,
#     'result': 'WIN'}],
#   'currentprice': 65.88999938964844,
#   'stopprice': 65.88999938964844,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 1836.0,
#   'duration': 29,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 37,
#   'entrydate': Timestamp('2011-01-04 00:00:00'),
#   'name': 'CME British Pound GBP',
#   'symbol': 'BP',
#   'sector': 'currency',
#   'position': 1,
#   'entryprice': 1.599299704170227,
#   'entrylots': 2,
#   'entryrisk': 2172.0,
#   'entryrisk_ticks': 181,
#   'exits': [{'exittype': 'exit',
#     'exitdate': Timestamp('2011-01-18 00:00:00'),
#     'exitprice': 1.6336997022628785,
#     'exitlots': 2,
#     'profit': -4128.0,
#     'profit_tick': -344,
#     'duration': 14,
#     'result': 'LOSE'}],
#   'currentprice': 1.6336997022628785,
#   'stopprice': 1.5811996459960938,
#   'risk': 0.0,
#   'risk_ticks': 525,
#   'lots': 0,
#   'flame': 0.0,
#   'profit': -4128.0,
#   'duration': 14,
#   'exittype': 'exit',
#   'result': 'LOSE',
#   'on_fire': False},
#  {'id': 38,
#   'entrydate': Timestamp('2011-01-04 00:00:00'),
#   'name': 'CBOT Corn',
#   'symbol': 'C',
#   'sector': 'grain',
#   'position': -1,
#   'entryprice': 540.75,
#   'entrylots': 2,
#   'entryrisk': 1752.0,
#   'entryrisk_ticks': 73,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2011-01-12 00:00:00'),
#     'exitprice': 559.0,
#     'exitlots': 2,
#     'profit': 1752.0,
#     'profit_tick': 73,
#     'duration': 8,
#     'result': 'WIN'}],
#   'currentprice': 559.0,
#   'stopprice': 559.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 1752.0,
#   'duration': 8,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 39,
#   'entrydate': Timestamp('2011-01-04 00:00:00'),
#   'name': 'ICE Cocoa',
#   'symbol': 'CC',
#   'sector': 'tropical',
#   'position': -1,
#   'entryprice': 3685.0,
#   'entrylots': 2,
#   'entryrisk': 2000.0,
#   'entryrisk_ticks': 100,
#   'exits': [{'exittype': 'exit',
#     'exitdate': Timestamp('2011-01-06 00:00:00'),
#     'exitprice': 3546.0,
#     'exitlots': 2,
#     'profit': -2780.0,
#     'profit_tick': -139,
#     'duration': 2,
#     'result': 'LOSE'}],
#   'currentprice': 3546.0,
#   'stopprice': 3779.0,
#   'risk': 0.0,
#   'risk_ticks': 233,
#   'lots': 0,
#   'flame': 0.0,
#   'profit': -2780.0,
#   'duration': 2,
#   'exittype': 'exit',
#   'result': 'LOSE',
#   'on_fire': False},
#  {'id': 40,
#   'entrydate': Timestamp('2011-01-04 00:00:00'),
#   'name': 'CME Canadian Dollar CAD',
#   'symbol': 'CD',
#   'sector': 'currency',
#   'position': -1,
#   'entryprice': 0.9830999433517456,
#   'entrylots': 2,
#   'entryrisk': 1430.0,
#   'entryrisk_ticks': 143,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2011-01-12 00:00:00'),
#     'exitprice': 0.9902498722076416,
#     'exitlots': 2,
#     'profit': 1430.0,
#     'profit_tick': 143,
#     'duration': 8,
#     'result': 'WIN'}],
#   'currentprice': 0.9902498722076416,
#   'stopprice': 0.9902498722076416,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 1430.0,
#   'duration': 8,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 41,
#   'entrydate': Timestamp('2011-01-04 00:00:00'),
#   'name': 'NYMEX WTI Crude Oil',
#   'symbol': 'CL',
#   'sector': 'petroleum',
#   'position': -1,
#   'entryprice': 131.22995849609376,
#   'entrylots': 2,
#   'entryrisk': 3740.0,
#   'entryrisk_ticks': 187,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2011-02-22 00:00:00'),
#     'exitprice': 132.16995239257812,
#     'exitlots': 2,
#     'profit': 1880.0,
#     'profit_tick': 94,
#     'duration': 49,
#     'result': 'WIN'}],
#   'currentprice': 132.16995239257812,
#   'stopprice': 132.16995239257812,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 1880.0,
#   'duration': 49,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 42,
#   'entrydate': Timestamp('2011-01-04 00:00:00'),
#   'name': 'ICE Cotton',
#   'symbol': 'CT',
#   'sector': 'fiber',
#   'position': -1,
#   'entryprice': 95.65998138427734,
#   'entrylots': 2,
#   'entryrisk': 18230.0,
#   'entryrisk_ticks': 1823,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2011-01-21 00:00:00'),
#     'exitprice': 107.7099838256836,
#     'exitlots': 2,
#     'profit': 12050.0,
#     'profit_tick': 1205,
#     'duration': 17,
#     'result': 'WIN'}],
#   'currentprice': 107.7099838256836,
#   'stopprice': 107.7099838256836,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 12050.0,
#   'duration': 17,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 43,
#   'entrydate': Timestamp('2011-01-04 00:00:00'),
#   'name': 'ICE US Dollar Index',
#   'symbol': 'DX',
#   'sector': 'currency',
#   'position': 1,
#   'entryprice': 80.29701263427734,
#   'entrylots': 2,
#   'entryrisk': 1090.0,
#   'entryrisk_ticks': 109,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2011-01-14 00:00:00'),
#     'exitprice': 79.75201416015625,
#     'exitlots': 2,
#     'profit': 1090.0,
#     'profit_tick': 109,
#     'duration': 10,
#     'result': 'WIN'}],
#   'currentprice': 79.75201416015625,
#   'stopprice': 79.75201416015625,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 1090.0,
#   'duration': 10,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 44,
#   'entrydate': Timestamp('2011-01-04 00:00:00'),
#   'name': 'CME Euro FX',
#   'symbol': 'EC',
#   'sector': 'currency',
#   'position': 1,
#   'entryprice': 1.4745998640060425,
#   'entrylots': 2,
#   'entryrisk': 7680.0,
#   'entryrisk_ticks': 640,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2011-01-06 00:00:00'),
#     'exitprice': 1.4425997734069824,
#     'exitlots': 2,
#     'profit': 7680.0,
#     'profit_tick': 640,
#     'duration': 2,
#     'result': 'WIN'}],
#   'currentprice': 1.4425997734069824,
#   'stopprice': 1.4425997734069824,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 7680.0,
#   'duration': 2,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 45,
#   'entrydate': Timestamp('2011-01-04 00:00:00'),
#   'name': 'CME S&P 500 Index E-Mini',
#   'symbol': 'ES',
#   'sector': 'equity',
#   'position': -1,
#   'entryprice': 1042.25,
#   'entrylots': 2,
#   'entryrisk': 888.0,
#   'entryrisk_ticks': 37,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2011-01-05 00:00:00'),
#     'exitprice': 1051.5,
#     'exitlots': 2,
#     'profit': 888.0,
#     'profit_tick': 37,
#     'duration': 1,
#     'result': 'WIN'}],
#   'currentprice': 1051.5,
#   'stopprice': 1051.5,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 888.0,
#   'duration': 1,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 46,
#   'entrydate': Timestamp('2011-01-04 00:00:00'),
#   'name': 'CBOT 5-year US Treasury Note',
#   'symbol': 'FV',
#   'sector': 'interest-rate',
#   'position': -1,
#   'entryprice': 101.4765625,
#   'entrylots': 2,
#   'entryrisk': 1960.0,
#   'entryrisk_ticks': 140,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2011-01-07 00:00:00'),
#     'exitprice': 101.8515625,
#     'exitlots': 2,
#     'profit': 672.0,
#     'profit_tick': 48,
#     'duration': 3,
#     'result': 'WIN'}],
#   'currentprice': 101.8515625,
#   'stopprice': 101.8515625,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 672.0,
#   'duration': 3,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 47,
#   'entrydate': Timestamp('2011-01-04 00:00:00'),
#   'name': 'NYMEX Gold',
#   'symbol': 'GC',
#   'sector': 'metal',
#   'position': -1,
#   'entryprice': 1623.6007080078125,
#   'entrylots': 2,
#   'entryrisk': 3920.0,
#   'entryrisk_ticks': 196,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2011-02-16 00:00:00'),
#     'exitprice': 1597.70068359375,
#     'exitlots': 2,
#     'profit': -5180.0,
#     'profit_tick': -259,
#     'duration': 43,
#     'result': 'LOSE'}],
#   'currentprice': 1597.70068359375,
#   'stopprice': 1597.70068359375,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': 0.0,
#   'profit': -5180.0,
#   'duration': 43,
#   'exittype': 'stop',
#   'result': 'LOSE',
#   'on_fire': False},
#  {'id': 48,
#   'entrydate': Timestamp('2011-01-04 00:00:00'),
#   'name': 'COMEX Copper',
#   'symbol': 'HG',
#   'sector': 'metal',
#   'position': -1,
#   'entryprice': 4.962502185821533,
#   'entrylots': 2,
#   'entryrisk': 4032.0,
#   'entryrisk_ticks': 168,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2011-02-01 00:00:00'),
#     'exitprice': 5.016002178192139,
#     'exitlots': 2,
#     'profit': 2568.0,
#     'profit_tick': 107,
#     'duration': 28,
#     'result': 'WIN'}],
#   'currentprice': 5.016002178192139,
#   'stopprice': 5.016002178192139,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 2568.0,
#   'duration': 28,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 49,
#   'entrydate': Timestamp('2011-01-04 00:00:00'),
#   'name': 'NYMEX Heating Oil',
#   'symbol': 'HO',
#   'sector': 'petroleum',
#   'position': -1,
#   'entryprice': 2.5678021808624267,
#   'entrylots': 2,
#   'entryrisk': 4080.0,
#   'entryrisk_ticks': 510,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2011-01-11 00:00:00'),
#     'exitprice': 2.6188018321990967,
#     'exitlots': 2,
#     'profit': 4080.0,
#     'profit_tick': 510,
#     'duration': 7,
#     'result': 'WIN'}],
#   'currentprice': 2.6188018321990967,
#   'stopprice': 2.6188018321990967,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 4080.0,
#   'duration': 7,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 50,
#   'entrydate': Timestamp('2011-01-04 00:00:00'),
#   'name': 'CME Japanese Yen JPY',
#   'symbol': 'JY',
#   'sector': 'currency',
#   'position': -1,
#   'entryprice': 13324.0,
#   'entrylots': 2,
#   'entryrisk': 3500.0,
#   'entryrisk_ticks': 280,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2011-02-01 00:00:00'),
#     'exitprice': 13362.0,
#     'exitlots': 2,
#     'profit': 950.0,
#     'profit_tick': 76,
#     'duration': 28,
#     'result': 'WIN'}],
#   'currentprice': 13362.0,
#   'stopprice': 13362.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 950.0,
#   'duration': 28,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 51,
#   'entrydate': Timestamp('2011-01-04 00:00:00'),
#   'name': 'ICE Coffee C',
#   'symbol': 'KC',
#   'sector': 'tropical',
#   'position': -1,
#   'entryprice': 389.49981689453125,
#   'entrylots': 2,
#   'entryrisk': 3600.0,
#   'entryrisk_ticks': 100,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2011-01-12 00:00:00'),
#     'exitprice': 394.49981689453125,
#     'exitlots': 2,
#     'profit': 3600.0,
#     'profit_tick': 100,
#     'duration': 8,
#     'result': 'WIN'}],
#   'currentprice': 394.49981689453125,
#   'stopprice': 394.49981689453125,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 3600.0,
#   'duration': 8,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 52,
#   'entrydate': Timestamp('2011-01-04 00:00:00'),
#   'name': 'CME Live Cattle',
#   'symbol': 'LC',
#   'sector': 'meat',
#   'position': -1,
#   'entryprice': 165.8749572753906,
#   'entrylots': 2,
#   'entryrisk': 1680.0,
#   'entryrisk_ticks': 84,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2011-01-11 00:00:00'),
#     'exitprice': 167.97494506835938,
#     'exitlots': 2,
#     'profit': 1680.0,
#     'profit_tick': 84,
#     'duration': 7,
#     'result': 'WIN'}],
#   'currentprice': 167.97494506835938,
#   'stopprice': 167.97494506835938,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 1680.0,
#   'duration': 7,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 53,
#   'entrydate': Timestamp('2011-01-04 00:00:00'),
#   'name': 'CME Lean Hogs',
#   'symbol': 'LN',
#   'sector': 'meat',
#   'position': 1,
#   'entryprice': 168.17501220703124,
#   'entrylots': 2,
#   'entryrisk': 3120.0,
#   'entryrisk_ticks': 156,
#   'exits': [{'exittype': 'exit',
#     'exitdate': Timestamp('2011-01-14 00:00:00'),
#     'exitprice': 171.4250061035156,
#     'exitlots': 2,
#     'profit': -2600.0,
#     'profit_tick': -130,
#     'duration': 10,
#     'result': 'LOSE'}],
#   'currentprice': 171.4250061035156,
#   'stopprice': 164.67498779296875,
#   'risk': 0.0,
#   'risk_ticks': 270,
#   'lots': 0,
#   'flame': 0.0,
#   'profit': -2600.0,
#   'duration': 10,
#   'exittype': 'exit',
#   'result': 'LOSE',
#   'on_fire': False},
#  {'id': 54,
#   'entrydate': Timestamp('2011-01-04 00:00:00'),
#   'name': 'CME S&P 400 Midcap Index',
#   'symbol': 'MD',
#   'sector': 'equity',
#   'position': -1,
#   'entryprice': 812.3498779296875,
#   'entrylots': 2,
#   'entryrisk': 1080.0,
#   'entryrisk_ticks': 54,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2011-01-12 00:00:00'),
#     'exitprice': 817.7498779296875,
#     'exitlots': 2,
#     'profit': 1080.0,
#     'profit_tick': 54,
#     'duration': 8,
#     'result': 'WIN'}],
#   'currentprice': 817.7498779296875,
#   'stopprice': 817.7498779296875,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 1080.0,
#   'duration': 8,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 55,
#   'entrydate': Timestamp('2011-01-04 00:00:00'),
#   'name': 'CME New Zealand Dollar NZD',
#   'symbol': 'NE',
#   'sector': 'currency',
#   'position': -1,
#   'entryprice': 0.6330498697280884,
#   'entrylots': 2,
#   'entryrisk': 2140.0,
#   'entryrisk_ticks': 214,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2011-02-01 00:00:00'),
#     'exitprice': 0.6432498693466187,
#     'exitlots': 2,
#     'profit': 2040.0,
#     'profit_tick': 204,
#     'duration': 28,
#     'result': 'WIN'}],
#   'currentprice': 0.6432498693466187,
#   'stopprice': 0.6432498693466187,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 2040.0,
#   'duration': 28,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 56,
#   'entrydate': Timestamp('2011-01-04 00:00:00'),
#   'name': 'NYMEX Natural Gas',
#   'symbol': 'NG',
#   'sector': 'petroleum',
#   'position': 1,
#   'entryprice': 12.328000305175781,
#   'entrylots': 2,
#   'entryrisk': 12380.0,
#   'entryrisk_ticks': 619,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2011-01-28 00:00:00'),
#     'exitprice': 12.031000137329102,
#     'exitlots': 2,
#     'profit': 5940.0,
#     'profit_tick': 297,
#     'duration': 24,
#     'result': 'WIN'}],
#   'currentprice': 12.031000137329102,
#   'stopprice': 12.031000137329102,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 5940.0,
#   'duration': 24,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 57,
#   'entrydate': Timestamp('2011-01-04 00:00:00'),
#   'name': 'CME Nikkei 225',
#   'symbol': 'NK',
#   'sector': 'equity',
#   'position': -1,
#   'entryprice': 9795.0,
#   'entrylots': 2,
#   'entryrisk': 950.0,
#   'entryrisk_ticks': 19,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2011-01-04 00:00:00'),
#     'exitprice': 9890.0,
#     'exitlots': 2,
#     'profit': 950.0,
#     'profit_tick': 19,
#     'duration': 0,
#     'result': 'WIN'}],
#   'currentprice': 9890.0,
#   'stopprice': 9890.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 950.0,
#   'duration': 0,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 58,
#   'entrydate': Timestamp('2011-01-04 00:00:00'),
#   'name': 'CME NASDAQ 100 Index Mini',
#   'symbol': 'NQ',
#   'sector': 'equity',
#   'position': -1,
#   'entryprice': 2303.5,
#   'entrylots': 2,
#   'entryrisk': 850.0,
#   'entryrisk_ticks': 85,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2011-01-05 00:00:00'),
#     'exitprice': 2324.75,
#     'exitlots': 2,
#     'profit': 850.0,
#     'profit_tick': 85,
#     'duration': 1,
#     'result': 'WIN'}],
#   'currentprice': 2324.75,
#   'stopprice': 2324.75,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 850.0,
#   'duration': 1,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 59,
#   'entrydate': Timestamp('2011-01-04 00:00:00'),
#   'name': 'ICE Orange Juice',
#   'symbol': 'OJ',
#   'sector': 'tropical',
#   'position': -1,
#   'entryprice': 168.90000610351564,
#   'entrylots': 2,
#   'entryrisk': 2338.0,
#   'entryrisk_ticks': 167,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2011-01-04 00:00:00'),
#     'exitprice': 177.25,
#     'exitlots': 2,
#     'profit': 2338.0,
#     'profit_tick': 167,
#     'duration': 0,
#     'result': 'WIN'}],
#   'currentprice': 177.25,
#   'stopprice': 177.25,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 2338.0,
#   'duration': 0,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 60,
#   'entrydate': Timestamp('2011-01-04 00:00:00'),
#   'name': 'NYMEX Palladium',
#   'symbol': 'PA',
#   'sector': 'metal',
#   'position': -1,
#   'entryprice': 833.5504760742188,
#   'entrylots': 2,
#   'entryrisk': 4700.0,
#   'entryrisk_ticks': 47,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2011-01-12 00:00:00'),
#     'exitprice': 856.9505004882812,
#     'exitlots': 2,
#     'profit': 4700.0,
#     'profit_tick': 47,
#     'duration': 8,
#     'result': 'WIN'}],
#   'currentprice': 856.9505004882812,
#   'stopprice': 856.9505004882812,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 4700.0,
#   'duration': 8,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 61,
#   'entrydate': Timestamp('2011-01-04 00:00:00'),
#   'name': 'NYMEX Platinum',
#   'symbol': 'PL',
#   'sector': 'metal',
#   'position': -1,
#   'entryprice': 1909.59931640625,
#   'entrylots': 2,
#   'entryrisk': 2660.0,
#   'entryrisk_ticks': 266,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2011-01-12 00:00:00'),
#     'exitprice': 1936.199462890625,
#     'exitlots': 2,
#     'profit': 2660.0,
#     'profit_tick': 266,
#     'duration': 8,
#     'result': 'WIN'}],
#   'currentprice': 1936.199462890625,
#   'stopprice': 1936.199462890625,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 2660.0,
#   'duration': 8,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 62,
#   'entrydate': Timestamp('2011-01-04 00:00:00'),
#   'name': 'NYMEX Gasoline',
#   'symbol': 'RB',
#   'sector': 'petroleum',
#   'position': -1,
#   'entryprice': 1.5124017642974854,
#   'entrylots': 2,
#   'entryrisk': 4376.0,
#   'entryrisk_ticks': 547,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2011-01-06 00:00:00'),
#     'exitprice': 1.5671017169952393,
#     'exitlots': 2,
#     'profit': 4376.0,
#     'profit_tick': 547,
#     'duration': 2,
#     'result': 'WIN'}],
#   'currentprice': 1.5671017169952393,
#   'stopprice': 1.5671017169952393,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 4376.0,
#   'duration': 2,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 63,
#   'entrydate': Timestamp('2011-01-04 00:00:00'),
#   'name': 'CBOT Soybeans',
#   'symbol': 'S',
#   'sector': 'grain',
#   'position': -1,
#   'entryprice': 880.0,
#   'entrylots': 2,
#   'entryrisk': 3456.0,
#   'entryrisk_ticks': 144,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2011-01-12 00:00:00'),
#     'exitprice': 916.0,
#     'exitlots': 2,
#     'profit': 3456.0,
#     'profit_tick': 144,
#     'duration': 8,
#     'result': 'WIN'}],
#   'currentprice': 916.0,
#   'stopprice': 916.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 3456.0,
#   'duration': 8,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 64,
#   'entrydate': Timestamp('2011-01-04 00:00:00'),
#   'name': 'ICE Sugar No. 11',
#   'symbol': 'SB',
#   'sector': 'tropical',
#   'position': -1,
#   'entryprice': 35.47001220703125,
#   'entrylots': 2,
#   'entryrisk': 6556.0,
#   'entryrisk_ticks': 298,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2011-01-27 00:00:00'),
#     'exitprice': 38.03001403808594,
#     'exitlots': 2,
#     'profit': 5632.0,
#     'profit_tick': 256,
#     'duration': 23,
#     'result': 'WIN'}],
#   'currentprice': 38.03001403808594,
#   'stopprice': 38.03001403808594,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 5632.0,
#   'duration': 23,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 65,
#   'entrydate': Timestamp('2011-01-04 00:00:00'),
#   'name': 'CME Swiss Franc CHF',
#   'symbol': 'SF',
#   'sector': 'currency',
#   'position': -1,
#   'entryprice': 1.2392000078201293,
#   'entrylots': 2,
#   'entryrisk': 2304.0,
#   'entryrisk_ticks': 96,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2011-02-02 00:00:00'),
#     'exitprice': 1.2442001104354858,
#     'exitlots': 2,
#     'profit': 1200.0,
#     'profit_tick': 50,
#     'duration': 29,
#     'result': 'WIN'}],
#   'currentprice': 1.2442001104354858,
#   'stopprice': 1.2442001104354858,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 1200.0,
#   'duration': 29,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 66,
#   'entrydate': Timestamp('2011-01-04 00:00:00'),
#   'name': 'NYMEX Silver',
#   'symbol': 'SI',
#   'sector': 'metal',
#   'position': -1,
#   'entryprice': 34.41400482177735,
#   'entrylots': 2,
#   'entryrisk': 8900.0,
#   'entryrisk_ticks': 178,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2011-02-08 00:00:00'),
#     'exitprice': 33.87400817871094,
#     'exitlots': 2,
#     'profit': -5400.0,
#     'profit_tick': -108,
#     'duration': 35,
#     'result': 'LOSE'}],
#   'currentprice': 33.87400817871094,
#   'stopprice': 33.87400817871094,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': 0.0,
#   'profit': -5400.0,
#   'duration': 35,
#   'exittype': 'stop',
#   'result': 'LOSE',
#   'on_fire': False},
#  {'id': 67,
#   'entrydate': Timestamp('2011-01-04 00:00:00'),
#   'name': 'CBOT Soybean Meal',
#   'symbol': 'SM',
#   'sector': 'grain',
#   'position': -1,
#   'entryprice': 213.40003662109376,
#   'entrylots': 2,
#   'entryrisk': 1800.0,
#   'entryrisk_ticks': 90,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2011-01-12 00:00:00'),
#     'exitprice': 222.4000244140625,
#     'exitlots': 2,
#     'profit': 1800.0,
#     'profit_tick': 90,
#     'duration': 8,
#     'result': 'WIN'}],
#   'currentprice': 222.4000244140625,
#   'stopprice': 222.4000244140625,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 1800.0,
#   'duration': 8,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 68,
#   'entrydate': Timestamp('2011-01-04 00:00:00'),
#   'name': 'CBOT 2-year US Treasury Note',
#   'symbol': 'TU',
#   'sector': 'interest-rate',
#   'position': -1,
#   'entryprice': 104.2054672241211,
#   'entrylots': 2,
#   'entryrisk': 280.0,
#   'entryrisk_ticks': 20,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2011-01-10 00:00:00'),
#     'exitprice': 104.2601547241211,
#     'exitlots': 2,
#     'profit': 196.0,
#     'profit_tick': 14,
#     'duration': 6,
#     'result': 'WIN'}],
#   'currentprice': 104.2601547241211,
#   'stopprice': 104.2601547241211,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 196.0,
#   'duration': 6,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 69,
#   'entrydate': Timestamp('2011-01-04 00:00:00'),
#   'name': 'CBOT 10-year US Treasury Note',
#   'symbol': 'TY',
#   'sector': 'interest-rate',
#   'position': 1,
# ...
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 978,
#   'entrydate': Timestamp('2011-02-09 00:00:00'),
#   'name': 'CME Japanese Yen JPY',
#   'symbol': 'JY',
#   'sector': 'currency',
#   'position': -1,
#   'entryprice': 13237.5,
#   'entrylots': 2,
#   'entryrisk': 5062.5,
#   'entryrisk_ticks': 405,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2011-03-14 00:00:00'),
#     'exitprice': 13360.0,
#     'exitlots': 2,
#     'profit': 3062.5,
#     'profit_tick': 245,
#     'duration': 33,
#     'result': 'WIN'}],
#   'currentprice': 13360.0,
#   'stopprice': 13360.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 3062.5,
#   'duration': 33,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 979,
#   'entrydate': Timestamp('2011-02-09 00:00:00'),
#   'name': 'ICE Coffee C',
#   'symbol': 'KC',
#   'sector': 'tropical',
#   'position': -1,
#   'entryprice': 400.74981689453125,
#   'entrylots': 2,
#   'entryrisk': 3996.0,
#   'entryrisk_ticks': 111,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2011-02-09 00:00:00'),
#     'exitprice': 406.2998046875,
#     'exitlots': 2,
#     'profit': 3996.0,
#     'profit_tick': 111,
#     'duration': 0,
#     'result': 'WIN'}],
#   'currentprice': 406.2998046875,
#   'stopprice': 406.2998046875,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 3996.0,
#   'duration': 0,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 980,
#   'entrydate': Timestamp('2011-02-09 00:00:00'),
#   'name': 'CME Live Cattle',
#   'symbol': 'LC',
#   'sector': 'meat',
#   'position': -1,
#   'entryprice': 166.02493896484376,
#   'entrylots': 2,
#   'entryrisk': 4200.0,
#   'entryrisk_ticks': 210,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2011-03-09 00:00:00'),
#     'exitprice': 170.29995727539062,
#     'exitlots': 2,
#     'profit': 3420.0,
#     'profit_tick': 171,
#     'duration': 28,
#     'result': 'WIN'}],
#   'currentprice': 170.29995727539062,
#   'stopprice': 170.29995727539062,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 3420.0,
#   'duration': 28,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 981,
#   'entrydate': Timestamp('2011-02-09 00:00:00'),
#   'name': 'CME Lean Hogs',
#   'symbol': 'LN',
#   'sector': 'meat',
#   'position': -1,
#   'entryprice': 176.225,
#   'entrylots': 2,
#   'entryrisk': 2760.0,
#   'entryrisk_ticks': 138,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2011-02-16 00:00:00'),
#     'exitprice': 179.67498779296875,
#     'exitlots': 2,
#     'profit': 2760.0,
#     'profit_tick': 138,
#     'duration': 7,
#     'result': 'WIN'}],
#   'currentprice': 179.67498779296875,
#   'stopprice': 179.67498779296875,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 2760.0,
#   'duration': 7,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 982,
#   'entrydate': Timestamp('2011-02-09 00:00:00'),
#   'name': 'CME S&P 400 Midcap Index',
#   'symbol': 'MD',
#   'sector': 'equity',
#   'position': -1,
#   'entryprice': 848.8498779296875,
#   'entrylots': 2,
#   'entryrisk': 700.0,
#   'entryrisk_ticks': 35,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2011-02-10 00:00:00'),
#     'exitprice': 852.349853515625,
#     'exitlots': 2,
#     'profit': 700.0,
#     'profit_tick': 35,
#     'duration': 1,
#     'result': 'WIN'}],
#   'currentprice': 852.349853515625,
#   'stopprice': 852.349853515625,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 700.0,
#   'duration': 1,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 983,
#   'entrydate': Timestamp('2011-02-09 00:00:00'),
#   'name': 'CME New Zealand Dollar NZD',
#   'symbol': 'NE',
#   'sector': 'currency',
#   'position': -1,
#   'entryprice': 0.638049861240387,
#   'entrylots': 2,
#   'entryrisk': 1800.0,
#   'entryrisk_ticks': 180,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2011-03-25 00:00:00'),
#     'exitprice': 0.6208498477935791,
#     'exitlots': 2,
#     'profit': -3440.0,
#     'profit_tick': -344,
#     'duration': 44,
#     'result': 'LOSE'}],
#   'currentprice': 0.6208498477935791,
#   'stopprice': 0.6208498477935791,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': 0.0,
#   'profit': -3440.0,
#   'duration': 44,
#   'exittype': 'stop',
#   'result': 'LOSE',
#   'on_fire': False},
#  {'id': 984,
#   'entrydate': Timestamp('2011-02-09 00:00:00'),
#   'name': 'NYMEX Natural Gas',
#   'symbol': 'NG',
#   'sector': 'petroleum',
#   'position': 1,
#   'entryprice': 11.805997589111328,
#   'entrylots': 2,
#   'entryrisk': 1700.0,
#   'entryrisk_ticks': 85,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2011-02-09 00:00:00'),
#     'exitprice': 11.720998764038086,
#     'exitlots': 2,
#     'profit': 1700.0,
#     'profit_tick': 85,
#     'duration': 0,
#     'result': 'WIN'}],
#   'currentprice': 11.720998764038086,
#   'stopprice': 11.720998764038086,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 1700.0,
#   'duration': 0,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 985,
#   'entrydate': Timestamp('2011-02-09 00:00:00'),
#   'name': 'CME Nikkei 225',
#   'symbol': 'NK',
#   'sector': 'equity',
#   'position': -1,
#   'entryprice': 10095.0,
#   'entrylots': 2,
#   'entryrisk': 400.0,
#   'entryrisk_ticks': 8,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2011-02-09 00:00:00'),
#     'exitprice': 10135.0,
#     'exitlots': 2,
#     'profit': 400.0,
#     'profit_tick': 8,
#     'duration': 0,
#     'result': 'WIN'}],
#   'currentprice': 10135.0,
#   'stopprice': 10135.0,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 400.0,
#   'duration': 0,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 986,
#   'entrydate': Timestamp('2011-02-09 00:00:00'),
#   'name': 'CME NASDAQ 100 Index Mini',
#   'symbol': 'NQ',
#   'sector': 'equity',
#   'position': -1,
#   'entryprice': 2416.5,
#   'entrylots': 2,
#   'entryrisk': 240.0,
#   'entryrisk_ticks': 24,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2011-02-09 00:00:00'),
#     'exitprice': 2422.5,
#     'exitlots': 2,
#     'profit': 240.0,
#     'profit_tick': 24,
#     'duration': 0,
#     'result': 'WIN'}],
#   'currentprice': 2422.5,
#   'stopprice': 2422.5,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 240.0,
#   'duration': 0,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 987,
#   'entrydate': Timestamp('2011-02-09 00:00:00'),
#   'name': 'ICE Orange Juice',
#   'symbol': 'OJ',
#   'sector': 'tropical',
#   'position': -1,
#   'entryprice': 165.95001220703125,
#   'entrylots': 2,
#   'entryrisk': 2086.0,
#   'entryrisk_ticks': 149,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2011-02-22 00:00:00'),
#     'exitprice': 171.95001220703125,
#     'exitlots': 2,
#     'profit': 1680.0,
#     'profit_tick': 120,
#     'duration': 13,
#     'result': 'WIN'}],
#   'currentprice': 171.95001220703125,
#   'stopprice': 171.95001220703125,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 1680.0,
#   'duration': 13,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 988,
#   'entrydate': Timestamp('2011-02-09 00:00:00'),
#   'name': 'NYMEX Palladium',
#   'symbol': 'PA',
#   'sector': 'metal',
#   'position': -1,
#   'entryprice': 882.6004028320312,
#   'entrylots': 2,
#   'entryrisk': 1000.0,
#   'entryrisk_ticks': 10,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2011-02-09 00:00:00'),
#     'exitprice': 887.5504760742188,
#     'exitlots': 2,
#     'profit': 1000.0,
#     'profit_tick': 10,
#     'duration': 0,
#     'result': 'WIN'}],
#   'currentprice': 887.5504760742188,
#   'stopprice': 887.5504760742188,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 1000.0,
#   'duration': 0,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 989,
#   'entrydate': Timestamp('2011-02-09 00:00:00'),
#   'name': 'NYMEX Platinum',
#   'symbol': 'PL',
#   'sector': 'metal',
#   'position': -1,
#   'entryprice': 2001.6994140625,
#   'entrylots': 2,
#   'entryrisk': 1070.0,
#   'entryrisk_ticks': 107,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2011-02-09 00:00:00'),
#     'exitprice': 2012.3994140625,
#     'exitlots': 2,
#     'profit': 1070.0,
#     'profit_tick': 107,
#     'duration': 0,
#     'result': 'WIN'}],
#   'currentprice': 2012.3994140625,
#   'stopprice': 2012.3994140625,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 1070.0,
#   'duration': 0,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 990,
#   'entrydate': Timestamp('2011-02-09 00:00:00'),
#   'name': 'NYMEX Gasoline',
#   'symbol': 'RB',
#   'sector': 'petroleum',
#   'position': -1,
#   'entryprice': 1.5807017402648926,
#   'entrylots': 2,
#   'entryrisk': 3168.0,
#   'entryrisk_ticks': 396,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2011-02-10 00:00:00'),
#     'exitprice': 1.6203017234802246,
#     'exitlots': 2,
#     'profit': 3168.0,
#     'profit_tick': 396,
#     'duration': 1,
#     'result': 'WIN'}],
#   'currentprice': 1.6203017234802246,
#   'stopprice': 1.6203017234802246,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 3168.0,
#   'duration': 1,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 991,
#   'entrydate': Timestamp('2011-02-09 00:00:00'),
#   'name': 'CBOT Soybeans',
#   'symbol': 'S',
#   'sector': 'grain',
#   'position': -1,
#   'entryprice': 943.5,
#   'entrylots': 2,
#   'entryrisk': 1848.0,
#   'entryrisk_ticks': 77,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2011-02-09 00:00:00'),
#     'exitprice': 962.75,
#     'exitlots': 2,
#     'profit': 1848.0,
#     'profit_tick': 77,
#     'duration': 0,
#     'result': 'WIN'}],
#   'currentprice': 962.75,
#   'stopprice': 962.75,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 1848.0,
#   'duration': 0,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 992,
#   'entrydate': Timestamp('2011-02-09 00:00:00'),
#   'name': 'ICE Sugar No. 11',
#   'symbol': 'SB',
#   'sector': 'tropical',
#   'position': -1,
#   'entryprice': 34.69001251220703,
#   'entrylots': 2,
#   'entryrisk': 11154.0,
#   'entryrisk_ticks': 507,
#   'exits': [],
#   'currentprice': 29.740005493164062,
#   'stopprice': 33.44001007080078,
#   'risk': 8140.0,
#   'risk_ticks': 370,
#   'lots': 2,
#   'flame': 10890.0,
#   'profit': 0,
#   'duration': 0,
#   'exittype': '',
#   'result': '',
#   'on_fire': True},
#  {'id': 993,
#   'entrydate': Timestamp('2011-02-09 00:00:00'),
#   'name': 'CME Swiss Franc CHF',
#   'symbol': 'SF',
#   'sector': 'currency',
#   'position': -1,
#   'entryprice': 1.2101001874923707,
#   'entrylots': 2,
#   'entryrisk': 8352.0,
#   'entryrisk_ticks': 348,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2011-02-23 00:00:00'),
#     'exitprice': 1.244900107383728,
#     'exitlots': 2,
#     'profit': 8352.0,
#     'profit_tick': 348,
#     'duration': 14,
#     'result': 'WIN'}],
#   'currentprice': 1.244900107383728,
#   'stopprice': 1.244900107383728,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 8352.0,
#   'duration': 14,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 994,
#   'entrydate': Timestamp('2011-02-09 00:00:00'),
#   'name': 'NYMEX Silver',
#   'symbol': 'SI',
#   'sector': 'metal',
#   'position': -1,
#   'entryprice': 34.274004516601565,
#   'entrylots': 2,
#   'entryrisk': 2550.0,
#   'entryrisk_ticks': 51,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2011-02-09 00:00:00'),
#     'exitprice': 34.52900695800781,
#     'exitlots': 2,
#     'profit': 2550.0,
#     'profit_tick': 51,
#     'duration': 0,
#     'result': 'WIN'}],
#   'currentprice': 34.52900695800781,
#   'stopprice': 34.52900695800781,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 2550.0,
#   'duration': 0,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 995,
#   'entrydate': Timestamp('2011-02-09 00:00:00'),
#   'name': 'CBOT Soybean Meal',
#   'symbol': 'SM',
#   'sector': 'grain',
#   'position': -1,
#   'entryprice': 232.50003051757812,
#   'entrylots': 2,
#   'entryrisk': 1020.0,
#   'entryrisk_ticks': 51,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2011-03-31 00:00:00'),
#     'exitprice': 217.70004272460938,
#     'exitlots': 2,
#     'profit': -2960.0,
#     'profit_tick': -148,
#     'duration': 50,
#     'result': 'LOSE'}],
#   'currentprice': 217.70004272460938,
#   'stopprice': 217.70004272460938,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': 0.0,
#   'profit': -2960.0,
#   'duration': 50,
#   'exittype': 'stop',
#   'result': 'LOSE',
#   'on_fire': False},
#  {'id': 996,
#   'entrydate': Timestamp('2011-02-09 00:00:00'),
#   'name': 'CBOT 2-year US Treasury Note',
#   'symbol': 'TU',
#   'sector': 'interest-rate',
#   'position': -1,
#   'entryprice': 103.7914047241211,
#   'entrylots': 2,
#   'entryrisk': 2324.0,
#   'entryrisk_ticks': 166,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2011-03-02 00:00:00'),
#     'exitprice': 104.3617172241211,
#     'exitlots': 2,
#     'profit': 2044.0,
#     'profit_tick': 146,
#     'duration': 21,
#     'result': 'WIN'}],
#   'currentprice': 104.3617172241211,
#   'stopprice': 104.3617172241211,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 2044.0,
#   'duration': 21,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 997,
#   'entrydate': Timestamp('2011-02-09 00:00:00'),
#   'name': 'CBOT 10-year US Treasury Note',
#   'symbol': 'TY',
#   'sector': 'interest-rate',
#   'position': 1,
#   'entryprice': 92.796875,
#   'entrylots': 2,
#   'entryrisk': 600.0,
#   'entryrisk_ticks': 25,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2011-02-09 00:00:00'),
#     'exitprice': 92.40625,
#     'exitlots': 2,
#     'profit': 600.0,
#     'profit_tick': 25,
#     'duration': 0,
#     'result': 'WIN'}],
#   'currentprice': 92.40625,
#   'stopprice': 92.40625,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 600.0,
#   'duration': 0,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 998,
#   'entrydate': Timestamp('2011-02-09 00:00:00'),
#   'name': 'CBOT 30-year US Treasury Bond',
#   'symbol': 'US',
#   'sector': 'interest-rate',
#   'position': 1,
#   'entryprice': 87.65625,
#   'entrylots': 2,
#   'entryrisk': 1488.0,
#   'entryrisk_ticks': 24,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2011-02-09 00:00:00'),
#     'exitprice': 86.90625,
#     'exitlots': 2,
#     'profit': 1488.0,
#     'profit_tick': 24,
#     'duration': 0,
#     'result': 'WIN'}],
#   'currentprice': 86.90625,
#   'stopprice': 86.90625,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 1488.0,
#   'duration': 0,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 999,
#   'entrydate': Timestamp('2011-02-09 00:00:00'),
#   'name': 'CBOT Wheat',
#   'symbol': 'W',
#   'sector': 'grain',
#   'position': -1,
#   'entryprice': 1517.0,
#   'entrylots': 2,
#   'entryrisk': 1680.0,
#   'entryrisk_ticks': 70,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2011-02-09 00:00:00'),
#     'exitprice': 1534.5,
#     'exitlots': 2,
#     'profit': 1680.0,
#     'profit_tick': 70,
#     'duration': 0,
#     'result': 'WIN'}],
#   'currentprice': 1534.5,
#   'stopprice': 1534.5,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 1680.0,
#   'duration': 0,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  {'id': 1000,
#   'entrydate': Timestamp('2011-02-10 00:00:00'),
#   'name': 'CME Australian Dollar AUD',
#   'symbol': 'AD',
#   'sector': 'currency',
#   'position': -1,
#   'entryprice': 0.861000492477417,
#   'entrylots': 2,
#   'entryrisk': 2140.0,
#   'entryrisk_ticks': 214,
#   'exits': [{'exittype': 'stop',
#     'exitdate': Timestamp('2011-02-25 00:00:00'),
#     'exitprice': 0.8717004656791687,
#     'exitlots': 2,
#     'profit': 2140.0,
#     'profit_tick': 214,
#     'duration': 15,
#     'result': 'WIN'}],
#   'currentprice': 0.8717004656791687,
#   'stopprice': 0.8717004656791687,
#   'risk': 0.0,
#   'risk_ticks': 0,
#   'lots': 0,
#   'flame': -0.0,
#   'profit': 2140.0,
#   'duration': 15,
#   'exittype': 'stop',
#   'result': 'WIN',
#   'on_fire': False},
#  ...]

# %%
kwargs = {'symbol':'AD', 'lots':0, 'result':'WIN'}

# %%
fires = []
for fire in system.trades.book:
    if all(getattr(fire, k) == v for k,v in kwargs.items()):
        fires.append(fire)

# %%
fires[10].result
# Out:
# 'WIN'

# %%
system.symbols
# Out:
# ['AD', 'CL', 'C', 'LC']

# %%
system.signals.loc['2002-01-02':]['LC']
# Out:
#            enter_long enter_short exit_long exit_short   stop_long  stop_short
# date
# 2002-01-02      False        True      True      False  174.454956  178.504974
# 2002-01-03      False        True      True      False  174.454956  178.654968
# 2002-01-04      False        True      True      False  174.454956  178.654968
# 2002-01-07      False        True      True      False  174.454956  178.654968
# 2002-01-08      False        True      True      False  174.454956  178.654968
# ...               ...         ...       ...        ...         ...         ...
# 2022-04-28       True       False     False       True  132.475006  140.000000
# 2022-04-29       True       False     False       True  132.475006  140.000000
# 2022-05-02       True       False     False       True  132.475006  140.000000
# 2022-05-03       True       False     False       True  132.475006  140.000000
# 2022-05-04       True       False     False       True  132.475006  140.000000
#
# [5264 rows x 6 columns]

# %%
view(quotes)

# %%
quotes = trader.loc[start:end].dropna()
        tradelog = self.tradelog[self.tradelog.symbol == symbol]
        #tradelog = tradelog[tradelog.symbol == symbol]
        
        
        if start and end:
            trade = tradelog[ (start <= tradelog.entrydate) & (tradelog.exitdate <= end)]
        else:
            trade = tradelog
        
        cumprofit = trade.profit.cumsum()
        num_trades = len(trade)
        
        fig, (ax) = plt.subplots(2,1, figsize=(15,10),
                                gridspec_kw = {'height_ratios':[3,1]})
        
        #price chart
        ax[0] = ohlc_chart(ax[0], feed, linewidth=0.8)
        for idx, row in trade.iterrows():
            y=feed.loc[row['entrydate']:row['exitdate']]
            colors=['red','red'] if row['position']=='Long' else ['blue','blue']
            ax[0] = ohlc_chart(ax[0], y, colors=colors)
        ax[0].plot(feed[['top','bottom']].shift(1), color='green', linewidth=0.8)
        #tick profit chart
        ax[1].bar(np.arange(1,num_trades+1), np.where(trade.position=='Long', trade.tick, 0), 0.3, color='red', alpha=0.6 )
        ax[1].bar(np.arange(1,num_trades+1), np.where(trade.position=='Short', trade.tick, 0), 0.3, color='blue', alpha=0.6 )
           
        #labels
        name = self.pinfo[symbol]['name']
        ax[0].set_title(name, fontsize=20)
        ax[0].set_ylabel('Price', fontsize=15)
        ax[1].set_ylabel('Profit (tick)', fontsize=15)
       
        #styles
        ax[1].axhline(y=0, linewidth=1, color='darkgrey')
        ax[1].yaxis.tick_right()
        ax[1].set_facecolor('lightgoldenrodyellow')
        ax[1].set_xticks(range(1,num_trades+1))
        ax[1].grid(linestyle='--')
# Out:
# 'NYMEX WTI Crude Oil'

# %%
table['duration'].mean()
# Out:
# 35.285714285714285

# %%
df.columns
# Out:
# Index(['id', 'entrydate', 'name', 'symbol', 'sector', 'position', 'entryprice',
#        'entrylots', 'entryrisk', 'entryrisk_ticks', 'exits', 'currentprice',
#        'stopprice', 'risk', 'risk_ticks', 'lots', 'flame', 'profit',
#        'duration', 'exittype', 'result', 'on_fire'],
#       dtype='object')

# %%
df=pd.DataFrame(system.equity.log())

# %%
df2 = df.set_index('date')

# %%
df2
# Out:
#               id  principal   capital  security     cash  fixed_capital  \
# date
# 2002-01-02     1     100000  100000.0   20900.0  79100.0        95860.0
# 2002-01-02     2     100000  100000.0   26730.0  73270.0        95740.0
# 2002-01-02     3     100000  100000.0   29810.0  70190.0        93120.0
# 2002-01-02     4     100000  100120.0   23980.0  76140.0        93360.0
# 2002-01-03     5     100000  100120.0   44880.0  55240.0        88040.0
# ...          ...        ...       ...       ...      ...            ...
# 2003-12-24  1255     100000     364.0       0.0    364.0          364.0
# 2003-12-26  1256     100000     364.0       0.0    364.0          364.0
# 2003-12-29  1257     100000     364.0       0.0    364.0          364.0
# 2003-12-30  1258     100000     364.0       0.0    364.0          364.0
# 2003-12-31  1259     100000     364.0       0.0    364.0          364.0
#
#              profit     risk  system_heat  \
# date
# 2002-01-02      0.0   4140.0     0.041400
# 2002-01-02      0.0   4260.0     0.042600
# 2002-01-02      0.0   6880.0     0.068800
# 2002-01-02    120.0   6760.0     0.067519
# 2002-01-03    120.0  12080.0     0.120655
# ...             ...      ...          ...
# 2003-12-24 -99636.0      0.0     0.000000
# 2003-12-26 -99636.0      0.0     0.000000
# 2003-12-29 -99636.0      0.0     0.000000
# 2003-12-30 -99636.0      0.0     0.000000
# 2003-12-31 -99636.0      0.0     0.000000
#
#                                                   sector_heat  \
# date
# 2002-01-02                              {'petroleum': 0.0414}
# 2002-01-02             {'petroleum': 0.0414, 'grain': 0.0012}
# 2002-01-02  {'petroleum': 0.0414, 'grain': 0.0012, 'meat':...
# 2002-01-02  {'petroleum': 0.041350379544546546, 'meat': 0....
# 2002-01-03  {'petroleum': 0.09448661606072713, 'meat': 0.0...
# ...                                                       ...
# 2003-12-24                                                 {}
# 2003-12-26                                                 {}
# 2003-12-29                                                 {}
# 2003-12-30                                                 {}
# 2003-12-31                                                 {}
#
#                                                   sector_risk  max_capital  \
# date
# 2002-01-02                              {'petroleum': 4140.0}     100000.0
# 2002-01-02              {'petroleum': 4140.0, 'grain': 120.0}     100000.0
# 2002-01-02  {'petroleum': 4140.0, 'grain': 120.0, 'meat': ...     100000.0
# 2002-01-02              {'petroleum': 4140.0, 'meat': 2620.0}     100120.0
# 2002-01-03              {'petroleum': 9460.0, 'meat': 2620.0}     100120.0
# ...                                                       ...          ...
# 2003-12-24                                                 {}     159978.0
# 2003-12-26                                                 {}     159978.0
# 2003-12-29                                                 {}     159978.0
# 2003-12-30                                                 {}     159978.0
# 2003-12-31                                                 {}     159978.0
#
#                    dd        mdd      cagr  commission
# date
# 2002-01-02   0.000000   0.000000  0.000000        5.98
# 2002-01-02   0.000000   0.000000  0.000000       11.96
# 2002-01-02   0.000000   0.000000  0.000000       17.94
# 2002-01-02   0.000000   0.000000  0.549198       17.94
# 2002-01-03   0.000000   0.000000  0.244668       23.92
# ...               ...        ...       ...         ...
# 2003-12-24  99.772469  99.772469 -0.941516     1710.28
# 2003-12-26  99.772469  99.772469 -0.941055     1710.28
# 2003-12-29  99.772469  99.772469 -0.940363     1710.28
# 2003-12-30  99.772469  99.772469 -0.940131     1710.28
# 2003-12-31  99.772469  99.772469 -0.939900     1710.28
#
# [1259 rows x 16 columns]

# %%
system
# Out:
# <<시스템: tf05>>

# %%
p = system.principal

# %%
x = equitylog.index.values
capital = equitylog.capital.values
fixed_capital = equitylog.fixed_capital.values
principal = (capital - equitylog.profit).values
max_capital = equitylog.max_capital.values

# %%
fig, ax = plt.subplots(1,1, figsize=(15, 8))
ax.fill_between(x,p,fixed_capital, where=fixed_capital>=p, facecolor='green', alpha=0.4, interpolate=True, label='fixed_capital')
ax.fill_between(x, p, fixed_capital, where=fixed_capital<p, facecolor='red', alpha=0.6, interpolate=True)
ax.fill_between(x, capital, max_capital, color='grey', alpha=0.2)

ax.plot(x, principal, color='orange',alpha=0.7, linewidth=1, label='capital')
ax.plot(x, capital, color='black',alpha=0.7, linewidth=1)

ax.set_xlim([x.min(), x.max()])

#reference curve
rate = 0.1 #annual interest rate
refx = (x-x[0])/np.timedelta64(365,'D')
refy = p*np.exp(rate*refx)
ax.plot(x, refy, color='magenta', linestyle='--', label='reference')

#labels
ax.legend(loc='upper left', fontsize='large')
ax.set_title('Equity Chart', fontsize=17)

#ax.set_xlabel('Date', fontsize=15)
ax.set_ylabel('equity ($)', fontsize=12)
ax.yaxis.set_label_position("right")
#style
ax.grid(linestyle='--')
ax.yaxis.set_major_formatter(FuncFormatter(lambda x, p: format(int(x), ',')))
ax.yaxis.tick_right()
fig.autofmt_xdate()
        
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [31], in <cell line: 26>()
#      24 #style
#      25 ax.grid(linestyle='--')
# ---> 26 ax.yaxis.set_major_formatter(FuncFormatter(lambda x, p: format(int(x), ',')))
#      27 ax.yaxis.tick_right()
#      28 fig.autofmt_xdate()
#
# NameError: name 'FuncFormatter' is not defined

# %%
class test:
    def __repr__(self):
        a={'a':1,'b':'sdf'}
        return f'{a}'

# %%
a=test()

# %%
b=[]

# %%
b.append(a)

# %%
b[0].name
# Out:
# 11

# %%
a.name = 11

# %%
trades = system.trades.book.statements

# %%
trades = [trade for trade in trades if trade['result'] != 'REJECT']

# %%
quote = trader.quotes['AD'].loc[today]

# %%
quote

# %%
trader.run()

# %%
system.trades.book.statements

# %%
price = quote['open']+round(diff*0.25)*instruments['AD'].tickunit

# %%
round(price, 5)

# %%
a={'b', 'c'}

# %%
a['b'] = 1

# %%
b['b'] = 'fffdd'

# %%
a

# %%
b

# %%
c

# %%
c.append(5)

# %%
instruments.get_symbols('srf')

# %%
type(trader.quotes)

# %%
system.metrics.attrs['type']
