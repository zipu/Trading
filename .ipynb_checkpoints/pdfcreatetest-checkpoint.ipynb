# %%
import os
from reportlab.pdfgen import canvas
from reportlab.lib.pagesizes import letter,A4
from reportlab.pdfbase import pdfmetrics
from reportlab.pdfbase.ttfonts import TTFont
from reportlab.lib.utils import ImageReader
from reportlab.graphics import renderPDF

# %%
import matplotlib.pyplot as plt
import yaml

# %%
import backtesting as bt

# %% [markdown]
# ### 1. 백테스팅

# %%
with open('03.전략연구/systems/system2.yaml', encoding='utf-8') as f:
    system1 = yaml.load(f, Loader=yaml.FullLoader)
    print(system1)
# Out:
# {'name': 'testSystem', 'description': '시스템 설명', 'sectors': 'default', 'instruments': ['AD'], 'from_date': '2019-08-01', 'to_date': None, 'principal': 1000000, 'heat_system': 'DefaultHeat', 'max_system_heat': 0.3, 'max_sector_heat': 0.3, 'max_trade_heat': 0.01, 'max_lots': 100, 'commission': 5.98, 'skid': 0.25, 'metrics': [['ema30', 'EMA', 'window=30'], ['ema5', 'EMA', 'window=5'], ['min30', 'MIN', 'window=30'], ['max300', 'MAX', 'window=300']], 'entry_rule': {'long': 'ema5>ema30', 'short': None}, 'exit_rule': {'long': 'ema5<ema30', 'short': None}, 'stop_rule': {'long': 'min30', 'short': None}}

# %%
trader = bt.Trader(systems=[system1])
system = trader.systems[0]
trader.run()
# Out:
# 매매시작
# 거래일: 2019-08-01 00:00:00, 시스템: testSystem 3.8349692821502686sec
# 거래일: 2019-08-02 00:00:00, 시스템: testSystem 0.004590511322021484sec
# 거래일: 2019-08-05 00:00:00, 시스템: testSystem 0.0019960403442382812sec
# 거래일: 2019-08-06 00:00:00, 시스템: testSystem 0.001994609832763672sec
# 거래일: 2019-08-07 00:00:00, 시스템: testSystem 0.001994609832763672sec
# 거래일: 2019-08-08 00:00:00, 시스템: testSystem 0.0019948482513427734sec
# 거래일: 2019-08-09 00:00:00, 시스템: testSystem 0.000997304916381836sec
# 거래일: 2019-08-12 00:00:00, 시스템: testSystem 0.002991914749145508sec
# 거래일: 2019-08-13 00:00:00, 시스템: testSystem 0.0009975433349609375sec
# 거래일: 2019-08-14 00:00:00, 시스템: testSystem 0.0019943714141845703sec
# 거래일: 2019-08-15 00:00:00, 시스템: testSystem 0.0019948482513427734sec
# 거래일: 2019-08-16 00:00:00, 시스템: testSystem 0.001994609832763672sec
# 거래일: 2019-08-19 00:00:00, 시스템: testSystem 0.001994609832763672sec
# 거래일: 2019-08-20 00:00:00, 시스템: testSystem 0.000997304916381836sec
# 거래일: 2019-08-21 00:00:00, 시스템: testSystem 0.0019948482513427734sec
# 거래일: 2019-08-22 00:00:00, 시스템: testSystem 0.002991914749145508sec
# 거래일: 2019-08-23 00:00:00, 시스템: testSystem 0.0009975433349609375sec
# 거래일: 2019-08-26 00:00:00, 시스템: testSystem 0.001994609832763672sec
# 거래일: 2019-08-27 00:00:00, 시스템: testSystem 0.0019943714141845703sec
# 거래일: 2019-08-28 00:00:00, 시스템: testSystem 0.0019948482513427734sec
# 거래일: 2019-08-29 00:00:00, 시스템: testSystem 0.001994609832763672sec
# 거래일: 2019-08-30 00:00:00, 시스템: testSystem 0.0009975433349609375sec
# 거래일: 2019-09-02 00:00:00, 시스템: testSystem 0.001994609832763672sec
# 거래일: 2019-09-03 00:00:00, 시스템: testSystem 0.0020227432250976562sec
# 거래일: 2019-09-04 00:00:00, 시스템: testSystem 0.001990079879760742sec
# 거래일: 2019-09-05 00:00:00, 시스템: testSystem 0.0010018348693847656sec
# 거래일: 2019-09-06 00:00:00, 시스템: testSystem 0.001995563507080078sec
# 거래일: 2019-09-09 00:00:00, 시스템: testSystem 0.0019965171813964844sec
# 거래일: 2019-09-10 00:00:00, 시스템: testSystem 0.0019927024841308594sec
# 거래일: 2019-09-11 00:00:00, 시스템: testSystem 0.002992391586303711sec
# 거래일: 2019-09-12 00:00:00, 시스템: testSystem 0.002964496612548828sec
# 거래일: 2019-09-13 00:00:00, 시스템: testSystem 0.00498652458190918sec
# 거래일: 2019-09-16 00:00:00, 시스템: testSystem 0.00498652458190918sec
# 거래일: 2019-09-17 00:00:00, 시스템: testSystem 0.005984067916870117sec
# 거래일: 2019-09-18 00:00:00, 시스템: testSystem 0.005983829498291016sec
# 거래일: 2019-09-19 00:00:00, 시스템: testSystem 0.007978677749633789sec
# 거래일: 2019-09-20 00:00:00, 시스템: testSystem 0.007978677749633789sec
# 거래일: 2019-09-23 00:00:00, 시스템: testSystem 0.008976221084594727sec
# 거래일: 2019-09-24 00:00:00, 시스템: testSystem 0.00498652458190918sec
# 거래일: 2019-09-25 00:00:00, 시스템: testSystem 0.001994609832763672sec
# 거래일: 2019-09-26 00:00:00, 시스템: testSystem 0.001994609832763672sec
# 거래일: 2019-09-27 00:00:00, 시스템: testSystem 0.0019948482513427734sec
# 거래일: 2019-09-30 00:00:00, 시스템: testSystem 0.0019927024841308594sec
# 거래일: 2019-10-01 00:00:00, 시스템: testSystem 0.001995086669921875sec
# 거래일: 2019-10-02 00:00:00, 시스템: testSystem 0.0019943714141845703sec
# 거래일: 2019-10-03 00:00:00, 시스템: testSystem 0.0009975433349609375sec
# 거래일: 2019-10-04 00:00:00, 시스템: testSystem 0.001994609832763672sec
# 거래일: 2019-10-07 00:00:00, 시스템: testSystem 0.0019948482513427734sec
# 거래일: 2019-10-08 00:00:00, 시스템: testSystem 0.0019943714141845703sec
# 거래일: 2019-10-09 00:00:00, 시스템: testSystem 0.0019948482513427734sec
# 거래일: 2019-10-10 00:00:00, 시스템: testSystem 0.000997304916381836sec
# 거래일: 2019-10-11 00:00:00, 시스템: testSystem 0.0019948482513427734sec
# 거래일: 2019-10-14 00:00:00, 시스템: testSystem 0.0019941329956054688sec
# 거래일: 2019-10-15 00:00:00, 시스템: testSystem 0.001995086669921875sec
# 거래일: 2019-10-16 00:00:00, 시스템: testSystem 0.0019943714141845703sec
# 거래일: 2019-10-17 00:00:00, 시스템: testSystem 0.0019948482513427734sec
# 거래일: 2019-10-18 00:00:00, 시스템: testSystem 0.000997304916381836sec
# 거래일: 2019-10-21 00:00:00, 시스템: testSystem 0.002991914749145508sec
# 거래일: 2019-10-22 00:00:00, 시스템: testSystem 0.003989458084106445sec
# 거래일: 2019-10-23 00:00:00, 시스템: testSystem 0.003989219665527344sec
# 거래일: 2019-10-24 00:00:00, 시스템: testSystem 0.005984067916870117sec
# 거래일: 2019-10-25 00:00:00, 시스템: testSystem 0.0059854984283447266sec
# 거래일: 2019-10-28 00:00:00, 시스템: testSystem 0.005984067916870117sec
# 거래일: 2019-10-29 00:00:00, 시스템: testSystem 0.007977008819580078sec
# 거래일: 2019-10-30 00:00:00, 시스템: testSystem 0.00797891616821289sec
# 거래일: 2019-10-31 00:00:00, 시스템: testSystem 0.008977413177490234sec
# 거래일: 2019-11-01 00:00:00, 시스템: testSystem 0.008975982666015625sec
# 거래일: 2019-11-04 00:00:00, 시스템: testSystem 0.010970830917358398sec
# 거래일: 2019-11-05 00:00:00, 시스템: testSystem 0.010969400405883789sec
# 거래일: 2019-11-06 00:00:00, 시스템: testSystem 0.011968135833740234sec
# 거래일: 2019-11-07 00:00:00, 시스템: testSystem 0.012964725494384766sec
# 거래일: 2019-11-08 00:00:00, 시스템: testSystem 0.015957117080688477sec
# 거래일: 2019-11-11 00:00:00, 시스템: testSystem 0.013962745666503906sec
# 거래일: 2019-11-12 00:00:00, 시스템: testSystem 0.014960289001464844sec
# 거래일: 2019-11-13 00:00:00, 시스템: testSystem 0.01595902442932129sec
# 거래일: 2019-11-14 00:00:00, 시스템: testSystem 0.015956878662109375sec
# 거래일: 2019-11-15 00:00:00, 시스템: testSystem 0.016954660415649414sec
# 거래일: 2019-11-18 00:00:00, 시스템: testSystem 0.008976221084594727sec
# 거래일: 2019-11-19 00:00:00, 시스템: testSystem 0.0019927024841308594sec
# 거래일: 2019-11-20 00:00:00, 시스템: testSystem 0.0019948482513427734sec
# 거래일: 2019-11-21 00:00:00, 시스템: testSystem 0.0009975433349609375sec
# 거래일: 2019-11-22 00:00:00, 시스템: testSystem 0.001994609832763672sec
# 거래일: 2019-11-25 00:00:00, 시스템: testSystem 0.001994609832763672sec
# 거래일: 2019-11-26 00:00:00, 시스템: testSystem 0.001994609832763672sec
# 거래일: 2019-11-27 00:00:00, 시스템: testSystem 0.0019943714141845703sec
# 거래일: 2019-11-28 00:00:00, 시스템: testSystem 0.0009975433349609375sec
# 거래일: 2019-11-29 00:00:00, 시스템: testSystem 0.0019948482513427734sec
# 거래일: 2019-12-02 00:00:00, 시스템: testSystem 0.0019943714141845703sec
# 거래일: 2019-12-03 00:00:00, 시스템: testSystem 0.001994609832763672sec
# 거래일: 2019-12-04 00:00:00, 시스템: testSystem 0.0009975433349609375sec
# 거래일: 2019-12-05 00:00:00, 시스템: testSystem 0.0019948482513427734sec
# 거래일: 2019-12-06 00:00:00, 시스템: testSystem 0.002991914749145508sec
# 거래일: 2019-12-09 00:00:00, 시스템: testSystem 0.003989219665527344sec
# 거래일: 2019-12-10 00:00:00, 시스템: testSystem 0.003990888595581055sec
# 거래일: 2019-12-11 00:00:00, 시스템: testSystem 0.004986763000488281sec
# 거래일: 2019-12-12 00:00:00, 시스템: testSystem 0.005983829498291016sec
# 거래일: 2019-12-13 00:00:00, 시스템: testSystem 0.005982637405395508sec
# 거래일: 2019-12-16 00:00:00, 시스템: testSystem 0.006981372833251953sec
# 거래일: 2019-12-17 00:00:00, 시스템: testSystem 0.008975744247436523sec
# 거래일: 2019-12-18 00:00:00, 시스템: testSystem 0.00797891616821289sec
# 거래일: 2019-12-19 00:00:00, 시스템: testSystem 0.00997471809387207sec
# 거래일: 2019-12-20 00:00:00, 시스템: testSystem 0.009973526000976562sec
# 거래일: 2019-12-23 00:00:00, 시스템: testSystem 0.010970592498779297sec
# 거래일: 2019-12-24 00:00:00, 시스템: testSystem 0.010969161987304688sec
# 거래일: 2019-12-26 00:00:00, 시스템: testSystem 0.011967897415161133sec
# 거래일: 2019-12-27 00:00:00, 시스템: testSystem 0.011996269226074219sec
# 거래일: 2019-12-30 00:00:00, 시스템: testSystem 0.011939764022827148sec
# 거래일: 2019-12-31 00:00:00, 시스템: testSystem 0.011967897415161133sec
# 거래일: 2020-01-02 00:00:00, 시스템: testSystem 0.010970354080200195sec
# 거래일: 2020-01-03 00:00:00, 시스템: testSystem 0.011968135833740234sec
# 거래일: 2020-01-06 00:00:00, 시스템: testSystem 0.010970592498779297sec
# 거래일: 2020-01-07 00:00:00, 시스템: testSystem 0.011967897415161133sec
# 거래일: 2020-01-08 00:00:00, 시스템: testSystem 0.010970592498779297sec
# 거래일: 2020-01-09 00:00:00, 시스템: testSystem 0.010971307754516602sec
# 거래일: 2020-01-10 00:00:00, 시스템: testSystem 0.012000560760498047sec
# 거래일: 2020-01-13 00:00:00, 시스템: testSystem 0.006948232650756836sec
# 거래일: 2020-01-14 00:00:00, 시스템: testSystem 0.001995086669921875sec
# 거래일: 2020-01-15 00:00:00, 시스템: testSystem 0.003989219665527344sec
# 거래일: 2020-01-16 00:00:00, 시스템: testSystem 0.003989219665527344sec
# 거래일: 2020-01-17 00:00:00, 시스템: testSystem 0.00498652458190918sec
# 거래일: 2020-01-20 00:00:00, 시스템: testSystem 0.002991914749145508sec
# 거래일: 2020-01-21 00:00:00, 시스템: testSystem 0.0019969940185546875sec
# 거래일: 2020-01-22 00:00:00, 시스템: testSystem 0.002000570297241211sec
# 거래일: 2020-01-23 00:00:00, 시스템: testSystem 0.0020105838775634766sec
# 거래일: 2020-01-24 00:00:00, 시스템: testSystem 0.0010080337524414062sec
# 거래일: 2020-01-27 00:00:00, 시스템: testSystem 0.0019881725311279297sec
# 거래일: 2020-01-28 00:00:00, 시스템: testSystem 0.0019960403442382812sec
# 거래일: 2020-01-29 00:00:00, 시스템: testSystem 0.001993417739868164sec
# 거래일: 2020-01-30 00:00:00, 시스템: testSystem 0.0009968280792236328sec
# 거래일: 2020-01-31 00:00:00, 시스템: testSystem 0.0029921531677246094sec
# 거래일: 2020-02-03 00:00:00, 시스템: testSystem 0.000997781753540039sec
# 거래일: 2020-02-04 00:00:00, 시스템: testSystem 0.0019941329956054688sec
# 거래일: 2020-02-05 00:00:00, 시스템: testSystem 0.0019958019256591797sec
# 거래일: 2020-02-06 00:00:00, 시스템: testSystem 0.0010020732879638672sec
# 거래일: 2020-02-07 00:00:00, 시스템: testSystem 0.0019893646240234375sec
# 거래일: 2020-02-10 00:00:00, 시스템: testSystem 0.0019943714141845703sec
# 거래일: 2020-02-11 00:00:00, 시스템: testSystem 0.0019948482513427734sec
# 거래일: 2020-02-12 00:00:00, 시스템: testSystem 0.0009701251983642578sec
# 거래일: 2020-02-13 00:00:00, 시스템: testSystem 0.0019943714141845703sec
# 거래일: 2020-02-14 00:00:00, 시스템: testSystem 0.00202178955078125sec
# 거래일: 2020-02-17 00:00:00, 시스템: testSystem 0.001995086669921875sec
# 거래일: 2020-02-18 00:00:00, 시스템: testSystem 0.0009970664978027344sec
# 거래일: 2020-02-19 00:00:00, 시스템: testSystem 0.0019958019256591797sec
# 거래일: 2020-02-20 00:00:00, 시스템: testSystem 0.0019948482513427734sec
# 거래일: 2020-02-21 00:00:00, 시스템: testSystem 0.0009970664978027344sec
# 거래일: 2020-02-24 00:00:00, 시스템: testSystem 0.0019948482513427734sec
# 거래일: 2020-02-25 00:00:00, 시스템: testSystem 0.001994609832763672sec
# 거래일: 2020-02-26 00:00:00, 시스템: testSystem 0.0019927024841308594sec
# 거래일: 2020-02-27 00:00:00, 시스템: testSystem 0.0010006427764892578sec
# 거래일: 2020-02-28 00:00:00, 시스템: testSystem 0.0019884109497070312sec
# 거래일: 2020-03-02 00:00:00, 시스템: testSystem 0.0019986629486083984sec
# 거래일: 2020-03-03 00:00:00, 시스템: testSystem 0.0009984970092773438sec
# 거래일: 2020-03-04 00:00:00, 시스템: testSystem 0.0019931793212890625sec
# 거래일: 2020-03-05 00:00:00, 시스템: testSystem 0.001995086669921875sec
# 거래일: 2020-03-06 00:00:00, 시스템: testSystem 0.0019948482513427734sec
# 거래일: 2020-03-09 00:00:00, 시스템: testSystem 0.0019948482513427734sec
# 거래일: 2020-03-10 00:00:00, 시스템: testSystem 0.0009965896606445312sec
# 거래일: 2020-03-11 00:00:00, 시스템: testSystem 0.0019948482513427734sec
# 거래일: 2020-03-12 00:00:00, 시스템: testSystem 0.001990795135498047sec
# 거래일: 2020-03-13 00:00:00, 시스템: testSystem 0.0020051002502441406sec
# 거래일: 2020-03-16 00:00:00, 시스템: testSystem 0.0009865760803222656sec
# 거래일: 2020-03-17 00:00:00, 시스템: testSystem 0.0019986629486083984sec
# 거래일: 2020-03-18 00:00:00, 시스템: testSystem 0.001995086669921875sec
# 거래일: 2020-03-19 00:00:00, 시스템: testSystem 0.0019941329956054688sec
# 거래일: 2020-03-20 00:00:00, 시스템: testSystem 0.0019948482513427734sec
# 거래일: 2020-03-23 00:00:00, 시스템: testSystem 0.000997781753540039sec
# 거래일: 2020-03-24 00:00:00, 시스템: testSystem 0.0019965171813964844sec
# 거래일: 2020-03-25 00:00:00, 시스템: testSystem 0.001993417739868164sec
# 거래일: 2020-03-26 00:00:00, 시스템: testSystem 0.001993894577026367sec
# 거래일: 2020-03-27 00:00:00, 시스템: testSystem 0.0009980201721191406sec
# 거래일: 2020-03-30 00:00:00, 시스템: testSystem 0.001989126205444336sec
# 거래일: 2020-03-31 00:00:00, 시스템: testSystem 0.0019991397857666016sec
# 거래일: 2020-04-01 00:00:00, 시스템: testSystem 0.0019948482513427734sec
# 거래일: 2020-04-02 00:00:00, 시스템: testSystem 0.000997781753540039sec
# 거래일: 2020-04-03 00:00:00, 시스템: testSystem 0.0019943714141845703sec
# 거래일: 2020-04-06 00:00:00, 시스템: testSystem 0.001989603042602539sec
# 거래일: 2020-04-07 00:00:00, 시스템: testSystem 0.0020008087158203125sec
# 거래일: 2020-04-08 00:00:00, 시스템: testSystem 0.001993894577026367sec
# 거래일: 2020-04-09 00:00:00, 시스템: testSystem 0.000997781753540039sec
# 거래일: 2020-04-13 00:00:00, 시스템: testSystem 0.0019936561584472656sec
# 거래일: 2020-04-14 00:00:00, 시스템: testSystem 0.0019953250885009766sec
# 거래일: 2020-04-15 00:00:00, 시스템: testSystem 0.0019943714141845703sec
# 거래일: 2020-04-16 00:00:00, 시스템: testSystem 0.0019981861114501953sec
# 거래일: 2020-04-17 00:00:00, 시스템: testSystem 0.002988576889038086sec
# 거래일: 2020-04-20 00:00:00, 시스템: testSystem 0.002991914749145508sec
# 거래일: 2020-04-21 00:00:00, 시스템: testSystem 0.0049860477447509766sec
# 거래일: 2020-04-22 00:00:00, 시스템: testSystem 0.004987955093383789sec
# 거래일: 2020-04-23 00:00:00, 시스템: testSystem 0.005982875823974609sec
# 거래일: 2020-04-24 00:00:00, 시스템: testSystem 0.005983829498291016sec
# 거래일: 2020-04-27 00:00:00, 시스템: testSystem 0.006981611251831055sec
# 거래일: 2020-04-28 00:00:00, 시스템: testSystem 0.005983591079711914sec
# 거래일: 2020-04-29 00:00:00, 시스템: testSystem 0.006982564926147461sec
# 거래일: 2020-04-30 00:00:00, 시스템: testSystem 0.005982875823974609sec
# 거래일: 2020-05-01 00:00:00, 시스템: testSystem 0.006983041763305664sec
# 거래일: 2020-05-04 00:00:00, 시스템: testSystem 0.006979703903198242sec
# 거래일: 2020-05-05 00:00:00, 시스템: testSystem 0.007950544357299805sec
# 거래일: 2020-05-06 00:00:00, 시스템: testSystem 0.009973287582397461sec
# 거래일: 2020-05-07 00:00:00, 시스템: testSystem 0.008976459503173828sec
# 거래일: 2020-05-08 00:00:00, 시스템: testSystem 0.010970354080200195sec
# 거래일: 2020-05-11 00:00:00, 시스템: testSystem 0.010972261428833008sec
# 거래일: 2020-05-12 00:00:00, 시스템: testSystem 0.011967897415161133sec
# 거래일: 2020-05-13 00:00:00, 시스템: testSystem 0.01296544075012207sec
# 거래일: 2020-05-14 00:00:00, 시스템: testSystem 0.012991905212402344sec
# 거래일: 2020-05-15 00:00:00, 시스템: testSystem 0.013962984085083008sec
# 거래일: 2020-05-18 00:00:00, 시스템: testSystem 0.013962268829345703sec
# 거래일: 2020-05-19 00:00:00, 시스템: testSystem 0.01595759391784668sec
# 거래일: 2020-05-20 00:00:00, 시스템: testSystem 0.015957355499267578sec
# 거래일: 2020-05-21 00:00:00, 시스템: testSystem 0.01795196533203125sec
# 거래일: 2020-05-22 00:00:00, 시스템: testSystem 0.016954898834228516sec
# 거래일: 2020-05-25 00:00:00, 시스템: testSystem 0.017951488494873047sec
# 거래일: 2020-05-26 00:00:00, 시스템: testSystem 0.001994609832763672sec
# 거래일: 2020-05-27 00:00:00, 시스템: testSystem 0.018949031829833984sec
# 거래일: 2020-05-28 00:00:00, 시스템: testSystem 0.019919395446777344sec
# 거래일: 2020-05-29 00:00:00, 시스템: testSystem 0.021942138671875sec
# 거래일: 2020-06-01 00:00:00, 시스템: testSystem 0.022937297821044922sec
# 거래일: 2020-06-02 00:00:00, 시스템: testSystem 0.022967100143432617sec
# 거래일: 2020-06-03 00:00:00, 시스템: testSystem 0.022910118103027344sec
# 거래일: 2020-06-04 00:00:00, 시스템: testSystem 0.024961471557617188sec
# 거래일: 2020-06-05 00:00:00, 시스템: testSystem 0.024933815002441406sec
# 거래일: 2020-06-08 00:00:00, 시스템: testSystem 0.0249330997467041sec
# 거래일: 2020-06-09 00:00:00, 시스템: testSystem 0.025931596755981445sec
# 거래일: 2020-06-10 00:00:00, 시스템: testSystem 0.026898860931396484sec
# 거래일: 2020-06-11 00:00:00, 시스템: testSystem 0.02792525291442871sec
# 거래일: 2020-06-12 00:00:00, 시스템: testSystem 0.028922557830810547sec
# 거래일: 2020-06-15 00:00:00, 시스템: testSystem 0.028922557830810547sec
# 거래일: 2020-06-16 00:00:00, 시스템: testSystem 0.02995467185974121sec
# 거래일: 2020-06-17 00:00:00, 시스템: testSystem 0.02991628646850586sec
# 거래일: 2020-06-18 00:00:00, 시스템: testSystem 0.031915903091430664sec
# 거래일: 2020-06-19 00:00:00, 시스템: testSystem 0.03191351890563965sec
# 거래일: 2020-06-22 00:00:00, 시스템: testSystem 0.031914472579956055sec
# 거래일: 2020-06-23 00:00:00, 시스템: testSystem 0.03390932083129883sec
# 거래일: 2020-06-24 00:00:00, 시스템: testSystem 0.03391075134277344sec
# 거래일: 2020-06-25 00:00:00, 시스템: testSystem 0.034905433654785156sec
# 거래일: 2020-06-26 00:00:00, 시스템: testSystem 0.0359041690826416sec
# 거래일: 2020-06-29 00:00:00, 시스템: testSystem 0.0359041690826416sec
# 거래일: 2020-06-30 00:00:00, 시스템: testSystem 0.03690147399902344sec
# 거래일: 2020-07-01 00:00:00, 시스템: testSystem 0.03789949417114258sec
# 거래일: 2020-07-02 00:00:00, 시스템: testSystem 0.03889584541320801sec
# 거래일: 2020-07-03 00:00:00, 시스템: testSystem 0.03989219665527344sec
# 거래일: 2020-07-06 00:00:00, 시스템: testSystem 0.0019948482513427734sec
# 거래일: 2020-07-07 00:00:00, 시스템: testSystem 0.04089069366455078sec
# 거래일: 2020-07-08 00:00:00, 시스템: testSystem 0.041887760162353516sec
# 거래일: 2020-07-09 00:00:00, 시스템: testSystem 0.04388260841369629sec
# 거래일: 2020-07-10 00:00:00, 시스템: testSystem 0.040891170501708984sec
# 거래일: 2020-07-13 00:00:00, 시스템: testSystem 0.04288482666015625sec
# 거래일: 2020-07-14 00:00:00, 시스템: testSystem 0.04388284683227539sec
# 거래일: 2020-07-15 00:00:00, 시스템: testSystem 0.04587841033935547sec
# 거래일: 2020-07-16 00:00:00, 시스템: testSystem 0.0468745231628418sec
# 거래일: 2020-07-17 00:00:00, 시스템: testSystem 0.04687356948852539sec
# 거래일: 2020-07-20 00:00:00, 시스템: testSystem 0.046875715255737305sec
# 거래일: 2020-07-21 00:00:00, 시스템: testSystem 0.04789400100708008sec
# 거래일: 2020-07-22 00:00:00, 시스템: testSystem 0.04884624481201172sec
# 거래일: 2020-07-23 00:00:00, 시스템: testSystem 0.05188918113708496sec
# 거래일: 2020-07-24 00:00:00, 시스템: testSystem 0.04884147644042969sec
# 거래일: 2020-07-27 00:00:00, 시스템: testSystem 0.05189037322998047sec
# 거래일: 2020-07-28 00:00:00, 시스템: testSystem 0.05083441734313965sec
# 거래일: 2020-07-29 00:00:00, 시스템: testSystem 0.051889657974243164sec
# 거래일: 2020-07-30 00:00:00, 시스템: testSystem 0.05186128616333008sec
# 거래일: 2020-07-31 00:00:00, 시스템: testSystem 0.05186128616333008sec
# 거래일: 2020-08-03 00:00:00, 시스템: testSystem 0.053827762603759766sec
# 거래일: 2020-08-04 00:00:00, 시스템: testSystem 0.05585074424743652sec
# 거래일: 2020-08-05 00:00:00, 시스템: testSystem 0.054854631423950195sec
# 거래일: 2020-08-06 00:00:00, 시스템: testSystem 0.05684804916381836sec
# 거래일: 2020-08-07 00:00:00, 시스템: testSystem 0.057843685150146484sec
# 거래일: 2020-08-10 00:00:00, 시스템: testSystem 0.05884432792663574sec
# 거래일: 2020-08-11 00:00:00, 시스템: testSystem 0.05983996391296387sec
# 거래일: 2020-08-12 00:00:00, 시스템: testSystem 0.05884194374084473sec
# 거래일: 2020-08-13 00:00:00, 시스템: testSystem 0.0608363151550293sec
# 거래일: 2020-08-14 00:00:00, 시스템: testSystem 0.05986428260803223sec
# 거래일: 2020-08-17 00:00:00, 시스템: testSystem 0.06480240821838379sec
# 거래일: 2020-08-18 00:00:00, 시스템: testSystem 0.0608370304107666sec
# 거래일: 2020-08-19 00:00:00, 시스템: testSystem 0.058870792388916016sec
# 거래일: 2020-08-20 00:00:00, 시스템: testSystem 0.05884552001953125sec
# 거래일: 2020-08-21 00:00:00, 시스템: testSystem 0.0608060359954834sec
# 거래일: 2020-08-24 00:00:00, 시스템: testSystem 0.060837507247924805sec
# 거래일: 2020-08-25 00:00:00, 시스템: testSystem 0.05884242057800293sec
# 거래일: 2020-08-26 00:00:00, 시스템: testSystem 0.05887103080749512sec
# 거래일: 2020-08-27 00:00:00, 시스템: testSystem 0.05884385108947754sec
# 거래일: 2020-08-28 00:00:00, 시스템: testSystem 0.06080794334411621sec
# 거래일: 2020-08-31 00:00:00, 시스템: testSystem 0.06083869934082031sec
# 거래일: 2020-09-01 00:00:00, 시스템: testSystem 0.05884099006652832sec
# 거래일: 2020-09-02 00:00:00, 시스템: testSystem 0.059839725494384766sec
# 거래일: 2020-09-03 00:00:00, 시스템: testSystem 0.05983996391296387sec
# 거래일: 2020-09-04 00:00:00, 시스템: testSystem 0.06183457374572754sec
# 거래일: 2020-09-07 00:00:00, 시스템: testSystem 0.05884265899658203sec
# 거래일: 2020-09-08 00:00:00, 시스템: testSystem 0.0019948482513427734sec
# 거래일: 2020-09-09 00:00:00, 시스템: testSystem 0.058873653411865234sec
# 거래일: 2020-09-10 00:00:00, 시스템: testSystem 0.05881214141845703sec
# 거래일: 2020-09-11 00:00:00, 시스템: testSystem 0.06086015701293945sec
# 거래일: 2020-09-14 00:00:00, 시스템: testSystem 0.06081533432006836sec
# 거래일: 2020-09-15 00:00:00, 시스템: testSystem 0.059838294982910156sec
# 거래일: 2020-09-16 00:00:00, 시스템: testSystem 0.05986833572387695sec
# 거래일: 2020-09-17 00:00:00, 시스템: testSystem 0.05981135368347168sec
# 거래일: 2020-09-18 00:00:00, 시스템: testSystem 0.06183481216430664sec
# 거래일: 2020-09-21 00:00:00, 시스템: testSystem 0.059841156005859375sec
# 거래일: 2020-09-22 00:00:00, 시스템: testSystem 0.05984044075012207sec
# 거래일: 2020-09-23 00:00:00, 시스템: testSystem 0.05884075164794922sec
# 거래일: 2020-09-24 00:00:00, 시스템: testSystem 0.028924226760864258sec
# 거래일: 2020-09-25 00:00:00, 시스템: testSystem 0.0019948482513427734sec
# 거래일: 2020-09-28 00:00:00, 시스템: testSystem 0.001994609832763672sec
# 거래일: 2020-09-29 00:00:00, 시스템: testSystem 0.0019948482513427734sec
# 거래일: 2020-09-30 00:00:00, 시스템: testSystem 0.0019943714141845703sec
# 거래일: 2020-10-01 00:00:00, 시스템: testSystem 0.0019931793212890625sec
# 거래일: 2020-10-02 00:00:00, 시스템: testSystem 0.001994609832763672sec
# 거래일: 2020-10-05 00:00:00, 시스템: testSystem 0.0019948482513427734sec
# 거래일: 2020-10-06 00:00:00, 시스템: testSystem 0.0019943714141845703sec
# 거래일: 2020-10-07 00:00:00, 시스템: testSystem 0.0019948482513427734sec
# 거래일: 2020-10-08 00:00:00, 시스템: testSystem 0.0019943714141845703sec
# 거래일: 2020-10-09 00:00:00, 시스템: testSystem 0.0009975433349609375sec
# 거래일: 2020-10-12 00:00:00, 시스템: testSystem 0.000997304916381836sec
# 거래일: 2020-10-13 00:00:00, 시스템: testSystem 0.0019948482513427734sec
# 거래일: 2020-10-14 00:00:00, 시스템: testSystem 0.0029921531677246094sec
# 거래일: 2020-10-15 00:00:00, 시스템: testSystem 0.0029916763305664062sec
# 거래일: 2020-10-16 00:00:00, 시스템: testSystem 0.001994609832763672sec
# 거래일: 2020-10-19 00:00:00, 시스템: testSystem 0.001995086669921875sec
# 거래일: 2020-10-20 00:00:00, 시스템: testSystem 0.0009970664978027344sec
# 거래일: 2020-10-21 00:00:00, 시스템: testSystem 0.001994609832763672sec
# 거래일: 2020-10-22 00:00:00, 시스템: testSystem 0.001994609832763672sec
# 거래일: 2020-10-23 00:00:00, 시스템: testSystem 0.0019948482513427734sec
# 거래일: 2020-10-26 00:00:00, 시스템: testSystem 0.001994609832763672sec
# 거래일: 2020-10-27 00:00:00, 시스템: testSystem 0.001994609832763672sec
# 거래일: 2020-10-28 00:00:00, 시스템: testSystem 0.001995563507080078sec
# 거래일: 2020-10-29 00:00:00, 시스템: testSystem 0.0019941329956054688sec
# 거래일: 2020-10-30 00:00:00, 시스템: testSystem 0.001995086669921875sec
# 거래일: 2020-11-02 00:00:00, 시스템: testSystem 0.001993894577026367sec
# 거래일: 2020-11-03 00:00:00, 시스템: testSystem 0.0019953250885009766sec
# 거래일: 2020-11-04 00:00:00, 시스템: testSystem 0.0019941329956054688sec
# 거래일: 2020-11-05 00:00:00, 시스템: testSystem 0.001995563507080078sec
# 거래일: 2020-11-06 00:00:00, 시스템: testSystem 0.001994609832763672sec
# 거래일: 2020-11-09 00:00:00, 시스템: testSystem 0.0029914379119873047sec
# 거래일: 2020-11-10 00:00:00, 시스템: testSystem 0.002991914749145508sec
# 거래일: 2020-11-11 00:00:00, 시스템: testSystem 0.005014657974243164sec
# 거래일: 2020-11-12 00:00:00, 시스템: testSystem 0.004960298538208008sec
# 거래일: 2020-11-13 00:00:00, 시스템: testSystem 0.005983591079711914sec
# 거래일: 2020-11-16 00:00:00, 시스템: testSystem 0.006981372833251953sec
# 거래일: 2020-11-17 00:00:00, 시스템: testSystem 0.006981372833251953sec
# 거래일: 2020-11-18 00:00:00, 시스템: testSystem 0.007978677749633789sec
# 거래일: 2020-11-19 00:00:00, 시스템: testSystem 0.009971857070922852sec
# 거래일: 2020-11-20 00:00:00, 시스템: testSystem 0.008975744247436523sec
# 거래일: 2020-11-23 00:00:00, 시스템: testSystem 0.010970592498779297sec
# 거래일: 2020-11-24 00:00:00, 시스템: testSystem 0.010970830917358398sec
# 거래일: 2020-11-25 00:00:00, 시스템: testSystem 0.011968135833740234sec
# 거래일: 2020-11-26 00:00:00, 시스템: testSystem 0.012965202331542969sec
# 거래일: 2020-11-27 00:00:00, 시스템: testSystem 0.001994609832763672sec
# 거래일: 2020-11-30 00:00:00, 시스템: testSystem 0.012995004653930664sec
# 거래일: 2020-12-01 00:00:00, 시스템: testSystem 0.013962030410766602sec
# 거래일: 2020-12-02 00:00:00, 시스템: testSystem 0.013965129852294922sec
# 거래일: 2020-12-03 00:00:00, 시스템: testSystem 0.015948772430419922sec
# 거래일: 2020-12-04 00:00:00, 시스템: testSystem 0.015962839126586914sec
# 거래일: 2020-12-07 00:00:00, 시스템: testSystem 0.016927242279052734sec
# 거래일: 2020-12-08 00:00:00, 시스템: testSystem 0.01698613166809082sec
# 거래일: 2020-12-09 00:00:00, 시스템: testSystem 0.01794743537902832sec
# 거래일: 2020-12-10 00:00:00, 시스템: testSystem 0.01991868019104004sec
# 거래일: 2020-12-11 00:00:00, 시스템: testSystem 0.019971847534179688sec
# 거래일: 2020-12-14 00:00:00, 시스템: testSystem 0.020937442779541016sec
# 거래일: 2020-12-15 00:00:00, 시스템: testSystem 0.02191948890686035sec
# 거래일: 2020-12-16 00:00:00, 시스템: testSystem 0.021941423416137695sec
# 거래일: 2020-12-17 00:00:00, 시스템: testSystem 0.023936033248901367sec
# 거래일: 2020-12-18 00:00:00, 시스템: testSystem 0.023937702178955078sec
# 거래일: 2020-12-21 00:00:00, 시스템: testSystem 0.02395319938659668sec
# 거래일: 2020-12-22 00:00:00, 시스템: testSystem 0.02491617202758789sec
# 거래일: 2020-12-23 00:00:00, 시스템: testSystem 0.025957345962524414sec
# 거래일: 2020-12-24 00:00:00, 시스템: testSystem 0.02689981460571289sec
# 거래일: 2020-12-28 00:00:00, 시스템: testSystem 0.027953147888183594sec
# 거래일: 2020-12-29 00:00:00, 시스템: testSystem 0.027925491333007812sec
# 거래일: 2020-12-30 00:00:00, 시스템: testSystem 0.027930498123168945sec
# 거래일: 2020-12-31 00:00:00, 시스템: testSystem 0.02991485595703125sec
# 거래일: 2021-01-04 00:00:00, 시스템: testSystem 0.029923200607299805sec
# 거래일: 2021-01-05 00:00:00, 시스템: testSystem 0.029922962188720703sec
# 거래일: 2021-01-06 00:00:00, 시스템: testSystem 0.030911922454833984sec
# 거래일: 2021-01-07 00:00:00, 시스템: testSystem 0.033881187438964844sec
# 거래일: 2021-01-08 00:00:00, 시스템: testSystem 0.03390836715698242sec
# 거래일: 2021-01-11 00:00:00, 시스템: testSystem 0.03291153907775879sec
# 거래일: 2021-01-12 00:00:00, 시스템: testSystem 0.031914710998535156sec
# 거래일: 2021-01-13 00:00:00, 시스템: testSystem 0.032912254333496094sec
# 거래일: 2021-01-14 00:00:00, 시스템: testSystem 0.03291153907775879sec
# 거래일: 2021-01-15 00:00:00, 시스템: testSystem 0.0329134464263916sec
# 거래일: 2021-01-18 00:00:00, 시스템: testSystem 0.03191351890563965sec
# 거래일: 2021-01-19 00:00:00, 시스템: testSystem 0.001995086669921875sec
# 거래일: 2021-01-20 00:00:00, 시스템: testSystem 0.03194475173950195sec
# 거래일: 2021-01-21 00:00:00, 시스템: testSystem 0.031914472579956055sec
# 거래일: 2021-01-22 00:00:00, 시스템: testSystem 0.03191423416137695sec
# 거래일: 2021-01-25 00:00:00, 시스템: testSystem 0.03191566467285156sec
# 거래일: 2021-01-26 00:00:00, 시스템: testSystem 0.03288102149963379sec
# 거래일: 2021-01-27 00:00:00, 시스템: testSystem 0.03390932083129883sec
# 거래일: 2021-01-28 00:00:00, 시스템: testSystem 0.03294038772583008sec
# 거래일: 2021-01-29 00:00:00, 시스템: testSystem 0.03188776969909668sec
# 거래일: 2021-02-01 00:00:00, 시스템: testSystem 0.032944440841674805sec
# 거래일: 2021-02-02 00:00:00, 시스템: testSystem 0.031882286071777344sec
# 거래일: 2021-02-03 00:00:00, 시스템: testSystem 0.03194117546081543sec
# 거래일: 2021-02-04 00:00:00, 시스템: testSystem 0.01595759391784668sec
# 거래일: 2021-02-05 00:00:00, 시스템: testSystem 0.001997709274291992sec
# 거래일: 2021-02-08 00:00:00, 시스템: testSystem 0.0019969940185546875sec
# 거래일: 2021-02-09 00:00:00, 시스템: testSystem 0.001989126205444336sec
# 거래일: 2021-02-10 00:00:00, 시스템: testSystem 0.0029926300048828125sec
# 거래일: 2021-02-11 00:00:00, 시스템: testSystem 0.0029926300048828125sec
# 거래일: 2021-02-12 00:00:00, 시스템: testSystem 0.0049860477447509766sec
# 거래일: 2021-02-15 00:00:00, 시스템: testSystem 0.004957437515258789sec
# 거래일: 2021-02-16 00:00:00, 시스템: testSystem 0.0019948482513427734sec
# 거래일: 2021-02-17 00:00:00, 시스템: testSystem 0.005984067916870117sec
# 거래일: 2021-02-18 00:00:00, 시스템: testSystem 0.007009983062744141sec
# 거래일: 2021-02-19 00:00:00, 시스템: testSystem 0.0069806575775146484sec
# 거래일: 2021-02-22 00:00:00, 시스템: testSystem 0.007984161376953125sec
# 거래일: 2021-02-23 00:00:00, 시스템: testSystem 0.008975744247436523sec
# 거래일: 2021-02-24 00:00:00, 시스템: testSystem 0.00897073745727539sec
# 거래일: 2021-02-25 00:00:00, 시스템: testSystem 0.010971784591674805sec
# 거래일: 2021-02-26 00:00:00, 시스템: testSystem 0.009974956512451172sec
# 거래일: 2021-03-01 00:00:00, 시스템: testSystem 0.011938810348510742sec
# 거래일: 2021-03-02 00:00:00, 시스템: testSystem 0.011995792388916016sec
# 거래일: 2021-03-03 00:00:00, 시스템: testSystem 0.012964725494384766sec
# 거래일: 2021-03-04 00:00:00, 시스템: testSystem 0.013963460922241211sec
# 거래일: 2021-03-05 00:00:00, 시스템: testSystem 0.013962030410766602sec
# 거래일: 2021-03-08 00:00:00, 시스템: testSystem 0.015956401824951172sec
# 거래일: 2021-03-09 00:00:00, 시스템: testSystem 0.007952213287353516sec
# 거래일: 2021-03-10 00:00:00, 시스템: testSystem 0.0019936561584472656sec
# 거래일: 2021-03-11 00:00:00, 시스템: testSystem 0.001024484634399414sec
# 거래일: 2021-03-12 00:00:00, 시스템: testSystem 0.001995563507080078sec
# 거래일: 2021-03-15 00:00:00, 시스템: testSystem 0.0019843578338623047sec
# 거래일: 2021-03-16 00:00:00, 시스템: testSystem 0.002004384994506836sec
# 거래일: 2021-03-17 00:00:00, 시스템: testSystem 0.0009987354278564453sec
# 거래일: 2021-03-18 00:00:00, 시스템: testSystem 0.0019936561584472656sec
# 거래일: 2021-03-19 00:00:00, 시스템: testSystem 0.002994060516357422sec
# 거래일: 2021-03-22 00:00:00, 시스템: testSystem 0.003986835479736328sec
# 거래일: 2021-03-23 00:00:00, 시스템: testSystem 0.0039920806884765625sec
# 거래일: 2021-03-24 00:00:00, 시스템: testSystem 0.0029904842376708984sec
# 거래일: 2021-03-25 00:00:00, 시스템: testSystem 0.001967191696166992sec
# 거래일: 2021-03-26 00:00:00, 시스템: testSystem 0.001993894577026367sec
# 거래일: 2021-03-29 00:00:00, 시스템: testSystem 0.0019941329956054688sec
# 거래일: 2021-03-30 00:00:00, 시스템: testSystem 0.0009975433349609375sec
# 거래일: 2021-03-31 00:00:00, 시스템: testSystem 0.0019943714141845703sec
# 거래일: 2021-04-01 00:00:00, 시스템: testSystem 0.0019953250885009766sec
# 거래일: 2021-04-02 00:00:00, 시스템: testSystem 0.0019943714141845703sec
# 거래일: 2021-04-05 00:00:00, 시스템: testSystem 0.0009968280792236328sec
# 거래일: 2021-04-06 00:00:00, 시스템: testSystem 0.002023935317993164sec
# 거래일: 2021-04-07 00:00:00, 시스템: testSystem 0.001994609832763672sec
# 거래일: 2021-04-08 00:00:00, 시스템: testSystem 0.001993894577026367sec
# 거래일: 2021-04-09 00:00:00, 시스템: testSystem 0.0009999275207519531sec
# 거래일: 2021-04-12 00:00:00, 시스템: testSystem 0.0019643306732177734sec
# 거래일: 2021-04-13 00:00:00, 시스템: testSystem 0.00202178955078125sec
# 거래일: 2021-04-14 00:00:00, 시스템: testSystem 0.001995563507080078sec
# 거래일: 2021-04-15 00:00:00, 시스템: testSystem 0.0009965896606445312sec
# 거래일: 2021-04-16 00:00:00, 시스템: testSystem 0.0019958019256591797sec
# 거래일: 2021-04-19 00:00:00, 시스템: testSystem 0.002963542938232422sec
# 거래일: 2021-04-20 00:00:00, 시스템: testSystem 0.0040166378021240234sec
# 거래일: 2021-04-21 00:00:00, 시스템: testSystem 0.003962039947509766sec
# 거래일: 2021-04-22 00:00:00, 시스템: testSystem 0.004981279373168945sec
# 거래일: 2021-04-23 00:00:00, 시스템: testSystem 0.005983829498291016sec
# 거래일: 2021-04-26 00:00:00, 시스템: testSystem 0.0069811344146728516sec
# 거래일: 2021-04-27 00:00:00, 시스템: testSystem 0.007978677749633789sec
# 거래일: 2021-04-28 00:00:00, 시스템: testSystem 0.00797891616821289sec
# 거래일: 2021-04-29 00:00:00, 시스템: testSystem 0.008975982666015625sec
# 거래일: 2021-04-30 00:00:00, 시스템: testSystem 0.009005069732666016sec
# 거래일: 2021-05-03 00:00:00, 시스템: testSystem 0.009972572326660156sec
# 거래일: 2021-05-04 00:00:00, 시스템: testSystem 0.015957355499267578sec
# 거래일: 2021-05-05 00:00:00, 시스템: testSystem 0.015958309173583984sec
# 거래일: 2021-05-06 00:00:00, 시스템: testSystem 0.011966705322265625sec
# 거래일: 2021-05-07 00:00:00, 시스템: testSystem 0.012965917587280273sec
# 거래일: 2021-05-10 00:00:00, 시스템: testSystem 0.013934850692749023sec
# 거래일: 2021-05-11 00:00:00, 시스템: testSystem 0.014959573745727539sec
# 거래일: 2021-05-12 00:00:00, 시스템: testSystem 0.014990806579589844sec
# 거래일: 2021-05-13 00:00:00, 시스템: testSystem 0.015956640243530273sec
# 거래일: 2021-05-14 00:00:00, 시스템: testSystem 0.016952037811279297sec
# 거래일: 2021-05-17 00:00:00, 시스템: testSystem 0.01695537567138672sec
# 거래일: 2021-05-18 00:00:00, 시스템: testSystem 0.017923355102539062sec
# 거래일: 2021-05-19 00:00:00, 시스템: testSystem 0.01795172691345215sec
# 거래일: 2021-05-20 00:00:00, 시스템: testSystem 0.018949270248413086sec
# 거래일: 2021-05-21 00:00:00, 시스템: testSystem 0.01795220375061035sec
# 거래일: 2021-05-24 00:00:00, 시스템: testSystem 0.0169827938079834sec
# 거래일: 2021-05-25 00:00:00, 시스템: testSystem 0.016954421997070312sec
# 거래일: 2021-05-26 00:00:00, 시스템: testSystem 0.01837611198425293sec
# 거래일: 2021-05-27 00:00:00, 시스템: testSystem 0.01795196533203125sec
# 거래일: 2021-05-28 00:00:00, 시스템: testSystem 0.01795196533203125sec
# 거래일: 2021-05-31 00:00:00, 시스템: testSystem 0.008976221084594727sec
# 거래일: 2021-06-01 00:00:00, 시스템: testSystem 0.0019941329956054688sec
# 거래일: 2021-06-02 00:00:00, 시스템: testSystem 0.001995086669921875sec
# 거래일: 2021-06-03 00:00:00, 시스템: testSystem 0.000997304916381836sec
# 거래일: 2021-06-04 00:00:00, 시스템: testSystem 0.002991914749145508sec
# 거래일: 2021-06-07 00:00:00, 시스템: testSystem 0.0019948482513427734sec
# 거래일: 2021-06-08 00:00:00, 시스템: testSystem 0.000997304916381836sec
# 거래일: 2021-06-09 00:00:00, 시스템: testSystem 0.001994609832763672sec
# 거래일: 2021-06-10 00:00:00, 시스템: testSystem 0.001994609832763672sec
# 거래일: 2021-06-11 00:00:00, 시스템: testSystem 0.001994609832763672sec
# 거래일: 2021-06-14 00:00:00, 시스템: testSystem 0.0019948482513427734sec
# 거래일: 2021-06-15 00:00:00, 시스템: testSystem 0.000997304916381836sec
# 거래일: 2021-06-16 00:00:00, 시스템: testSystem 0.001994609832763672sec
# 거래일: 2021-06-17 00:00:00, 시스템: testSystem 0.001994609832763672sec
# 거래일: 2021-06-18 00:00:00, 시스템: testSystem 0.001995086669921875sec
# 거래일: 2021-06-21 00:00:00, 시스템: testSystem 0.0019943714141845703sec
# 거래일: 2021-06-22 00:00:00, 시스템: testSystem 0.0019948482513427734sec
# 거래일: 2021-06-23 00:00:00, 시스템: testSystem 0.0009996891021728516sec
# 거래일: 2021-06-24 00:00:00, 시스템: testSystem 0.000997304916381836sec
# 거래일: 2021-06-25 00:00:00, 시스템: testSystem 0.001994609832763672sec
# 거래일: 2021-06-28 00:00:00, 시스템: testSystem 0.0019948482513427734sec
# 거래일: 2021-06-29 00:00:00, 시스템: testSystem 0.001994609832763672sec
# 거래일: 2021-06-30 00:00:00, 시스템: testSystem 0.0019958019256591797sec
# 거래일: 2021-07-01 00:00:00, 시스템: testSystem 0.000997304916381836sec
# 거래일: 2021-07-02 00:00:00, 시스템: testSystem 0.001994609832763672sec
# 거래일: 2021-07-05 00:00:00, 시스템: testSystem 0.0019943714141845703sec
# 거래일: 2021-07-06 00:00:00, 시스템: testSystem 0.000997781753540039sec
# 거래일: 2021-07-07 00:00:00, 시스템: testSystem 0.0019943714141845703sec
# 거래일: 2021-07-08 00:00:00, 시스템: testSystem 0.0019948482513427734sec
# 거래일: 2021-07-09 00:00:00, 시스템: testSystem 0.001994609832763672sec
# 거래일: 2021-07-12 00:00:00, 시스템: testSystem 0.001994609832763672sec
# 거래일: 2021-07-13 00:00:00, 시스템: testSystem 0.0019948482513427734sec
# 거래일: 2021-07-14 00:00:00, 시스템: testSystem 0.001994609832763672sec
# 거래일: 2021-07-15 00:00:00, 시스템: testSystem 0.0009970664978027344sec
# 거래일: 2021-07-16 00:00:00, 시스템: testSystem 0.0019948482513427734sec
# 거래일: 2021-07-19 00:00:00, 시스템: testSystem 0.0019948482513427734sec
# 거래일: 2021-07-20 00:00:00, 시스템: testSystem 0.001994609832763672sec
# 거래일: 2021-07-21 00:00:00, 시스템: testSystem 0.001994609832763672sec
# 거래일: 2021-07-22 00:00:00, 시스템: testSystem 0.000997304916381836sec
# 거래일: 2021-07-23 00:00:00, 시스템: testSystem 0.0019948482513427734sec
# 거래일: 2021-07-26 00:00:00, 시스템: testSystem 0.0019948482513427734sec
# 거래일: 2021-07-27 00:00:00, 시스템: testSystem 0.0019943714141845703sec
# 거래일: 2021-07-28 00:00:00, 시스템: testSystem 0.001994609832763672sec
# 거래일: 2021-07-29 00:00:00, 시스템: testSystem 0.001994609832763672sec
# 거래일: 2021-07-30 00:00:00, 시스템: testSystem 0.000997304916381836sec
# 거래일: 2021-08-02 00:00:00, 시스템: testSystem 0.0019948482513427734sec
# 거래일: 2021-08-03 00:00:00, 시스템: testSystem 0.0019943714141845703sec
# 거래일: 2021-08-04 00:00:00, 시스템: testSystem 0.001993894577026367sec
# 거래일: 2021-08-05 00:00:00, 시스템: testSystem 0.001994609832763672sec
# 거래일: 2021-08-06 00:00:00, 시스템: testSystem 0.001994609832763672sec
# 거래일: 2021-08-09 00:00:00, 시스템: testSystem 0.000997304916381836sec
# 거래일: 2021-08-10 00:00:00, 시스템: testSystem 0.0019948482513427734sec
# 거래일: 2021-08-11 00:00:00, 시스템: testSystem 0.0019943714141845703sec
# 거래일: 2021-08-12 00:00:00, 시스템: testSystem 0.0019948482513427734sec
# 거래일: 2021-08-13 00:00:00, 시스템: testSystem 0.001994609832763672sec
# 거래일: 2021-08-16 00:00:00, 시스템: testSystem 0.001994609832763672sec
# 거래일: 2021-08-17 00:00:00, 시스템: testSystem 0.000997304916381836sec
# 거래일: 2021-08-18 00:00:00, 시스템: testSystem 0.0019948482513427734sec
# 거래일: 2021-08-19 00:00:00, 시스템: testSystem 0.0019943714141845703sec
# 거래일: 2021-08-20 00:00:00, 시스템: testSystem 0.0019948482513427734sec
# 거래일: 2021-08-23 00:00:00, 시스템: testSystem 0.0019943714141845703sec
# 거래일: 2021-08-24 00:00:00, 시스템: testSystem 0.001995086669921875sec
# 거래일: 2021-08-25 00:00:00, 시스템: testSystem 0.001994609832763672sec
# 거래일: 2021-08-26 00:00:00, 시스템: testSystem 0.0019948482513427734sec
# 거래일: 2021-08-27 00:00:00, 시스템: testSystem 0.001994609832763672sec
# 거래일: 2021-08-30 00:00:00, 시스템: testSystem 0.0019941329956054688sec
# 거래일: 2021-08-31 00:00:00, 시스템: testSystem 0.0019965171813964844sec
# 거래일: 2021-09-01 00:00:00, 시스템: testSystem 0.001024007797241211sec
# 거래일: 2021-09-02 00:00:00, 시스템: testSystem 0.000995635986328125sec
# 거래일: 2021-09-03 00:00:00, 시스템: testSystem 0.0019936561584472656sec
# 거래일: 2021-09-06 00:00:00, 시스템: testSystem 0.0029935836791992188sec
# 거래일: 2021-09-07 00:00:00, 시스템: testSystem 0.001990079879760742sec
# 거래일: 2021-09-08 00:00:00, 시스템: testSystem 0.0029969215393066406sec
# 거래일: 2021-09-09 00:00:00, 시스템: testSystem 0.004991292953491211sec
# 거래일: 2021-09-10 00:00:00, 시스템: testSystem 0.0049517154693603516sec
# 거래일: 2021-09-13 00:00:00, 시스템: testSystem 0.005984067916870117sec
# 거래일: 2021-09-14 00:00:00, 시스템: testSystem 0.0069811344146728516sec
# 거래일: 2021-09-15 00:00:00, 시스템: testSystem 0.007978677749633789sec
# 거래일: 2021-09-16 00:00:00, 시스템: testSystem 0.00797891616821289sec
# 거래일: 2021-09-17 00:00:00, 시스템: testSystem 0.004987478256225586sec
# 거래일: 2021-09-20 00:00:00, 시스템: testSystem 0.0019948482513427734sec
# 거래일: 2021-09-21 00:00:00, 시스템: testSystem 0.001994609832763672sec
# 거래일: 2021-09-22 00:00:00, 시스템: testSystem 0.0019948482513427734sec
# 거래일: 2021-09-23 00:00:00, 시스템: testSystem 0.001994609832763672sec
# 거래일: 2021-09-24 00:00:00, 시스템: testSystem 0.000997304916381836sec
# 거래일: 2021-09-27 00:00:00, 시스템: testSystem 0.0019948482513427734sec
# 거래일: 2021-09-28 00:00:00, 시스템: testSystem 0.0019943714141845703sec
# 거래일: 2021-09-29 00:00:00, 시스템: testSystem 0.001994609832763672sec
# 거래일: 2021-09-30 00:00:00, 시스템: testSystem 0.001994609832763672sec
# 거래일: 2021-10-01 00:00:00, 시스템: testSystem 0.0019948482513427734sec
# 거래일: 2021-10-04 00:00:00, 시스템: testSystem 0.000997304916381836sec
# 거래일: 2021-10-05 00:00:00, 시스템: testSystem 0.0019948482513427734sec
# 거래일: 2021-10-06 00:00:00, 시스템: testSystem 0.0019943714141845703sec
# 거래일: 2021-10-07 00:00:00, 시스템: testSystem 0.0019948482513427734sec
# 거래일: 2021-10-08 00:00:00, 시스템: testSystem 0.0019943714141845703sec
# 거래일: 2021-10-11 00:00:00, 시스템: testSystem 0.0019948482513427734sec
# 거래일: 2021-10-12 00:00:00, 시스템: testSystem 0.000997304916381836sec
# 거래일: 2021-10-13 00:00:00, 시스템: testSystem 0.0029921531677246094sec
# 거래일: 2021-10-14 00:00:00, 시스템: testSystem 0.003988981246948242sec
# 거래일: 2021-10-15 00:00:00, 시스템: testSystem 0.003989458084106445sec
# 거래일: 2021-10-18 00:00:00, 시스템: testSystem 0.004986763000488281sec
# 거래일: 2021-10-19 00:00:00, 시스템: testSystem 0.00598454475402832sec
# 거래일: 2021-10-20 00:00:00, 시스템: testSystem 0.007005214691162109sec
# 거래일: 2021-10-21 00:00:00, 시스템: testSystem 0.006984233856201172sec
# 거래일: 2021-10-22 00:00:00, 시스템: testSystem 0.007979631423950195sec
# 거래일: 2021-10-25 00:00:00, 시스템: testSystem 0.008976459503173828sec
# 거래일: 2021-10-26 00:00:00, 시스템: testSystem 0.00896906852722168sec
# 거래일: 2021-10-27 00:00:00, 시스템: testSystem 0.009980201721191406sec
# 거래일: 2021-10-28 00:00:00, 시스템: testSystem 0.009999752044677734sec
# 거래일: 2021-10-29 00:00:00, 시스템: testSystem 0.011963367462158203sec
# 거래일: 2021-11-01 00:00:00, 시스템: testSystem 0.012969732284545898sec
# 거래일: 2021-11-02 00:00:00, 시스템: testSystem 0.012965679168701172sec
# 거래일: 2021-11-03 00:00:00, 시스템: testSystem 0.012964725494384766sec
# 거래일: 2021-11-04 00:00:00, 시스템: testSystem 0.014957427978515625sec
# 거래일: 2021-11-05 00:00:00, 시스템: testSystem 0.01596236228942871sec
# 거래일: 2021-11-08 00:00:00, 시스템: testSystem 0.015957117080688477sec
# 거래일: 2021-11-09 00:00:00, 시스템: testSystem 0.017921924591064453sec
# 거래일: 2021-11-10 00:00:00, 시스템: testSystem 0.018949270248413086sec
# 거래일: 2021-11-11 00:00:00, 시스템: testSystem 0.008975982666015625sec
# 거래일: 2021-11-12 00:00:00, 시스템: testSystem 0.001994609832763672sec
# 거래일: 2021-11-15 00:00:00, 시스템: testSystem 0.0019948482513427734sec
# 거래일: 2021-11-16 00:00:00, 시스템: testSystem 0.0019948482513427734sec
# 거래일: 2021-11-17 00:00:00, 시스템: testSystem 0.0009970664978027344sec
# 거래일: 2021-11-18 00:00:00, 시스템: testSystem 0.001994609832763672sec
# 거래일: 2021-11-19 00:00:00, 시스템: testSystem 0.001994609832763672sec
# 거래일: 2021-11-22 00:00:00, 시스템: testSystem 0.001995086669921875sec
# 거래일: 2021-11-23 00:00:00, 시스템: testSystem 0.0019943714141845703sec
# 거래일: 2021-11-24 00:00:00, 시스템: testSystem 0.0019948482513427734sec
# 거래일: 2021-11-25 00:00:00, 시스템: testSystem 0.0009970664978027344sec
# 거래일: 2021-11-26 00:00:00, 시스템: testSystem 0.0019948482513427734sec
# 거래일: 2021-11-29 00:00:00, 시스템: testSystem 0.0019943714141845703sec
# 거래일: 2021-11-30 00:00:00, 시스템: testSystem 0.0019948482513427734sec
# 거래일: 2021-12-01 00:00:00, 시스템: testSystem 0.0009970664978027344sec
# 거래일: 2021-12-02 00:00:00, 시스템: testSystem 0.001995086669921875sec
# 거래일: 2021-12-03 00:00:00, 시스템: testSystem 0.0019943714141845703sec
# 거래일: 2021-12-06 00:00:00, 시스템: testSystem 0.0019948482513427734sec
# 거래일: 2021-12-07 00:00:00, 시스템: testSystem 0.0019943714141845703sec
# 거래일: 2021-12-08 00:00:00, 시스템: testSystem 0.000997781753540039sec
# 거래일: 2021-12-09 00:00:00, 시스템: testSystem 0.0019943714141845703sec
# 거래일: 2021-12-10 00:00:00, 시스템: testSystem 0.0019948482513427734sec
# 거래일: 2021-12-13 00:00:00, 시스템: testSystem 0.0019943714141845703sec
# 거래일: 2021-12-14 00:00:00, 시스템: testSystem 0.0019948482513427734sec
# 거래일: 2021-12-15 00:00:00, 시스템: testSystem 0.001994609832763672sec
# 거래일: 2021-12-16 00:00:00, 시스템: testSystem 0.000997304916381836sec
# 거래일: 2021-12-17 00:00:00, 시스템: testSystem 0.001994609832763672sec
# 거래일: 2021-12-20 00:00:00, 시스템: testSystem 0.0019948482513427734sec
# 거래일: 2021-12-21 00:00:00, 시스템: testSystem 0.0019943714141845703sec
# 거래일: 2021-12-22 00:00:00, 시스템: testSystem 0.001995086669921875sec
# 거래일: 2021-12-23 00:00:00, 시스템: testSystem 0.0009970664978027344sec
# 거래일: 2021-12-24 00:00:00, 시스템: testSystem 0.0019948482513427734sec
# 거래일: 2021-12-27 00:00:00, 시스템: testSystem 0.0019943714141845703sec
# 거래일: 2021-12-28 00:00:00, 시스템: testSystem 0.0019948482513427734sec
# 거래일: 2021-12-29 00:00:00, 시스템: testSystem 0.0019943714141845703sec
# 거래일: 2021-12-30 00:00:00, 시스템: testSystem 0.003989458084106445sec
# 거래일: 2021-12-31 00:00:00, 시스템: testSystem 0.003989458084106445sec
# 거래일: 2022-01-03 00:00:00, 시스템: testSystem 0.005984067916870117sec
# 거래일: 2022-01-04 00:00:00, 시스템: testSystem 0.00498652458190918sec
# 거래일: 2022-01-05 00:00:00, 시스템: testSystem 0.006981372833251953sec
# 거래일: 2022-01-06 00:00:00, 시스템: testSystem 0.006981372833251953sec
# 거래일: 2022-01-07 00:00:00, 시스템: testSystem 0.008009195327758789sec
# 거래일: 2022-01-10 00:00:00, 시스템: testSystem 0.003989458084106445sec
# 거래일: 2022-01-11 00:00:00, 시스템: testSystem 0.001994609832763672sec
# 거래일: 2022-01-12 00:00:00, 시스템: testSystem 0.001995086669921875sec
# 거래일: 2022-01-13 00:00:00, 시스템: testSystem 0.001996278762817383sec
# 거래일: 2022-01-14 00:00:00, 시스템: testSystem 0.002991914749145508sec
# 거래일: 2022-01-17 00:00:00, 시스템: testSystem 0.0029900074005126953sec
# 거래일: 2022-01-18 00:00:00, 시스템: testSystem 0.001991748809814453sec
# 거래일: 2022-01-19 00:00:00, 시스템: testSystem 0.003992557525634766sec
# 거래일: 2022-01-20 00:00:00, 시스템: testSystem 0.0029916763305664062sec
# 거래일: 2022-01-21 00:00:00, 시스템: testSystem 0.0029935836791992188sec
# 거래일: 2022-01-24 00:00:00, 시스템: testSystem 0.0039844512939453125sec
# 거래일: 2022-01-25 00:00:00, 시스템: testSystem 0.002000093460083008sec
# 거래일: 2022-01-26 00:00:00, 시스템: testSystem 0.0019941329956054688sec
# 거래일: 2022-01-27 00:00:00, 시스템: testSystem 0.001993417739868164sec
# 거래일: 2022-01-28 00:00:00, 시스템: testSystem 0.0019943714141845703sec
# 거래일: 2022-01-31 00:00:00, 시스템: testSystem 0.0009970664978027344sec
# 거래일: 2022-02-01 00:00:00, 시스템: testSystem 0.001995563507080078sec
# 거래일: 2022-02-02 00:00:00, 시스템: testSystem 0.0019958019256591797sec
# 거래일: 2022-02-03 00:00:00, 시스템: testSystem 0.0019931793212890625sec
# 거래일: 2022-02-04 00:00:00, 시스템: testSystem 0.0019948482513427734sec
# 거래일: 2022-02-07 00:00:00, 시스템: testSystem 0.0019953250885009766sec
# 거래일: 2022-02-08 00:00:00, 시스템: testSystem 0.0009963512420654297sec
# 거래일: 2022-02-09 00:00:00, 시스템: testSystem 0.0019943714141845703sec
# 거래일: 2022-02-10 00:00:00, 시스템: testSystem 0.0019948482513427734sec
# 거래일: 2022-02-11 00:00:00, 시스템: testSystem 0.001991748809814453sec
# 거래일: 2022-02-14 00:00:00, 시스템: testSystem 0.0019974708557128906sec
# 거래일: 2022-02-15 00:00:00, 시스템: testSystem 0.0010027885437011719sec
# 거래일: 2022-02-16 00:00:00, 시스템: testSystem 0.0019915103912353516sec
# 거래일: 2022-02-17 00:00:00, 시스템: testSystem 0.001992940902709961sec
# 거래일: 2022-02-18 00:00:00, 시스템: testSystem 0.0029914379119873047sec
# 거래일: 2022-02-21 00:00:00, 시스템: testSystem 0.003989458084106445sec
# 거래일: 2022-02-22 00:00:00, 시스템: testSystem 0.003994464874267578sec
# 거래일: 2022-02-23 00:00:00, 시스템: testSystem 0.004987001419067383sec
# 거래일: 2022-02-24 00:00:00, 시스템: testSystem 0.005984067916870117sec
# 거래일: 2022-02-25 00:00:00, 시스템: testSystem 0.006951332092285156sec
# 거래일: 2022-02-28 00:00:00, 시스템: testSystem 0.008975744247436523sec
# 거래일: 2022-03-01 00:00:00, 시스템: testSystem 0.007978439331054688sec
# 거래일: 2022-03-02 00:00:00, 시스템: testSystem 0.008976221084594727sec
# 거래일: 2022-03-03 00:00:00, 시스템: testSystem 0.010998725891113281sec
# 거래일: 2022-03-04 00:00:00, 시스템: testSystem 0.009973287582397461sec
# 거래일: 2022-03-07 00:00:00, 시스템: testSystem 0.010943174362182617sec
# 거래일: 2022-03-08 00:00:00, 시스템: testSystem 0.011997222900390625sec
# 거래일: 2022-03-09 00:00:00, 시스템: testSystem 0.01296091079711914sec
# 거래일: 2022-03-10 00:00:00, 시스템: testSystem 0.012964248657226562sec
# 거래일: 2022-03-11 00:00:00, 시스템: testSystem 0.013968229293823242sec
# 거래일: 2022-03-14 00:00:00, 시스템: testSystem 0.013961076736450195sec
# 거래일: 2022-03-15 00:00:00, 시스템: testSystem 0.015957117080688477sec
# 거래일: 2022-03-16 00:00:00, 시스템: testSystem 0.016954898834228516sec
# 거래일: 2022-03-17 00:00:00, 시스템: testSystem 0.016926050186157227sec
# 거래일: 2022-03-18 00:00:00, 시스템: testSystem 0.017982959747314453sec
# 거래일: 2022-03-21 00:00:00, 시스템: testSystem 0.018920183181762695sec
# 거래일: 2022-03-22 00:00:00, 시스템: testSystem 0.0199737548828125sec
# 거래일: 2022-03-23 00:00:00, 시스템: testSystem 0.019917726516723633sec
# 거래일: 2022-03-24 00:00:00, 시스템: testSystem 0.020972013473510742sec
# 거래일: 2022-03-25 00:00:00, 시스템: testSystem 0.021941184997558594sec
# 거래일: 2022-03-28 00:00:00, 시스템: testSystem 0.02191448211669922sec
# 거래일: 2022-03-29 00:00:00, 시스템: testSystem 0.02296614646911621sec
# 거래일: 2022-03-30 00:00:00, 시스템: testSystem 0.02293539047241211sec
# 거래일: 2022-03-31 00:00:00, 시스템: testSystem 0.024936437606811523sec
# 거래일: 2022-04-01 00:00:00, 시스템: testSystem 0.024904727935791016sec
# 거래일: 2022-04-04 00:00:00, 시스템: testSystem 0.025930404663085938sec
# 거래일: 2022-04-05 00:00:00, 시스템: testSystem 0.026929616928100586sec
# 거래일: 2022-04-06 00:00:00, 시스템: testSystem 0.0279238224029541sec
# 거래일: 2022-04-07 00:00:00, 시스템: testSystem 0.028922557830810547sec
# 거래일: 2022-04-08 00:00:00, 시스템: testSystem 0.029920339584350586sec
# 거래일: 2022-04-11 00:00:00, 시스템: testSystem 0.029919862747192383sec
# 거래일: 2022-04-12 00:00:00, 시스템: testSystem 0.029919862747192383sec
# 거래일: 2022-04-13 00:00:00, 시스템: testSystem 0.03291177749633789sec
# 거래일: 2022-04-14 00:00:00, 시스템: testSystem 0.03091740608215332sec
# 거래일: 2022-04-18 00:00:00, 시스템: testSystem 0.03191566467285156sec
# 거래일: 2022-04-19 00:00:00, 시스템: testSystem 0.030916452407836914sec
# 거래일: 2022-04-20 00:00:00, 시스템: testSystem 0.015957117080688477sec
# 거래일: 2022-04-21 00:00:00, 시스템: testSystem 0.001994609832763672sec
# 거래일: 2022-04-22 00:00:00, 시스템: testSystem 0.000997304916381836sec
# 거래일: 2022-04-25 00:00:00, 시스템: testSystem 0.0019948482513427734sec
# 거래일: 2022-04-26 00:00:00, 시스템: testSystem 0.001994609832763672sec
# 거래일: 2022-04-27 00:00:00, 시스템: testSystem 0.001994609832763672sec
# 거래일: 2022-04-28 00:00:00, 시스템: testSystem 0.001994609832763672sec
# 거래일: 2022-04-29 00:00:00, 시스템: testSystem 0.0009975433349609375sec
# 거래일: 2022-05-02 00:00:00, 시스템: testSystem 0.0019941329956054688sec
# 거래일: 2022-05-03 00:00:00, 시스템: testSystem 0.001995086669921875sec
# 거래일: 2022-05-04 00:00:00, 시스템: testSystem 0.001994609832763672sec

# %% [markdown]
# ### 2. PDF 파일 생성

# %%
font = 'Malgun Gothic'
fontdir = os.path.join("c:\\windows",'fonts','malgun.ttf')
pdfmetrics.registerFont(TTFont('malgun', fontdir))
pdfmetrics.registerFont(TTFont('gulim', os.path.join("c:\\windows",'fonts','NGULIM.TTF')))
p = canvas.Canvas('hello.pdf', pagesize=A4) #객체 생성
A4
# Out:
# (595.2755905511812, 841.8897637795277)

# %%
system1
# Out:
# {'name': 'testSystem',
#  'description': '시스템 설명',
#  'sectors': 'default',
#  'instruments': ['AD'],
#  'from_date': '2019-08-01',
#  'to_date': None,
#  'principal': 1000000,
#  'heat_system': 'DefaultHeat',
#  'max_system_heat': 0.3,
#  'max_sector_heat': 0.3,
#  'max_trade_heat': 0.01,
#  'max_lots': 100,
#  'commission': 5.98,
#  'skid': 0.25,
#  'metrics': [['ema30', 'EMA', 'window=30'],
#   ['ema5', 'EMA', 'window=5'],
#   ['min30', 'MIN', 'window=30'],
#   ['max300', 'MAX', 'window=300']],
#  'entry_rule': {'long': 'ema5>ema30', 'short': None},
#  'exit_rule': {'long': 'ema5<ema30', 'short': None},
#  'stop_rule': {'long': 'min30', 'short': None}}

# %% [markdown]
# ### Page 1. 시스템 설명

# %%
p = canvas.Canvas('hello.pdf', pagesize=A4)
p.setFont('gulim',15)


p.drawString(30, 740, f"시스템 이름: {system1['name']}")
p.drawString(30, 720, f"시스템 설명: {system1['description']}")
style = 'Backward Panama Adjusted Method'
p.drawString(30, 700, f"테스팅 데이터: ")
p.drawString(30, 680, f"거래기간: {system1['from_date']} ~ {system1['to_date'] if system1['to_date'] else ''}")
p.drawString(30, 660, f"거래상품: {system1['instruments']}")
p.drawString(30, 640, f"리스크 관리: {system1['heat_system']}")
p.drawString(30, 620, f"최대허용 시스템 리스크: {system1['max_system_heat']}")
p.drawString(30, 600, f"최대허용 섹터 리스크: {system1['max_sector_heat']}")
p.drawString(30, 580, f"최대허용 매매당 리스크: {system1['max_trade_heat']}")
p.drawString(30, 560, f"수수료/계약: ${system1['commission']}")
p.drawString(30, 540, f"skid: {system1['skid']} 틱")
p.drawString(30, 520, f"진입전략: {system1['entry_rule']}")
p.drawString(30, 500, f"청산전략: {system1['exit_rule']}")



#renderPDF.draw(img, p, 30, 100)
#img =ImageReader(im)
#p.drawImage(img, 30, 400)
#p.save()

# %% [markdown]
# ### Page 2. 결과요약

# %%
p.save()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In [27], line 1
# ----> 1 p.save()
#
# File c:\python\miniconda3\lib\site-packages\reportlab\pdfgen\canvas.py:1272, in Canvas.save(self)
#    1268 """Saves and close the PDF document in the file.
#    1269    If there is current data a ShowPage is executed automatically.
#    1270    After this operation the canvas must not be used further."""
#    1271 if len(self._code): self.showPage()
# -> 1272 self._doc.SaveToFile(self._filename, self)
#
# File c:\python\miniconda3\lib\site-packages\reportlab\pdfbase\pdfdoc.py:194, in PDFDocument.SaveToFile(self, filename, canvas)
#     192 def SaveToFile(self, filename, canvas):
#     193     if getattr(self,'_savedToFile',False):
# --> 194         raise RuntimeError("class %s instances can only be saved once" % self.__class__.__name__)
#     195     self._savedToFile = True
#     196     if hasattr(getattr(filename, "write",None),'__call__'):
#
# RuntimeError: class PDFDocument instances can only be saved once

# %%
import io
from PIL import Image
from svglib.svglib import svg2rlg

# %%
ax = plt.subplot()
ax.plot([1,2,3],[1,41,9])

buf = io.BytesIO()
plt.savefig(buf, format='svg')
buf.seek(0)
img = svg2rlg(buf)

# %%
img = svg2rlg('test.svg')

# %%
plt.savefig?

# %%
im.show()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Input In [140], in <cell line: 1>()
# ----> 1 im.show()
#
# File c:\python\miniconda3\lib\site-packages\PIL\Image.py:2259, in Image.show(self, title)
#    2239 def show(self, title=None):
#    2240     """
#    2241     Displays this image. This method is mainly intended for debugging purposes.
#    2242
#    (...)
#    2256     :param title: Optional title to use for the image window, where possible.
#    2257     """
# -> 2259     _show(self, title=title)
#
# File c:\python\miniconda3\lib\site-packages\PIL\Image.py:3233, in _show(image, **options)
#    3230 def _show(image, **options):
#    3231     from . import ImageShow
# -> 3233     ImageShow.show(image, **options)
#
# File c:\python\miniconda3\lib\site-packages\PIL\ImageShow.py:55, in show(image, title, **options)
#      46 r"""
#      47 Display a given image.
#      48
#    (...)
#      52 :returns: ``True`` if a suitable viewer was found, ``False`` otherwise.
#      53 """
#      54 for viewer in _viewers:
# ---> 55     if viewer.show(image, title=title, **options):
#      56         return 1
#      57 return 0
#
# File c:\python\miniconda3\lib\site-packages\PIL\ImageShow.py:79, in Viewer.show(self, image, **options)
#      76     if image.mode != base:
#      77         image = image.convert(base)
# ---> 79 return self.show_image(image, **options)
#
# File c:\python\miniconda3\lib\site-packages\PIL\ImageShow.py:105, in Viewer.show_image(self, image, **options)
#     103 def show_image(self, image, **options):
#     104     """Display the given image."""
# --> 105     return self.show_file(self.save_image(image), **options)
#
# File c:\python\miniconda3\lib\site-packages\PIL\ImageShow.py:101, in Viewer.save_image(self, image)
#      99 def save_image(self, image):
#     100     """Save to temporary file and return filename."""
# --> 101     return image._dump(format=self.get_format(image), **self.options)
#
# File c:\python\miniconda3\lib\site-packages\PIL\Image.py:614, in Image._dump(self, file, format, **options)
#     611     if not filename.endswith(suffix):
#     612         filename = filename + suffix
# --> 614 self.load()
#     616 if not format or format == "PPM":
#     617     self.im.save_ppm(filename)
#
# File c:\python\miniconda3\lib\site-packages\PIL\EpsImagePlugin.py:334, in EpsImageFile.load(self, scale, transparency)
#     332 if not self.tile:
#     333     return
# --> 334 self.im = Ghostscript(self.tile, self.size, self.fp, scale, transparency)
#     335 self.mode = self.im.mode
#     336 self._size = self.im.size
#
# File c:\python\miniconda3\lib\site-packages\PIL\EpsImagePlugin.py:136, in Ghostscript(tile, size, fp, scale, transparency)
#     134 if gs_windows_binary is not None:
#     135     if not gs_windows_binary:
# --> 136         raise OSError("Unable to locate Ghostscript on paths")
#     137     command[0] = gs_windows_binary
#     139 # push data through Ghostscript
#
# OSError: Unable to locate Ghostscript on paths

# %%
buf.close
# Out:
# <function BytesIO.close()>

# %%
plt.savefig('test.jpg')

# %%
os.path.join("c:\\windows",'fonts','malgun.ttf')
# Out:
# 'c:\\windows\\fonts\\malgun.ttf'

# %%
print(os.listdir(r'C:\Windows\fonts'))
# Out:
# ['8514fix.fon', '8514fixe.fon', '8514fixg.fon', '8514fixr.fon', '8514fixt.fon', '8514oem.fon', '8514oeme.fon', '8514oemg.fon', '8514oemr.fon', '8514oemt.fon', '8514sys.fon', '8514syse.fon', '8514sysg.fon', '8514sysr.fon', '8514syst.fon', '85775.fon', '85855.fon', '85f1255.fon', '85f1256.fon', '85f1257.fon', '85f874.fon', '85s1255.fon', '85s1256.fon', '85s1257.fon', '85s874.fon', 'ahn_b.ttf', 'ahn_l.ttf', 'ahn_m.ttf', 'ALGER.TTF', 'ANTQUAB.TTF', 'ANTQUABI.TTF', 'ANTQUAI.TTF', 'app775.fon', 'app850.fon', 'app852.fon', 'app855.fon', 'app857.fon', 'app866.fon', 'app932.fon', 'app936.fon', 'app949.fon', 'app950.fon', 'arial.ttf', 'arialbd.ttf', 'arialbi.ttf', 'ariali.ttf', 'ARIALN.TTF', 'ARIALNB.TTF', 'ARIALNBI.TTF', 'ARIALNI.TTF', 'ARIALUNI.TTF', 'ariblk.ttf', 'bahnschrift.ttf', 'BASKVILL.TTF', 'batang.ttc', 'BAUHS93.TTF', 'BELL.TTF', 'BELLB.TTF', 'BELLI.TTF', 'BERNHC.TTF', 'BKANT.TTF', 'BOD_PSTC.TTF', 'BOOKOS.TTF', 'BOOKOSB.TTF', 'BOOKOSBI.TTF', 'BOOKOSI.TTF', 'BRITANIC.TTF', 'BRLNSB.TTF', 'BRLNSDB.TTF', 'BRLNSR.TTF', 'BROADW.TTF', 'BRUSHSCI.TTF', 'BSSYM7.TTF', 'c8514fix.fon', 'c8514oem.fon', 'c8514sys.fon', 'calibri.ttf', 'calibrib.ttf', 'calibrii.ttf', 'calibril.ttf', 'calibrili.ttf', 'calibriz.ttf', 'CALIFB.TTF', 'CALIFI.TTF', 'CALIFR.TTF', 'cambria.ttc', 'cambriab.ttf', 'cambriai.ttf', 'cambriaz.ttf', 'Candara.ttf', 'Candarab.ttf', 'Candarai.ttf', 'Candaral.ttf', 'Candarali.ttf', 'Candaraz.ttf', 'CENTAUR.TTF', 'CENTURY.TTF', 'cga40737.fon', 'cga40850.fon', 'cga40852.fon', 'cga40857.fon', 'cga40866.fon', 'cga40869.fon', 'cga40woa.fon', 'cga80737.fon', 'cga80850.fon', 'cga80852.fon', 'cga80857.fon', 'cga80866.fon', 'cga80869.fon', 'cga80woa.fon', 'CHILLER.TTF', 'COLONNA.TTF', 'comic.ttf', 'comicbd.ttf', 'comici.ttf', 'comicz.ttf', 'consola.ttf', 'consolab.ttf', 'consolai.ttf', 'consolaz.ttf', 'constan.ttf', 'constanb.ttf', 'constani.ttf', 'constanz.ttf', 'COOPBL.TTF', 'corbel.ttf', 'corbelb.ttf', 'corbeli.ttf', 'corbell.ttf', 'corbelli.ttf', 'corbelz.ttf', 'coue1255.fon', 'coue1256.fon', 'coue1257.fon', 'couf1255.fon', 'couf1256.fon', 'couf1257.fon', 'cour.ttf', 'courbd.ttf', 'courbi.ttf', 'coure.fon', 'couree.fon', 'coureg.fon', 'courer.fon', 'couret.fon', 'courf.fon', 'courfe.fon', 'courfg.fon', 'courfr.fon', 'courft.fon', 'couri.ttf', 'cvgafix.fon', 'cvgasys.fon', 'Deng.ttf', 'Dengb.ttf', 'Dengl.ttf', 'desktop.ini', 'dos737.fon', 'dos869.fon', 'dosapp.fon', 'ebrima.ttf', 'ebrimabd.ttf', 'ega40737.fon', 'ega40850.fon', 'ega40852.fon', 'ega40857.fon', 'ega40866.fon', 'ega40869.fon', 'ega40woa.fon', 'ega80737.fon', 'ega80850.fon', 'ega80852.fon', 'ega80857.fon', 'ega80866.fon', 'ega80869.fon', 'ega80woa.fon', 'euclid.ttf', 'euclidb.ttf', 'euclidbi.ttf', 'euclidi.ttf', 'eucsym.ttf', 'eucsymb.ttf', 'eucsymbi.ttf', 'eucsymi.ttf', 'euextra.ttf', 'euextrab.ttf', 'eufrak.ttf', 'eufrakb.ttf', 'eumat1.ttf', 'eumat1b.ttf', 'eumat2.ttf', 'eumat2b.ttf', 'fences.ttf', 'fms_metadata.xml', 'framd.ttf', 'framdit.ttf', 'FREESCPT.TTF', 'FTLTLT.TTF', 'FZSong_Super.TTF', 'Gabriola.ttf', 'gadugi.ttf', 'gadugib.ttf', 'GARA.TTF', 'GARABD.TTF', 'GARAIT.TTF', 'georgia.ttf', 'georgiab.ttf', 'georgiai.ttf', 'georgiaz.ttf', 'GOTHIC.TTF', 'GOTHICB.TTF', 'GOTHICBI.TTF', 'GOTHICI.TTF', 'gulim.ttc', 'H2GPRM.TTF', 'H2GSRB.TTF', 'H2GTRE.TTF', 'H2GTRM.TTF', 'H2HDRM.TTF', 'H2MJRE.TTF', 'H2MJSM.TTF', 'H2MKPB.TTF', 'H2PORL.TTF', 'H2PORM.TTF', 'H2SA1M.TTF', 'h8514fix.fon', 'h8514oem.fon', 'h8514sys.fon', 'HARLOWSI.TTF', 'HARNGTON.TTF', 'HBATANG.TTF', 'HDOTUM.TTF', 'himalaya.ttf', 'HMFMMUEX.TTC', 'HMFMOLD.TTF', 'HMFMPYUN.TTF', 'HMKMAMI.TTF', 'HMKMMAG.TTF', 'HMKMRHD.TTF', 'holomdl2.ttf', 'HTOWERT.TTF', 'HTOWERTI.TTF', 'hvgafix.fon', 'hvgasys.fon', 'HYBDAL.TTF', 'HYBDAM.TTF', 'HYBSRB.TTF', 'HYCYSM.TTF', 'HYDNKB.TTF', 'HYDNKM.TTF', 'HYGPRM.TTF', 'HYGSRB.TTF', 'HYGTRE.TTF', 'HYHWPEQ.TTF', 'HYKANB.TTF', 'HYKANM.TTF', 'HYMJRE.TTF', 'HYMPRL.TTF', 'HYNAMB.TTF', 'HYNAML.TTF', 'HYNAMM.TTF', 'HYPORM.TTF', 'HYSANB.TTF', 'HYSNRL.TTF', 'HYSUPB.TTF', 'HYSUPM.TTF', 'HYTBRB.TTF', 'H ...
