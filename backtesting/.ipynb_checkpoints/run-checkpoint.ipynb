# %%
import sys, os #imp
sys.path.append('..')
import pandas as pd
import yaml
import backtesting as bt
import matplotlib.pyplot as plt

from tools.instruments import instruments

# %%
# %load_ext autoreload
# %aimport backtesting.system
# %aimport backtesting.trader
# %aimport tools.quotes
# %aimport backtesting.trades
# %autoreload 2

# %%
plt.ioff()

# %%
with open('systems/emacross.yaml', encoding='utf-8') as f:
    system1 = yaml.load(f, Loader=yaml.FullLoader)
    print(system1)
# Out:
# {'name': 'emacross', 'description': '시스템 설명', 'sectors': 'default', 'instruments': ['NQ'], 'from_date': '2018-01-01', 'to_date': None, 'principal': 100000, 'heat_system': 'DefaultHeat', 'max_system_heat': 0.5, 'max_sector_heat': 0.2, 'max_trade_heat': 0.1, 'max_lots': 1, 'commission': 2.99, 'skid': 20, 'allow_pyramiding': False, 'metrics': [['ema50', 'EMA', 'window=50'], ['ema200', 'EMA', 'window=200'], ['volatility', 'ATR', 'window=30'], ['min50', 'MIN', 'window=50'], ['max20', 'MAX', 'window=20']], 'entry_rule': {'long': 'ema50>ema200', 'short': None}, 'exit_rule': {'long': 'low<min50', 'short': None}, 'stop_rule': {'long': 'min50', 'short': None}}

# %%
trader = bt.Trader(systems=[system1])
system = trader.systems[0]
trader.run()
# Out:
# 매매시작
# 거래일: 2018-01-02 00:00:00, 시스템: emacross
# 거래일: 2018-01-03 00:00:00, 시스템: emacross
# 거래일: 2018-01-04 00:00:00, 시스템: emacross
# 거래일: 2018-01-05 00:00:00, 시스템: emacross
# 거래일: 2018-01-08 00:00:00, 시스템: emacross
# 거래일: 2018-01-09 00:00:00, 시스템: emacross
# 거래일: 2018-01-10 00:00:00, 시스템: emacross
# 거래일: 2018-01-11 00:00:00, 시스템: emacross
# 거래일: 2018-01-12 00:00:00, 시스템: emacross
# 거래일: 2018-01-15 00:00:00, 시스템: emacross
# 거래일: 2018-01-16 00:00:00, 시스템: emacross
# 거래일: 2018-01-17 00:00:00, 시스템: emacross
# 거래일: 2018-01-18 00:00:00, 시스템: emacross
# 거래일: 2018-01-19 00:00:00, 시스템: emacross
# 거래일: 2018-01-22 00:00:00, 시스템: emacross
# 거래일: 2018-01-23 00:00:00, 시스템: emacross
# 거래일: 2018-01-24 00:00:00, 시스템: emacross
# 거래일: 2018-01-25 00:00:00, 시스템: emacross
# 거래일: 2018-01-26 00:00:00, 시스템: emacross
# 거래일: 2018-01-29 00:00:00, 시스템: emacross
# 거래일: 2018-01-30 00:00:00, 시스템: emacross
# 거래일: 2018-01-31 00:00:00, 시스템: emacross
# 거래일: 2018-02-01 00:00:00, 시스템: emacross
# 거래일: 2018-02-02 00:00:00, 시스템: emacross
# 거래일: 2018-02-05 00:00:00, 시스템: emacross
# 거래일: 2018-02-06 00:00:00, 시스템: emacross
# 거래일: 2018-02-07 00:00:00, 시스템: emacross
# 거래일: 2018-02-08 00:00:00, 시스템: emacross
# 거래일: 2018-02-09 00:00:00, 시스템: emacross
# 거래일: 2018-02-12 00:00:00, 시스템: emacross
# 거래일: 2018-02-13 00:00:00, 시스템: emacross
# 거래일: 2018-02-14 00:00:00, 시스템: emacross
# 거래일: 2018-02-15 00:00:00, 시스템: emacross
# 거래일: 2018-02-16 00:00:00, 시스템: emacross
# 거래일: 2018-02-19 00:00:00, 시스템: emacross
# 거래일: 2018-02-20 00:00:00, 시스템: emacross
# 거래일: 2018-02-21 00:00:00, 시스템: emacross
# 거래일: 2018-02-22 00:00:00, 시스템: emacross
# 거래일: 2018-02-23 00:00:00, 시스템: emacross
# 거래일: 2018-02-26 00:00:00, 시스템: emacross
# 거래일: 2018-02-27 00:00:00, 시스템: emacross
# 거래일: 2018-02-28 00:00:00, 시스템: emacross
# 거래일: 2018-03-01 00:00:00, 시스템: emacross
# 거래일: 2018-03-02 00:00:00, 시스템: emacross
# 거래일: 2018-03-05 00:00:00, 시스템: emacross
# 거래일: 2018-03-06 00:00:00, 시스템: emacross
# 거래일: 2018-03-07 00:00:00, 시스템: emacross
# 거래일: 2018-03-08 00:00:00, 시스템: emacross
# 거래일: 2018-03-09 00:00:00, 시스템: emacross
# 거래일: 2018-03-12 00:00:00, 시스템: emacross
# 거래일: 2018-03-13 00:00:00, 시스템: emacross
# 거래일: 2018-03-14 00:00:00, 시스템: emacross
# 거래일: 2018-03-15 00:00:00, 시스템: emacross
# 거래일: 2018-03-16 00:00:00, 시스템: emacross
# 거래일: 2018-03-19 00:00:00, 시스템: emacross
# 거래일: 2018-03-20 00:00:00, 시스템: emacross
# 거래일: 2018-03-21 00:00:00, 시스템: emacross
# 거래일: 2018-03-22 00:00:00, 시스템: emacross
# 거래일: 2018-03-23 00:00:00, 시스템: emacross
# 거래일: 2018-03-26 00:00:00, 시스템: emacross
# 거래일: 2018-03-27 00:00:00, 시스템: emacross
# 거래일: 2018-03-28 00:00:00, 시스템: emacross
# 거래일: 2018-03-29 00:00:00, 시스템: emacross
# 거래일: 2018-04-02 00:00:00, 시스템: emacross
# 거래일: 2018-04-03 00:00:00, 시스템: emacross
# 거래일: 2018-04-04 00:00:00, 시스템: emacross
# 거래일: 2018-04-05 00:00:00, 시스템: emacross
# 거래일: 2018-04-06 00:00:00, 시스템: emacross
# 거래일: 2018-04-09 00:00:00, 시스템: emacross
# 거래일: 2018-04-10 00:00:00, 시스템: emacross
# 거래일: 2018-04-11 00:00:00, 시스템: emacross
# 거래일: 2018-04-12 00:00:00, 시스템: emacross
# 거래일: 2018-04-13 00:00:00, 시스템: emacross
# 거래일: 2018-04-16 00:00:00, 시스템: emacross
# 거래일: 2018-04-17 00:00:00, 시스템: emacross
# 거래일: 2018-04-18 00:00:00, 시스템: emacross
# 거래일: 2018-04-19 00:00:00, 시스템: emacross
# 거래일: 2018-04-20 00:00:00, 시스템: emacross
# 거래일: 2018-04-23 00:00:00, 시스템: emacross
# 거래일: 2018-04-24 00:00:00, 시스템: emacross
# 거래일: 2018-04-25 00:00:00, 시스템: emacross
# 거래일: 2018-04-26 00:00:00, 시스템: emacross
# 거래일: 2018-04-27 00:00:00, 시스템: emacross
# 거래일: 2018-04-30 00:00:00, 시스템: emacross
# 거래일: 2018-05-01 00:00:00, 시스템: emacross
# 거래일: 2018-05-02 00:00:00, 시스템: emacross
# 거래일: 2018-05-03 00:00:00, 시스템: emacross
# 거래일: 2018-05-04 00:00:00, 시스템: emacross
# 거래일: 2018-05-07 00:00:00, 시스템: emacross
# 거래일: 2018-05-08 00:00:00, 시스템: emacross
# 거래일: 2018-05-09 00:00:00, 시스템: emacross
# 거래일: 2018-05-10 00:00:00, 시스템: emacross
# 거래일: 2018-05-11 00:00:00, 시스템: emacross
# 거래일: 2018-05-14 00:00:00, 시스템: emacross
# 거래일: 2018-05-15 00:00:00, 시스템: emacross
# 거래일: 2018-05-16 00:00:00, 시스템: emacross
# 거래일: 2018-05-17 00:00:00, 시스템: emacross
# 거래일: 2018-05-18 00:00:00, 시스템: emacross
# 거래일: 2018-05-21 00:00:00, 시스템: emacross
# 거래일: 2018-05-22 00:00:00, 시스템: emacross
# 거래일: 2018-05-23 00:00:00, 시스템: emacross
# 거래일: 2018-05-24 00:00:00, 시스템: emacross
# 거래일: 2018-05-25 00:00:00, 시스템: emacross
# 거래일: 2018-05-28 00:00:00, 시스템: emacross
# 거래일: 2018-05-29 00:00:00, 시스템: emacross
# 거래일: 2018-05-30 00:00:00, 시스템: emacross
# 거래일: 2018-05-31 00:00:00, 시스템: emacross
# 거래일: 2018-06-01 00:00:00, 시스템: emacross
# 거래일: 2018-06-04 00:00:00, 시스템: emacross
# 거래일: 2018-06-05 00:00:00, 시스템: emacross
# 거래일: 2018-06-06 00:00:00, 시스템: emacross
# 거래일: 2018-06-07 00:00:00, 시스템: emacross
# 거래일: 2018-06-08 00:00:00, 시스템: emacross
# 거래일: 2018-06-11 00:00:00, 시스템: emacross
# 거래일: 2018-06-12 00:00:00, 시스템: emacross
# 거래일: 2018-06-13 00:00:00, 시스템: emacross
# 거래일: 2018-06-14 00:00:00, 시스템: emacross
# 거래일: 2018-06-15 00:00:00, 시스템: emacross
# 거래일: 2018-06-18 00:00:00, 시스템: emacross
# 거래일: 2018-06-19 00:00:00, 시스템: emacross
# 거래일: 2018-06-20 00:00:00, 시스템: emacross
# 거래일: 2018-06-21 00:00:00, 시스템: emacross
# 거래일: 2018-06-22 00:00:00, 시스템: emacross
# 거래일: 2018-06-25 00:00:00, 시스템: emacross
# 거래일: 2018-06-26 00:00:00, 시스템: emacross
# 거래일: 2018-06-27 00:00:00, 시스템: emacross
# 거래일: 2018-06-28 00:00:00, 시스템: emacross
# 거래일: 2018-06-29 00:00:00, 시스템: emacross
# 거래일: 2018-07-02 00:00:00, 시스템: emacross
# 거래일: 2018-07-03 00:00:00, 시스템: emacross
# 거래일: 2018-07-04 00:00:00, 시스템: emacross
# 거래일: 2018-07-05 00:00:00, 시스템: emacross
# 거래일: 2018-07-06 00:00:00, 시스템: emacross
# 거래일: 2018-07-09 00:00:00, 시스템: emacross
# 거래일: 2018-07-10 00:00:00, 시스템: emacross
# 거래일: 2018-07-11 00:00:00, 시스템: emacross
# 거래일: 2018-07-12 00:00:00, 시스템: emacross
# 거래일: 2018-07-13 00:00:00, 시스템: emacross
# 거래일: 2018-07-16 00:00:00, 시스템: emacross
# 거래일: 2018-07-17 00:00:00, 시스템: emacross
# 거래일: 2018-07-18 00:00:00, 시스템: emacross
# 거래일: 2018-07-19 00:00:00, 시스템: emacross
# 거래일: 2018-07-20 00:00:00, 시스템: emacross
# 거래일: 2018-07-23 00:00:00, 시스템: emacross
# 거래일: 2018-07-24 00:00:00, 시스템: emacross
# 거래일: 2018-07-25 00:00:00, 시스템: emacross
# 거래일: 2018-07-26 00:00:00, 시스템: emacross
# 거래일: 2018-07-27 00:00:00, 시스템: emacross
# 거래일: 2018-07-30 00:00:00, 시스템: emacross
# 거래일: 2018-07-31 00:00:00, 시스템: emacross
# 거래일: 2018-08-01 00:00:00, 시스템: emacross
# 거래일: 2018-08-02 00:00:00, 시스템: emacross
# 거래일: 2018-08-03 00:00:00, 시스템: emacross
# 거래일: 2018-08-06 00:00:00, 시스템: emacross
# 거래일: 2018-08-07 00:00:00, 시스템: emacross
# 거래일: 2018-08-08 00:00:00, 시스템: emacross
# 거래일: 2018-08-09 00:00:00, 시스템: emacross
# 거래일: 2018-08-10 00:00:00, 시스템: emacross
# 거래일: 2018-08-13 00:00:00, 시스템: emacross
# 거래일: 2018-08-14 00:00:00, 시스템: emacross
# 거래일: 2018-08-15 00:00:00, 시스템: emacross
# 거래일: 2018-08-16 00:00:00, 시스템: emacross
# 거래일: 2018-08-17 00:00:00, 시스템: emacross
# 거래일: 2018-08-20 00:00:00, 시스템: emacross
# 거래일: 2018-08-21 00:00:00, 시스템: emacross
# 거래일: 2018-08-22 00:00:00, 시스템: emacross
# 거래일: 2018-08-23 00:00:00, 시스템: emacross
# 거래일: 2018-08-24 00:00:00, 시스템: emacross
# 거래일: 2018-08-27 00:00:00, 시스템: emacross
# 거래일: 2018-08-28 00:00:00, 시스템: emacross
# 거래일: 2018-08-29 00:00:00, 시스템: emacross
# 거래일: 2018-08-30 00:00:00, 시스템: emacross
# 거래일: 2018-08-31 00:00:00, 시스템: emacross
# 거래일: 2018-09-03 00:00:00, 시스템: emacross
# 거래일: 2018-09-04 00:00:00, 시스템: emacross
# 거래일: 2018-09-05 00:00:00, 시스템: emacross
# 거래일: 2018-09-06 00:00:00, 시스템: emacross
# 거래일: 2018-09-07 00:00:00, 시스템: emacross
# 거래일: 2018-09-10 00:00:00, 시스템: emacross
# 거래일: 2018-09-11 00:00:00, 시스템: emacross
# 거래일: 2018-09-12 00:00:00, 시스템: emacross
# 거래일: 2018-09-13 00:00:00, 시스템: emacross
# 거래일: 2018-09-14 00:00:00, 시스템: emacross
# 거래일: 2018-09-17 00:00:00, 시스템: emacross
# 거래일: 2018-09-18 00:00:00, 시스템: emacross
# 거래일: 2018-09-19 00:00:00, 시스템: emacross
# 거래일: 2018-09-20 00:00:00, 시스템: emacross
# 거래일: 2018-09-21 00:00:00, 시스템: emacross
# 거래일: 2018-09-24 00:00:00, 시스템: emacross
# 거래일: 2018-09-25 00:00:00, 시스템: emacross
# 거래일: 2018-09-26 00:00:00, 시스템: emacross
# 거래일: 2018-09-27 00:00:00, 시스템: emacross
# 거래일: 2018-09-28 00:00:00, 시스템: emacross
# 거래일: 2018-10-01 00:00:00, 시스템: emacross
# 거래일: 2018-10-02 00:00:00, 시스템: emacross
# 거래일: 2018-10-03 00:00:00, 시스템: emacross
# 거래일: 2018-10-04 00:00:00, 시스템: emacross
# 거래일: 2018-10-05 00:00:00, 시스템: emacross
# 거래일: 2018-10-08 00:00:00, 시스템: emacross
# 거래일: 2018-10-09 00:00:00, 시스템: emacross
# 거래일: 2018-10-10 00:00:00, 시스템: emacross
# 거래일: 2018-10-11 00:00:00, 시스템: emacross
# 거래일: 2018-10-12 00:00:00, 시스템: emacross
# 거래일: 2018-10-15 00:00:00, 시스템: emacross
# 거래일: 2018-10-16 00:00:00, 시스템: emacross
# 거래일: 2018-10-17 00:00:00, 시스템: emacross
# 거래일: 2018-10-18 00:00:00, 시스템: emacross
# 거래일: 2018-10-19 00:00:00, 시스템: emacross
# 거래일: 2018-10-22 00:00:00, 시스템: emacross
# 거래일: 2018-10-23 00:00:00, 시스템: emacross
# 거래일: 2018-10-24 00:00:00, 시스템: emacross
# 거래일: 2018-10-25 00:00:00, 시스템: emacross
# 거래일: 2018-10-26 00:00:00, 시스템: emacross
# 거래일: 2018-10-29 00:00:00, 시스템: emacross
# 거래일: 2018-10-30 00:00:00, 시스템: emacross
# 거래일: 2018-10-31 00:00:00, 시스템: emacross
# 거래일: 2018-11-01 00:00:00, 시스템: emacross
# 거래일: 2018-11-02 00:00:00, 시스템: emacross
# 거래일: 2018-11-05 00:00:00, 시스템: emacross
# 거래일: 2018-11-06 00:00:00, 시스템: emacross
# 거래일: 2018-11-07 00:00:00, 시스템: emacross
# 거래일: 2018-11-08 00:00:00, 시스템: emacross
# 거래일: 2018-11-09 00:00:00, 시스템: emacross
# 거래일: 2018-11-12 00:00:00, 시스템: emacross
# 거래일: 2018-11-13 00:00:00, 시스템: emacross
# 거래일: 2018-11-14 00:00:00, 시스템: emacross
# 거래일: 2018-11-15 00:00:00, 시스템: emacross
# 거래일: 2018-11-16 00:00:00, 시스템: emacross
# 거래일: 2018-11-19 00:00:00, 시스템: emacross
# 거래일: 2018-11-20 00:00:00, 시스템: emacross
# 거래일: 2018-11-21 00:00:00, 시스템: emacross
# 거래일: 2018-11-22 00:00:00, 시스템: emacross
# 거래일: 2018-11-23 00:00:00, 시스템: emacross
# 거래일: 2018-11-26 00:00:00, 시스템: emacross
# 거래일: 2018-11-27 00:00:00, 시스템: emacross
# 거래일: 2018-11-28 00:00:00, 시스템: emacross
# 거래일: 2018-11-29 00:00:00, 시스템: emacross
# 거래일: 2018-11-30 00:00:00, 시스템: emacross
# 거래일: 2018-12-03 00:00:00, 시스템: emacross
# 거래일: 2018-12-04 00:00:00, 시스템: emacross
# 거래일: 2018-12-05 00:00:00, 시스템: emacross
# 거래일: 2018-12-06 00:00:00, 시스템: emacross
# 거래일: 2018-12-07 00:00:00, 시스템: emacross
# 거래일: 2018-12-10 00:00:00, 시스템: emacross
# 거래일: 2018-12-11 00:00:00, 시스템: emacross
# 거래일: 2018-12-12 00:00:00, 시스템: emacross
# 거래일: 2018-12-13 00:00:00, 시스템: emacross
# 거래일: 2018-12-14 00:00:00, 시스템: emacross
# 거래일: 2018-12-17 00:00:00, 시스템: emacross
# 거래일: 2018-12-18 00:00:00, 시스템: emacross
# 거래일: 2018-12-19 00:00:00, 시스템: emacross
# 거래일: 2018-12-20 00:00:00, 시스템: emacross
# 거래일: 2018-12-21 00:00:00, 시스템: emacross
# 거래일: 2018-12-24 00:00:00, 시스템: emacross
# 거래일: 2018-12-26 00:00:00, 시스템: emacross
# 거래일: 2018-12-27 00:00:00, 시스템: emacross
# 거래일: 2018-12-28 00:00:00, 시스템: emacross
# 거래일: 2018-12-31 00:00:00, 시스템: emacross
# 거래일: 2019-01-02 00:00:00, 시스템: emacross
# 거래일: 2019-01-03 00:00:00, 시스템: emacross
# 거래일: 2019-01-04 00:00:00, 시스템: emacross
# 거래일: 2019-01-07 00:00:00, 시스템: emacross
# 거래일: 2019-01-08 00:00:00, 시스템: emacross
# 거래일: 2019-01-09 00:00:00, 시스템: emacross
# 거래일: 2019-01-10 00:00:00, 시스템: emacross
# 거래일: 2019-01-11 00:00:00, 시스템: emacross
# 거래일: 2019-01-14 00:00:00, 시스템: emacross
# 거래일: 2019-01-15 00:00:00, 시스템: emacross
# 거래일: 2019-01-16 00:00:00, 시스템: emacross
# 거래일: 2019-01-17 00:00:00, 시스템: emacross
# 거래일: 2019-01-18 00:00:00, 시스템: emacross
# 거래일: 2019-01-21 00:00:00, 시스템: emacross
# 거래일: 2019-01-22 00:00:00, 시스템: emacross
# 거래일: 2019-01-23 00:00:00, 시스템: emacross
# 거래일: 2019-01-24 00:00:00, 시스템: emacross
# 거래일: 2019-01-25 00:00:00, 시스템: emacross
# 거래일: 2019-01-28 00:00:00, 시스템: emacross
# 거래일: 2019-01-29 00:00:00, 시스템: emacross
# 거래일: 2019-01-30 00:00:00, 시스템: emacross
# 거래일: 2019-01-31 00:00:00, 시스템: emacross
# 거래일: 2019-02-01 00:00:00, 시스템: emacross
# 거래일: 2019-02-04 00:00:00, 시스템: emacross
# 거래일: 2019-02-05 00:00:00, 시스템: emacross
# 거래일: 2019-02-06 00:00:00, 시스템: emacross
# 거래일: 2019-02-07 00:00:00, 시스템: emacross
# 거래일: 2019-02-08 00:00:00, 시스템: emacross
# 거래일: 2019-02-11 00:00:00, 시스템: emacross
# 거래일: 2019-02-12 00:00:00, 시스템: emacross
# 거래일: 2019-02-13 00:00:00, 시스템: emacross
# 거래일: 2019-02-14 00:00:00, 시스템: emacross
# 거래일: 2019-02-15 00:00:00, 시스템: emacross
# 거래일: 2019-02-18 00:00:00, 시스템: emacross
# 거래일: 2019-02-19 00:00:00, 시스템: emacross
# 거래일: 2019-02-20 00:00:00, 시스템: emacross
# 거래일: 2019-02-21 00:00:00, 시스템: emacross
# 거래일: 2019-02-22 00:00:00, 시스템: emacross
# 거래일: 2019-02-25 00:00:00, 시스템: emacross
# 거래일: 2019-02-26 00:00:00, 시스템: emacross
# 거래일: 2019-02-27 00:00:00, 시스템: emacross
# 거래일: 2019-02-28 00:00:00, 시스템: emacross
# 거래일: 2019-03-01 00:00:00, 시스템: emacross
# 거래일: 2019-03-04 00:00:00, 시스템: emacross
# 거래일: 2019-03-05 00:00:00, 시스템: emacross
# 거래일: 2019-03-06 00:00:00, 시스템: emacross
# 거래일: 2019-03-07 00:00:00, 시스템: emacross
# 거래일: 2019-03-08 00:00:00, 시스템: emacross
# 거래일: 2019-03-11 00:00:00, 시스템: emacross
# 거래일: 2019-03-12 00:00:00, 시스템: emacross
# 거래일: 2019-03-13 00:00:00, 시스템: emacross
# 거래일: 2019-03-14 00:00:00, 시스템: emacross
# 거래일: 2019-03-15 00:00:00, 시스템: emacross
# 거래일: 2019-03-18 00:00:00, 시스템: emacross
# 거래일: 2019-03-19 00:00:00, 시스템: emacross
# 거래일: 2019-03-20 00:00:00, 시스템: emacross
# 거래일: 2019-03-21 00:00:00, 시스템: emacross
# 거래일: 2019-03-22 00:00:00, 시스템: emacross
# 거래일: 2019-03-25 00:00:00, 시스템: emacross
# 거래일: 2019-03-26 00:00:00, 시스템: emacross
# 거래일: 2019-03-27 00:00:00, 시스템: emacross
# 거래일: 2019-03-28 00:00:00, 시스템: emacross
# 거래일: 2019-03-29 00:00:00, 시스템: emacross
# 거래일: 2019-04-01 00:00:00, 시스템: emacross
# 거래일: 2019-04-02 00:00:00, 시스템: emacross
# 거래일: 2019-04-03 00:00:00, 시스템: emacross
# 거래일: 2019-04-04 00:00:00, 시스템: emacross
# 거래일: 2019-04-05 00:00:00, 시스템: emacross
# 거래일: 2019-04-08 00:00:00, 시스템: emacross
# 거래일: 2019-04-09 00:00:00, 시스템: emacross
# 거래일: 2019-04-10 00:00:00, 시스템: emacross
# 거래일: 2019-04-11 00:00:00, 시스템: emacross
# 거래일: 2019-04-12 00:00:00, 시스템: emacross
# 거래일: 2019-04-15 00:00:00, 시스템: emacross
# 거래일: 2019-04-16 00:00:00, 시스템: emacross
# 거래일: 2019-04-17 00:00:00, 시스템: emacross
# 거래일: 2019-04-18 00:00:00, 시스템: emacross
# 거래일: 2019-04-22 00:00:00, 시스템: emacross
# 거래일: 2019-04-23 00:00:00, 시스템: emacross
# 거래일: 2019-04-24 00:00:00, 시스템: emacross
# 거래일: 2019-04-25 00:00:00, 시스템: emacross
# 거래일: 2019-04-26 00:00:00, 시스템: emacross
# 거래일: 2019-04-29 00:00:00, 시스템: emacross
# 거래일: 2019-04-30 00:00:00, 시스템: emacross
# 거래일: 2019-05-01 00:00:00, 시스템: emacross
# 거래일: 2019-05-02 00:00:00, 시스템: emacross
# 거래일: 2019-05-03 00:00:00, 시스템: emacross
# 거래일: 2019-05-06 00:00:00, 시스템: emacross
# 거래일: 2019-05-07 00:00:00, 시스템: emacross
# 거래일: 2019-05-08 00:00:00, 시스템: emacross
# 거래일: 2019-05-09 00:00:00, 시스템: emacross
# 거래일: 2019-05-10 00:00:00, 시스템: emacross
# 거래일: 2019-05-13 00:00:00, 시스템: emacross
# 거래일: 2019-05-14 00:00:00, 시스템: emacross
# 거래일: 2019-05-15 00:00:00, 시스템: emacross
# 거래일: 2019-05-16 00:00:00, 시스템: emacross
# 거래일: 2019-05-17 00:00:00, 시스템: emacross
# 거래일: 2019-05-20 00:00:00, 시스템: emacross
# 거래일: 2019-05-21 00:00:00, 시스템: emacross
# 거래일: 2019-05-22 00:00:00, 시스템: emacross
# 거래일: 2019-05-23 00:00:00, 시스템: emacross
# 거래일: 2019-05-24 00:00:00, 시스템: emacross
# 거래일: 2019-05-27 00:00:00, 시스템: emacross
# 거래일: 2019-05-28 00:00:00, 시스템: emacross
# 거래일: 2019-05-29 00:00:00, 시스템: emacross
# 거래일: 2019-05-30 00:00:00, 시스템: emacross
# 거래일: 2019-05-31 00:00:00, 시스템: emacross
# 거래일: 2019-06-03 00:00:00, 시스템: emacross
# 거래일: 2019-06-04 00:00:00, 시스템: emacross
# 거래일: 2019-06-05 00:00:00, 시스템: emacross
# 거래일: 2019-06-06 00:00:00, 시스템: emacross
# 거래일: 2019-06-07 00:00:00, 시스템: emacross
# 거래일: 2019-06-10 00:00:00, 시스템: emacross
# 거래일: 2019-06-11 00:00:00, 시스템: emacross
# 거래일: 2019-06-12 00:00:00, 시스템: emacross
# 거래일: 2019-06-13 00:00:00, 시스템: emacross
# 거래일: 2019-06-14 00:00:00, 시스템: emacross
# 거래일: 2019-06-17 00:00:00, 시스템: emacross
# 거래일: 2019-06-18 00:00:00, 시스템: emacross
# 거래일: 2019-06-19 00:00:00, 시스템: emacross
# 거래일: 2019-06-20 00:00:00, 시스템: emacross
# 거래일: 2019-06-21 00:00:00, 시스템: emacross
# 거래일: 2019-06-24 00:00:00, 시스템: emacross
# 거래일: 2019-06-25 00:00:00, 시스템: emacross
# 거래일: 2019-06-26 00:00:00, 시스템: emacross
# 거래일: 2019-06-27 00:00:00, 시스템: emacross
# 거래일: 2019-06-28 00:00:00, 시스템: emacross
# 거래일: 2019-07-01 00:00:00, 시스템: emacross
# 거래일: 2019-07-02 00:00:00, 시스템: emacross
# 거래일: 2019-07-03 00:00:00, 시스템: emacross
# 거래일: 2019-07-04 00:00:00, 시스템: emacross
# 거래일: 2019-07-05 00:00:00, 시스템: emacross
# 거래일: 2019-07-08 00:00:00, 시스템: emacross
# 거래일: 2019-07-09 00:00:00, 시스템: emacross
# 거래일: 2019-07-10 00:00:00, 시스템: emacross
# 거래일: 2019-07-11 00:00:00, 시스템: emacross
# 거래일: 2019-07-12 00:00:00, 시스템: emacross
# 거래일: 2019-07-15 00:00:00, 시스템: emacross
# 거래일: 2019-07-16 00:00:00, 시스템: emacross
# 거래일: 2019-07-17 00:00:00, 시스템: emacross
# 거래일: 2019-07-18 00:00:00, 시스템: emacross
# 거래일: 2019-07-19 00:00:00, 시스템: emacross
# 거래일: 2019-07-22 00:00:00, 시스템: emacross
# 거래일: 2019-07-23 00:00:00, 시스템: emacross
# 거래일: 2019-07-24 00:00:00, 시스템: emacross
# 거래일: 2019-07-25 00:00:00, 시스템: emacross
# 거래일: 2019-07-26 00:00:00, 시스템: emacross
# 거래일: 2019-07-29 00:00:00, 시스템: emacross
# 거래일: 2019-07-30 00:00:00, 시스템: emacross
# 거래일: 2019-07-31 00:00:00, 시스템: emacross
# 거래일: 2019-08-01 00:00:00, 시스템: emacross
# 거래일: 2019-08-02 00:00:00, 시스템: emacross
# 거래일: 2019-08-05 00:00:00, 시스템: emacross
# 거래일: 2019-08-06 00:00:00, 시스템: emacross
# 거래일: 2019-08-07 00:00:00, 시스템: emacross
# 거래일: 2019-08-08 00:00:00, 시스템: emacross
# 거래일: 2019-08-09 00:00:00, 시스템: emacross
# 거래일: 2019-08-12 00:00:00, 시스템: emacross
# 거래일: 2019-08-13 00:00:00, 시스템: emacross
# 거래일: 2019-08-14 00:00:00, 시스템: emacross
# 거래일: 2019-08-15 00:00:00, 시스템: emacross
# 거래일: 2019-08-16 00:00:00, 시스템: emacross
# 거래일: 2019-08-19 00:00:00, 시스템: emacross
# 거래일: 2019-08-20 00:00:00, 시스템: emacross
# 거래일: 2019-08-21 00:00:00, 시스템: emacross
# 거래일: 2019-08-22 00:00:00, 시스템: emacross
# 거래일: 2019-08-23 00:00:00, 시스템: emacross
# 거래일: 2019-08-26 00:00:00, 시스템: emacross
# 거래일: 2019-08-27 00:00:00, 시스템: emacross
# 거래일: 2019-08-28 00:00:00, 시스템: emacross
# 거래일: 2019-08-29 00:00:00, 시스템: emacross
# 거래일: 2019-08-30 00:00:00, 시스템: emacross
# 거래일: 2019-09-02 00:00:00, 시스템: emacross
# 거래일: 2019-09-03 00:00:00, 시스템: emacross
# 거래일: 2019-09-04 00:00:00, 시스템: emacross
# 거래일: 2019-09-05 00:00:00, 시스템: emacross
# 거래일: 2019-09-06 00:00:00, 시스템: emacross
# 거래일: 2019-09-09 00:00:00, 시스템: emacross
# 거래일: 2019-09-10 00:00:00, 시스템: emacross
# 거래일: 2019-09-11 00:00:00, 시스템: emacross
# 거래일: 2019-09-12 00:00:00, 시스템: emacross
# 거래일: 2019-09-13 00:00:00, 시스템: emacross
# 거래일: 2019-09-16 00:00:00, 시스템: emacross
# 거래일: 2019-09-17 00:00:00, 시스템: emacross
# 거래일: 2019-09-18 00:00:00, 시스템: emacross
# 거래일: 2019-09-19 00:00:00, 시스템: emacross
# 거래일: 2019-09-20 00:00:00, 시스템: emacross
# 거래일: 2019-09-23 00:00:00, 시스템: emacross
# 거래일: 2019-09-24 00:00:00, 시스템: emacross
# 거래일: 2019-09-25 00:00:00, 시스템: emacross
# 거래일: 2019-09-26 00:00:00, 시스템: emacross
# 거래일: 2019-09-27 00:00:00, 시스템: emacross
# 거래일: 2019-09-30 00:00:00, 시스템: emacross
# 거래일: 2019-10-01 00:00:00, 시스템: emacross
# 거래일: 2019-10-02 00:00:00, 시스템: emacross
# 거래일: 2019-10-03 00:00:00, 시스템: emacross
# 거래일: 2019-10-04 00:00:00, 시스템: emacross
# 거래일: 2019-10-07 00:00:00, 시스템: emacross
# 거래일: 2019-10-08 00:00:00, 시스템: emacross
# 거래일: 2019-10-09 00:00:00, 시스템: emacross
# 거래일: 2019-10-10 00:00:00, 시스템: emacross
# 거래일: 2019-10-11 00:00:00, 시스템: emacross
# 거래일: 2019-10-14 00:00:00, 시스템: emacross
# 거래일: 2019-10-15 00:00:00, 시스템: emacross
# 거래일: 2019-10-16 00:00:00, 시스템: emacross
# 거래일: 2019-10-17 00:00:00, 시스템: emacross
# 거래일: 2019-10-18 00:00:00, 시스템: emacross
# 거래일: 2019-10-21 00:00:00, 시스템: emacross
# 거래일: 2019-10-22 00:00:00, 시스템: emacross
# 거래일: 2019-10-23 00:00:00, 시스템: emacross
# 거래일: 2019-10-24 00:00:00, 시스템: emacross
# 거래일: 2019-10-25 00:00:00, 시스템: emacross
# 거래일: 2019-10-28 00:00:00, 시스템: emacross
# 거래일: 2019-10-29 00:00:00, 시스템: emacross
# 거래일: 2019-10-30 00:00:00, 시스템: emacross
# 거래일: 2019-10-31 00:00:00, 시스템: emacross
# 거래일: 2019-11-01 00:00:00, 시스템: emacross
# 거래일: 2019-11-04 00:00:00, 시스템: emacross
# 거래일: 2019-11-05 00:00:00, 시스템: emacross
# 거래일: 2019-11-06 00:00:00, 시스템: emacross
# 거래일: 2019-11-07 00:00:00, 시스템: emacross
# 거래일: 2019-11-08 00:00:00, 시스템: emacross
# 거래일: 2019-11-11 00:00:00, 시스템: emacross
# 거래일: 2019-11-12 00:00:00, 시스템: emacross
# 거래일: 2019-11-13 00:00:00, 시스템: emacross
# 거래일: 2019-11-14 00:00:00, 시스템: emacross
# 거래일: 2019-11-15 00:00:00, 시스템: emacross
# 거래일: 2019-11-18 00:00:00, 시스템: emacross
# 거래일: 2019-11-19 00:00:00, 시스템: emacross
# 거래일: 2019-11-20 00:00:00, 시스템: emacross
# 거래일: 2019-11-21 00:00:00, 시스템: emacross
# 거래일: 2019-11-22 00:00:00, 시스템: emacross
# 거래일: 2019-11-25 00:00:00, 시스템: emacross
# 거래일: 2019-11-26 00:00:00, 시스템: emacross
# 거래일: 2019-11-27 00:00:00, 시스템: emacross
# 거래일: 2019-11-28 00:00:00, 시스템: emacross
# 거래일: 2019-11-29 00:00:00, 시스템: emacross
# 거래일: 2019-12-02 00:00:00, 시스템: emacross
# 거래일: 2019-12-03 00:00:00, 시스템: emacross
# 거래일: 2019-12-04 00:00:00, 시스템: emacross
# 거래일: 2019-12-05 00:00:00, 시스템: emacross
# 거래일: 2019-12-06 00:00:00, 시스템: emacross
# 거래일: 2019-12-09 00:00:00, 시스템: emacross
# 거래일: 2019-12-10 00:00:00, 시스템: emacross
# 거래일: 2019-12-11 00:00:00, 시스템: emacross
# 거래일: 2019-12-12 00:00:00, 시스템: emacross
# 거래일: 2019-12-13 00:00:00, 시스템: emacross
# 거래일: 2019-12-16 00:00:00, 시스템: emacross
# 거래일: 2019-12-17 00:00:00, 시스템: emacross
# 거래일: 2019-12-18 00:00:00, 시스템: emacross
# 거래일: 2019-12-19 00:00:00, 시스템: emacross
# 거래일: 2019-12-20 00:00:00, 시스템: emacross
# 거래일: 2019-12-23 00:00:00, 시스템: emacross
# 거래일: 2019-12-24 00:00:00, 시스템: emacross
# 거래일: 2019-12-26 00:00:00, 시스템: emacross
# 거래일: 2019-12-27 00:00:00, 시스템: emacross
# 거래일: 2019-12-30 00:00:00, 시스템: emacross
# 거래일: 2019-12-31 00:00:00, 시스템: emacross
# 거래일: 2020-01-02 00:00:00, 시스템: emacross
# 거래일: 2020-01-03 00:00:00, 시스템: emacross
# 거래일: 2020-01-06 00:00:00, 시스템: emacross
# 거래일: 2020-01-07 00:00:00, 시스템: emacross
# 거래일: 2020-01-08 00:00:00, 시스템: emacross
# 거래일: 2020-01-09 00:00:00, 시스템: emacross
# 거래일: 2020-01-10 00:00:00, 시스템: emacross
# 거래일: 2020-01-13 00:00:00, 시스템: emacross
# 거래일: 2020-01-14 00:00:00, 시스템: emacross
# 거래일: 2020-01-15 00:00:00, 시스템: emacross
# 거래일: 2020-01-16 00:00:00, 시스템: emacross
# 거래일: 2020-01-17 00:00:00, 시스템: emacross
# 거래일: 2020-01-20 00:00:00, 시스템: emacross
# 거래일: 2020-01-21 00:00:00, 시스템: emacross
# 거래일: 2020-01-22 00:00:00, 시스템: emacross
# 거래일: 2020-01-23 00:00:00, 시스템: emacross
# 거래일: 2020-01-24 00:00:00, 시스템: emacross
# 거래일: 2020-01-27 00:00:00, 시스템: emacross
# 거래일: 2020-01-28 00:00:00, 시스템: emacross
# 거래일: 2020-01-29 00:00:00, 시스템: emacross
# 거래일: 2020-01-30 00:00:00, 시스템: emacross
# 거래일: 2020-01-31 00:00:00, 시스템: emacross
# 거래일: 2020-02-03 00:00:00, 시스템: emacross
# 거래일: 2020-02-04 00:00:00, 시스템: emacross
# 거래일: 2020-02-05 00:00:00, 시스템: emacross
# 거래일: 2020-02-06 00:00:00, 시스템: emacross
# 거래일: 2020-02-07 00:00:00, 시스템: emacross
# 거래일: 2020-02-10 00:00:00, 시스템: emacross
# 거래일: 2020-02-11 00:00:00, 시스템: emacross
# 거래일: 2020-02-12 00:00:00, 시스템: emacross
# 거래일: 2020-02-13 00:00:00, 시스템: emacross
# 거래일: 2020-02-14 00:00:00, 시스템: emacross
# 거래일: 2020-02-17 00:00:00, 시스템: emacross
# 거래일: 2020-02-18 00:00:00, 시스템: emacross
# 거래일: 2020-02-19 00:00:00, 시스템: emacross
# 거래일: 2020-02-20 00:00:00, 시스템: emacross
# 거래일: 2020-02-21 00:00:00, 시스템: emacross
# 거래일: 2020-02-24 00:00:00, 시스템: emacross
# 거래일: 2020-02-25 00:00:00, 시스템: emacross
# 거래일: 2020-02-26 00:00:00, 시스템: emacross
# 거래일: 2020-02-27 00:00:00, 시스템: emacross
# 거래일: 2020-02-28 00:00:00, 시스템: emacross
# 거래일: 2020-03-02 00:00:00, 시스템: emacross
# 거래일: 2020-03-03 00:00:00, 시스템: emacross
# 거래일: 2020-03-04 00:00:00, 시스템: emacross
# 거래일: 2020-03-05 00:00:00, 시스템: emacross
# 거래일: 2020-03-06 00:00:00, 시스템: emacross
# 거래일: 2020-03-09 00:00:00, 시스템: emacross
# 거래일: 2020-03-10 00:00:00, 시스템: emacross
# 거래일: 2020-03-11 00:00:00, 시스템: emacross
# 거래일: 2020-03-12 00:00:00, 시스템: emacross
# 거래일: 2020-03-13 00:00:00, 시스템: emacross
# 거래일: 2020-03-16 00:00:00, 시스템: emacross
# 거래일: 2020-03-17 00:00:00, 시스템: emacross
# 거래일: 2020-03-18 00:00:00, 시스템: emacross
# 거래일: 2020-03-19 00:00:00, 시스템: emacross
# 거래일: 2020-03-20 00:00:00, 시스템: emacross
# 거래일: 2020-03-23 00:00:00, 시스템: emacross
# 거래일: 2020-03-24 00:00:00, 시스템: emacross
# 거래일: 2020-03-25 00:00:00, 시스템: emacross
# 거래일: 2020-03-26 00:00:00, 시스템: emacross
# 거래일: 2020-03-27 00:00:00, 시스템: emacross
# 거래일: 2020-03-30 00:00:00, 시스템: emacross
# 거래일: 2020-03-31 00:00:00, 시스템: emacross
# 거래일: 2020-04-01 00:00:00, 시스템: emacross
# 거래일: 2020-04-02 00:00:00, 시스템: emacross
# 거래일: 2020-04-03 00:00:00, 시스템: emacross
# 거래일: 2020-04-06 00:00:00, 시스템: emacross
# 거래일: 2020-04-07 00:00:00, 시스템: emacross
# 거래일: 2020-04-08 00:00:00, 시스템: emacross
# 거래일: 2020-04-09 00:00:00, 시스템: emacross
# 거래일: 2020-04-13 00:00:00, 시스템: emacross
# 거래일: 2020-04-14 00:00:00, 시스템: emacross
# 거래일: 2020-04-15 00:00:00, 시스템: emacross
# 거래일: 2020-04-16 00:00:00, 시스템: emacross
# 거래일: 2020-04-17 00:00:00, 시스템: emacross
# 거래일: 2020-04-20 00:00:00, 시스템: emacross
# 거래일: 2020-04-21 00:00:00, 시스템: emacross
# 거래일: 2020-04-22 00:00:00, 시스템: emacross
# 거래일: 2020-04-23 00:00:00, 시스템: emacross
# 거래일: 2020-04-24 00:00:00, 시스템: emacross
# 거래일: 2020-04-27 00:00:00, 시스템: emacross
# 거래일: 2020-04-28 00:00:00, 시스템: emacross
# 거래일: 2020-04-29 00:00:00, 시스템: emacross
# 거래일: 2020-04-30 00:00:00, 시스템: emacross
# 거래일: 2020-05-01 00:00:00, 시스템: emacross
# 거래일: 2020-05-04 00:00:00, 시스템: emacross
# 거래일: 2020-05-05 00:00:00, 시스템: emacross
# 거래일: 2020-05-06 00:00:00, 시스템: emacross
# 거래일: 2020-05-07 00:00:00, 시스템: emacross
# 거래일: 2020-05-08 00:00:00, 시스템: emacross
# 거래일: 2020-05-11 00:00:00, 시스템: emacross
# 거래일: 2020-05-12 00:00:00, 시스템: emacross
# 거래일: 2020-05-13 00:00:00, 시스템: emacross
# 거래일: 2020-05-14 00:00:00, 시스템: emacross
# 거래일: 2020-05-15 00:00:00, 시스템: emacross
# 거래일: 2020-05-18 00:00:00, 시스템: emacross
# 거래일: 2020-05-19 00:00:00, 시스템: emacross
# 거래일: 2020-05-20 00:00:00, 시스템: emacross
# 거래일: 2020-05-21 00:00:00, 시스템: emacross
# 거래일: 2020-05-22 00:00:00, 시스템: emacross
# 거래일: 2020-05-25 00:00:00, 시스템: emacross
# 거래일: 2020-05-26 00:00:00, 시스템: emacross
# 거래일: 2020-05-27 00:00:00, 시스템: emacross
# 거래일: 2020-05-28 00:00:00, 시스템: emacross
# 거래일: 2020-05-29 00:00:00, 시스템: emacross
# 거래일: 2020-06-01 00:00:00, 시스템: emacross
# 거래일: 2020-06-02 00:00:00, 시스템: emacross
# 거래일: 2020-06-03 00:00:00, 시스템: emacross
# 거래일: 2020-06-04 00:00:00, 시스템: emacross
# 거래일: 2020-06-05 00:00:00, 시스템: emacross
# 거래일: 2020-06-08 00:00:00, 시스템: emacross
# 거래일: 2020-06-09 00:00:00, 시스템: emacross
# 거래일: 2020-06-10 00:00:00, 시스템: emacross
# 거래일: 2020-06-11 00:00:00, 시스템: emacross
# 거래일: 2020-06-12 00:00:00, 시스템: emacross
# 거래일: 2020-06-15 00:00:00, 시스템: emacross
# 거래일: 2020-06-16 00:00:00, 시스템: emacross
# 거래일: 2020-06-17 00:00:00, 시스템: emacross
# 거래일: 2020-06-18 00:00:00, 시스템: emacross
# 거래일: 2020-06-19 00:00:00, 시스템: emacross
# 거래일: 2020-06-22 00:00:00, 시스템: emacross
# 거래일: 2020-06-23 00:00:00, 시스템: emacross
# 거래일: 2020-06-24 00:00:00, 시스템: emacross
# 거래일: 2020-06-25 00:00:00, 시스템: emacross
# 거래일: 2020-06-26 00:00:00, 시스템: emacross
# 거래일: 2020-06-29 00:00:00, 시스템: emacross
# 거래일: 2020-06-30 00:00:00, 시스템: emacross
# 거래일: 2020-07-01 00:00:00, 시스템: emacross
# 거래일: 2020-07-02 00:00:00, 시스템: emacross
# 거래일: 2020-07-03 00:00:00, 시스템: emacross
# 거래일: 2020-07-06 00:00:00, 시스템: emacross
# 거래일: 2020-07-07 00:00:00, 시스템: emacross
# 거래일: 2020-07-08 00:00:00, 시스템: emacross
# 거래일: 2020-07-09 00:00:00, 시스템: emacross
# 거래일: 2020-07-10 00:00:00, 시스템: emacross
# 거래일: 2020-07-13 00:00:00, 시스템: emacross
# 거래일: 2020-07-14 00:00:00, 시스템: emacross
# 거래일: 2020-07-15 00:00:00, 시스템: emacross
# 거래일: 2020-07-16 00:00:00, 시스템: emacross
# 거래일: 2020-07-17 00:00:00, 시스템: emacross
# 거래일: 2020-07-20 00:00:00, 시스템: emacross
# 거래일: 2020-07-21 00:00:00, 시스템: emacross
# 거래일: 2020-07-22 00:00:00, 시스템: emacross
# 거래일: 2020-07-23 00:00:00, 시스템: emacross
# 거래일: 2020-07-24 00:00:00, 시스템: emacross
# 거래일: 2020-07-27 00:00:00, 시스템: emacross
# 거래일: 2020-07-28 00:00:00, 시스템: emacross
# 거래일: 2020-07-29 00:00:00, 시스템: emacross
# 거래일: 2020-07-30 00:00:00, 시스템: emacross
# 거래일: 2020-07-31 00:00:00, 시스템: emacross
# 거래일: 2020-08-03 00:00:00, 시스템: emacross
# 거래일: 2020-08-04 00:00:00, 시스템: emacross
# 거래일: 2020-08-05 00:00:00, 시스템: emacross
# 거래일: 2020-08-06 00:00:00, 시스템: emacross
# 거래일: 2020-08-07 00:00:00, 시스템: emacross
# 거래일: 2020-08-10 00:00:00, 시스템: emacross
# 거래일: 2020-08-11 00:00:00, 시스템: emacross
# 거래일: 2020-08-12 00:00:00, 시스템: emacross
# 거래일: 2020-08-13 00:00:00, 시스템: emacross
# 거래일: 2020-08-14 00:00:00, 시스템: emacross
# 거래일: 2020-08-17 00:00:00, 시스템: emacross
# 거래일: 2020-08-18 00:00:00, 시스템: emacross
# 거래일: 2020-08-19 00:00:00, 시스템: emacross
# 거래일: 2020-08-20 00:00:00, 시스템: emacross
# 거래일: 2020-08-21 00:00:00, 시스템: emacross
# 거래일: 2020-08-24 00:00:00, 시스템: emacross
# 거래일: 2020-08-25 00:00:00, 시스템: emacross
# 거래일: 2020-08-26 00:00:00, 시스템: emacross
# 거래일: 2020-08-27 00:00:00, 시스템: emacross
# 거래일: 2020-08-28 00:00:00, 시스템: emacross
# 거래일: 2020-08-31 00:00:00, 시스템: emacross
# 거래일: 2020-09-01 00:00:00, 시스템: emacross
# 거래일: 2020-09-02 00:00:00, 시스템: emacross
# 거래일: 2020-09-03 00:00:00, 시스템: emacross
# 거래일: 2020-09-04 00:00:00, 시스템: emacross
# 거래일: 2020-09-07 00:00:00, 시스템: emacross
# 거래일: 2020-09-08 00:00:00, 시스템: emacross
# 거래일: 2020-09-09 00:00:00, 시스템: emacross
# 거래일: 2020-09-10 00:00:00, 시스템: emacross
# 거래일: 2020-09-11 00:00:00, 시스템: emacross
# 거래일: 2020-09-14 00:00:00, 시스템: emacross
# 거래일: 2020-09-15 00:00:00, 시스템: emacross
# 거래일: 2020-09-16 00:00:00, 시스템: emacross
# 거래일: 2020-09-17 00:00:00, 시스템: emacross
# 거래일: 2020-09-18 00:00:00, 시스템: emacross
# 거래일: 2020-09-21 00:00:00, 시스템: emacross
# 거래일: 2020-09-22 00:00:00, 시스템: emacross
# 거래일: 2020-09-23 00:00:00, 시스템: emacross
# 거래일: 2020-09-24 00:00:00, 시스템: emacross
# 거래일: 2020-09-25 00:00:00, 시스템: emacross
# 거래일: 2020-09-28 00:00:00, 시스템: emacross
# 거래일: 2020-09-29 00:00:00, 시스템: emacross
# 거래일: 2020-09-30 00:00:00, 시스템: emacross
# 거래일: 2020-10-01 00:00:00, 시스템: emacross
# 거래일: 2020-10-02 00:00:00, 시스템: emacross
# 거래일: 2020-10-05 00:00:00, 시스템: emacross
# 거래일: 2020-10-06 00:00:00, 시스템: emacross
# 거래일: 2020-10-07 00:00:00, 시스템: emacross
# 거래일: 2020-10-08 00:00:00, 시스템: emacross
# 거래일: 2020-10-09 00:00:00, 시스템: emacross
# 거래일: 2020-10-12 00:00:00, 시스템: emacross
# 거래일: 2020-10-13 00:00:00, 시스템: emacross
# 거래일: 2020-10-14 00:00:00, 시스템: emacross
# 거래일: 2020-10-15 00:00:00, 시스템: emacross
# 거래일: 2020-10-16 00:00:00, 시스템: emacross
# 거래일: 2020-10-19 00:00:00, 시스템: emacross
# 거래일: 2020-10-20 00:00:00, 시스템: emacross
# 거래일: 2020-10-21 00:00:00, 시스템: emacross
# 거래일: 2020-10-22 00:00:00, 시스템: emacross
# 거래일: 2020-10-23 00:00:00, 시스템: emacross
# 거래일: 2020-10-26 00:00:00, 시스템: emacross
# 거래일: 2020-10-27 00:00:00, 시스템: emacross
# 거래일: 2020-10-28 00:00:00, 시스템: emacross
# 거래일: 2020-10-29 00:00:00, 시스템: emacross
# 거래일: 2020-10-30 00:00:00, 시스템: emacross
# 거래일: 2020-11-02 00:00:00, 시스템: emacross
# 거래일: 2020-11-03 00:00:00, 시스템: emacross
# 거래일: 2020-11-04 00:00:00, 시스템: emacross
# 거래일: 2020-11-05 00:00:00, 시스템: emacross
# 거래일: 2020-11-06 00:00:00, 시스템: emacross
# 거래일: 2020-11-09 00:00:00, 시스템: emacross
# 거래일: 2020-11-10 00:00:00, 시스템: emacross
# 거래일: 2020-11-11 00:00:00, 시스템: emacross
# 거래일: 2020-11-12 00:00:00, 시스템: emacross
# 거래일: 2020-11-13 00:00:00, 시스템: emacross
# 거래일: 2020-11-16 00:00:00, 시스템: emacross
# 거래일: 2020-11-17 00:00:00, 시스템: emacross
# 거래일: 2020-11-18 00:00:00, 시스템: emacross
# 거래일: 2020-11-19 00:00:00, 시스템: emacross
# 거래일: 2020-11-20 00:00:00, 시스템: emacross
# 거래일: 2020-11-23 00:00:00, 시스템: emacross
# 거래일: 2020-11-24 00:00:00, 시스템: emacross
# 거래일: 2020-11-25 00:00:00, 시스템: emacross
# 거래일: 2020-11-26 00:00:00, 시스템: emacross
# 거래일: 2020-11-27 00:00:00, 시스템: emacross
# 거래일: 2020-11-30 00:00:00, 시스템: emacross
# 거래일: 2020-12-01 00:00:00, 시스템: emacross
# 거래일: 2020-12-02 00:00:00, 시스템: emacross
# 거래일: 2020-12-03 00:00:00, 시스템: emacross
# 거래일: 2020-12-04 00:00:00, 시스템: emacross
# 거래일: 2020-12-07 00:00:00, 시스템: emacross
# 거래일: 2020-12-08 00:00:00, 시스템: emacross
# 거래일: 2020-12-09 00:00:00, 시스템: emacross
# 거래일: 2020-12-10 00:00:00, 시스템: emacross
# 거래일: 2020-12-11 00:00:00, 시스템: emacross
# 거래일: 2020-12-14 00:00:00, 시스템: emacross
# 거래일: 2020-12-15 00:00:00, 시스템: emacross
# 거래일: 2020-12-16 00:00:00, 시스템: emacross
# 거래일: 2020-12-17 00:00:00, 시스템: emacross
# 거래일: 2020-12-18 00:00:00, 시스템: emacross
# 거래일: 2020-12-21 00:00:00, 시스템: emacross
# 거래일: 2020-12-22 00:00:00, 시스템: emacross
# 거래일: 2020-12-23 00:00:00, 시스템: emacross
# 거래일: 2020-12-24 00:00:00, 시스템: emacross
# 거래일: 2020-12-28 00:00:00, 시스템: emacross
# 거래일: 2020-12-29 00:00:00, 시스템: emacross
# 거래일: 2020-12-30 00:00:00, 시스템: emacross
# 거래일: 2020-12-31 00:00:00, 시스템: emacross
# 거래일: 2021-01-04 00:00:00, 시스템: emacross
# 거래일: 2021-01-05 00:00:00, 시스템: emacross
# 거래일: 2021-01-06 00:00:00, 시스템: emacross
# 거래일: 2021-01-07 00:00:00, 시스템: emacross
# 거래일: 2021-01-08 00:00:00, 시스템: emacross
# 거래일: 2021-01-11 00:00:00, 시스템: emacross
# 거래일: 2021-01-12 00:00:00, 시스템: emacross
# 거래일: 2021-01-13 00:00:00, 시스템: emacross
# 거래일: 2021-01-14 00:00:00, 시스템: emacross
# 거래일: 2021-01-15 00:00:00, 시스템: emacross
# 거래일: 2021-01-18 00:00:00, 시스템: emacross
# 거래일: 2021-01-19 00:00:00, 시스템: emacross
# 거래일: 2021-01-20 00:00:00, 시스템: emacross
# 거래일: 2021-01-21 00:00:00, 시스템: emacross
# 거래일: 2021-01-22 00:00:00, 시스템: emacross
# 거래일: 2021-01-25 00:00:00, 시스템: emacross
# 거래일: 2021-01-26 00:00:00, 시스템: emacross
# 거래일: 2021-01-27 00:00:00, 시스템: emacross
# 거래일: 2021-01-28 00:00:00, 시스템: emacross
# 거래일: 2021-01-29 00:00:00, 시스템: emacross
# 거래일: 2021-02-01 00:00:00, 시스템: emacross
# 거래일: 2021-02-02 00:00:00, 시스템: emacross
# 거래일: 2021-02-03 00:00:00, 시스템: emacross
# 거래일: 2021-02-04 00:00:00, 시스템: emacross
# 거래일: 2021-02-05 00:00:00, 시스템: emacross
# 거래일: 2021-02-08 00:00:00, 시스템: emacross
# 거래일: 2021-02-09 00:00:00, 시스템: emacross
# 거래일: 2021-02-10 00:00:00, 시스템: emacross
# 거래일: 2021-02-11 00:00:00, 시스템: emacross
# 거래일: 2021-02-12 00:00:00, 시스템: emacross
# 거래일: 2021-02-15 00:00:00, 시스템: emacross
# 거래일: 2021-02-16 00:00:00, 시스템: emacross
# 거래일: 2021-02-17 00:00:00, 시스템: emacross
# 거래일: 2021-02-18 00:00:00, 시스템: emacross
# 거래일: 2021-02-19 00:00:00, 시스템: emacross
# 거래일: 2021-02-22 00:00:00, 시스템: emacross
# 거래일: 2021-02-23 00:00:00, 시스템: emacross
# 거래일: 2021-02-24 00:00:00, 시스템: emacross
# 거래일: 2021-02-25 00:00:00, 시스템: emacross
# 거래일: 2021-02-26 00:00:00, 시스템: emacross
# 거래일: 2021-03-01 00:00:00, 시스템: emacross
# 거래일: 2021-03-02 00:00:00, 시스템: emacross
# 거래일: 2021-03-03 00:00:00, 시스템: emacross
# 거래일: 2021-03-04 00:00:00, 시스템: emacross
# 거래일: 2021-03-05 00:00:00, 시스템: emacross
# 거래일: 2021-03-08 00:00:00, 시스템: emacross
# 거래일: 2021-03-09 00:00:00, 시스템: emacross
# 거래일: 2021-03-10 00:00:00, 시스템: emacross
# 거래일: 2021-03-11 00:00:00, 시스템: emacross
# 거래일: 2021-03-12 00:00:00, 시스템: emacross
# 거래일: 2021-03-15 00:00:00, 시스템: emacross
# 거래일: 2021-03-16 00:00:00, 시스템: emacross
# 거래일: 2021-03-17 00:00:00, 시스템: emacross
# 거래일: 2021-03-18 00:00:00, 시스템: emacross
# 거래일: 2021-03-19 00:00:00, 시스템: emacross
# 거래일: 2021-03-22 00:00:00, 시스템: emacross
# 거래일: 2021-03-23 00:00:00, 시스템: emacross
# 거래일: 2021-03-24 00:00:00, 시스템: emacross
# 거래일: 2021-03-25 00:00:00, 시스템: emacross
# 거래일: 2021-03-26 00:00:00, 시스템: emacross
# 거래일: 2021-03-29 00:00:00, 시스템: emacross
# 거래일: 2021-03-30 00:00:00, 시스템: emacross
# 거래일: 2021-03-31 00:00:00, 시스템: emacross
# 거래일: 2021-04-01 00:00:00, 시스템: emacross
# 거래일: 2021-04-02 00:00:00, 시스템: emacross
# 거래일: 2021-04-05 00:00:00, 시스템: emacross
# 거래일: 2021-04-06 00:00:00, 시스템: emacross
# 거래일: 2021-04-07 00:00:00, 시스템: emacross
# 거래일: 2021-04-08 00:00:00, 시스템: emacross
# 거래일: 2021-04-09 00:00:00, 시스템: emacross
# 거래일: 2021-04-12 00:00:00, 시스템: emacross
# 거래일: 2021-04-13 00:00:00, 시스템: emacross
# 거래일: 2021-04-14 00:00:00, 시스템: emacross
# 거래일: 2021-04-15 00:00:00, 시스템: emacross
# 거래일: 2021-04-16 00:00:00, 시스템: emacross
# 거래일: 2021-04-19 00:00:00, 시스템: emacross
# 거래일: 2021-04-20 00:00:00, 시스템: emacross
# 거래일: 2021-04-21 00:00:00, 시스템: emacross
# 거래일: 2021-04-22 00:00:00, 시스템: emacross
# 거래일: 2021-04-23 00:00:00, 시스템: emacross
# 거래일: 2021-04-26 00:00:00, 시스템: emacross
# 거래일: 2021-04-27 00:00:00, 시스템: emacross
# 거래일: 2021-04-28 00:00:00, 시스템: emacross
# 거래일: 2021-04-29 00:00:00, 시스템: emacross
# 거래일: 2021-04-30 00:00:00, 시스템: emacross
# 거래일: 2021-05-03 00:00:00, 시스템: emacross
# 거래일: 2021-05-04 00:00:00, 시스템: emacross
# 거래일: 2021-05-05 00:00:00, 시스템: emacross
# 거래일: 2021-05-06 00:00:00, 시스템: emacross
# 거래일: 2021-05-07 00:00:00, 시스템: emacross
# 거래일: 2021-05-10 00:00:00, 시스템: emacross
# 거래일: 2021-05-11 00:00:00, 시스템: emacross
# 거래일: 2021-05-12 00:00:00, 시스템: emacross
# 거래일: 2021-05-13 00:00:00, 시스템: emacross
# 거래일: 2021-05-14 00:00:00, 시스템: emacross
# 거래일: 2021-05-17 00:00:00, 시스템: emacross
# 거래일: 2021-05-18 00:00:00, 시스템: emacross
# 거래일: 2021-05-19 00:00:00, 시스템: emacross
# 거래일: 2021-05-20 00:00:00, 시스템: emacross
# 거래일: 2021-05-21 00:00:00, 시스템: emacross
# 거래일: 2021-05-24 00:00:00, 시스템: emacross
# 거래일: 2021-05-25 00:00:00, 시스템: emacross
# 거래일: 2021-05-26 00:00:00, 시스템: emacross
# 거래일: 2021-05-27 00:00:00, 시스템: emacross
# 거래일: 2021-05-28 00:00:00, 시스템: emacross
# 거래일: 2021-05-31 00:00:00, 시스템: emacross
# 거래일: 2021-06-01 00:00:00, 시스템: emacross
# 거래일: 2021-06-02 00:00:00, 시스템: emacross
# 거래일: 2021-06-03 00:00:00, 시스템: emacross
# 거래일: 2021-06-04 00:00:00, 시스템: emacross
# 거래일: 2021-06-07 00:00:00, 시스템: emacross
# 거래일: 2021-06-08 00:00:00, 시스템: emacross
# 거래일: 2021-06-09 00:00:00, 시스템: emacross
# 거래일: 2021-06-10 00:00:00, 시스템: emacross
# 거래일: 2021-06-11 00:00:00, 시스템: emacross
# 거래일: 2021-06-14 00:00:00, 시스템: emacross
# 거래일: 2021-06-15 00:00:00, 시스템: emacross
# 거래일: 2021-06-16 00:00:00, 시스템: emacross
# 거래일: 2021-06-17 00:00:00, 시스템: emacross
# 거래일: 2021-06-18 00:00:00, 시스템: emacross
# 거래일: 2021-06-21 00:00:00, 시스템: emacross
# 거래일: 2021-06-22 00:00:00, 시스템: emacross
# 거래일: 2021-06-23 00:00:00, 시스템: emacross
# 거래일: 2021-06-24 00:00:00, 시스템: emacross
# 거래일: 2021-06-25 00:00:00, 시스템: emacross
# 거래일: 2021-06-28 00:00:00, 시스템: emacross
# 거래일: 2021-06-29 00:00:00, 시스템: emacross
# 거래일: 2021-06-30 00:00:00, 시스템: emacross
# 거래일: 2021-07-01 00:00:00, 시스템: emacross
# 거래일: 2021-07-02 00:00:00, 시스템: emacross
# 거래일: 2021-07-05 00:00:00, 시스템: emacross
# 거래일: 2021-07-06 00:00:00, 시스템: emacross
# 거래일: 2021-07-07 00:00:00, 시스템: emacross
# 거래일: 2021-07-08 00:00:00, 시스템: emacross
# 거래일: 2021-07-09 00:00:00, 시스템: emacross
# 거래일: 2021-07-12 00:00:00, 시스템: emacross
# 거래일: 2021-07-13 00:00:00, 시스템: emacross
# 거래일: 2021-07-14 00:00:00, 시스템: emacross
# 거래일: 2021-07-15 00:00:00, 시스템: emacross
# 거래일: 2021-07-16 00:00:00, 시스템: emacross
# 거래일: 2021-07-19 00:00:00, 시스템: emacross
# 거래일: 2021-07-20 00:00:00, 시스템: emacross
# 거래일: 2021-07-21 00:00:00, 시스템: emacross
# 거래일: 2021-07-22 00:00:00, 시스템: emacross
# 거래일: 2021-07-23 00:00:00, 시스템: emacross
# 거래일: 2021-07-26 00:00:00, 시스템: emacross
# 거래일: 2021-07-27 00:00:00, 시스템: emacross
# 거래일: 2021-07-28 00:00:00, 시스템: emacross
# 거래일: 2021-07-29 00:00:00, 시스템: emacross
# 거래일: 2021-07-30 00:00:00, 시스템: emacross
# 거래일: 2021-08-02 00:00:00, 시스템: emacross
# 거래일: 2021-08-03 00:00:00, 시스템: emacross
# 거래일: 2021-08-04 00:00:00, 시스템: emacross
# 거래일: 2021-08-05 00:00:00, 시스템: emacross
# 거래일: 2021-08-06 00:00:00, 시스템: emacross
# 거래일: 2021-08-09 00:00:00, 시스템: emacross
# 거래일: 2021-08-10 00:00:00, 시스템: emacross
# 거래일: 2021-08-11 00:00:00, 시스템: emacross
# 거래일: 2021-08-12 00:00:00, 시스템: emacross
# 거래일: 2021-08-13 00:00:00, 시스템: emacross
# 거래일: 2021-08-16 00:00:00, 시스템: emacross
# 거래일: 2021-08-17 00:00:00, 시스템: emacross
# 거래일: 2021-08-18 00:00:00, 시스템: emacross
# 거래일: 2021-08-19 00:00:00, 시스템: emacross
# 거래일: 2021-08-20 00:00:00, 시스템: emacross
# 거래일: 2021-08-23 00:00:00, 시스템: emacross
# 거래일: 2021-08-24 00:00:00, 시스템: emacross
# 거래일: 2021-08-25 00:00:00, 시스템: emacross
# 거래일: 2021-08-26 00:00:00, 시스템: emacross
# 거래일: 2021-08-27 00:00:00, 시스템: emacross
# 거래일: 2021-08-30 00:00:00, 시스템: emacross
# 거래일: 2021-08-31 00:00:00, 시스템: emacross
# 거래일: 2021-09-01 00:00:00, 시스템: emacross
# 거래일: 2021-09-02 00:00:00, 시스템: emacross
# 거래일: 2021-09-03 00:00:00, 시스템: emacross
# 거래일: 2021-09-06 00:00:00, 시스템: emacross
# 거래일: 2021-09-07 00:00:00, 시스템: emacross
# 거래일: 2021-09-08 00:00:00, 시스템: emacross
# 거래일: 2021-09-09 00:00:00, 시스템: emacross
# 거래일: 2021-09-10 00:00:00, 시스템: emacross
# 거래일: 2021-09-13 00:00:00, 시스템: emacross
# 거래일: 2021-09-14 00:00:00, 시스템: emacross
# 거래일: 2021-09-15 00:00:00, 시스템: emacross
# 거래일: 2021-09-16 00:00:00, 시스템: emacross
# 거래일: 2021-09-17 00:00:00, 시스템: emacross
# 거래일: 2021-09-20 00:00:00, 시스템: emacross
# 거래일: 2021-09-21 00:00:00, 시스템: emacross
# 거래일: 2021-09-22 00:00:00, 시스템: emacross
# 거래일: 2021-09-23 00:00:00, 시스템: emacross
# 거래일: 2021-09-24 00:00:00, 시스템: emacross
# 거래일: 2021-09-27 00:00:00, 시스템: emacross
# 거래일: 2021-09-28 00:00:00, 시스템: emacross
# 거래일: 2021-09-29 00:00:00, 시스템: emacross
# 거래일: 2021-09-30 00:00:00, 시스템: emacross
# 거래일: 2021-10-01 00:00:00, 시스템: emacross
# 거래일: 2021-10-04 00:00:00, 시스템: emacross
# 거래일: 2021-10-05 00:00:00, 시스템: emacross
# 거래일: 2021-10-06 00:00:00, 시스템: emacross
# 거래일: 2021-10-07 00:00:00, 시스템: emacross
# 거래일: 2021-10-08 00:00:00, 시스템: emacross
# 거래일: 2021-10-11 00:00:00, 시스템: emacross
# 거래일: 2021-10-12 00:00:00, 시스템: emacross
# 거래일: 2021-10-13 00:00:00, 시스템: emacross
# 거래일: 2021-10-14 00:00:00, 시스템: emacross
# 거래일: 2021-10-15 00:00:00, 시스템: emacross
# 거래일: 2021-10-18 00:00:00, 시스템: emacross
# 거래일: 2021-10-19 00:00:00, 시스템: emacross
# 거래일: 2021-10-20 00:00:00, 시스템: emacross
# 거래일: 2021-10-21 00:00:00, 시스템: emacross
# 거래일: 2021-10-22 00:00:00, 시스템: emacross
# 거래일: 2021-10-25 00:00:00, 시스템: emacross
# 거래일: 2021-10-26 00:00:00, 시스템: emacross
# 거래일: 2021-10-27 00:00:00, 시스템: emacross
# 거래일: 2021-10-28 00:00:00, 시스템: emacross
# 거래일: 2021-10-29 00:00:00, 시스템: emacross
# 거래일: 2021-11-01 00:00:00, 시스템: emacross
# 거래일: 2021-11-02 00:00:00, 시스템: emacross
# 거래일: 2021-11-03 00:00:00, 시스템: emacross
# 거래일: 2021-11-04 00:00:00, 시스템: emacross
# 거래일: 2021-11-05 00:00:00, 시스템: emacross
# 거래일: 2021-11-08 00:00:00, 시스템: emacross
# 거래일: 2021-11-09 00:00:00, 시스템: emacross
# 거래일: 2021-11-10 00:00:00, 시스템: emacross
# 거래일: 2021-11-11 00:00:00, 시스템: emacross
# 거래일: 2021-11-12 00:00:00, 시스템: emacross
# 거래일: 2021-11-15 00:00:00, 시스템: emacross
# 거래일: 2021-11-16 00:00:00, 시스템: emacross
# 거래일: 2021-11-17 00:00:00, 시스템: emacross
# 거래일: 2021-11-18 00:00:00, 시스템: emacross
# 거래일: 2021-11-19 00:00:00, 시스템: emacross
# 거래일: 2021-11-22 00:00:00, 시스템: emacross
# 거래일: 2021-11-23 00:00:00, 시스템: emacross
# 거래일: 2021-11-24 00:00:00, 시스템: emacross
# 거래일: 2021-11-25 00:00:00, 시스템: emacross
# 거래일: 2021-11-26 00:00:00, 시스템: emacross
# 거래일: 2021-11-29 00:00:00, 시스템: emacross
# 거래일: 2021-11-30 00:00:00, 시스템: emacross
# 거래일: 2021-12-01 00:00:00, 시스템: emacross
# 거래일: 2021-12-02 00:00:00, 시스템: emacross
# 거래일: 2021-12-03 00:00:00, 시스템: emacross
# 거래일: 2021-12-06 00:00:00, 시스템: emacross
# 거래일: 2021-12-07 00:00:00, 시스템: emacross
# 거래일: 2021-12-08 00:00:00, 시스템: emacross
# 거래일: 2021-12-09 00:00:00, 시스템: emacross
# 거래일: 2021-12-10 00:00:00, 시스템: emacross
# 거래일: 2021-12-13 00:00:00, 시스템: emacross
# 거래일: 2021-12-14 00:00:00, 시스템: emacross
# 거래일: 2021-12-15 00:00:00, 시스템: emacross
# 거래일: 2021-12-16 00:00:00, 시스템: emacross
# 거래일: 2021-12-17 00:00:00, 시스템: emacross
# 거래일: 2021-12-20 00:00:00, 시스템: emacross
# 거래일: 2021-12-21 00:00:00, 시스템: emacross
# 거래일: 2021-12-22 00:00:00, 시스템: emacross
# 거래일: 2021-12-23 00:00:00, 시스템: emacross
# 거래일: 2021-12-24 00:00:00, 시스템: emacross
# 거래일: 2021-12-27 00:00:00, 시스템: emacross
# 거래일: 2021-12-28 00:00:00, 시스템: emacross
# 거래일: 2021-12-29 00:00:00, 시스템: emacross
# 거래일: 2021-12-30 00:00:00, 시스템: emacross
# 거래일: 2021-12-31 00:00:00, 시스템: emacross
# 거래일: 2022-01-03 00:00:00, 시스템: emacross
# 거래일: 2022-01-04 00:00:00, 시스템: emacross
# 거래일: 2022-01-05 00:00:00, 시스템: emacross
# 거래일: 2022-01-06 00:00:00, 시스템: emacross
# 거래일: 2022-01-07 00:00:00, 시스템: emacross
# 거래일: 2022-01-10 00:00:00, 시스템: emacross
# 거래일: 2022-01-11 00:00:00, 시스템: emacross
# 거래일: 2022-01-12 00:00:00, 시스템: emacross
# 거래일: 2022-01-13 00:00:00, 시스템: emacross
# 거래일: 2022-01-14 00:00:00, 시스템: emacross
# 거래일: 2022-01-17 00:00:00, 시스템: emacross
# 거래일: 2022-01-18 00:00:00, 시스템: emacross
# 거래일: 2022-01-19 00:00:00, 시스템: emacross
# 거래일: 2022-01-20 00:00:00, 시스템: emacross
# 거래일: 2022-01-21 00:00:00, 시스템: emacross
# 거래일: 2022-01-24 00:00:00, 시스템: emacross
# 거래일: 2022-01-25 00:00:00, 시스템: emacross
# 거래일: 2022-01-26 00:00:00, 시스템: emacross
# 거래일: 2022-01-27 00:00:00, 시스템: emacross
# 거래일: 2022-01-28 00:00:00, 시스템: emacross
# 거래일: 2022-01-31 00:00:00, 시스템: emacross
# 거래일: 2022-02-01 00:00:00, 시스템: emacross
# 거래일: 2022-02-02 00:00:00, 시스템: emacross
# 거래일: 2022-02-03 00:00:00, 시스템: emacross
# 거래일: 2022-02-04 00:00:00, 시스템: emacross
# 거래일: 2022-02-07 00:00:00, 시스템: emacross
# 거래일: 2022-02-08 00:00:00, 시스템: emacross
# 거래일: 2022-02-09 00:00:00, 시스템: emacross
# 거래일: 2022-02-10 00:00:00, 시스템: emacross
# 거래일: 2022-02-11 00:00:00, 시스템: emacross
# 거래일: 2022-02-14 00:00:00, 시스템: emacross
# 거래일: 2022-02-15 00:00:00, 시스템: emacross
# 거래일: 2022-02-16 00:00:00, 시스템: emacross
# 거래일: 2022-02-17 00:00:00, 시스템: emacross
# 거래일: 2022-02-18 00:00:00, 시스템: emacross
# 거래일: 2022-02-21 00:00:00, 시스템: emacross
# 거래일: 2022-02-22 00:00:00, 시스템: emacross
# 거래일: 2022-02-23 00:00:00, 시스템: emacross
# 거래일: 2022-02-24 00:00:00, 시스템: emacross
# 거래일: 2022-02-25 00:00:00, 시스템: emacross
# 거래일: 2022-02-28 00:00:00, 시스템: emacross
# 거래일: 2022-03-01 00:00:00, 시스템: emacross
# 거래일: 2022-03-02 00:00:00, 시스템: emacross
# 거래일: 2022-03-03 00:00:00, 시스템: emacross
# 거래일: 2022-03-04 00:00:00, 시스템: emacross
# 거래일: 2022-03-07 00:00:00, 시스템: emacross
# 거래일: 2022-03-08 00:00:00, 시스템: emacross
# 거래일: 2022-03-09 00:00:00, 시스템: emacross
# 거래일: 2022-03-10 00:00:00, 시스템: emacross
# 거래일: 2022-03-11 00:00:00, 시스템: emacross
# 거래일: 2022-03-14 00:00:00, 시스템: emacross
# 거래일: 2022-03-15 00:00:00, 시스템: emacross
# 거래일: 2022-03-16 00:00:00, 시스템: emacross
# 거래일: 2022-03-17 00:00:00, 시스템: emacross
# 거래일: 2022-03-18 00:00:00, 시스템: emacross
# 거래일: 2022-03-21 00:00:00, 시스템: emacross
# 거래일: 2022-03-22 00:00:00, 시스템: emacross
# 거래일: 2022-03-23 00:00:00, 시스템: emacross
# 거래일: 2022-03-24 00:00:00, 시스템: emacross
# 거래일: 2022-03-25 00:00:00, 시스템: emacross
# 거래일: 2022-03-28 00:00:00, 시스템: emacross
# 거래일: 2022-03-29 00:00:00, 시스템: emacross
# 거래일: 2022-03-30 00:00:00, 시스템: emacross
# 거래일: 2022-03-31 00:00:00, 시스템: emacross
# 거래일: 2022-04-01 00:00:00, 시스템: emacross
# 거래일: 2022-04-04 00:00:00, 시스템: emacross
# 거래일: 2022-04-05 00:00:00, 시스템: emacross
# 거래일: 2022-04-06 00:00:00, 시스템: emacross
# 거래일: 2022-04-07 00:00:00, 시스템: emacross
# 거래일: 2022-04-08 00:00:00, 시스템: emacross
# 거래일: 2022-04-11 00:00:00, 시스템: emacross
# 거래일: 2022-04-12 00:00:00, 시스템: emacross
# 거래일: 2022-04-13 00:00:00, 시스템: emacross
# 거래일: 2022-04-14 00:00:00, 시스템: emacross
# 거래일: 2022-04-18 00:00:00, 시스템: emacross
# 거래일: 2022-04-19 00:00:00, 시스템: emacross
# 거래일: 2022-04-20 00:00:00, 시스템: emacross
# 거래일: 2022-04-21 00:00:00, 시스템: emacross
# 거래일: 2022-04-22 00:00:00, 시스템: emacross
# 거래일: 2022-04-25 00:00:00, 시스템: emacross
# 거래일: 2022-04-26 00:00:00, 시스템: emacross
# 거래일: 2022-04-27 00:00:00, 시스템: emacross
# 거래일: 2022-04-28 00:00:00, 시스템: emacross
# 거래일: 2022-04-29 00:00:00, 시스템: emacross
# 거래일: 2022-05-02 00:00:00, 시스템: emacross
# 거래일: 2022-05-03 00:00:00, 시스템: emacross
# 거래일: 2022-05-04 00:00:00, 시스템: emacross
# 매매종료

# %%
equitylog = pd.DataFrame(system.equity.log()).set_index('date')
equity = equitylog.groupby(by='date').last()
x = equity.index.values
capital = equity.capital.values
fixed_capital = equity.fixed_capital.values

# %%
x=(equity.index.astype('int64')/1000000).values

# %%
datafile = f"equitydata = {{\
'total_value' :  {list(map(list, zip(x,capital)))}\
'defined_value': {list(map(list, zip(x,fixed_capital)))}\ 
}}"

# %%
with open('equitydata.txt', 'w') as f:
  f.write(datafile)

# %%
equitylog = pd.DataFrame(system.equity.log()).set_index('date')

# %%
equity = equitylog.groupby(by='date').last()

# %%
x = equity.index.values

# %%
x
# Out:
# array(['2002-12-04T00:00:00.000000000', '2002-12-05T00:00:00.000000000',
#        '2002-12-06T00:00:00.000000000', ...,
#        '2022-01-19T00:00:00.000000000', '2022-01-20T00:00:00.000000000',
#        '2022-01-21T00:00:00.000000000'], dtype='datetime64[ns]')

# %%
refx = (x-x[0])/np.timedelta64(365,'D')

# %%
refx[-1]
# Out:
# 19.145205479452056

# %%
c
# Out:
# [[3], 'hh']

# %%
b.pop(1)
# Out:
# [3]

# %%
b
# Out:
# [[1, 2, 3, 4], 'hh']

# %%
starts = {} #첫 거래 시작일
for symbol in ['AD']:
    flag = trader.quotes[symbol][['open','high','low','close']].isna().any(axis=1)
    system.signals.loc[flag, symbol] = np.nan
    starts[symbol] = trader.quotes[symbol][~flag].index[0]

# %%
starts
# Out:
# {'AD': Timestamp('1987-01-13 00:00:00')}

# %%
flag = trader.quotes['AD'].isna().any(axis=1)

# %%
system.signals.first_valid_index()
# Out:
# Timestamp('1987-01-13 00:00:00')

# %%
system.signals.index[system.signals.index.get_loc(system.signals.first_valid_index())-1]
# Out:
# Timestamp('1987-01-12 00:00:00')

# %%
df=df.iloc[1000]

# %%
mask = df.isna().groupby('symbol').any()

# %%
mask[~mask]
# Out:
# symbol
# BO    False
# C     False
# HG    False
# W     False
# Name: 1963-07-22 00:00:00, dtype: bool

# %%
instruments['NQ'].tickunit
# Out:
# 0.25

# %%
while a:
    print(a.pop())

# %%
df=trader.quotes['AD']

# %%
df.iloc[0][['open','high','low','close']].notna().all()
# Out:
# False

# %%
a=[1,2,3,4]

# %%
a.pop(2)
# Out:
# 3

# %%
for i in a:
    a.remove(i)

# %%
system.trades.get_on_fires(symbol='AD')
# Out:
# []

# %%
system.trades.get_on_fires()
# Out:
# []

# %%
df=Quotes(quote['AD'], type='single')

# %%
df.MA(window=10, inplace=True)

# %%
df
# Out:
# field          open     high      low    close    volume        oi      ma30  \
# date
# 1959-08-03      NaN      NaN      NaN      NaN       NaN       NaN       NaN
# 1959-08-04      NaN      NaN      NaN      NaN       NaN       NaN       NaN
# 1959-08-05      NaN      NaN      NaN      NaN       NaN       NaN       NaN
# 1959-08-06      NaN      NaN      NaN      NaN       NaN       NaN       NaN
# 1959-08-07      NaN      NaN      NaN      NaN       NaN       NaN       NaN
# ...             ...      ...      ...      ...       ...       ...       ...
# 2022-04-28  0.71290  0.71660  0.70595  0.70995  112019.0  144283.0  0.741827
# 2022-04-29  0.71035  0.71845  0.70610  0.70870  124501.0  144179.0  0.740832
# 2022-05-02  0.70710  0.70870  0.70355  0.70415   91807.0  140428.0  0.739580
# 2022-05-03  0.70570  0.71535  0.70525  0.70990  114059.0  143087.0  0.738575
# 2022-05-04  0.71005  0.72700  0.70925  0.72370  117416.0  151039.0  0.737803
#
# field           ma10
# date
# 1959-08-03       NaN
# 1959-08-04       NaN
# 1959-08-05       NaN
# 1959-08-06       NaN
# 1959-08-07       NaN
# ...              ...
# 2022-04-28  0.727695
# 2022-04-29  0.724340
# 2022-05-02  0.721195
# 2022-05-03  0.718380
# 2022-05-04  0.716285
#
# [15987 rows x 8 columns]

# %%
df.columns.levels
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [73], line 1
# ----> 1 df.columns.levels[0]
#
# AttributeError: 'Index' object has no attribute 'levels'

# %%
f=quote.columns

# %%
len(f.names)
# Out:
# 2

# %%
d =df.columns

# %%
len(d.names)
# Out:
# 1
