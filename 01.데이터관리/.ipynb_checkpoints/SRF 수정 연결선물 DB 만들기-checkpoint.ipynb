# %%
import sys, os, csv, h5py
sys.path.append('..')
import pandas as pd
import numpy as np

# %%
#del sys.modules['tools.instruments']
from tools.instruments import instruments
from tools.constants import SRF_ROLLOVER_BO_CSV_PATH, SRF_ROLLOVER_BV_CSV_PATH,\
                              SRF_CONTINUOUS_BO_DB_PATH, SRF_CONTINUOUS_BV_DB_PATH
from tools.visualisation import view

# %%
file = h5py.File(SRF_ROLLOVER_BO_CSV_PATH, 'w')

# %%
method = 'bo'
fields = ['open','high','low','close']
# numpy array datatypes
dtypes= np.dtype([
        ('date', 'i'),
        ('open', 'f'),
        ('high','f'),
        ('low','f'),
        ('close','f'),
        ('volume', 'i'),
        ('open_interest','i')
    ])

for instrument in instruments.values():
    if not instrument.contracts:
        print(f"{instrument.name}은 대상 상품이 아님")
        continue
    print(f"{instrument.name}: {method} 방식으로 연결")
        
    rolls = instrument.rolldates(method = method)
    data = pd.DataFrame()
    for roll in rolls:
        code, start, diff = roll[1], roll[2], float(roll[4])
        end = roll[3] if roll[3] else None

        quotes = instrument.quotes(contract=code)[start:end]

        if len(data) > 0:
            data[fields] = data[fields]+ diff
        data = pd.concat([data, quotes])
        
    data.reset_index(inplace=True)
    data['date'] = data['date'].values.astype('M8[D]').astype('i')
    data = np.array(list(map(tuple, data.values)), dtypes)
    file.create_dataset(instrument.symbol, data=data)
    
print('DOne')
# Out:
# CME Australian Dollar AUD: bo 방식으로 연결
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12752/3742968862.py in <module>
#      18     print(f"{instrument.name}: {method} 방식으로 연결")
#      19
# ---> 20     rolls = instrument.rolldates(method = method)
#      21     data = pd.DataFrame()
#      22     for roll in rolls:
#
# ~\Documents\projects\Trading\tools\instruments.py in rolldates(self, method)
#     121         with open(filepath, mode='r') as f:
#     122             lines = csv.reader(f)
# --> 123             for line in lines:
#     124                 if line[0] == self.symbol:
#     125                     rolls.append(line)
#
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xff in position 32: illegal multibyte sequence

# %%
rolls = instruments['C'].rolldates(method='bo')

# %%
view(data)

# %%
data.isna().sum()
# Out:
# date             0
# open             0
# high             0
# low              0
# close            0
# volume           0
# open_interest    0
# dtype: int64

# %%
quotes
# Out:
#               open    high     low   close  volume  open_interest
# date
# 1987-03-13  0.6610  0.6656  0.6580  0.6628     445           1370
# 1987-03-16  0.6656  0.6656  0.6634  0.6645     131           1431
# 1987-03-17  0.6700  0.6732  0.6700  0.6732     137           1504
# 1987-03-18  0.6725  0.6743  0.6719  0.6735     101           1540
# 1987-03-19  0.6703  0.6723  0.6684  0.6691     388           1576
# 1987-03-20  0.6694  0.6720  0.6690  0.6715      66           1557
# 1987-03-23  0.6740  0.6750  0.6740  0.6746      95           1539
# 1987-03-24  0.6825  0.6825  0.6784  0.6799     255           1654
# 1987-03-25  0.6804  0.6815  0.6797  0.6797      94           1688
# 1987-03-26  0.6815  0.6823  0.6800  0.6800      93           1664
