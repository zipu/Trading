# %% [markdown]
# ## Kibot.com 월물리스트 다운로드 및 파일 생성
#  * KibotAPI 이용
#  * 과거 상품별 월물 OHLC 데이터 제공
#
#  - Data/instruments.csv 에 등록된 kibot 상품에 대한 월물목록을
#    kibot.com에서 다운로드하여 contracts_list.txt 파일로 저장

# %%
import sys
sys.path.append('..')
import requests
import csv
import h5py
import os
import numpy as np

# %%
from tools.instruments import instruments
from tools.constants import DATADIR
from tools.common import monitor_memory

# %%
del sys.modules['tools.common']
del sys.modules['tools.instruments']

# %%
monitor_memory(dir())
# Out:
# [('ret', 2447), ('t', 819), ('np', 157), ('s', 67), ('contracts_list', 63), ('instruments', 6), ('session', 6), ('DATADIR', 5), ('DataRequestURL', 5), ('FILEPATH', 5), ('LoginURL', 5), ('LogoutURL', 5), ('res', 5), ('contracts', 4), ('defaultdict', 4), ('a', 3), ('line', 3), ('monitor_memory', 3), ('symbols', 2), ('lines', 1)]

# %%
FILEPATH = os.path.join(DATADIR,'kibot/contracts-list.csv')

# %% [markdown]
# ### 1. Kibot에서 다운 가능한 종목 코드 불러오기
# * 불러온 종목코드는 symbols[] 에 저장

# %%
symbols = instruments.getlist('kibot')

# %% [markdown]
# ### 2. Kibot.com 서버에서 월물정보 다운로드

# %%
LoginURL = "http://api.kibot.com?action=login&user=guest&password=guest"
DataRequestURL = "http://api.kibot.com"
LogoutURL = "http://api.kibot.com?action=logout"

# %%
# http requests session 연결 후 종목별 다운로드
print("서버 접속 시작")
with requests.Session() as session:
    res = session.get(LoginURL)
    if res.status_code != 200:
        print(res.text)
        session.close()
        
    ret = session.get("http://www.kibot.com/Files/2/Futures_tickbidask.txt")

print("다운로드 완료")
# Out:
# 서버 접속 시작
# 다운로드 완료

# %% [markdown]
# ### 3. 데이터 저장
# * 상품별 월물을 생성시간 순으로 정리하여 파일로 저장

# %%
from collections import defaultdict
from datetime import datetime

# %%
symbols = instruments.getlist('kibot')

# %%
contracts = defaultdict(list)

# %%
s = list(filter(bool, ret.text.splitlines()[6:]))

# %%
contracts_list = [x.split('\t') for x in filter(bool, ret.text.splitlines()[6:])]

# %%
filtered = list(filter(lambda x: len(x[2])>3, contracts_list))

# %%
list(filtered.sort(key=lambda x: x[0]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8240/2976654365.py in <module>
# ----> 1 list(filtered.sort(key=lambda x: x[0]))
#
# TypeError: 'NoneType' object is not iterable

# %%
'7188'

# %%
filtered
# Out:
# [['7188',
#   'AC',
#   'ACF11',
#   '4/1/2010',
#   '0.16           ',
#   'ETHANOL JANUARY 2011',
#   'Chicago Board Of Trade (CBOT GLOBEX)'],
#  ['7189',
#   'AC',
#   'ACF12',
#   '5/4/2010',
#   '0.27           ',
#   'ETHANOL JANUARY 2012',
#   'Chicago Board Of Trade (CBOT GLOBEX)'],
#  ['7190',
#   'AC',
#   'ACF13',
#   '7/27/2011',
#   '0.45           ',
#   'ETHANOL JANUARY 2013',
#   'Chicago Board Of Trade (CBOT GLOBEX)'],
#  ['7191',
#   'AC',
#   'ACF14',
#   '11/27/2012',
#   '0.24           ',
#   'ETHANOL JANUARY 2014',
#   'Chicago Board Of Trade (CBOT GLOBEX)'],
#  ['7192',
#   'AC',
#   'ACF15',
#   '2/5/2014',
#   '0.34           ',
#   'ETHANOL JANUARY 2015',
#   'Chicago Board Of Trade (CBOT GLOBEX)'],
#  ['7193',
#   'AC',
#   'ACF16',
#   '4/21/2015',
#   '0.12           ',
#   'ETHANOL JANUARY 2016',
#   'Chicago Board Of Trade (CBOT GLOBEX)'],
#  ['7194',
#   'AC',
#   'ACF17',
#   '6/8/2016',
#   '0.13           ',
#   'ETHANOL JANUARY 2017',
# ...

# %%
contracts_list = [x.split('\t') for x in list(filter(bool, ret.text.splitlines()[6:]))]

# %%
for line in contracts_list:
    if line[1] in symbols and len(line[2])>3:
        contracts[line[1]].append((line[1],line[2], line[3],line[5]))
        #print(line[0],line[2], line[3],line[5])

# %%
for symbol in contracts['values']

# %%
with open(FILEPATH, 'wb') as file:
    wr = csv.writer(file, quoting=csv.QUOTE_ALL)
    wr.writerow(co)

# %%
a.sort(key=lambda x: (int(x[1][3:]), instruments.month_code(x[1][2])))

# %%
[x for x in contracts.values()]
# Out:
# [[('ES', 'ESH11', '4/6/2010', 'E-MINI S&P 500 MARCH 2011'),
#   ('ES', 'ESH12', '3/6/2011', 'E-MINI S&P 500 MARCH 2012'),
#   ('ES', 'ESH13', '3/19/2012', 'E-MINI S&P 500 MARCH 2013'),
#   ('ES', 'ESH14', '3/6/2013', 'E-MINI S&P 500 MARCH 2014'),
#   ('ES', 'ESH15', '1/6/2014', 'E-MINI S&P 500 MARCH 2015'),
#   ('ES', 'ESH16', '1/6/2015', 'E-MINI S&P 500 MARCH 2016'),
#   ('ES', 'ESH17', '2/2/2016', 'E-MINI S&P 500 MARCH 2017'),
#   ('ES', 'ESH18', '1/6/2017', 'E-MINI S&P 500 MARCH 2018'),
#   ('ES', 'ESH19', '1/16/2018', 'E-MINI S&P 500 MARCH 2019'),
#   ('ES', 'ESH20', '1/11/2019', 'E-MINI S&P 500 MARCH 2020'),
#   ('ES', 'ESH21', '1/2/2020', 'E-MINI S&P 500 MARCH 2021'),
#   ('ES', 'ESH22', '1/8/2021', 'E-MINI S&P 500 MARCH 2022'),
#   ('ES', 'ESH23', '11/30/2021', 'E-MINI S&P 500 MARCH 2023'),
#   ('ES', 'ESM10', '6/7/2010', 'E-MINI S&P 500 JUNE 2010'),
#   ('ES', 'ESM11', '5/4/2010', 'E-MINI S&P 500 JUNE 2011'),
#   ('ES', 'ESM12', '3/21/2011', 'E-MINI S&P 500 JUNE 2012'),
# ...

# %%
a
# Out:
# [('58', 'NQH11', '5/24/2010', 'E-MINI NASDAQ 100 MARCH 2011'),
#  ('58', 'NQH11', '5/24/2010', 'E-MINI NASDAQ 100 MARCH 2011'),
#  ('59', 'NQH12', '3/7/2011', 'E-MINI NASDAQ 100 MARCH 2012'),
#  ('59', 'NQH12', '3/7/2011', 'E-MINI NASDAQ 100 MARCH 2012'),
#  ('60', 'NQH13', '7/6/2012', 'E-MINI NASDAQ 100 MARCH 2013'),
#  ('60', 'NQH13', '7/6/2012', 'E-MINI NASDAQ 100 MARCH 2013'),
#  ('61', 'NQH14', '12/24/2012', 'E-MINI NASDAQ 100 MARCH 2014'),
#  ('61', 'NQH14', '12/24/2012', 'E-MINI NASDAQ 100 MARCH 2014'),
#  ('62', 'NQH15', '1/2/2014', 'E-MINI NASDAQ 100 MARCH 2015'),
#  ('62', 'NQH15', '1/2/2014', 'E-MINI NASDAQ 100 MARCH 2015'),
#  ('63', 'NQH16', '7/1/2015', 'E-MINI NASDAQ 100 MARCH 2016'),
#  ('63', 'NQH16', '7/1/2015', 'E-MINI NASDAQ 100 MARCH 2016'),
#  ('64', 'NQH17', '3/30/2016', 'E-MINI NASDAQ 100 MARCH 2017'),
#  ('64', 'NQH17', '3/30/2016', 'E-MINI NASDAQ 100 MARCH 2017'),
#  ('65', 'NQH18', '1/24/2017', 'E-MINI NASDAQ 100 MARCH 2018'),
# ...
