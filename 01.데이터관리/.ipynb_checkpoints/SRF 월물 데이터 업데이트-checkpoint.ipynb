# %% [markdown]
# * SRF 에서 월물 전체 데이터를 매번 다운 받는것이 비효율적이어서
#   업데이트된 데이터만 추가로 다운 받는 코드

# %%
import sys, os, csv
sys.path.append('..')
from datetime import datetime
import numpy as np
import pandas as pd
import h5py

import nasdaqdatalink as ndl

# %%
#del sys.modules['tools.instruments']
#del sys.modules['tools.visualisation']
from tools.instruments import instruments
from tools.display import view
from tools.constants import SRF_CONTRACTS_DB_PATH

# %%
# 저장할 DB파일 생성 및 그룹생성
file = h5py.File(SRF_CONTRACTS_DB_PATH, 'w')
for instrument in instruments.values():
    if instrument.contracts:
        file.create_group(instrument.symbol)

# %%
instruments['AD'].contracts
# Out:
# [['AD',
#   'CME_AD',
#   'CME_ADH1987',
#   '1987-01-13',
#   '1987-03-16',
#   '2015-04-27 16:19:23'],
#  ['AD',
#   'CME_AD',
#   'CME_ADM1987',
#   '1987-01-13',
#   '1987-06-15',
#   '2015-04-27 16:19:23'],
#  ['AD',
#   'CME_AD',
#   'CME_ADU1987',
#   '1987-01-16',
#   '1987-09-14',
#   '2015-04-27 16:19:24'],
#  ['AD',
#   'CME_AD',
#   'CME_ADZ1987',
#   '1987-03-18',
#   '1987-12-14',
#   '2015-04-27 16:19:25'],
#  ['AD',
#   'CME_AD',
#   'CME_ADH1988',
#   '1987-06-17',
#   '1988-03-14',
#   '2015-04-27 16:19:24'],
#  ['AD',
#   'CME_AD',
#   'CME_ADM1988',
#   '1987-10-30',
#   '1988-06-13',
#   '2015-04-27 16:19:24'],
#  ['AD',
#   'CME_AD',
#   'CME_ADU1988',
#   '1988-02-24',
#   '1988-09-19',
#   '2015-04-27 16:19:24'],
#  ['AD',
#   'CME_AD',
#   'CME_ADZ1988',
#   '1988-05-17',
#   '1988-12-19',
#   '2015-04-27 16:19:24'],
#  ['AD',
#   'CME_AD',
#   'CME_ADH1989',
#   '1988-09-02',
#   '1989-03-13',
#   '2015-04-27 16:19:24'],
#  ['AD',
#   'CME_AD',
#   'CME_ADM1989',
#   '1989-01-03',
#   '1989-06-19',
#   '2015-04-27 16:19:24'],
#  ['AD',
#   'CME_AD',
#   'CME_ADU1989',
#   '1989-02-21',
#   '1989-09-18',
#   '2015-04-27 16:19:24'],
#  ['AD',
#   'CME_AD',
#   'CME_ADZ1989',
#   '1989-04-19',
#   '1989-12-18',
#   '2015-04-27 16:19:24'],
#  ['AD',
#   'CME_AD',
#   'CME_ADH1990',
#   '1989-06-20',
#   '1990-03-19',
#   '2015-04-27 16:19:24'],
#  ['AD',
#   'CME_AD',
#   'CME_ADM1990',
#   '1989-10-11',
#   '1990-06-18',
#   '2015-04-27 16:19:24'],
#  ['AD',
#   'CME_AD',
#   'CME_ADU1990',
#   '1990-03-21',
#   '1990-09-17',
#   '2015-04-27 16:19:24'],
#  ['AD',
#   'CME_AD',
#   'CME_ADZ1990',
#   '1990-07-06',
#   '1990-12-17',
#   '2015-04-27 16:19:24'],
#  ['AD',
#   'CME_AD',
#   'CME_ADH1991',
#   '1990-09-27',
#   '1991-03-18',
#   '2015-04-27 16:19:24'],
#  ['AD',
#   'CME_AD',
#   'CME_ADM1991',
#   '1990-12-07',
#   '1991-06-17',
#   '2015-04-27 16:19:25'],
#  ['AD',
#   'CME_AD',
#   'CME_ADU1991',
#   '1991-03-06',
#   '1991-09-16',
#   '2015-04-27 16:19:25'],
#  ['AD',
#   'CME_AD',
#   'CME_ADZ1991',
#   '1991-06-06',
#   '1991-12-16',
#   '2015-04-27 16:19:25'],
#  ['AD',
#   'CME_AD',
#   'CME_ADH1992',
#   '1991-08-15',
#   '1992-03-16',
#   '2015-04-27 16:19:25'],
#  ['AD',
#   'CME_AD',
#   'CME_ADM1992',
#   '1991-12-11',
#   '1992-06-15',
#   '2015-04-27 16:19:25'],
#  ['AD',
#   'CME_AD',
#   'CME_ADU1992',
#   '1992-03-05',
#   '1992-09-14',
#   '2015-04-27 16:19:25'],
#  ['AD',
#   'CME_AD',
#   'CME_ADZ1992',
#   '1992-03-17',
#   '1992-12-14',
#   '2015-04-27 16:19:25'],
#  ['AD',
#   'CME_AD',
#   'CME_ADH1993',
#   '1992-06-08',
#   '1993-03-15',
#   '2015-04-27 16:19:25'],
#  ['AD',
#   'CME_AD',
#   'CME_ADM1993',
#   '1992-09-08',
#   '1993-06-14',
#   '2015-04-27 16:19:25'],
#  ['AD',
#   'CME_AD',
#   'CME_ADU1993',
#   '1992-12-10',
#   '1993-09-13',
#   '2015-04-27 16:19:25'],
#  ['AD',
#   'CME_AD',
#   'CME_ADZ1993',
#   '1992-12-30',
#   '1993-12-13',
#   '2015-04-27 16:19:25'],
#  ['AD',
#   'CME_AD',
#   'CME_ADH1994',
#   '1993-06-03',
#   '1994-03-14',
#   '2015-04-27 16:19:25'],
#  ['AD',
#   'CME_AD',
#   'CME_ADM1994',
#   '1993-09-03',
#   '1994-06-13',
#   '2015-04-27 16:19:25'],
#  ['AD',
#   'CME_AD',
#   'CME_ADU1994',
#   '1993-12-03',
#   '1994-09-19',
#   '2015-04-27 16:19:26'],
#  ['AD',
#   'CME_AD',
#   'CME_ADZ1994',
#   '1994-03-02',
#   '1994-12-19',
#   '2015-04-27 16:19:25'],
#  ['AD',
#   'CME_AD',
#   'CME_ADH1995',
#   '1994-06-03',
#   '1995-03-13',
#   '2015-04-27 16:19:26'],
#  ['AD',
#   'CME_AD',
#   'CME_ADM1995',
#   '1994-09-09',
#   '1995-06-19',
#   '2015-04-27 16:19:26'],
#  ['AD',
#   'CME_AD',
#   'CME_ADU1995',
#   '1994-12-09',
#   '1995-09-18',
#   '2015-04-27 16:19:26'],
#  ['AD',
#   'CME_AD',
#   'CME_ADZ1995',
#   '1995-03-06',
#   '1995-12-18',
#   '2015-04-27 16:19:26'],
#  ['AD',
#   'CME_AD',
#   'CME_ADH1996',
#   '1995-06-16',
#   '1996-03-18',
#   '2015-04-27 16:19:26'],
#  ['AD',
#   'CME_AD',
#   'CME_ADM1996',
#   '1995-09-11',
#   '1996-06-17',
#   '2015-04-27 16:19:26'],
#  ['AD',
#   'CME_AD',
#   'CME_ADU1996',
#   '1995-12-08',
#   '1996-09-16',
#   '2015-04-27 16:19:26'],
#  ['AD',
#   'CME_AD',
#   'CME_ADZ1996',
#   '1996-03-08',
#   '1996-12-16',
#   '2015-04-27 16:19:26'],
#  ['AD',
#   'CME_AD',
#   'CME_ADH1997',
#   '1996-06-10',
#   '1997-03-17',
#   '2015-04-27 16:19:26'],
#  ['AD',
#   'CME_AD',
#   'CME_ADM1997',
#   '1996-09-06',
#   '1997-06-17',
#   '2015-04-27 16:19:27'],
#  ['AD',
#   'CME_AD',
#   'CME_ADU1997',
#   '1996-12-09',
#   '1997-09-15',
#   '2015-04-27 16:19:27'],
#  ['AD',
#   'CME_AD',
#   'CME_ADZ1997',
#   '1997-03-11',
#   '1997-12-15',
#   '2015-04-27 16:19:27'],
#  ['AD',
#   'CME_AD',
#   'CME_ADH1998',
#   '1997-06-10',
#   '1998-03-16',
#   '2015-04-27 16:19:27'],
#  ['AD',
#   'CME_AD',
#   'CME_ADM1998',
#   '1997-09-02',
#   '1998-06-15',
#   '2015-04-27 16:19:27'],
#  ['AD',
#   'CME_AD',
#   'CME_ADU1998',
#   '1997-09-16',
#   '1998-09-14',
#   '2015-04-27 16:19:27'],
#  ['AD',
#   'CME_AD',
#   'CME_ADZ1998',
#   '1998-03-06',
#   '1998-12-14',
#   '2015-04-27 16:19:27'],
#  ['AD',
#   'CME_AD',
#   'CME_ADH1999',
#   '1998-05-12',
#   '1999-03-15',
#   '2015-04-27 16:19:28'],
#  ['AD',
#   'CME_AD',
#   'CME_ADM1999',
#   '1998-06-10',
#   '1999-06-14',
#   '2015-04-27 16:19:28'],
#  ['AD',
#   'CME_AD',
#   'CME_ADU1999',
#   '1998-09-09',
#   '1999-09-13',
#   '2015-04-27 16:19:28'],
#  ['AD',
#   'CME_AD',
#   'CME_ADZ1999',
#   '1998-09-11',
#   '1999-12-13',
#   '2015-04-27 16:19:28'],
#  ['AD',
#   'CME_AD',
#   'CME_ADH2000',
#   '1999-03-05',
#   '2000-03-13',
#   '2015-04-27 16:19:28'],
#  ['AD',
#   'CME_AD',
#   'CME_ADM2000',
#   '1999-06-08',
#   '2000-06-19',
#   '2015-04-27 16:19:28'],
#  ['AD',
#   'CME_AD',
#   'CME_ADU2000',
#   '1999-08-10',
#   '2000-09-18',
#   '2015-04-27 16:19:28'],
#  ['AD',
#   'CME_AD',
#   'CME_ADZ2000',
#   '1999-12-07',
#   '2000-12-18',
#   '2015-04-27 16:19:28'],
#  ['AD',
#   'CME_AD',
#   'CME_ADH2001',
#   '2000-01-31',
#   '2001-03-19',
#   '2015-04-27 16:19:28'],
#  ['AD',
#   'CME_AD',
#   'CME_ADM2001',
#   '2000-06-13',
#   '2001-06-18',
#   '2015-04-27 16:19:28'],
#  ['AD',
#   'CME_AD',
#   'CME_ADU2001',
#   '2000-09-12',
#   '2001-09-17',
#   '2015-04-27 16:19:28'],
#  ['AD',
#   'CME_AD',
#   'CME_ADZ2001',
#   '2000-11-08',
#   '2001-12-17',
#   '2015-04-27 16:19:28'],
#  ['AD',
#   'CME_AD',
#   'CME_ADH2002',
#   '2001-03-13',
#   '2002-03-18',
#   '2015-04-27 16:19:28'],
#  ['AD',
#   'CME_AD',
#   'CME_ADM2002',
#   '2001-04-05',
#   '2002-06-17',
#   '2015-04-27 16:19:28'],
#  ['AD',
#   'CME_AD',
#   'CME_ADU2002',
#   '2001-04-05',
#   '2002-09-16',
#   '2015-04-27 16:19:29'],
#  ['AD',
#   'CME_AD',
#   'CME_ADZ2002',
#   '2001-06-19',
#   '2002-12-16',
#   '2015-04-27 16:19:30'],
#  ['AD',
#   'CME_AD',
#   'CME_ADH2003',
#   '2001-09-18',
#   '2003-03-17',
#   '2015-04-27 16:19:30'],
#  ['AD',
#   'CME_AD',
#   'CME_ADM2003',
#   '2001-12-19',
#   '2003-06-16',
#   '2015-04-27 16:19:30'],
#  ['AD',
#   'CME_AD',
#   'CME_ADU2003',
#   '2002-03-19',
#   '2003-09-15',
#   '2015-04-27 16:19:30'],
#  ['AD',
#   'CME_AD',
#   'CME_ADZ2003',
#   '2002-06-18',
#   '2003-12-15',
#   '2015-04-27 16:19:30'],
#  ['AD',
#   'CME_AD',
#   'CME_ADH2004',
#   '2002-09-17',
#   '2004-03-15',
#   '2015-04-27 16:19:30'],
#  ['AD',
#   'CME_AD',
#   'CME_ADM2004',
#   '2002-12-18',
#   '2004-06-14',
#   '2015-04-27 16:19:30'],
#  ['AD',
#   'CME_AD',
#   'CME_ADU2004',
#   '2003-03-17',
#   '2004-09-13',
#   '2015-04-27 16:19:30'],
#  ['AD',
#   'CME_AD',
#   'CME_ADZ2004',
#   '2003-06-16',
#   '2004-12-13',
#   '2015-04-27 16:19:30'],
#  ['AD',
#   'CME_AD',
#   'CME_ADH2005',
#   '2003-09-15',
#   '2005-03-14',
#   '2015-04-27 16:19:30'],
#  ['AD',
#   'CME_AD',
#   'CME_ADM2005',
#   '2003-12-15',
#   '2005-06-13',
#   '2015-04-27 16:19:30'],
#  ['AD',
#   'CME_AD',
#   'CME_ADU2005',
#   '2004-03-15',
#   '2005-09-19',
#   '2015-04-27 16:19:30'],
#  ['AD',
#   'CME_AD',
#   'CME_ADZ2005',
#   '2004-06-14',
#   '2005-12-19',
#   '2015-04-27 16:19:30'],
#  ['AD',
#   'CME_AD',
#   'CME_ADH2006',
#   '2004-09-13',
#   '2006-03-13',
#   '2015-04-27 16:19:31'],
#  ['AD',
#   'CME_AD',
#   'CME_ADM2006',
#   '2004-12-13',
#   '2006-06-19',
#   '2015-04-27 16:19:31'],
#  ['AD',
#   'CME_AD',
#   'CME_ADU2006',
#   '2005-03-14',
#   '2006-09-18',
#   '2015-04-27 16:19:31'],
#  ['AD',
#   'CME_AD',
#   'CME_ADZ2006',
#   '2005-06-13',
#   '2006-12-18',
#   '2015-04-27 16:19:32'],
#  ['AD',
#   'CME_AD',
#   'CME_ADH2007',
#   '2005-09-27',
#   '2007-03-19',
#   '2015-12-17 18:12:01'],
#  ['AD',
#   'CME_AD',
#   'CME_ADM2007',
#   '2005-12-19',
#   '2007-06-18',
#   '2015-12-17 18:12:01'],
#  ['AD',
#   'CME_AD',
#   'CME_ADU2007',
#   '2006-03-27',
#   '2007-09-17',
#   '2015-12-17 18:12:02'],
#  ['AD',
#   'CME_AD',
#   'CME_ADZ2007',
#   '2006-06-26',
#   '2007-12-17',
#   '2015-12-17 18:12:02'],
#  ['AD',
#   'CME_AD',
#   'CME_ADH2008',
#   '2006-09-19',
#   '2008-03-17',
#   '2015-12-17 18:12:02'],
#  ['AD',
#   'CME_AD',
#   'CME_ADM2008',
#   '2006-12-18',
#   '2008-06-16',
#   '2015-12-17 18:12:02'],
#  ['AD',
#   'CME_AD',
#   'CME_ADU2008',
#   '2007-03-20',
#   '2008-09-15',
#   '2015-12-17 18:12:02'],
#  ['AD',
#   'CME_AD',
#   'CME_ADZ2008',
#   '2007-06-19',
#   '2008-12-15',
#   '2015-12-17 18:12:02'],
#  ['AD',
#   'CME_AD',
#   'CME_ADH2009',
#   '2007-09-18',
#   '2009-03-16',
#   '2015-12-17 18:12:02'],
#  ['AD',
#   'CME_AD',
#   'CME_ADM2009',
#   '2007-12-17',
#   '2009-06-15',
#   '2015-12-17 18:12:02'],
#  ['AD',
#   'CME_AD',
#   'CME_ADU2009',
#   '2008-03-17',
#   '2009-09-14',
#   '2015-12-17 18:12:02'],
#  ['AD',
#   'CME_AD',
#   'CME_ADZ2009',
#   '2008-06-16',
#   '2009-12-14',
#   '2015-12-17 18:12:02'],
#  ['AD',
#   'CME_AD',
#   'CME_ADH2010',
#   '2008-09-15',
#   '2010-03-15',
#   '2015-12-17 18:12:03'],
#  ['AD',
#   'CME_AD',
#   'CME_ADM2010',
#   '2008-12-15',
#   '2010-06-15',
#   '2015-12-17 18:12:03'],
#  ['AD',
#   'CME_AD',
#   'CME_ADU2010',
#   '2009-03-16',
#   '2010-09-13',
#   '2015-12-17 18:12:02'],
#  ['AD',
#   'CME_AD',
#   'CME_ADZ2010',
#   '2009-06-15',
#   '2010-12-13',
#   '2015-12-17 18:12:03'],
#  ['AD',
#   'CME_AD',
#   'CME_ADH2011',
#   '2009-09-14',
#   '2011-03-15',
#   '2015-12-17 18:12:03'],
#  ['AD',
#   'CME_AD',
#   'CME_ADM2011',
#   '2009-12-14',
#   '2011-06-14',
#   '2015-12-17 18:12:03'],
#  ['AD',
#   'CME_AD',
#   'CME_ADU2011',
#   '2010-03-15',
#   '2011-09-20',
#   '2015-12-17 18:12:03'],
#  ['AD',
#   'CME_AD',
#   'CME_ADZ2011',
#   '2010-06-14',
#   '2011-12-19',
#   '2015-12-17 18:12:03'],
#  ['AD',
#   'CME_AD',
#   'CME_ADH2012',
#   '2010-09-13',
#   '2012-03-19',
#   '2015-12-17 18:12:03'],
#  ['AD',
#   'CME_AD',
#   'CME_ADM2012',
#   '2010-12-13',
#   '2012-06-18',
#   '2015-12-17 18:12:03'],
#  ['AD',
#   'CME_AD',
#   'CME_ADU2012',
#   '2011-03-14',
#   '2012-09-17',
#   '2015-12-17 18:12:03'],
#  ['AD',
#   'CME_AD',
#   'CME_ADZ2012',
#   '2011-06-13',
#   '2012-12-17',
#   '2015-12-17 18:12:03'],
#  ['AD',
#   'CME_AD',
#   'CME_ADH2013',
#   '2011-09-19',
#   '2013-03-18',
#   '2015-12-17 18:12:03'],
#  ['AD',
#   'CME_AD',
#   'CME_ADM2013',
#   '2011-12-19',
#   '2013-06-17',
#   '2015-12-17 18:12:03'],
#  ['AD',
#   'CME_AD',
#   'CME_ADU2013',
#   '2012-03-19',
#   '2013-09-16',
#   '2015-12-17 18:12:03'],
#  ['AD',
#   'CME_AD',
#   'CME_ADZ2013',
#   '2012-06-18',
#   '2013-12-16',
#   '2015-12-17 18:12:03'],
#  ['AD',
#   'CME_AD',
#   'CME_ADH2014',
#   '2012-09-17',
#   '2014-03-17',
#   '2015-12-17 18:12:03'],
#  ['AD',
#   'CME_AD',
#   'CME_ADM2014',
#   '2012-12-17',
#   '2014-06-16',
#   '2015-12-17 18:12:04'],
#  ['AD',
#   'CME_AD',
#   'CME_ADU2014',
#   '2013-03-18',
#   '2014-09-15',
#   '2015-12-17 18:12:03'],
#  ['AD',
#   'CME_AD',
#   'CME_ADZ2014',
#   '2013-06-17',
#   '2014-12-15',
#   '2015-12-17 18:12:04'],
#  ['AD',
#   'CME_AD',
#   'CME_ADH2015',
#   '2013-08-09',
#   '2015-03-16',
#   '2015-12-17 18:12:04'],
#  ['AD',
#   'CME_AD',
#   'CME_ADM2015',
#   '2013-08-12',
#   '2015-06-15',
#   '2015-12-17 18:12:04'],
#  ['AD',
#   'CME_AD',
#   'CME_ADU2015',
#   '2013-08-12',
#   '2015-09-14',
#   '2015-12-17 18:12:04'],
#  ['AD',
#   'CME_AD',
#   'CME_ADZ2015',
#   '2013-08-12',
#   '2015-12-14',
#   '2015-12-17 18:12:04'],
#  ['AD',
#   'CME_AD',
#   'CME_ADH2016',
#   '2013-08-12',
#   '2016-03-14',
#   '2016-03-16 23:34:57'],
#  ['AD',
#   'CME_AD',
#   'CME_ADM2016',
#   '2013-08-12',
#   '2016-06-13',
#   '2016-06-15 02:33:02'],
#  ['AD',
#   'CME_AD',
#   'CME_ADU2016',
#   '2013-08-12',
#   '2016-09-19',
#   '2016-09-21 02:31:33'],
#  ['AD',
#   'CME_AD',
#   'CME_ADZ2016',
#   '2013-08-12',
#   '2016-12-19',
#   '2016-12-21 02:32:46'],
#  ['AD',
#   'CME_AD',
#   'CME_ADH2017',
#   '2013-08-12',
#   '2017-03-13',
#   '2017-03-15 02:35:00'],
#  ['AD',
#   'CME_AD',
#   'CME_ADJ2017',
#   '2017-02-27',
#   '2017-04-17',
#   '2017-04-19 02:31:21'],
#  ['AD',
#   'CME_AD',
#   'CME_ADK2017',
#   '2017-02-27',
#   '2017-05-15',
#   '2017-05-17 03:29:47'],
#  ['AD',
#   'CME_AD',
#   'CME_ADM2017',
#   '2013-08-12',
#   '2017-06-19',
#   '2017-06-21 02:36:03'],
#  ['AD',
#   'CME_AD',
#   'CME_ADN2017',
#   '2017-02-27',
#   '2017-07-17',
#   '2017-07-19 02:30:41'],
#  ['AD',
#   'CME_AD',
#   'CME_ADQ2017',
#   '2017-04-18',
#   '2017-08-14',
#   '2017-08-16 02:46:38'],
#  ['AD',
#   'CME_AD',
#   'CME_ADU2017',
#   '2013-08-12',
#   '2017-09-18',
#   '2017-09-20 02:39:23'],
#  ['AD',
#   'CME_AD',
#   'CME_ADV2017',
#   '2017-05-16',
#   '2017-10-16',
#   '2017-10-18 02:28:48'],
#  ['AD',
#   'CME_AD',
#   'CME_ADX2017',
#   '2017-07-18',
#   '2017-11-13',
#   '2017-11-15 03:38:09'],
#  ['AD',
#   'CME_AD',
#   'CME_ADZ2017',
#   '2013-08-12',
#   '2017-12-18',
#   '2017-12-20 03:38:00'],
#  ['AD',
#   'CME_AD',
#   'CME_ADF2018',
#   '2017-08-15',
#   '2018-01-12',
#   '2018-01-13 03:39:03'],
#  ['AD',
#   'CME_AD',
#   'CME_ADG2018',
#   '2017-10-17',
#   '2018-02-16',
#   '2018-02-17 03:35:52'],
#  ['AD',
#   'CME_AD',
#   'CME_ADH2018',
#   '2013-08-12',
#   '2018-03-19',
#   '2018-03-21 23:36:59'],
#  ['AD',
#   'CME_AD',
#   'CME_ADJ2018',
#   '2017-11-14',
#   '2018-04-16',
#   '2018-04-18 23:36:00'],
#  ['AD',
#   'CME_AD',
#   'CME_ADK2018',
#   '2018-01-16',
#   '2018-05-14',
#   '2018-05-16 23:36:51'],
#  ['AD',
#   'CME_AD',
#   'CME_ADM2018',
#   '2013-08-12',
#   '2018-06-18',
#   '2018-06-22 23:36:37'],
#  ['AD',
#   'CME_AD',
#   'CME_ADN2018',
#   '2018-02-20',
#   '2018-07-16',
#   '2018-07-20 23:35:54'],
#  ['AD',
#   'CME_AD',
#   'CME_ADQ2018',
#   '2018-04-17',
#   '2018-08-13',
#   '2018-08-17 23:37:26'],
#  ['AD',
#   'CME_AD',
#   'CME_ADU2018',
#   '2013-09-16',
#   '2018-09-17',
#   '2018-09-21 23:38:55'],
#  ['AD',
#   'CME_AD',
#   'CME_ADV2018',
#   '2018-05-15',
#   '2018-10-15',
#   '2018-10-19 23:36:21'],
#  ['AD',
#   'CME_AD',
#   'CME_ADX2018',
#   '2018-07-17',
#   '2018-11-19',
#   '2018-11-23 03:35:13'],
#  ['AD',
#   'CME_AD',
#   'CME_ADZ2018',
#   '2014-02-14',
#   '2018-12-17',
#   '2018-12-21 03:35:57'],
#  ['AD',
#   'CME_AD',
#   'CME_ADF2019',
#   '2018-08-14',
#   '2019-01-14',
#   '2019-01-18 03:35:56'],
#  ['AD',
#   'CME_AD',
#   'CME_ADG2019',
#   '2018-10-16',
#   '2019-02-15',
#   '2019-02-19 03:35:31'],
#  ['AD',
#   'CME_AD',
#   'CME_ADH2019',
#   '2014-03-17',
#   '2019-03-18',
#   '2019-03-22 23:36:29'],
#  ['AD',
#   'CME_AD',
#   'CME_ADJ2019',
#   '2018-11-20',
#   '2019-04-15',
#   '2019-04-19 23:36:16'],
#  ['AD',
#   'CME_AD',
#   'CME_ADK2019',
#   '2019-01-15',
#   '2019-05-13',
#   '2019-05-17 23:35:43'],
#  ['AD',
#   'CME_AD',
#   'CME_ADM2019',
#   '2014-06-16',
#   '2019-06-17',
#   '2019-06-21 23:36:23'],
#  ['AD',
#   'CME_AD',
#   'CME_ADN2019',
#   '2019-02-19',
#   '2019-07-15',
#   '2019-07-19 23:36:27'],
#  ['AD',
#   'CME_AD',
#   'CME_ADQ2019',
#   '2019-04-16',
#   '2019-08-19',
#   '2019-08-23 23:38:24'],
#  ['AD',
#   'CME_AD',
#   'CME_ADU2019',
#   '2014-09-16',
#   '2019-09-16',
#   '2019-09-20 23:46:10'],
#  ['AD',
#   'CME_AD',
#   'CME_ADV2019',
#   '2019-05-14',
#   '2019-10-11',
#   '2019-10-15 23:42:46'],
#  ['AD',
#   'CME_AD',
#   'CME_ADX2019',
#   '2019-07-16',
#   '2019-11-18',
#   '2019-11-22 03:36:34'],
#  ['AD',
#   'CME_AD',
#   'CME_ADZ2019',
#   '2014-12-16',
#   '2019-12-16',
#   '2019-12-20 03:37:05'],
#  ['AD',
#   'CME_AD',
#   'CME_ADF2020',
#   '2019-08-20',
#   '2020-01-13',
#   '2020-01-17 03:37:23'],
#  ['AD',
#   'CME_AD',
#   'CME_ADG2020',
#   '2019-10-14',
#   '2020-02-14',
#   '2020-02-18 03:37:21'],
#  ['AD',
#   'CME_AD',
#   'CME_ADH2020',
#   '2015-03-17',
#   '2020-03-16',
#   '2020-03-20 23:36:34'],
#  ['AD',
#   'CME_AD',
#   'CME_ADJ2020',
#   '2019-11-19',
#   '2020-04-13',
#   '2020-04-17 23:36:28'],
#  ['AD',
#   'CME_AD',
#   'CME_ADK2020',
#   '2020-01-14',
#   '2020-05-18',
#   '2020-05-22 23:36:16'],
#  ['AD',
#   'CME_AD',
#   'CME_ADM2020',
#   '2015-06-16',
#   '2020-06-15',
#   '2020-06-19 02:37:00'],
#  ['AD',
#   'CME_AD',
#   'CME_ADN2020',
#   '2020-02-18',
#   '2020-07-13',
#   '2020-07-17 23:36:33'],
#  ['AD',
#   'CME_AD',
#   'CME_ADQ2020',
#   '2020-04-14',
#   '2020-08-17',
#   '2020-08-21 23:37:30'],
#  ['AD',
#   'CME_AD',
#   'CME_ADU2020',
#   '2015-09-15',
#   '2020-09-14',
#   '2020-09-18 23:37:37'],
#  ['AD',
#   'CME_AD',
#   'CME_ADV2020',
#   '2020-05-19',
#   '2020-10-19',
#   '2020-10-23 23:37:37'],
#  ['AD',
#   'CME_AD',
#   'CME_ADX2020',
#   '2020-07-14',
#   '2020-11-16',
#   '2020-11-20 03:44:10'],
#  ['AD',
#   'CME_AD',
#   'CME_ADZ2020',
#   '2015-12-15',
#   '2020-12-14',
#   '2020-12-18 03:37:32'],
#  ['AD',
#   'CME_AD',
#   'CME_ADF2021',
#   '2020-08-18',
#   '2021-01-15',
#   '2021-01-19 03:37:28'],
#  ['AD',
#   'CME_AD',
#   'CME_ADG2021',
#   '2020-10-20',
#   '2021-02-12',
#   '2021-02-16 03:37:20'],
#  ['AD',
#   'CME_AD',
#   'CME_ADH2021',
#   '2016-03-15',
#   '2021-03-15',
#   '2021-03-19 03:38:57'],
#  ['AD',
#   'CME_AD',
#   'CME_ADJ2021',
#   '2020-11-17',
#   '2021-04-19',
#   '2021-04-23 23:37:56'],
#  ['AD',
#   'CME_AD',
#   'CME_ADK2021',
#   '2021-01-19',
#   '2021-05-17',
#   '2021-05-21 23:37:37'],
#  ['AD',
#   'CME_AD',
#   'CME_ADM2021',
#   '2016-06-14',
#   '2021-06-14',
#   '2021-06-18 23:37:31'],
#  ['AD',
#   'CME_AD',
#   'CME_ADN2021',
#   '2021-02-16',
#   '2021-07-19',
#   '2021-07-23 23:37:30'],
#  ['AD',
#   'CME_AD',
#   'CME_ADQ2021',
#   '2021-04-20',
#   '2021-08-16',
#   '2021-08-20 23:37:26'],
#  ['AD',
#   'CME_AD',
#   'CME_ADU2021',
#   '2016-09-20',
#   '2021-09-13',
#   '2021-09-17 23:38:17'],
#  ['AD',
#   'CME_AD',
#   'CME_ADV2021',
#   '2021-05-18',
#   '2021-10-18',
#   '2021-10-22 23:37:47'],
#  ['AD',
#   'CME_AD',
#   'CME_ADX2021',
#   '2021-07-20',
#   '2021-11-15',
#   '2021-11-19 03:37:19'],
#  ['AD',
#   'CME_AD',
#   'CME_ADZ2021',
#   '2016-12-20',
#   '2021-12-13',
#   '2021-12-17 03:38:32'],
#  ['AD',
#   'CME_AD',
#   'CME_ADF2022',
#   '2021-08-17',
#   '2022-01-14',
#   '2022-01-18 03:38:48'],
#  ['AD',
#   'CME_AD',
#   'CME_ADG2022',
#   '2021-10-19',
#   '2022-02-14',
#   '2022-02-18 03:38:49'],
#  ['AD',
#   'CME_AD',
#   'CME_ADH2022',
#   '2017-03-14',
#   '2022-03-14',
#   '2022-03-18 23:38:52'],
#  ['AD',
#   'CME_AD',
#   'CME_ADJ2022',
#   '2021-11-16',
#   '2022-04-18',
#   '2022-04-20 02:38:02'],
#  ['AD',
#   'CME_AD',
#   'CME_ADK2022',
#   '2022-01-18',
#   '2022-04-19',
#   '2022-04-20 02:38:02'],
#  ['AD',
#   'CME_AD',
#   'CME_ADM2022',
#   '2017-06-20',
#   '2022-04-19',
#   '2022-04-20 02:38:02'],
#  ['AD',
#   'CME_AD',
#   'CME_ADN2022',
#   '2022-02-15',
#   '2022-04-19',
#   '2022-04-20 02:38:02'],
#  ['AD',
#   'CME_AD',
#   'CME_ADQ2022',
#   '2022-04-19',
#   '2022-04-19',
#   '2022-04-20 02:38:02'],
#  ['AD',
#   'CME_AD',
#   'CME_ADU2022',
#   '2017-09-19',
#   '2022-04-19',
#   '2022-04-20 02:38:02'],
#  ['AD',
#   'CME_AD',
#   'CME_ADZ2022',
#   '2017-12-19',
#   '2022-04-19',
#   '2022-04-20 02:38:02'],
#  ['AD',
#   'CME_AD',
#   'CME_ADH2023',
#   '2018-03-20',
#   '2022-04-19',
#   '2022-04-20 02:38:02'],
#  ['AD',
#   'CME_AD',
#   'CME_ADM2023',
#   '2018-06-19',
#   '2022-04-19',
#   '2022-04-20 02:38:02'],
#  ['AD',
#   'CME_AD',
#   'CME_ADU2023',
#   '2018-09-18',
#   '2022-04-19',
#   '2022-04-20 02:38:02'],
#  ['AD',
#   'CME_AD',
#   'CME_ADZ2023',
#   '2018-12-18',
#   '2022-04-19',
#   '2022-04-20 02:38:02'],
#  ['AD',
#   'CME_AD',
#   'CME_ADH2024',
#   '2019-03-19',
#   '2022-04-19',
#   '2022-04-20 02:38:02'],
#  ['AD',
#   'CME_AD',
#   'CME_ADM2024',
#   '2019-06-18',
#   '2022-04-19',
#   '2022-04-20 02:38:02'],
#  ['AD',
#   'CME_AD',
#   'CME_ADU2024',
#   '2019-09-17',
#   '2022-04-19',
#   '2022-04-20 02:38:02'],
#  ['AD',
#   'CME_AD',
#   'CME_ADZ2024',
#   '2019-12-17',
#   '2022-04-19',
#   '2022-04-20 02:38:02'],
#  ['AD',
#   'CME_AD',
#   'CME_ADH2025',
#   '2020-03-17',
#   '2022-04-19',
#   '2022-04-20 02:38:02'],
#  ['AD',
#   'CME_AD',
#   'CME_ADM2025',
#   '2020-06-16',
#   '2022-04-19',
#   '2022-04-20 02:38:02'],
#  ['AD',
#   'CME_AD',
#   'CME_ADU2025',
#   '2020-09-15',
#   '2022-04-19',
#   '2022-04-20 02:38:02'],
#  ['AD',
#   'CME_AD',
#   'CME_ADZ2025',
#   '2020-12-15',
#   '2022-04-19',
#   '2022-04-20 02:38:02'],
#  ['AD',
#   'CME_AD',
#   'CME_ADH2026',
#   '2021-03-16',
#   '2022-04-19',
#   '2022-04-20 02:38:02'],
#  ['AD',
#   'CME_AD',
#   'CME_ADM2026',
#   '2021-06-15',
#   '2022-04-19',
#   '2022-04-20 02:38:02'],
#  ['AD',
#   'CME_AD',
#   'CME_ADU2026',
#   '2021-09-14',
#   '2022-04-19',
#   '2022-04-20 02:38:02'],
#  ['AD',
#   'CME_AD',
#   'CME_ADZ2026',
#   '2021-12-14',
#   '2022-04-19',
#   '2022-04-20 02:38:02'],
#  ['AD',
#   'CME_AD',
#   'CME_ADH2027',
#   '2022-03-15',
#   '2022-04-19',
#   '2022-04-20 02:38:02']]

# %%
# 다운 가능한 상품에 대해서 nasdaq-data-link 에서 SRF 데이터 다운
dtypes= np.dtype([
        ('date', 'i'),
        ('open', 'f'),
        ('high','f'),
        ('low','f'),
        ('close','f'),
        ('volume', 'i'),
        ('open_interest','i')
    ])

i=0
for instrument in instruments.values():
    if not instrument.contracts:
        continue
        
    if len(file[instrument.symbol]):
        print(f"SKIP DB: {instrument.name}")
        continue
    
    for contract in instrument.contracts:
        print(f"{i}: {contract[2]} 다운로드 중...")
        symbol = instrument.symbol
        code = contract[2]
        data = ndl.get(f'SRF/{code}')
        data.reset_index(inplace=True)
        data['Date'] = data['Date'].values.astype('M8[D]').astype('i')
        
        #미결제 약정에 들어있는 nan value를 0으로 변경
        if data.iloc[:,6].isna().sum():
            counter = data.iloc[:,6].isna().sum()
            print(f"미결제 약정 Nan Value 발생: {counter}개\n")
            data.iloc[:,6] = data.iloc[:,6].fillna(0)
        
        #거래량에 들어있는 nan value를 0으로 변경
        if data.iloc[:,5].isna().sum():
            counter = data.iloc[:,5].isna().sum()
            print(f"거래량 Nan Value 발생: ({counter}개)")
            data.iloc[:,5] = data.iloc[:,5].fillna(0)
        
        data = np.array(list(map(tuple, data.values)), dtypes)
        file[symbol].create_dataset(code, data=np.array(data, dtypes))
        i+= 1 #카운터
    
print("완료")
# Out:
# 0: CME_ADH1987 다운로드 중...
# 1: CME_ADM1987 다운로드 중...
# 2: CME_ADU1987 다운로드 중...
# 3: CME_ADZ1987 다운로드 중...
# 4: CME_ADH1988 다운로드 중...
# 5: CME_ADM1988 다운로드 중...
# 6: CME_ADU1988 다운로드 중...
# 7: CME_ADZ1988 다운로드 중...
# 8: CME_ADH1989 다운로드 중...
# 9: CME_ADM1989 다운로드 중...
# 10: CME_ADU1989 다운로드 중...
# 11: CME_ADZ1989 다운로드 중...
# 12: CME_ADH1990 다운로드 중...
# 13: CME_ADM1990 다운로드 중...
# 14: CME_ADU1990 다운로드 중...
# 15: CME_ADZ1990 다운로드 중...
# 16: CME_ADH1991 다운로드 중...
# 17: CME_ADM1991 다운로드 중...
# 18: CME_ADU1991 다운로드 중...
# 19: CME_ADZ1991 다운로드 중...
# 20: CME_ADH1992 다운로드 중...
# 21: CME_ADM1992 다운로드 중...
# 22: CME_ADU1992 다운로드 중...
# 23: CME_ADZ1992 다운로드 중...
# 24: CME_ADH1993 다운로드 중...
# 25: CME_ADM1993 다운로드 중...
# 26: CME_ADU1993 다운로드 중...
# 27: CME_ADZ1993 다운로드 중...
# 28: CME_ADH1994 다운로드 중...
# 29: CME_ADM1994 다운로드 중...
# 30: CME_ADU1994 다운로드 중...
# 31: CME_ADZ1994 다운로드 중...
# 32: CME_ADH1995 다운로드 중...
# 33: CME_ADM1995 다운로드 중...
# 34: CME_ADU1995 다운로드 중...
# 35: CME_ADZ1995 다운로드 중...
# 36: CME_ADH1996 다운로드 중...
# 37: CME_ADM1996 다운로드 중...
# 38: CME_ADU1996 다운로드 중...
# 39: CME_ADZ1996 다운로드 중...
# 40: CME_ADH1997 다운로드 중...
# 41: CME_ADM1997 다운로드 중...
# 42: CME_ADU1997 다운로드 중...
# 43: CME_ADZ1997 다운로드 중...
# 44: CME_ADH1998 다운로드 중...
# 45: CME_ADM1998 다운로드 중...
# 46: CME_ADU1998 다운로드 중...
# 47: CME_ADZ1998 다운로드 중...
# 48: CME_ADH1999 다운로드 중...
# 49: CME_ADM1999 다운로드 중...
# 50: CME_ADU1999 다운로드 중...
# 51: CME_ADZ1999 다운로드 중...
# 52: CME_ADH2000 다운로드 중...
# 53: CME_ADM2000 다운로드 중...
# 54: CME_ADU2000 다운로드 중...
# 55: CME_ADZ2000 다운로드 중...
# 56: CME_ADH2001 다운로드 중...
# 57: CME_ADM2001 다운로드 중...
# 58: CME_ADU2001 다운로드 중...
# 59: CME_ADZ2001 다운로드 중...
# 60: CME_ADH2002 다운로드 중...
# 61: CME_ADM2002 다운로드 중...
# 62: CME_ADU2002 다운로드 중...
# 63: CME_ADZ2002 다운로드 중...
# 64: CME_ADH2003 다운로드 중...
# 65: CME_ADM2003 다운로드 중...
# 66: CME_ADU2003 다운로드 중...
# 67: CME_ADZ2003 다운로드 중...
# 68: CME_ADH2004 다운로드 중...
# 69: CME_ADM2004 다운로드 중...
# 70: CME_ADU2004 다운로드 중...
# 71: CME_ADZ2004 다운로드 중...
# 72: CME_ADH2005 다운로드 중...
# 73: CME_ADM2005 다운로드 중...
# 74: CME_ADU2005 다운로드 중...
# 75: CME_ADZ2005 다운로드 중...
# 76: CME_ADH2006 다운로드 중...
# 77: CME_ADM2006 다운로드 중...
# 78: CME_ADU2006 다운로드 중...
# 79: CME_ADZ2006 다운로드 중...
# 80: CME_ADH2007 다운로드 중...
# 81: CME_ADM2007 다운로드 중...
# 82: CME_ADU2007 다운로드 중...
# 83: CME_ADZ2007 다운로드 중...
# 84: CME_ADH2008 다운로드 중...
# 85: CME_ADM2008 다운로드 중...
# 86: CME_ADU2008 다운로드 중...
# 87: CME_ADZ2008 다운로드 중...
# 88: CME_ADH2009 다운로드 중...
# 89: CME_ADM2009 다운로드 중...
# 90: CME_ADU2009 다운로드 중...
# 91: CME_ADZ2009 다운로드 중...
# 92: CME_ADH2010 다운로드 중...
# 93: CME_ADM2010 다운로드 중...
# 94: CME_ADU2010 다운로드 중...
# 95: CME_ADZ2010 다운로드 중...
# 96: CME_ADH2011 다운로드 중...
# 97: CME_ADM2011 다운로드 중...
# 98: CME_ADU2011 다운로드 중...
# 99: CME_ADZ2011 다운로드 중...
# 100: CME_ADH2012 다운로드 중...
# 101: CME_ADM2012 다운로드 중...
# 102: CME_ADU2012 다운로드 중...
# 103: CME_ADZ2012 다운로드 중...
# 104: CME_ADH2013 다운로드 중...
# 105: CME_ADM2013 다운로드 중...
# 106: CME_ADU2013 다운로드 중...
# 107: CME_ADZ2013 다운로드 중...
# 108: CME_ADH2014 다운로드 중...
# 109: CME_ADM2014 다운로드 중...
# 110: CME_ADU2014 다운로드 중...
# 111: CME_ADZ2014 다운로드 중...
# 112: CME_ADH2015 다운로드 중...
# 113: CME_ADM2015 다운로드 중...
# 114: CME_ADU2015 다운로드 중...
# 115: CME_ADZ2015 다운로드 중...
# 116: CME_ADH2016 다운로드 중...
# 117: CME_ADM2016 다운로드 중...
# 118: CME_ADU2016 다운로드 중...
# 119: CME_ADZ2016 다운로드 중...
# 120: CME_ADH2017 다운로드 중...
# 121: CME_ADJ2017 다운로드 중...
# 122: CME_ADK2017 다운로드 중...
# 123: CME_ADM2017 다운로드 중...
# 124: CME_ADN2017 다운로드 중...
# 125: CME_ADQ2017 다운로드 중...
# 126: CME_ADU2017 다운로드 중...
# 127: CME_ADV2017 다운로드 중...
# 128: CME_ADX2017 다운로드 중...
# 129: CME_ADZ2017 다운로드 중...
# 130: CME_ADF2018 다운로드 중...
# 131: CME_ADG2018 다운로드 중...
# 132: CME_ADH2018 다운로드 중...
# 133: CME_ADJ2018 다운로드 중...
# 134: CME_ADK2018 다운로드 중...
# 135: CME_ADM2018 다운로드 중...
# 136: CME_ADN2018 다운로드 중...
# 137: CME_ADQ2018 다운로드 중...
# 138: CME_ADU2018 다운로드 중...
# 139: CME_ADV2018 다운로드 중...
# 140: CME_ADX2018 다운로드 중...
# 141: CME_ADZ2018 다운로드 중...
# 142: CME_ADF2019 다운로드 중...
# 143: CME_ADG2019 다운로드 중...
# 144: CME_ADH2019 다운로드 중...
# 145: CME_ADJ2019 다운로드 중...
# 146: CME_ADK2019 다운로드 중...
# 147: CME_ADM2019 다운로드 중...
# 148: CME_ADN2019 다운로드 중...
# 149: CME_ADQ2019 다운로드 중...
# 150: CME_ADU2019 다운로드 중...
# 151: CME_ADV2019 다운로드 중...
# 152: CME_ADX2019 다운로드 중...
# 153: CME_ADZ2019 다운로드 중...
# 154: CME_ADF2020 다운로드 중...
# 155: CME_ADG2020 다운로드 중...
# 156: CME_ADH2020 다운로드 중...
# 157: CME_ADJ2020 다운로드 중...
# 158: CME_ADK2020 다운로드 중...
# 159: CME_ADM2020 다운로드 중...
# 160: CME_ADN2020 다운로드 중...
# 161: CME_ADQ2020 다운로드 중...
# 162: CME_ADU2020 다운로드 중...
# 163: CME_ADV2020 다운로드 중...
# 164: CME_ADX2020 다운로드 중...
# 165: CME_ADZ2020 다운로드 중...
# 166: CME_ADF2021 다운로드 중...
# 167: CME_ADG2021 다운로드 중...
# 168: CME_ADH2021 다운로드 중...
# 169: CME_ADJ2021 다운로드 중...
# 170: CME_ADK2021 다운로드 중...
# 171: CME_ADM2021 다운로드 중...
# 172: CME_ADN2021 다운로드 중...
# 173: CME_ADQ2021 다운로드 중...
# 174: CME_ADU2021 다운로드 중...
# 175: CME_ADV2021 다운로드 중...
# 176: CME_ADX2021 다운로드 중...
# 177: CME_ADZ2021 다운로드 중...
# 178: CME_ADF2022 다운로드 중...
# 179: CME_ADG2022 다운로드 중...
# 180: CME_ADH2022 다운로드 중...
# 181: CME_ADJ2022 다운로드 중...
# 182: CME_ADK2022 다운로드 중...
# 183: CME_ADM2022 다운로드 중...
# 184: CME_ADN2022 다운로드 중...
# 185: CME_ADQ2022 다운로드 중...
# 186: CME_ADU2022 다운로드 중...
# 187: CME_ADZ2022 다운로드 중...
# 188: CME_ADH2023 다운로드 중...
# 189: CME_ADM2023 다운로드 중...
# 190: CME_ADU2023 다운로드 중...
# 191: CME_ADZ2023 다운로드 중...
# 192: CME_ADH2024 다운로드 중...
# 193: CME_ADM2024 다운로드 중...
# 194: CME_ADU2024 다운로드 중...
# 195: CME_ADZ2024 다운로드 중...
# 196: CME_ADH2025 다운로드 중...
# 197: CME_ADM2025 다운로드 중...
# 198: CME_ADU2025 다운로드 중...
# 199: CME_ADZ2025 다운로드 중...
# 200: CME_ADH2026 다운로드 중...
# 201: CME_ADM2026 다운로드 중...
# 202: CME_ADU2026 다운로드 중...
# 203: CME_ADZ2026 다운로드 중...
# 204: CME_ADH2027 다운로드 중...
# 205: CME_BOF1961 다운로드 중...
# 206: CME_BOH1961 다운로드 중...
# 207: CME_BOK1961 다운로드 중...
# 208: CME_BON1961 다운로드 중...
# 209: CME_BOU1961 다운로드 중...
# 210: CME_BOV1961 다운로드 중...
# 211: CME_BOZ1961 다운로드 중...
# 212: CME_BOF1962 다운로드 중...
# 213: CME_BOH1962 다운로드 중...
# 214: CME_BOK1962 다운로드 중...
# 215: CME_BON1962 다운로드 중...
# 216: CME_BOQ1962 다운로드 중...
# 217: CME_BOU1962 다운로드 중...
# 218: CME_BOV1962 다운로드 중...
# 219: CME_BOZ1962 다운로드 중...
# 220: CME_BOF1963 다운로드 중...
# 221: CME_BOH1963 다운로드 중...
# 222: CME_BOK1963 다운로드 중...
# 223: CME_BON1963 다운로드 중...
# 224: CME_BOQ1963 다운로드 중...
# 225: CME_BOU1963 다운로드 중...
# 226: CME_BOV1963 다운로드 중...
# 227: CME_BOZ1963 다운로드 중...
# 228: CME_BOF1964 다운로드 중...
# 229: CME_BOH1964 다운로드 중...
# 230: CME_BOK1964 다운로드 중...
# 231: CME_BON1964 다운로드 중...
# 232: CME_BOQ1964 다운로드 중...
# 233: CME_BOU1964 다운로드 중...
# 234: CME_BOV1964 다운로드 중...
# 235: CME_BOZ1964 다운로드 중...
# 236: CME_BOF1965 다운로드 중...
# 237: CME_BOH1965 다운로드 중...
# 238: CME_BOK1965 다운로드 중...
# 239: CME_BON1965 다운로드 중...
# 240: CME_BOQ1965 다운로드 중...
# 241: CME_BOU1965 다운로드 중...
# 242: CME_BOV1965 다운로드 중...
# 243: CME_BOZ1965 다운로드 중...
# 244: CME_BOF1966 다운로드 중...
# 245: CME_BOH1966 다운로드 중...
# 246: CME_BOK1966 다운로드 중...
# 247: CME_BON1966 다운로드 중...
# 248: CME_BOQ1966 다운로드 중...
# 249: CME_BOU1966 다운로드 중...
# 250: CME_BOV1966 다운로드 중...
# 251: CME_BOZ1966 다운로드 중...
# 252: CME_BOF1967 다운로드 중...
# 253: CME_BOH1967 다운로드 중...
# 254: CME_BOK1967 다운로드 중...
# 255: CME_BON1967 다운로드 중...
# 256: CME_BOQ1967 다운로드 중...
# 257: CME_BOU1967 다운로드 중...
# 258: CME_BOV1967 다운로드 중...
# 259: CME_BOZ1967 다운로드 중...
# 260: CME_BOF1968 다운로드 중...
# 261: CME_BOH1968 다운로드 중...
# 262: CME_BOK1968 다운로드 중...
# 263: CME_BON1968 다운로드 중...
# 264: CME_BOQ1968 다운로드 중...
# 265: CME_BOU1968 다운로드 중...
# 266: CME_BOV1968 다운로드 중...
# 267: CME_BOZ1968 다운로드 중...
# 268: CME_BOF1969 다운로드 중...
# 269: CME_BOH1969 다운로드 중...
# 270: CME_BOK1969 다운로드 중...
# 271: CME_BON1969 다운로드 중...
# 272: CME_BOQ1969 다운로드 중...
# 273: CME_BOU1969 다운로드 중...
# 274: CME_BOV1969 다운로드 중...
# 275: CME_BOZ1969 다운로드 중...
# 276: CME_BOF1970 다운로드 중...
# 277: CME_BOH1970 다운로드 중...
# 278: CME_BOK1970 다운로드 중...
# 279: CME_BON1970 다운로드 중...
# 280: CME_BOQ1970 다운로드 중...
# 281: CME_BOU1970 다운로드 중...
# 282: CME_BOV1970 다운로드 중...
# 283: CME_BOZ1970 다운로드 중...
# 284: CME_BOF1971 다운로드 중...
# 285: CME_BOH1971 다운로드 중...
# 286: CME_BOK1971 다운로드 중...
# 287: CME_BON1971 다운로드 중...
# 288: CME_BOQ1971 다운로드 중...
# 289: CME_BOU1971 다운로드 중...
# 290: CME_BOV1971 다운로드 중...
# 291: CME_BOZ1971 다운로드 중...
# 292: CME_BOF1972 다운로드 중...
# 293: CME_BOH1972 다운로드 중...
# 294: CME_BOK1972 다운로드 중...
# 295: CME_BON1972 다운로드 중...
# 296: CME_BOQ1972 다운로드 중...
# 297: CME_BOU1972 다운로드 중...
# 298: CME_BOV1972 다운로드 중...
# 299: CME_BOZ1972 다운로드 중...
# 300: CME_BOF1973 다운로드 중...
# 301: CME_BOH1973 다운로드 중...
# 302: CME_BOK1973 다운로드 중...
# 303: CME_BON1973 다운로드 중...
# 304: CME_BOQ1973 다운로드 중...
# 305: CME_BOU1973 다운로드 중...
# 306: CME_BOV1973 다운로드 중...
# 307: CME_BOZ1973 다운로드 중...
# 308: CME_BOF1974 다운로드 중...
# 309: CME_BOH1974 다운로드 중...
# 310: CME_BOK1974 다운로드 중...
# 311: CME_BON1974 다운로드 중...
# 312: CME_BOQ1974 다운로드 중...
# 313: CME_BOU1974 다운로드 중...
# 314: CME_BOV1974 다운로드 중...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [17], in <cell line: 13>()
#      23 symbol = instrument.symbol
#      24 code = contract[2]
# ---> 25 data = ndl.get(f'SRF/{code}')
#      26 data.reset_index(inplace=True)
#      27 data['Date'] = data['Date'].values.astype('M8[D]').astype('i')
#
# File c:\python\miniconda3\lib\site-packages\nasdaqdatalink\get.py:48, in get(dataset, **kwargs)
#      46     if dataset_args['column_index'] is not None:
#      47         kwargs.update({'column_index': dataset_args['column_index']})
# ---> 48     data = Dataset(dataset_args['code']).data(params=kwargs, handle_column_not_found=True)
#      49 # Array
#      50 elif isinstance(dataset, list):
#
# File c:\python\miniconda3\lib\site-packages\nasdaqdatalink\model\dataset.py:47, in Dataset.data(self, **options)
#      45 updated_options = Util.merge_options('params', params, **options)
#      46 try:
# ---> 47     return Data.all(**updated_options)
#      48 except NotFoundError:
#      49     if handle_not_found_error:
#
# File c:\python\miniconda3\lib\site-packages\nasdaqdatalink\operations\list.py:15, in ListOperation.all(cls, **options)
#      13     options['params'] = {}
#      14 path = Util.constructed_path(cls.list_path(), options['params'])
# ---> 15 r = Connection.request('get', path, **options)
#      16 response_data = r.json()
#      17 Util.convert_to_dates(response_data)
#
# File c:\python\miniconda3\lib\site-packages\nasdaqdatalink\connection.py:39, in Connection.request(cls, http_verb, url, **options)
#      35 options['headers'] = headers
#      37 abs_url = '%s/%s' % (ApiConfig.api_base, url)
# ---> 39 return cls.execute_request(http_verb, abs_url, **options)
#
# File c:\python\miniconda3\lib\site-packages\nasdaqdatalink\connection.py:46, in Connection.execute_request(cls, http_verb, url, **options)
#      43 session = cls.get_session()
#      45 try:
# ---> 46     response = session.request(method=http_verb,
#      47                                url=url,
#      48                                verify=ApiConfig.verify_ssl,
#      49                                **options)
#      50     if response.status_code < 200 or response.status_code >= 300:
#      51         cls.handle_api_error(response)
#
# File c:\python\miniconda3\lib\site-packages\requests\sessions.py:529, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     524 send_kwargs = {
#     525     'timeout': timeout,
#     526     'allow_redirects': allow_redirects,
#     527 }
#     528 send_kwargs.update(settings)
# --> 529 resp = self.send(prep, **send_kwargs)
#     531 return resp
#
# File c:\python\miniconda3\lib\site-packages\requests\sessions.py:645, in Session.send(self, request, **kwargs)
#     642 start = preferred_clock()
#     644 # Send the request
# --> 645 r = adapter.send(request, **kwargs)
#     647 # Total elapsed time of the request (approximately)
#     648 elapsed = preferred_clock() - start
#
# File c:\python\miniconda3\lib\site-packages\requests\adapters.py:440, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     438 try:
#     439     if not chunked:
# --> 440         resp = conn.urlopen(
#     441             method=request.method,
#     442             url=url,
#     443             body=request.body,
#     444             headers=request.headers,
#     445             redirect=False,
#     446             assert_same_host=False,
#     447             preload_content=False,
#     448             decode_content=False,
#     449             retries=self.max_retries,
#     450             timeout=timeout
#     451         )
#     453     # Send the request.
#     454     else:
#     455         if hasattr(conn, 'proxy_pool'):
#
# File c:\python\miniconda3\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File c:\python\miniconda3\lib\site-packages\urllib3\connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File c:\python\miniconda3\lib\site-packages\urllib3\connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File c:\python\miniconda3\lib\http\client.py:1347, in HTTPConnection.getresponse(self)
#    1345 try:
#    1346     try:
# -> 1347         response.begin()
#    1348     except ConnectionError:
#    1349         self.close()
#
# File c:\python\miniconda3\lib\http\client.py:307, in HTTPResponse.begin(self)
#     305 # read until we get a non-100 response
#     306 while True:
# --> 307     version, status, reason = self._read_status()
#     308     if status != CONTINUE:
#     309         break
#
# File c:\python\miniconda3\lib\http\client.py:268, in HTTPResponse._read_status(self)
#     267 def _read_status(self):
# --> 268     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269     if len(line) > _MAXLINE:
#     270         raise LineTooLong("status line")
#
# File c:\python\miniconda3\lib\socket.py:669, in SocketIO.readinto(self, b)
#     667 while True:
#     668     try:
# --> 669         return self._sock.recv_into(b)
#     670     except timeout:
#     671         self._timeout_occurred = True
#
# File c:\python\miniconda3\lib\ssl.py:1241, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1237     if flags != 0:
#    1238         raise ValueError(
#    1239           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240           self.__class__)
# -> 1241     return self.read(nbytes, buffer)
#    1242 else:
#    1243     return super().recv_into(buffer, nbytes, flags)
#
# File c:\python\miniconda3\lib\ssl.py:1099, in SSLSocket.read(self, len, buffer)
#    1097 try:
#    1098     if buffer is not None:
# -> 1099         return self._sslobj.read(len, buffer)
#    1100     else:
#    1101         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
file.close()

# %% [markdown]
# ### 데이터 확인

# %%
from tools.visualisation import view

# %%
instruments['W'].contracts
# Out:
# [('W',
#   'CME_W',
#   'CME_WZ1959',
#   datetime.datetime(1959, 7, 1, 0, 0),
#   datetime.datetime(1959, 12, 21, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, December 1959 (WZ1959)'),
#  ('W',
#   'CME_W',
#   'CME_WH1960',
#   datetime.datetime(1959, 7, 1, 0, 0),
#   datetime.datetime(1960, 3, 22, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, March 1960 (WH1960)'),
#  ('W',
#   'CME_W',
#   'CME_WK1960',
#   datetime.datetime(1959, 7, 1, 0, 0),
#   datetime.datetime(1960, 5, 19, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, May 1960 (WK1960)'),
#  ('W',
#   'CME_W',
#   'CME_WN1960',
#   datetime.datetime(1959, 7, 1, 0, 0),
#   datetime.datetime(1960, 7, 20, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, July 1960 (WN1960)'),
#  ('W',
#   'CME_W',
#   'CME_WU1960',
#   datetime.datetime(1959, 7, 1, 0, 0),
#   datetime.datetime(1960, 9, 21, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, September 1960 (WU1960)'),
#  ('W',
#   'CME_W',
#   'CME_WZ1960',
#   datetime.datetime(1960, 1, 4, 0, 0),
#   datetime.datetime(1960, 12, 20, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, December 1960 (WZ1960)'),
#  ('W',
#   'CME_W',
#   'CME_WH1961',
#   datetime.datetime(1960, 4, 1, 0, 0),
#   datetime.datetime(1961, 3, 21, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, March 1961 (WH1961)'),
#  ('W',
#   'CME_W',
#   'CME_WK1961',
#   datetime.datetime(1960, 6, 1, 0, 0),
#   datetime.datetime(1961, 5, 19, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, May 1961 (WK1961)'),
#  ('W',
#   'CME_W',
#   'CME_WN1961',
#   datetime.datetime(1960, 8, 1, 0, 0),
#   datetime.datetime(1961, 7, 20, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, July 1961 (WN1961)'),
#  ('W',
#   'CME_W',
#   'CME_WU1961',
#   datetime.datetime(1960, 10, 3, 0, 0),
#   datetime.datetime(1961, 9, 20, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, September 1961 (WU1961)'),
#  ('W',
#   'CME_W',
#   'CME_WZ1961',
#   datetime.datetime(1961, 1, 3, 0, 0),
#   datetime.datetime(1961, 12, 19, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, December 1961 (WZ1961)'),
#  ('W',
#   'CME_W',
#   'CME_WH1962',
#   datetime.datetime(1961, 4, 3, 0, 0),
#   datetime.datetime(1962, 3, 21, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, March 1962 (WH1962)'),
#  ('W',
#   'CME_W',
#   'CME_WK1962',
#   datetime.datetime(1961, 6, 1, 0, 0),
#   datetime.datetime(1962, 5, 21, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, May 1962 (WK1962)'),
#  ('W',
#   'CME_W',
#   'CME_WN1962',
#   datetime.datetime(1961, 8, 1, 0, 0),
#   datetime.datetime(1962, 7, 20, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, July 1962 (WN1962)'),
#  ('W',
#   'CME_W',
#   'CME_WU1962',
#   datetime.datetime(1961, 10, 2, 0, 0),
#   datetime.datetime(1962, 9, 19, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, September 1962 (WU1962)'),
#  ('W',
#   'CME_W',
#   'CME_WZ1962',
#   datetime.datetime(1962, 1, 3, 0, 0),
#   datetime.datetime(1962, 12, 18, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, December 1962 (WZ1962)'),
#  ('W',
#   'CME_W',
#   'CME_WH1963',
#   datetime.datetime(1962, 4, 2, 0, 0),
#   datetime.datetime(1963, 3, 20, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, March 1963 (WH1963)'),
#  ('W',
#   'CME_W',
#   'CME_WK1963',
#   datetime.datetime(1962, 6, 1, 0, 0),
#   datetime.datetime(1963, 5, 21, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, May 1963 (WK1963)'),
#  ('W',
#   'CME_W',
#   'CME_WN1963',
#   datetime.datetime(1962, 9, 24, 0, 0),
#   datetime.datetime(1963, 7, 22, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, July 1963 (WN1963)'),
#  ('W',
#   'CME_W',
#   'CME_WU1963',
#   datetime.datetime(1962, 10, 1, 0, 0),
#   datetime.datetime(1963, 9, 19, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, September 1963 (WU1963)'),
#  ('W',
#   'CME_W',
#   'CME_WZ1963',
#   datetime.datetime(1963, 1, 2, 0, 0),
#   datetime.datetime(1963, 12, 19, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, December 1963 (WZ1963)'),
#  ('W',
#   'CME_W',
#   'CME_WH1964',
#   datetime.datetime(1963, 4, 1, 0, 0),
#   datetime.datetime(1964, 3, 19, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, March 1964 (WH1964)'),
#  ('W',
#   'CME_W',
#   'CME_WK1964',
#   datetime.datetime(1963, 6, 3, 0, 0),
#   datetime.datetime(1964, 5, 19, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, May 1964 (WK1964)'),
#  ('W',
#   'CME_W',
#   'CME_WN1964',
#   datetime.datetime(1963, 7, 1, 0, 0),
#   datetime.datetime(1964, 7, 22, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, July 1964 (WN1964)'),
#  ('W',
#   'CME_W',
#   'CME_WU1964',
#   datetime.datetime(1963, 7, 2, 0, 0),
#   datetime.datetime(1964, 9, 21, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, September 1964 (WU1964)'),
#  ('W',
#   'CME_W',
#   'CME_WZ1964',
#   datetime.datetime(1964, 1, 2, 0, 0),
#   datetime.datetime(1964, 12, 21, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, December 1964 (WZ1964)'),
#  ('W',
#   'CME_W',
#   'CME_WH1965',
#   datetime.datetime(1964, 4, 15, 0, 0),
#   datetime.datetime(1965, 3, 22, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, March 1965 (WH1965)'),
#  ('W',
#   'CME_W',
#   'CME_WK1965',
#   datetime.datetime(1964, 6, 1, 0, 0),
#   datetime.datetime(1965, 5, 19, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, May 1965 (WK1965)'),
#  ('W',
#   'CME_W',
#   'CME_WN1965',
#   datetime.datetime(1964, 8, 4, 0, 0),
#   datetime.datetime(1965, 7, 21, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, July 1965 (WN1965)'),
#  ('W',
#   'CME_W',
#   'CME_WU1965',
#   datetime.datetime(1964, 10, 8, 0, 0),
#   datetime.datetime(1965, 9, 21, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, September 1965 (WU1965)'),
#  ('W',
#   'CME_W',
#   'CME_WZ1965',
#   datetime.datetime(1965, 1, 5, 0, 0),
#   datetime.datetime(1965, 12, 20, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, December 1965 (WZ1965)'),
#  ('W',
#   'CME_W',
#   'CME_WH1966',
#   datetime.datetime(1965, 5, 5, 0, 0),
#   datetime.datetime(1966, 3, 22, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, March 1966 (WH1966)'),
#  ('W',
#   'CME_W',
#   'CME_WK1966',
#   datetime.datetime(1965, 6, 1, 0, 0),
#   datetime.datetime(1966, 5, 19, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, May 1966 (WK1966)'),
#  ('W',
#   'CME_W',
#   'CME_WN1966',
#   datetime.datetime(1965, 8, 2, 0, 0),
#   datetime.datetime(1966, 7, 20, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, July 1966 (WN1966)'),
#  ('W',
#   'CME_W',
#   'CME_WU1966',
#   datetime.datetime(1965, 10, 4, 0, 0),
#   datetime.datetime(1966, 9, 21, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, September 1966 (WU1966)'),
#  ('W',
#   'CME_W',
#   'CME_WZ1966',
#   datetime.datetime(1966, 1, 3, 0, 0),
#   datetime.datetime(1966, 12, 20, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, December 1966 (WZ1966)'),
#  ('W',
#   'CME_W',
#   'CME_WH1967',
#   datetime.datetime(1966, 4, 1, 0, 0),
#   datetime.datetime(1967, 3, 21, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, March 1967 (WH1967)'),
#  ('W',
#   'CME_W',
#   'CME_WK1967',
#   datetime.datetime(1966, 6, 1, 0, 0),
#   datetime.datetime(1967, 5, 19, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, May 1967 (WK1967)'),
#  ('W',
#   'CME_W',
#   'CME_WN1967',
#   datetime.datetime(1966, 8, 1, 0, 0),
#   datetime.datetime(1967, 7, 20, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, July 1967 (WN1967)'),
#  ('W',
#   'CME_W',
#   'CME_WU1967',
#   datetime.datetime(1966, 10, 3, 0, 0),
#   datetime.datetime(1967, 9, 20, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, September 1967 (WU1967)'),
#  ('W',
#   'CME_W',
#   'CME_WZ1967',
#   datetime.datetime(1967, 1, 3, 0, 0),
#   datetime.datetime(1967, 12, 19, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, December 1967 (WZ1967)'),
#  ('W',
#   'CME_W',
#   'CME_WH1968',
#   datetime.datetime(1967, 4, 3, 0, 0),
#   datetime.datetime(1968, 3, 20, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, March 1968 (WH1968)'),
#  ('W',
#   'CME_W',
#   'CME_WK1968',
#   datetime.datetime(1967, 6, 1, 0, 0),
#   datetime.datetime(1968, 5, 21, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, May 1968 (WK1968)'),
#  ('W',
#   'CME_W',
#   'CME_WN1968',
#   datetime.datetime(1967, 8, 1, 0, 0),
#   datetime.datetime(1968, 7, 22, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, July 1968 (WN1968)'),
#  ('W',
#   'CME_W',
#   'CME_WU1968',
#   datetime.datetime(1967, 10, 2, 0, 0),
#   datetime.datetime(1968, 9, 19, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, September 1968 (WU1968)'),
#  ('W',
#   'CME_W',
#   'CME_WZ1968',
#   datetime.datetime(1968, 1, 2, 0, 0),
#   datetime.datetime(1968, 12, 19, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, December 1968 (WZ1968)'),
#  ('W',
#   'CME_W',
#   'CME_WH1969',
#   datetime.datetime(1968, 4, 1, 0, 0),
#   datetime.datetime(1969, 3, 20, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, March 1969 (WH1969)'),
#  ('W',
#   'CME_W',
#   'CME_WK1969',
#   datetime.datetime(1968, 6, 3, 0, 0),
#   datetime.datetime(1969, 5, 20, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, May 1969 (WK1969)'),
#  ('W',
#   'CME_W',
#   'CME_WN1969',
#   datetime.datetime(1968, 8, 1, 0, 0),
#   datetime.datetime(1969, 7, 22, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, July 1969 (WN1969)'),
#  ('W',
#   'CME_W',
#   'CME_WU1969',
#   datetime.datetime(1968, 8, 1, 0, 0),
#   datetime.datetime(1969, 9, 19, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, September 1969 (WU1969)'),
#  ('W',
#   'CME_W',
#   'CME_WZ1969',
#   datetime.datetime(1969, 1, 2, 0, 0),
#   datetime.datetime(1969, 12, 18, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, December 1969 (WZ1969)'),
#  ('W',
#   'CME_W',
#   'CME_WH1970',
#   datetime.datetime(1969, 4, 1, 0, 0),
#   datetime.datetime(1970, 3, 19, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, March 1970 (WH1970)'),
#  ('W',
#   'CME_W',
#   'CME_WK1970',
#   datetime.datetime(1969, 5, 21, 0, 0),
#   datetime.datetime(1970, 5, 19, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, May 1970 (WK1970)'),
#  ('W',
#   'CME_W',
#   'CME_WN1970',
#   datetime.datetime(1969, 7, 23, 0, 0),
#   datetime.datetime(1970, 7, 22, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, July 1970 (WN1970)'),
#  ('W',
#   'CME_W',
#   'CME_WU1970',
#   datetime.datetime(1969, 10, 1, 0, 0),
#   datetime.datetime(1970, 9, 21, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, September 1970 (WU1970)'),
#  ('W',
#   'CME_W',
#   'CME_WZ1970',
#   datetime.datetime(1969, 12, 19, 0, 0),
#   datetime.datetime(1970, 12, 21, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, December 1970 (WZ1970)'),
#  ('W',
#   'CME_W',
#   'CME_WH1971',
#   datetime.datetime(1970, 3, 23, 0, 0),
#   datetime.datetime(1971, 3, 22, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, March 1971 (WH1971)'),
#  ('W',
#   'CME_W',
#   'CME_WK1971',
#   datetime.datetime(1970, 5, 21, 0, 0),
#   datetime.datetime(1971, 5, 19, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, May 1971 (WK1971)'),
#  ('W',
#   'CME_W',
#   'CME_WN1971',
#   datetime.datetime(1970, 8, 4, 0, 0),
#   datetime.datetime(1971, 7, 21, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, July 1971 (WN1971)'),
#  ('W',
#   'CME_W',
#   'CME_WU1971',
#   datetime.datetime(1970, 9, 28, 0, 0),
#   datetime.datetime(1971, 9, 21, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, September 1971 (WU1971)'),
#  ('W',
#   'CME_W',
#   'CME_WZ1971',
#   datetime.datetime(1970, 12, 23, 0, 0),
#   datetime.datetime(1971, 12, 20, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, December 1971 (WZ1971)'),
#  ('W',
#   'CME_W',
#   'CME_WH1972',
#   datetime.datetime(1971, 3, 23, 0, 0),
#   datetime.datetime(1972, 3, 21, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, March 1972 (WH1972)'),
#  ('W',
#   'CME_W',
#   'CME_WK1972',
#   datetime.datetime(1971, 5, 21, 0, 0),
#   datetime.datetime(1972, 5, 19, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, May 1972 (WK1972)'),
#  ('W',
#   'CME_W',
#   'CME_WN1972',
#   datetime.datetime(1971, 8, 2, 0, 0),
#   datetime.datetime(1972, 7, 20, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, July 1972 (WN1972)'),
#  ('W',
#   'CME_W',
#   'CME_WU1972',
#   datetime.datetime(1971, 9, 22, 0, 0),
#   datetime.datetime(1972, 9, 20, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, September 1972 (WU1972)'),
#  ('W',
#   'CME_W',
#   'CME_WZ1972',
#   datetime.datetime(1972, 1, 5, 0, 0),
#   datetime.datetime(1972, 12, 19, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, December 1972 (WZ1972)'),
#  ('W',
#   'CME_W',
#   'CME_WH1973',
#   datetime.datetime(1972, 3, 29, 0, 0),
#   datetime.datetime(1973, 3, 21, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, March 1973 (WH1973)'),
#  ('W',
#   'CME_W',
#   'CME_WK1973',
#   datetime.datetime(1972, 6, 6, 0, 0),
#   datetime.datetime(1973, 5, 21, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, May 1973 (WK1973)'),
#  ('W',
#   'CME_W',
#   'CME_WN1973',
#   datetime.datetime(1972, 9, 25, 0, 0),
#   datetime.datetime(1973, 7, 20, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, July 1973 (WN1973)'),
#  ('W',
#   'CME_W',
#   'CME_WU1973',
#   datetime.datetime(1972, 9, 25, 0, 0),
#   datetime.datetime(1973, 9, 19, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, September 1973 (WU1973)'),
#  ('W',
#   'CME_W',
#   'CME_WZ1973',
#   datetime.datetime(1973, 1, 2, 0, 0),
#   datetime.datetime(1973, 12, 18, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, December 1973 (WZ1973)'),
#  ('W',
#   'CME_W',
#   'CME_WH1974',
#   datetime.datetime(1973, 4, 2, 0, 0),
#   datetime.datetime(1974, 3, 20, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, March 1974 (WH1974)'),
#  ('W',
#   'CME_W',
#   'CME_WK1974',
#   datetime.datetime(1973, 6, 4, 0, 0),
#   datetime.datetime(1974, 5, 21, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, May 1974 (WK1974)'),
#  ('W',
#   'CME_W',
#   'CME_WN1974',
#   datetime.datetime(1973, 7, 24, 0, 0),
#   datetime.datetime(1974, 7, 22, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, July 1974 (WN1974)'),
#  ('W',
#   'CME_W',
#   'CME_WU1974',
#   datetime.datetime(1973, 10, 1, 0, 0),
#   datetime.datetime(1974, 9, 19, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, September 1974 (WU1974)'),
#  ('W',
#   'CME_W',
#   'CME_WZ1974',
#   datetime.datetime(1974, 1, 2, 0, 0),
#   datetime.datetime(1974, 12, 19, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, December 1974 (WZ1974)'),
#  ('W',
#   'CME_W',
#   'CME_WH1975',
#   datetime.datetime(1974, 4, 10, 0, 0),
#   datetime.datetime(1975, 3, 19, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, March 1975 (WH1975)'),
#  ('W',
#   'CME_W',
#   'CME_WK1975',
#   datetime.datetime(1974, 6, 3, 0, 0),
#   datetime.datetime(1975, 5, 20, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, May 1975 (WK1975)'),
#  ('W',
#   'CME_W',
#   'CME_WN1975',
#   datetime.datetime(1974, 7, 29, 0, 0),
#   datetime.datetime(1975, 7, 22, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, July 1975 (WN1975)'),
#  ('W',
#   'CME_W',
#   'CME_WU1975',
#   datetime.datetime(1974, 10, 2, 0, 0),
#   datetime.datetime(1975, 9, 19, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, September 1975 (WU1975)'),
#  ('W',
#   'CME_W',
#   'CME_WZ1975',
#   datetime.datetime(1974, 10, 9, 0, 0),
#   datetime.datetime(1975, 12, 18, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, December 1975 (WZ1975)'),
#  ('W',
#   'CME_W',
#   'CME_WH1976',
#   datetime.datetime(1975, 3, 19, 0, 0),
#   datetime.datetime(1976, 3, 22, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, March 1976 (WH1976)'),
#  ('W',
#   'CME_W',
#   'CME_WK1976',
#   datetime.datetime(1975, 6, 2, 0, 0),
#   datetime.datetime(1976, 5, 19, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, May 1976 (WK1976)'),
#  ('W',
#   'CME_W',
#   'CME_WN1976',
#   datetime.datetime(1975, 8, 1, 0, 0),
#   datetime.datetime(1976, 7, 21, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, July 1976 (WN1976)'),
#  ('W',
#   'CME_W',
#   'CME_WU1976',
#   datetime.datetime(1975, 10, 1, 0, 0),
#   datetime.datetime(1976, 9, 21, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, September 1976 (WU1976)'),
#  ('W',
#   'CME_W',
#   'CME_WZ1976',
#   datetime.datetime(1976, 1, 2, 0, 0),
#   datetime.datetime(1976, 12, 20, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, December 1976 (WZ1976)'),
#  ('W',
#   'CME_W',
#   'CME_WH1977',
#   datetime.datetime(1976, 2, 2, 0, 0),
#   datetime.datetime(1977, 3, 22, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, March 1977 (WH1977)'),
#  ('W',
#   'CME_W',
#   'CME_WK1977',
#   datetime.datetime(1976, 7, 6, 0, 0),
#   datetime.datetime(1977, 5, 19, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, May 1977 (WK1977)'),
#  ('W',
#   'CME_W',
#   'CME_WN1977',
#   datetime.datetime(1976, 7, 6, 0, 0),
#   datetime.datetime(1977, 7, 20, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, July 1977 (WN1977)'),
#  ('W',
#   'CME_W',
#   'CME_WU1977',
#   datetime.datetime(1976, 10, 1, 0, 0),
#   datetime.datetime(1977, 9, 21, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, September 1977 (WU1977)'),
#  ('W',
#   'CME_W',
#   'CME_WZ1977',
#   datetime.datetime(1976, 10, 1, 0, 0),
#   datetime.datetime(1977, 12, 20, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, December 1977 (WZ1977)'),
#  ('W',
#   'CME_W',
#   'CME_WH1978',
#   datetime.datetime(1977, 1, 4, 0, 0),
#   datetime.datetime(1978, 3, 21, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, March 1978 (WH1978)'),
#  ('W',
#   'CME_W',
#   'CME_WK1978',
#   datetime.datetime(1977, 3, 23, 0, 0),
#   datetime.datetime(1978, 5, 19, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, May 1978 (WK1978)'),
#  ('W',
#   'CME_W',
#   'CME_WN1978',
#   datetime.datetime(1977, 6, 7, 0, 0),
#   datetime.datetime(1978, 7, 20, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, July 1978 (WN1978)'),
#  ('W',
#   'CME_W',
#   'CME_WU1978',
#   datetime.datetime(1977, 8, 2, 0, 0),
#   datetime.datetime(1978, 9, 20, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, September 1978 (WU1978)'),
#  ('W',
#   'CME_W',
#   'CME_WZ1978',
#   datetime.datetime(1977, 10, 3, 0, 0),
#   datetime.datetime(1978, 12, 19, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, December 1978 (WZ1978)'),
#  ('W',
#   'CME_W',
#   'CME_WH1979',
#   datetime.datetime(1978, 1, 5, 0, 0),
#   datetime.datetime(1979, 3, 21, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, March 1979 (WH1979)'),
#  ('W',
#   'CME_W',
#   'CME_WK1979',
#   datetime.datetime(1978, 3, 22, 0, 0),
#   datetime.datetime(1979, 5, 21, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, May 1979 (WK1979)'),
#  ('W',
#   'CME_W',
#   'CME_WN1979',
#   datetime.datetime(1978, 5, 24, 0, 0),
#   datetime.datetime(1979, 7, 20, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, July 1979 (WN1979)'),
#  ('W',
#   'CME_W',
#   'CME_WU1979',
#   datetime.datetime(1978, 7, 31, 0, 0),
#   datetime.datetime(1979, 9, 19, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, September 1979 (WU1979)'),
#  ('W',
#   'CME_W',
#   'CME_WZ1979',
#   datetime.datetime(1978, 9, 22, 0, 0),
#   datetime.datetime(1979, 12, 18, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, December 1979 (WZ1979)'),
#  ('W',
#   'CME_W',
#   'CME_WH1980',
#   datetime.datetime(1979, 1, 8, 0, 0),
#   datetime.datetime(1980, 3, 20, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, March 1980 (WH1980)'),
#  ('W',
#   'CME_W',
#   'CME_WK1980',
#   datetime.datetime(1979, 4, 6, 0, 0),
#   datetime.datetime(1980, 5, 20, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, May 1980 (WK1980)'),
#  ('W',
#   'CME_W',
#   'CME_WN1980',
#   datetime.datetime(1979, 6, 5, 0, 0),
#   datetime.datetime(1980, 7, 22, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, July 1980 (WN1980)'),
#  ('W',
#   'CME_W',
#   'CME_WU1980',
#   datetime.datetime(1979, 7, 23, 0, 0),
#   datetime.datetime(1980, 9, 19, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, September 1980 (WU1980)'),
#  ('W',
#   'CME_W',
#   'CME_WZ1980',
#   datetime.datetime(1979, 9, 27, 0, 0),
#   datetime.datetime(1980, 12, 18, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, December 1980 (WZ1980)'),
#  ('W',
#   'CME_W',
#   'CME_WH1981',
#   datetime.datetime(1979, 12, 19, 0, 0),
#   datetime.datetime(1981, 3, 20, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, March 1981 (WH1981)'),
#  ('W',
#   'CME_W',
#   'CME_WK1981',
#   datetime.datetime(1980, 3, 21, 0, 0),
#   datetime.datetime(1981, 5, 19, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, May 1981 (WK1981)'),
#  ('W',
#   'CME_W',
#   'CME_WN1981',
#   datetime.datetime(1980, 5, 21, 0, 0),
#   datetime.datetime(1981, 7, 22, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, July 1981 (WN1981)'),
#  ('W',
#   'CME_W',
#   'CME_WU1981',
#   datetime.datetime(1980, 7, 23, 0, 0),
#   datetime.datetime(1981, 9, 21, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, September 1981 (WU1981)'),
#  ('W',
#   'CME_W',
#   'CME_WZ1981',
#   datetime.datetime(1980, 9, 22, 0, 0),
#   datetime.datetime(1981, 12, 21, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, December 1981 (WZ1981)'),
#  ('W',
#   'CME_W',
#   'CME_WH1982',
#   datetime.datetime(1981, 1, 22, 0, 0),
#   datetime.datetime(1982, 3, 22, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, March 1982 (WH1982)'),
#  ('W',
#   'CME_W',
#   'CME_WK1982',
#   datetime.datetime(1981, 4, 1, 0, 0),
#   datetime.datetime(1982, 5, 19, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, May 1982 (WK1982)'),
#  ('W',
#   'CME_W',
#   'CME_WN1982',
#   datetime.datetime(1981, 5, 20, 0, 0),
#   datetime.datetime(1982, 7, 21, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, July 1982 (WN1982)'),
#  ('W',
#   'CME_W',
#   'CME_WU1982',
#   datetime.datetime(1981, 7, 27, 0, 0),
#   datetime.datetime(1982, 9, 21, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, September 1982 (WU1982)'),
#  ('W',
#   'CME_W',
#   'CME_WZ1982',
#   datetime.datetime(1981, 9, 25, 0, 0),
#   datetime.datetime(1982, 12, 20, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, December 1982 (WZ1982)'),
#  ('W',
#   'CME_W',
#   'CME_WH1983',
#   datetime.datetime(1981, 12, 22, 0, 0),
#   datetime.datetime(1983, 3, 22, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, March 1983 (WH1983)'),
#  ('W',
#   'CME_W',
#   'CME_WK1983',
#   datetime.datetime(1982, 3, 23, 0, 0),
#   datetime.datetime(1983, 5, 19, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, May 1983 (WK1983)'),
#  ('W',
#   'CME_W',
#   'CME_WN1983',
#   datetime.datetime(1982, 5, 21, 0, 0),
#   datetime.datetime(1983, 7, 20, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, July 1983 (WN1983)'),
#  ('W',
#   'CME_W',
#   'CME_WU1983',
#   datetime.datetime(1982, 7, 22, 0, 0),
#   datetime.datetime(1983, 9, 21, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, September 1983 (WU1983)'),
#  ('W',
#   'CME_W',
#   'CME_WZ1983',
#   datetime.datetime(1982, 9, 22, 0, 0),
#   datetime.datetime(1983, 12, 20, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, December 1983 (WZ1983)'),
#  ('W',
#   'CME_W',
#   'CME_WH1984',
#   datetime.datetime(1982, 12, 21, 0, 0),
#   datetime.datetime(1984, 3, 21, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, March 1984 (WH1984)'),
#  ('W',
#   'CME_W',
#   'CME_WK1984',
#   datetime.datetime(1983, 3, 23, 0, 0),
#   datetime.datetime(1984, 5, 21, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, May 1984 (WK1984)'),
#  ('W',
#   'CME_W',
#   'CME_WN1984',
#   datetime.datetime(1983, 5, 6, 0, 0),
#   datetime.datetime(1984, 7, 20, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, July 1984 (WN1984)'),
#  ('W',
#   'CME_W',
#   'CME_WU1984',
#   datetime.datetime(1983, 8, 4, 0, 0),
#   datetime.datetime(1984, 9, 19, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, September 1984 (WU1984)'),
#  ('W',
#   'CME_W',
#   'CME_WZ1984',
#   datetime.datetime(1983, 9, 22, 0, 0),
#   datetime.datetime(1984, 12, 19, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, December 1984 (WZ1984)'),
#  ('W',
#   'CME_W',
#   'CME_WH1985',
#   datetime.datetime(1983, 12, 21, 0, 0),
#   datetime.datetime(1985, 3, 20, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, March 1985 (WH1985)'),
#  ('W',
#   'CME_W',
#   'CME_WK1985',
#   datetime.datetime(1984, 3, 22, 0, 0),
#   datetime.datetime(1985, 5, 21, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, May 1985 (WK1985)'),
#  ('W',
#   'CME_W',
#   'CME_WN1985',
#   datetime.datetime(1984, 5, 22, 0, 0),
#   datetime.datetime(1985, 7, 22, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, July 1985 (WN1985)'),
#  ('W',
#   'CME_W',
#   'CME_WU1985',
#   datetime.datetime(1984, 7, 23, 0, 0),
#   datetime.datetime(1985, 9, 19, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, September 1985 (WU1985)'),
#  ('W',
#   'CME_W',
#   'CME_WZ1985',
#   datetime.datetime(1984, 9, 24, 0, 0),
#   datetime.datetime(1985, 12, 19, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, December 1985 (WZ1985)'),
#  ('W',
#   'CME_W',
#   'CME_WH1986',
#   datetime.datetime(1984, 12, 24, 0, 0),
#   datetime.datetime(1986, 3, 19, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, March 1986 (WH1986)'),
#  ('W',
#   'CME_W',
#   'CME_WK1986',
#   datetime.datetime(1985, 3, 21, 0, 0),
#   datetime.datetime(1986, 5, 20, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, May 1986 (WK1986)'),
#  ('W',
#   'CME_W',
#   'CME_WN1986',
#   datetime.datetime(1985, 5, 22, 0, 0),
#   datetime.datetime(1986, 7, 22, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, July 1986 (WN1986)'),
#  ('W',
#   'CME_W',
#   'CME_WU1986',
#   datetime.datetime(1985, 7, 23, 0, 0),
#   datetime.datetime(1986, 9, 19, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, September 1986 (WU1986)'),
#  ('W',
#   'CME_W',
#   'CME_WZ1986',
#   datetime.datetime(1985, 10, 4, 0, 0),
#   datetime.datetime(1986, 12, 19, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, December 1986 (WZ1986)'),
#  ('W',
#   'CME_W',
#   'CME_WH1987',
#   datetime.datetime(1986, 1, 16, 0, 0),
#   datetime.datetime(1987, 3, 20, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, March 1987 (WH1987)'),
#  ('W',
#   'CME_W',
#   'CME_WK1987',
#   datetime.datetime(1986, 4, 3, 0, 0),
#   datetime.datetime(1987, 5, 19, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, May 1987 (WK1987)'),
#  ('W',
#   'CME_W',
#   'CME_WN1987',
#   datetime.datetime(1986, 5, 21, 0, 0),
#   datetime.datetime(1987, 7, 22, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, July 1987 (WN1987)'),
#  ('W',
#   'CME_W',
#   'CME_WU1987',
#   datetime.datetime(1986, 8, 13, 0, 0),
#   datetime.datetime(1987, 9, 21, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, September 1987 (WU1987)'),
#  ('W',
#   'CME_W',
#   'CME_WZ1987',
#   datetime.datetime(1986, 10, 2, 0, 0),
#   datetime.datetime(1987, 12, 21, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, December 1987 (WZ1987)'),
#  ('W',
#   'CME_W',
#   'CME_WH1988',
#   datetime.datetime(1987, 1, 13, 0, 0),
#   datetime.datetime(1988, 3, 22, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, March 1988 (WH1988)'),
#  ('W',
#   'CME_W',
#   'CME_WK1988',
#   datetime.datetime(1987, 3, 23, 0, 0),
#   datetime.datetime(1988, 5, 19, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, May 1988 (WK1988)'),
#  ('W',
#   'CME_W',
#   'CME_WN1988',
#   datetime.datetime(1987, 5, 20, 0, 0),
#   datetime.datetime(1988, 7, 20, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, July 1988 (WN1988)'),
#  ('W',
#   'CME_W',
#   'CME_WU1988',
#   datetime.datetime(1987, 8, 6, 0, 0),
#   datetime.datetime(1988, 9, 21, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, September 1988 (WU1988)'),
#  ('W',
#   'CME_W',
#   'CME_WZ1988',
#   datetime.datetime(1987, 10, 2, 0, 0),
#   datetime.datetime(1988, 12, 20, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, December 1988 (WZ1988)'),
#  ('W',
#   'CME_W',
#   'CME_WH1989',
#   datetime.datetime(1988, 1, 7, 0, 0),
#   datetime.datetime(1989, 3, 21, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, March 1989 (WH1989)'),
#  ('W',
#   'CME_W',
#   'CME_WK1989',
#   datetime.datetime(1988, 4, 5, 0, 0),
#   datetime.datetime(1989, 5, 19, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, May 1989 (WK1989)'),
#  ('W',
#   'CME_W',
#   'CME_WN1989',
#   datetime.datetime(1988, 5, 20, 0, 0),
#   datetime.datetime(1989, 7, 20, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, July 1989 (WN1989)'),
#  ('W',
#   'CME_W',
#   'CME_WU1989',
#   datetime.datetime(1988, 8, 23, 0, 0),
#   datetime.datetime(1989, 9, 20, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, September 1989 (WU1989)'),
#  ('W',
#   'CME_W',
#   'CME_WZ1989',
#   datetime.datetime(1988, 10, 7, 0, 0),
#   datetime.datetime(1989, 12, 19, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, December 1989 (WZ1989)'),
#  ('W',
#   'CME_W',
#   'CME_WH1990',
#   datetime.datetime(1989, 1, 5, 0, 0),
#   datetime.datetime(1990, 3, 21, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, March 1990 (WH1990)'),
#  ('W',
#   'CME_W',
#   'CME_WK1990',
#   datetime.datetime(1989, 3, 22, 0, 0),
#   datetime.datetime(1990, 5, 21, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, May 1990 (WK1990)'),
#  ('W',
#   'CME_W',
#   'CME_WN1990',
#   datetime.datetime(1989, 5, 22, 0, 0),
#   datetime.datetime(1990, 7, 20, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, July 1990 (WN1990)'),
#  ('W',
#   'CME_W',
#   'CME_WU1990',
#   datetime.datetime(1989, 7, 21, 0, 0),
#   datetime.datetime(1990, 9, 19, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, September 1990 (WU1990)'),
#  ('W',
#   'CME_W',
#   'CME_WZ1990',
#   datetime.datetime(1989, 9, 21, 0, 0),
#   datetime.datetime(1990, 12, 19, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, December 1990 (WZ1990)'),
#  ('W',
#   'CME_W',
#   'CME_WH1991',
#   datetime.datetime(1989, 12, 20, 0, 0),
#   datetime.datetime(1991, 3, 19, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, March 1991 (WH1991)'),
#  ('W',
#   'CME_W',
#   'CME_WK1991',
#   datetime.datetime(1990, 3, 22, 0, 0),
#   datetime.datetime(1991, 5, 21, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, May 1991 (WK1991)'),
#  ('W',
#   'CME_W',
#   'CME_WN1991',
#   datetime.datetime(1990, 5, 24, 0, 0),
#   datetime.datetime(1991, 7, 22, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, July 1991 (WN1991)'),
#  ('W',
#   'CME_W',
#   'CME_WU1991',
#   datetime.datetime(1990, 7, 27, 0, 0),
#   datetime.datetime(1991, 9, 19, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, September 1991 (WU1991)'),
#  ('W',
#   'CME_W',
#   'CME_WZ1991',
#   datetime.datetime(1990, 9, 20, 0, 0),
#   datetime.datetime(1991, 12, 19, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, December 1991 (WZ1991)'),
#  ('W',
#   'CME_W',
#   'CME_WH1992',
#   datetime.datetime(1990, 12, 28, 0, 0),
#   datetime.datetime(1992, 3, 20, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, March 1992 (WH1992)'),
#  ('W',
#   'CME_W',
#   'CME_WK1992',
#   datetime.datetime(1991, 3, 20, 0, 0),
#   datetime.datetime(1992, 5, 19, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, May 1992 (WK1992)'),
#  ('W',
#   'CME_W',
#   'CME_WN1992',
#   datetime.datetime(1991, 5, 22, 0, 0),
#   datetime.datetime(1992, 7, 22, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, July 1992 (WN1992)'),
#  ('W',
#   'CME_W',
#   'CME_WU1992',
#   datetime.datetime(1991, 8, 2, 0, 0),
#   datetime.datetime(1992, 9, 21, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, September 1992 (WU1992)'),
#  ('W',
#   'CME_W',
#   'CME_WZ1992',
#   datetime.datetime(1991, 10, 1, 0, 0),
#   datetime.datetime(1992, 12, 21, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, December 1992 (WZ1992)'),
#  ('W',
#   'CME_W',
#   'CME_WH1993',
#   datetime.datetime(1991, 12, 20, 0, 0),
#   datetime.datetime(1993, 3, 22, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, March 1993 (WH1993)'),
#  ('W',
#   'CME_W',
#   'CME_WK1993',
#   datetime.datetime(1992, 3, 23, 0, 0),
#   datetime.datetime(1993, 5, 19, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, May 1993 (WK1993)'),
#  ('W',
#   'CME_W',
#   'CME_WN1993',
#   datetime.datetime(1992, 2, 18, 0, 0),
#   datetime.datetime(1993, 7, 21, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, July 1993 (WN1993)'),
#  ('W',
#   'CME_W',
#   'CME_WU1993',
#   datetime.datetime(1992, 3, 23, 0, 0),
#   datetime.datetime(1993, 9, 21, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, September 1993 (WU1993)'),
#  ('W',
#   'CME_W',
#   'CME_WZ1993',
#   datetime.datetime(1992, 6, 3, 0, 0),
#   datetime.datetime(1993, 12, 20, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, December 1993 (WZ1993)'),
#  ('W',
#   'CME_W',
#   'CME_WH1994',
#   datetime.datetime(1992, 12, 22, 0, 0),
#   datetime.datetime(1994, 3, 22, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, March 1994 (WH1994)'),
#  ('W',
#   'CME_W',
#   'CME_WK1994',
#   datetime.datetime(1993, 3, 23, 0, 0),
#   datetime.datetime(1994, 5, 19, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, May 1994 (WK1994)'),
#  ('W',
#   'CME_W',
#   'CME_WN1994',
#   datetime.datetime(1992, 8, 18, 0, 0),
#   datetime.datetime(1994, 7, 20, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, July 1994 (WN1994)'),
#  ('W',
#   'CME_W',
#   'CME_WU1994',
#   datetime.datetime(1993, 7, 23, 0, 0),
#   datetime.datetime(1994, 9, 21, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, September 1994 (WU1994)'),
#  ('W',
#   'CME_W',
#   'CME_WZ1994',
#   datetime.datetime(1993, 8, 12, 0, 0),
#   datetime.datetime(1994, 12, 20, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, December 1994 (WZ1994)'),
#  ('W',
#   'CME_W',
#   'CME_WH1995',
#   datetime.datetime(1994, 2, 18, 0, 0),
#   datetime.datetime(1995, 3, 22, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, March 1995 (WH1995)'),
#  ('W',
#   'CME_W',
#   'CME_WK1995',
#   datetime.datetime(1994, 3, 23, 0, 0),
#   datetime.datetime(1995, 5, 19, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, May 1995 (WK1995)'),
#  ('W',
#   'CME_W',
#   'CME_WN1995',
#   datetime.datetime(1993, 11, 3, 0, 0),
#   datetime.datetime(1995, 7, 20, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, July 1995 (WN1995)'),
#  ('W',
#   'CME_W',
#   'CME_WU1995',
#   datetime.datetime(1994, 8, 31, 0, 0),
#   datetime.datetime(1995, 9, 20, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, September 1995 (WU1995)'),
#  ('W',
#   'CME_W',
#   'CME_WZ1995',
#   datetime.datetime(1994, 6, 2, 0, 0),
#   datetime.datetime(1995, 12, 19, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, December 1995 (WZ1995)'),
#  ('W',
#   'CME_W',
#   'CME_WH1996',
#   datetime.datetime(1994, 12, 27, 0, 0),
#   datetime.datetime(1996, 3, 18, 0, 0),
#   '2015-05-22 16:12',
#   'CBOT Wheat, March 1996 (WH1996)'),
#  ('W',
#   'CME_W',
#   'CME_WK1996',
#   datetime.datetime(1995, 5, 23, 0, 0),
#   datetime.datetime(1996, 5, 21, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, May 1996 (WK1996)'),
#  ('W',
#   'CME_W',
#   'CME_WN1996',
#   datetime.datetime(1994, 9, 27, 0, 0),
#   datetime.datetime(1996, 7, 22, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, July 1996 (WN1996)'),
#  ('W',
#   'CME_W',
#   'CME_WU1996',
#   datetime.datetime(1995, 7, 25, 0, 0),
#   datetime.datetime(1996, 9, 19, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, September 1996 (WU1996)'),
#  ('W',
#   'CME_W',
#   'CME_WZ1996',
#   datetime.datetime(1995, 5, 25, 0, 0),
#   datetime.datetime(1996, 12, 19, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, December 1996 (WZ1996)'),
#  ('W',
#   'CME_W',
#   'CME_WH1997',
#   datetime.datetime(1996, 2, 1, 0, 0),
#   datetime.datetime(1997, 3, 19, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, March 1997 (WH1997)'),
#  ('W',
#   'CME_W',
#   'CME_WK1997',
#   datetime.datetime(1996, 4, 9, 0, 0),
#   datetime.datetime(1997, 5, 21, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, May 1997 (WK1997)'),
#  ('W',
#   'CME_W',
#   'CME_WN1997',
#   datetime.datetime(1995, 10, 5, 0, 0),
#   datetime.datetime(1997, 7, 23, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, July 1997 (WN1997)'),
#  ('W',
#   'CME_W',
#   'CME_WU1997',
#   datetime.datetime(1996, 7, 24, 0, 0),
#   datetime.datetime(1997, 9, 19, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, September 1997 (WU1997)'),
#  ('W',
#   'CME_W',
#   'CME_WZ1997',
#   datetime.datetime(1996, 3, 15, 0, 0),
#   datetime.datetime(1997, 12, 19, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, December 1997 (WZ1997)'),
#  ('W',
#   'CME_W',
#   'CME_WH1998',
#   datetime.datetime(1997, 1, 3, 0, 0),
#   datetime.datetime(1998, 3, 20, 0, 0),
#   '2015-04-27 16:18',
#   'CBOT Wheat, March 1998 (WH1998)'),
#  ('W',
#   'CME_W',
#   'CME_WK1998',
#   datetime.datetime(1997, 4, 14, 0, 0),
#   datetime.datetime(1998, 5, 19, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, May 1998 (WK1998)'),
#  ('W',
#   'CME_W',
#   'CME_WN1998',
#   datetime.datetime(1996, 1, 5, 0, 0),
#   datetime.datetime(1998, 7, 22, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, July 1998 (WN1998)'),
#  ('W',
#   'CME_W',
#   'CME_WU1998',
#   datetime.datetime(1997, 8, 28, 0, 0),
#   datetime.datetime(1998, 9, 21, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, September 1998 (WU1998)'),
#  ('W',
#   'CME_W',
#   'CME_WZ1998',
#   datetime.datetime(1997, 4, 15, 0, 0),
#   datetime.datetime(1998, 12, 21, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, December 1998 (WZ1998)'),
#  ('W',
#   'CME_W',
#   'CME_WH1999',
#   datetime.datetime(1998, 1, 20, 0, 0),
#   datetime.datetime(1999, 3, 22, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, March 1999 (WH1999)'),
#  ('W',
#   'CME_W',
#   'CME_WK1999',
#   datetime.datetime(1998, 4, 14, 0, 0),
#   datetime.datetime(1999, 5, 19, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, May 1999 (WK1999)'),
#  ('W',
#   'CME_W',
#   'CME_WN1999',
#   datetime.datetime(1996, 8, 15, 0, 0),
#   datetime.datetime(1999, 7, 21, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, July 1999 (WN1999)'),
#  ('W',
#   'CME_W',
#   'CME_WU1999',
#   datetime.datetime(1998, 7, 23, 0, 0),
#   datetime.datetime(1999, 9, 21, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, September 1999 (WU1999)'),
#  ('W',
#   'CME_W',
#   'CME_WZ1999',
#   datetime.datetime(1998, 8, 6, 0, 0),
#   datetime.datetime(1999, 12, 20, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, December 1999 (WZ1999)'),
#  ('W',
#   'CME_W',
#   'CME_WH2000',
#   datetime.datetime(1999, 1, 27, 0, 0),
#   datetime.datetime(2000, 3, 14, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, March 2000 (WH2000)'),
#  ('W',
#   'CME_W',
#   'CME_WK2000',
#   datetime.datetime(1999, 4, 12, 0, 0),
#   datetime.datetime(2000, 5, 12, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, May 2000 (WK2000)'),
#  ('W',
#   'CME_W',
#   'CME_WN2000',
#   datetime.datetime(1999, 1, 27, 0, 0),
#   datetime.datetime(2000, 7, 14, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, July 2000 (WN2000)'),
#  ('W',
#   'CME_W',
#   'CME_WU2000',
#   datetime.datetime(1999, 7, 23, 0, 0),
#   datetime.datetime(2000, 9, 14, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, September 2000 (WU2000)'),
#  ('W',
#   'CME_W',
#   'CME_WZ2000',
#   datetime.datetime(2000, 1, 3, 0, 0),
#   datetime.datetime(2000, 12, 14, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, December 2000 (WZ2000)'),
#  ('W',
#   'CME_W',
#   'CME_WH2001',
#   datetime.datetime(1999, 12, 21, 0, 0),
#   datetime.datetime(2001, 3, 14, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, March 2001 (WH2001)'),
#  ('W',
#   'CME_W',
#   'CME_WK2001',
#   datetime.datetime(2000, 3, 22, 0, 0),
#   datetime.datetime(2001, 5, 14, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, May 2001 (WK2001)'),
#  ('W',
#   'CME_W',
#   'CME_WN2001',
#   datetime.datetime(1999, 1, 27, 0, 0),
#   datetime.datetime(2001, 7, 13, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, July 2001 (WN2001)'),
#  ('W',
#   'CME_W',
#   'CME_WU2001',
#   datetime.datetime(2000, 6, 29, 0, 0),
#   datetime.datetime(2001, 9, 14, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, September 2001 (WU2001)'),
#  ('W',
#   'CME_W',
#   'CME_WZ2001',
#   datetime.datetime(1999, 10, 15, 0, 0),
#   datetime.datetime(2001, 12, 14, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, December 2001 (WZ2001)'),
#  ('W',
#   'CME_W',
#   'CME_WH2002',
#   datetime.datetime(2000, 12, 15, 0, 0),
#   datetime.datetime(2002, 3, 14, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, March 2002 (WH2002)'),
#  ('W',
#   'CME_W',
#   'CME_WK2002',
#   datetime.datetime(2001, 3, 16, 0, 0),
#   datetime.datetime(2002, 5, 14, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, May 2002 (WK2002)'),
#  ('W',
#   'CME_W',
#   'CME_WN2002',
#   datetime.datetime(1999, 8, 20, 0, 0),
#   datetime.datetime(2002, 7, 12, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, July 2002 (WN2002)'),
#  ('W',
#   'CME_W',
#   'CME_WU2002',
#   datetime.datetime(2001, 7, 17, 0, 0),
#   datetime.datetime(2002, 9, 13, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, September 2002 (WU2002)'),
#  ('W',
#   'CME_W',
#   'CME_WZ2002',
#   datetime.datetime(2000, 10, 17, 0, 0),
#   datetime.datetime(2002, 12, 13, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, December 2002 (WZ2002)'),
#  ('W',
#   'CME_W',
#   'CME_WH2003',
#   datetime.datetime(2002, 1, 9, 0, 0),
#   datetime.datetime(2003, 3, 14, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, March 2003 (WH2003)'),
#  ('W',
#   'CME_W',
#   'CME_WK2003',
#   datetime.datetime(2002, 4, 4, 0, 0),
#   datetime.datetime(2003, 5, 14, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, May 2003 (WK2003)'),
#  ('W',
#   'CME_W',
#   'CME_WN2003',
#   datetime.datetime(2001, 1, 4, 0, 0),
#   datetime.datetime(2003, 7, 14, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, July 2003 (WN2003)'),
#  ('W',
#   'CME_W',
#   'CME_WU2003',
#   datetime.datetime(2002, 7, 15, 0, 0),
#   datetime.datetime(2003, 9, 12, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, September 2003 (WU2003)'),
#  ('W',
#   'CME_W',
#   'CME_WZ2003',
#   datetime.datetime(2001, 9, 19, 0, 0),
#   datetime.datetime(2003, 12, 12, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, December 2003 (WZ2003)'),
#  ('W',
#   'CME_W',
#   'CME_WH2004',
#   datetime.datetime(2002, 9, 26, 0, 0),
#   datetime.datetime(2004, 3, 12, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, March 2004 (WH2004)'),
#  ('W',
#   'CME_W',
#   'CME_WK2004',
#   datetime.datetime(2003, 3, 10, 0, 0),
#   datetime.datetime(2004, 5, 14, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, May 2004 (WK2004)'),
#  ('W',
#   'CME_W',
#   'CME_WN2004',
#   datetime.datetime(2002, 2, 13, 0, 0),
#   datetime.datetime(2004, 7, 14, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, July 2004 (WN2004)'),
#  ('W',
#   'CME_W',
#   'CME_WU2004',
#   datetime.datetime(2003, 6, 24, 0, 0),
#   datetime.datetime(2004, 9, 14, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, September 2004 (WU2004)'),
#  ('W',
#   'CME_W',
#   'CME_WZ2004',
#   datetime.datetime(2003, 5, 12, 0, 0),
#   datetime.datetime(2004, 12, 14, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, December 2004 (WZ2004)'),
#  ('W',
#   'CME_W',
#   'CME_WH2005',
#   datetime.datetime(2003, 9, 26, 0, 0),
#   datetime.datetime(2005, 3, 14, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, March 2005 (WH2005)'),
#  ('W',
#   'CME_W',
#   'CME_WK2005',
#   datetime.datetime(2004, 2, 5, 0, 0),
#   datetime.datetime(2005, 5, 16, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, May 2005 (WK2005)'),
#  ('W',
#   'CME_W',
#   'CME_WN2005',
#   datetime.datetime(2003, 11, 10, 0, 0),
#   datetime.datetime(2005, 7, 14, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, July 2005 (WN2005)'),
#  ('W',
#   'CME_W',
#   'CME_WU2005',
#   datetime.datetime(2004, 9, 30, 0, 0),
#   datetime.datetime(2005, 9, 14, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, September 2005 (WU2005)'),
#  ('W',
#   'CME_W',
#   'CME_WZ2005',
#   datetime.datetime(2004, 9, 30, 0, 0),
#   datetime.datetime(2005, 12, 14, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, December 2005 (WZ2005)'),
#  ('W',
#   'CME_W',
#   'CME_WH2006',
#   datetime.datetime(2004, 9, 30, 0, 0),
#   datetime.datetime(2006, 3, 14, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, March 2006 (WH2006)'),
#  ('W',
#   'CME_W',
#   'CME_WK2006',
#   datetime.datetime(2004, 12, 16, 0, 0),
#   datetime.datetime(2006, 5, 12, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, May 2006 (WK2006)'),
#  ('W',
#   'CME_W',
#   'CME_WN2006',
#   datetime.datetime(2004, 9, 30, 0, 0),
#   datetime.datetime(2006, 7, 14, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, July 2006 (WN2006)'),
#  ('W',
#   'CME_W',
#   'CME_WU2006',
#   datetime.datetime(2005, 5, 16, 0, 0),
#   datetime.datetime(2006, 9, 14, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, September 2006 (WU2006)'),
#  ('W',
#   'CME_W',
#   'CME_WZ2006',
#   datetime.datetime(2004, 9, 30, 0, 0),
#   datetime.datetime(2006, 12, 14, 0, 0),
#   '2015-04-27 16:17',
#   'CBOT Wheat, December 2006 (WZ2006)'),
#  ('W',
#   'CME_W',
#   'CME_WH2007',
#   datetime.datetime(2005, 9, 15, 0, 0),
#   datetime.datetime(2007, 3, 14, 0, 0),
#   '2015-12-17 18:13',
#   'CBOT Wheat, March 2007 (WH2007)'),
#  ('W',
#   'CME_W',
#   'CME_WK2007',
#   datetime.datetime(2005, 12, 16, 0, 0),
#   datetime.datetime(2007, 5, 14, 0, 0),
#   '2015-12-17 18:13',
#   'CBOT Wheat, May 2007 (WK2007)'),
#  ('W',
#   'CME_W',
#   'CME_WN2007',
#   datetime.datetime(2004, 9, 30, 0, 0),
#   datetime.datetime(2007, 7, 13, 0, 0),
#   '2015-12-17 18:13',
#   'CBOT Wheat, July 2007 (WN2007)'),
#  ('W',
#   'CME_W',
#   'CME_WU2007',
#   datetime.datetime(2006, 3, 24, 0, 0),
#   datetime.datetime(2007, 9, 14, 0, 0),
#   '2015-12-17 18:13',
#   'CBOT Wheat, September 2007 (WU2007)'),
#  ('W',
#   'CME_W',
#   'CME_WZ2007',
#   datetime.datetime(2005, 7, 15, 0, 0),
#   datetime.datetime(2007, 12, 14, 0, 0),
#   '2015-12-17 18:13',
#   'CBOT Wheat, December 2007 (WZ2007)'),
#  ('W',
#   'CME_W',
#   'CME_WH2008',
#   datetime.datetime(2006, 9, 15, 0, 0),
#   datetime.datetime(2008, 3, 14, 0, 0),
#   '2015-12-17 18:13',
#   'CBOT Wheat, March 2008 (WH2008)'),
#  ('W',
#   'CME_W',
#   'CME_WK2008',
#   datetime.datetime(2006, 12, 15, 0, 0),
#   datetime.datetime(2008, 5, 14, 0, 0),
#   '2015-12-17 18:13',
#   'CBOT Wheat, May 2008 (WK2008)'),
#  ('W',
#   'CME_W',
#   'CME_WN2008',
#   datetime.datetime(2005, 7, 15, 0, 0),
#   datetime.datetime(2008, 7, 14, 0, 0),
#   '2015-12-17 18:13',
#   'CBOT Wheat, July 2008 (WN2008)'),
#  ('W',
#   'CME_W',
#   'CME_WU2008',
#   datetime.datetime(2007, 5, 15, 0, 0),
#   datetime.datetime(2008, 9, 12, 0, 0),
#   '2015-12-17 18:13',
#   'CBOT Wheat, September 2008 (WU2008)'),
#  ('W',
#   'CME_W',
#   'CME_WZ2008',
#   datetime.datetime(2006, 4, 19, 0, 0),
#   datetime.datetime(2008, 12, 12, 0, 0),
#   '2015-12-17 18:13',
#   'CBOT Wheat, December 2008 (WZ2008)'),
#  ('W',
#   'CME_W',
#   'CME_WH2009',
#   datetime.datetime(2007, 9, 17, 0, 0),
#   datetime.datetime(2009, 3, 13, 0, 0),
#   '2015-12-17 18:13',
#   'CBOT Wheat, March 2009 (WH2009)'),
#  ('W',
#   'CME_W',
#   'CME_WK2009',
#   datetime.datetime(2008, 1, 10, 0, 0),
#   datetime.datetime(2009, 5, 14, 0, 0),
#   '2015-12-17 18:13',
#   'CBOT Wheat, May 2009 (WK2009)'),
#  ('W',
#   'CME_W',
#   'CME_WN2009',
#   datetime.datetime(2006, 7, 18, 0, 0),
#   datetime.datetime(2009, 7, 14, 0, 0),
#   '2015-12-17 18:13',
#   'CBOT Wheat, July 2009 (WN2009)'),
#  ('W',
#   'CME_W',
#   'CME_WU2009',
#   datetime.datetime(2008, 2, 4, 0, 0),
#   datetime.datetime(2009, 9, 14, 0, 0),
#   '2015-12-17 18:13',
#   'CBOT Wheat, September 2009 (WU2009)'),
#  ('W',
#   'CME_W',
#   'CME_WZ2009',
#   datetime.datetime(2007, 5, 21, 0, 0),
#   datetime.datetime(2009, 12, 14, 0, 0),
#   '2015-12-17 18:13',
#   'CBOT Wheat, December 2009 (WZ2009)'),
#  ('W',
#   'CME_W',
#   'CME_WH2010',
#   datetime.datetime(2008, 3, 17, 0, 0),
#   datetime.datetime(2010, 3, 12, 0, 0),
#   '2015-12-17 18:13',
#   'CBOT Wheat, March 2010 (WH2010)'),
#  ('W',
#   'CME_W',
#   'CME_WK2010',
#   datetime.datetime(2008, 12, 15, 0, 0),
#   datetime.datetime(2010, 5, 14, 0, 0),
#   '2015-12-17 18:13',
#   'CBOT Wheat, May 2010 (WK2010)'),
#  ('W',
#   'CME_W',
#   'CME_WN2010',
#   datetime.datetime(2007, 7, 16, 0, 0),
#   datetime.datetime(2010, 7, 14, 0, 0),
#   '2015-12-17 18:13',
#   'CBOT Wheat, July 2010 (WN2010)'),
#  ('W',
#   'CME_W',
#   'CME_WU2010',
#   datetime.datetime(2009, 4, 16, 0, 0),
#   datetime.datetime(2010, 9, 14, 0, 0),
#   '2015-12-17 18:13',
#   'CBOT Wheat, September 2010 (WU2010)'),
#  ('W',
#   'CME_W',
#   'CME_WZ2010',
#   datetime.datetime(2008, 3, 17, 0, 0),
#   datetime.datetime(2010, 12, 14, 0, 0),
#   '2015-12-17 18:13',
#   'CBOT Wheat, December 2010 (WZ2010)'),
#  ('W',
#   'CME_W',
#   'CME_WH2011',
#   datetime.datetime(2009, 6, 8, 0, 0),
#   datetime.datetime(2011, 3, 14, 0, 0),
#   '2015-12-17 18:13',
#   'CBOT Wheat, March 2011 (WH2011)'),
#  ('W',
#   'CME_W',
#   'CME_WK2011',
#   datetime.datetime(2009, 6, 8, 0, 0),
#   datetime.datetime(2011, 5, 13, 0, 0),
#   '2015-12-17 18:13',
#   'CBOT Wheat, May 2011 (WK2011)'),
#  ('W',
#   'CME_W',
#   'CME_WN2011',
#   datetime.datetime(2008, 7, 17, 0, 0),
#   datetime.datetime(2011, 7, 14, 0, 0),
#   '2015-12-17 18:13',
#   'CBOT Wheat, July 2011 (WN2011)'),
#  ('W',
#   'CME_W',
#   'CME_WU2011',
#   datetime.datetime(2009, 7, 15, 0, 0),
#   datetime.datetime(2011, 9, 14, 0, 0),
#   '2015-12-17 18:13',
#   'CBOT Wheat, September 2011 (WU2011)'),
#  ('W',
#   'CME_W',
#   'CME_WZ2011',
#   datetime.datetime(2009, 7, 14, 0, 0),
#   datetime.datetime(2011, 12, 14, 0, 0),
#   '2015-12-17 18:13',
#   'CBOT Wheat, December 2011 (WZ2011)'),
#  ('W',
#   'CME_W',
#   'CME_WH2012',
#   datetime.datetime(2009, 7, 15, 0, 0),
#   datetime.datetime(2012, 3, 14, 0, 0),
#   '2015-12-17 18:13',
#   'CBOT Wheat, March 2012 (WH2012)'),
#  ('W',
#   'CME_W',
#   'CME_WK2012',
#   datetime.datetime(2009, 7, 15, 0, 0),
#   datetime.datetime(2012, 5, 14, 0, 0),
#   '2015-12-17 18:13',
#   'CBOT Wheat, May 2012 (WK2012)'),
#  ('W',
#   'CME_W',
#   'CME_WN2012',
#   datetime.datetime(2009, 7, 15, 0, 0),
#   datetime.datetime(2012, 7, 13, 0, 0),
#   '2015-12-17 18:13',
#   'CBOT Wheat, July 2012 (WN2012)'),
#  ('W',
#   'CME_W',
#   'CME_WU2012',
#   datetime.datetime(2010, 7, 14, 0, 0),
#   datetime.datetime(2012, 9, 14, 0, 0),
#   '2015-12-17 18:13',
#   'CBOT Wheat, September 2012 (WU2012)'),
#  ('W',
#   'CME_W',
#   'CME_WZ2012',
#   datetime.datetime(2010, 7, 2, 0, 0),
#   datetime.datetime(2012, 12, 14, 0, 0),
#   '2015-12-17 18:13',
#   'CBOT Wheat, December 2012 (WZ2012)'),
#  ('W',
#   'CME_W',
#   'CME_WH2013',
#   datetime.datetime(2010, 7, 14, 0, 0),
#   datetime.datetime(2013, 3, 14, 0, 0),
#   '2015-12-17 18:13',
#   'CBOT Wheat, March 2013 (WH2013)'),
#  ('W',
#   'CME_W',
#   'CME_WK2013',
#   datetime.datetime(2010, 7, 14, 0, 0),
#   datetime.datetime(2013, 5, 14, 0, 0),
#   '2015-12-17 18:13',
#   'CBOT Wheat, May 2013 (WK2013)'),
#  ('W',
#   'CME_W',
#   'CME_WN2013',
#   datetime.datetime(2010, 7, 2, 0, 0),
#   datetime.datetime(2013, 7, 12, 0, 0),
#   '2015-12-17 18:13',
#   'CBOT Wheat, July 2013 (WN2013)'),
#  ('W',
#   'CME_W',
#   'CME_WU2013',
#   datetime.datetime(2011, 9, 15, 0, 0),
#   datetime.datetime(2013, 9, 13, 0, 0),
#   '2015-12-17 18:13',
#   'CBOT Wheat, September 2013 (WU2013)'),
#  ('W',
#   'CME_W',
#   'CME_WZ2013',
#   datetime.datetime(2011, 9, 15, 0, 0),
#   datetime.datetime(2013, 12, 13, 0, 0),
#   '2015-12-17 18:13',
#   'CBOT Wheat, December 2013 (WZ2013)'),
#  ('W',
#   'CME_W',
#   'CME_WH2014',
#   datetime.datetime(2011, 10, 3, 0, 0),
#   datetime.datetime(2014, 3, 14, 0, 0),
#   '2015-12-17 18:13',
#   'CBOT Wheat, March 2014 (WH2014)'),
#  ('W',
#   'CME_W',
#   'CME_WK2014',
#   datetime.datetime(2011, 10, 3, 0, 0),
#   datetime.datetime(2014, 5, 14, 0, 0),
#   '2015-12-17 18:13',
#   'CBOT Wheat, May 2014 (WK2014)'),
#  ('W',
#   'CME_W',
#   'CME_WN2014',
#   datetime.datetime(2011, 10, 3, 0, 0),
#   datetime.datetime(2014, 7, 14, 0, 0),
#   '2015-12-17 18:13',
#   'CBOT Wheat, July 2014 (WN2014)'),
#  ('W',
#   'CME_W',
#   'CME_WU2014',
#   datetime.datetime(2012, 7, 13, 0, 0),
#   datetime.datetime(2014, 9, 12, 0, 0),
#   '2015-12-17 18:13',
#   'CBOT Wheat, September 2014 (WU2014)'),
#  ('W',
#   'CME_W',
#   'CME_WZ2014',
#   datetime.datetime(2012, 7, 13, 0, 0),
#   datetime.datetime(2014, 12, 12, 0, 0),
#   '2015-12-17 18:13',
#   'CBOT Wheat, December 2014 (WZ2014)'),
#  ('W',
#   'CME_W',
#   'CME_WH2015',
#   datetime.datetime(2012, 7, 13, 0, 0),
#   datetime.datetime(2015, 3, 13, 0, 0),
#   '2015-12-17 18:13',
#   'CBOT Wheat, March 2015 (WH2015)'),
#  ('W',
#   'CME_W',
#   'CME_WK2015',
#   datetime.datetime(2012, 7, 13, 0, 0),
#   datetime.datetime(2015, 5, 14, 0, 0),
#   '2015-12-17 18:13',
#   'CBOT Wheat, May 2015 (WK2015)'),
#  ('W',
#   'CME_W',
#   'CME_WN2015',
#   datetime.datetime(2012, 7, 13, 0, 0),
#   datetime.datetime(2015, 7, 14, 0, 0),
#   '2015-12-17 18:13',
#   'CBOT Wheat, July 2015 (WN2015)'),
#  ('W',
#   'CME_W',
#   'CME_WU2015',
#   datetime.datetime(2013, 7, 12, 0, 0),
#   datetime.datetime(2015, 9, 14, 0, 0),
#   '2015-12-17 18:13',
#   'CBOT Wheat, September 2015 (WU2015)'),
#  ('W',
#   'CME_W',
#   'CME_WZ2015',
#   datetime.datetime(2013, 7, 12, 0, 0),
#   datetime.datetime(2015, 12, 14, 0, 0),
#   '2015-12-17 18:13',
#   'CBOT Wheat, December 2015 (WZ2015)'),
#  ('W',
#   'CME_W',
#   'CME_WH2016',
#   datetime.datetime(2013, 7, 12, 0, 0),
#   datetime.datetime(2016, 3, 14, 0, 0),
#   '2016-03-16 23:34',
#   'CBOT Wheat, March 2016 (WH2016)'),
#  ('W',
#   'CME_W',
#   'CME_WK2016',
#   datetime.datetime(2013, 7, 12, 0, 0),
#   datetime.datetime(2016, 5, 13, 0, 0),
#   '2016-05-14 2:30',
#   'CBOT Wheat, May 2016 (WK2016)'),
#  ('W',
#   'CME_W',
#   'CME_WN2016',
#   datetime.datetime(2013, 7, 12, 0, 0),
#   datetime.datetime(2016, 7, 14, 0, 0),
#   '2016-07-16 2:33',
#   'CBOT Wheat, July 2016 (WN2016)'),
#  ('W',
#   'CME_W',
#   'CME_WU2016',
#   datetime.datetime(2014, 7, 14, 0, 0),
#   datetime.datetime(2016, 9, 14, 0, 0),
#   '2016-09-16 2:31',
#   'CBOT Wheat, September 2016 (WU2016)'),
#  ('W',
#   'CME_W',
#   'CME_WZ2016',
#   datetime.datetime(2014, 7, 14, 0, 0),
#   datetime.datetime(2016, 12, 14, 0, 0),
#   '2016-12-16 2:34',
#   'CBOT Wheat, December 2016 (WZ2016)'),
#  ('W',
#   'CME_W',
#   'CME_WH2017',
#   datetime.datetime(2014, 7, 14, 0, 0),
#   datetime.datetime(2017, 3, 14, 0, 0),
#   '2017-03-16 2:32',
#   'CBOT Wheat, March 2017 (WH2017)'),
#  ('W',
#   'CME_W',
#   'CME_WK2017',
#   datetime.datetime(2014, 7, 14, 0, 0),
#   datetime.datetime(2017, 5, 12, 0, 0),
#   '2017-05-13 2:31',
#   'CBOT Wheat, May 2017 (WK2017)'),
#  ('W',
#   'CME_W',
#   'CME_WN2017',
#   datetime.datetime(2014, 7, 14, 0, 0),
#   datetime.datetime(2017, 7, 14, 0, 0),
#   '2017-07-15 2:42',
#   'CBOT Wheat, July 2017 (WN2017)'),
#  ('W',
#   'CME_W',
#   'CME_WU2017',
#   datetime.datetime(2015, 7, 15, 0, 0),
#   datetime.datetime(2017, 9, 14, 0, 0),
#   '2017-09-16 2:28',
#   'CBOT Wheat, September 2017 (WU2017)'),
#  ('W',
#   'CME_W',
#   'CME_WZ2017',
#   datetime.datetime(2015, 7, 15, 0, 0),
#   datetime.datetime(2017, 12, 14, 0, 0),
#   '2017-12-16 3:35',
#   'CBOT Wheat, December 2017 (WZ2017)'),
#  ('W',
#   'CME_W',
#   'CME_WH2018',
#   datetime.datetime(2015, 7, 15, 0, 0),
#   datetime.datetime(2018, 3, 14, 0, 0),
#   '2018-03-16 23:41',
#   'CBOT Wheat, March 2018 (WH2018)'),
#  ('W',
#   'CME_W',
#   'CME_WK2018',
#   datetime.datetime(2015, 7, 15, 0, 0),
#   datetime.datetime(2018, 5, 14, 0, 0),
#   '2018-05-16 23:36',
#   'CBOT Wheat, May 2018 (WK2018)'),
#  ('W',
#   'CME_W',
#   'CME_WN2018',
#   datetime.datetime(2015, 7, 15, 0, 0),
#   datetime.datetime(2018, 7, 13, 0, 0),
#   '2018-07-17 23:36',
#   'CBOT Wheat, July 2018 (WN2018)'),
#  ('W',
#   'CME_W',
#   'CME_WU2018',
#   datetime.datetime(2016, 7, 14, 0, 0),
#   datetime.datetime(2018, 9, 14, 0, 0),
#   '2018-09-18 23:35',
#   'CBOT Wheat, September 2018 (WU2018)'),
#  ('W',
#   'CME_W',
#   'CME_WZ2018',
#   datetime.datetime(2016, 7, 14, 0, 0),
#   datetime.datetime(2018, 12, 14, 0, 0),
#   '2018-12-18 3:35',
#   'CBOT Wheat, December 2018 (WZ2018)'),
#  ('W',
#   'CME_W',
#   'CME_WH2019',
#   datetime.datetime(2016, 7, 14, 0, 0),
#   datetime.datetime(2019, 3, 14, 0, 0),
#   '2019-03-18 23:48',
#   'CBOT Wheat, March 2019 (WH2019)'),
#  ('W',
#   'CME_W',
#   'CME_WK2019',
#   datetime.datetime(2016, 7, 14, 0, 0),
#   datetime.datetime(2019, 5, 14, 0, 0),
#   '2019-05-18 2:35',
#   'CBOT Wheat, May 2019 (WK2019)'),
#  ('W',
#   'CME_W',
#   'CME_WN2019',
#   datetime.datetime(2016, 7, 14, 0, 0),
#   datetime.datetime(2019, 7, 12, 0, 0),
#   '2019-07-16 23:35',
#   'CBOT Wheat, July 2019 (WN2019)'),
#  ('W',
#   'CME_W',
#   'CME_WU2019',
#   datetime.datetime(2017, 7, 14, 0, 0),
#   datetime.datetime(2019, 9, 13, 0, 0),
#   '2019-09-17 23:40',
#   'CBOT Wheat, September 2019 (WU2019)'),
#  ('W',
#   'CME_W',
#   'CME_WZ2019',
#   datetime.datetime(2017, 7, 14, 0, 0),
#   datetime.datetime(2019, 12, 13, 0, 0),
#   '2019-12-17 3:38',
#   'CBOT Wheat, December 2019 (WZ2019)'),
#  ('W',
#   'CME_W',
#   'CME_WH2020',
#   datetime.datetime(2017, 7, 14, 0, 0),
#   datetime.datetime(2020, 3, 13, 0, 0),
#   '2020-03-17 23:36',
#   'CBOT Wheat, March 2020 (WH2020)'),
#  ('W',
#   'CME_W',
#   'CME_WK2020',
#   datetime.datetime(2017, 7, 14, 0, 0),
#   datetime.datetime(2020, 5, 14, 0, 0),
#   '2020-05-18 23:35',
#   'Wheat Futures, May 2020 (WK2020)'),
#  ('W',
#   'CME_W',
#   'CME_WN2020',
#   datetime.datetime(2017, 7, 14, 0, 0),
#   datetime.datetime(2020, 7, 14, 0, 0),
#   '2020-07-18 2:36',
#   'Wheat Futures, July 2020 (WN2020)'),
#  ('W',
#   'CME_W',
#   'CME_WU2020',
#   datetime.datetime(2018, 7, 13, 0, 0),
#   datetime.datetime(2020, 9, 14, 0, 0),
#   '2020-09-18 23:37',
#   'Wheat Futures, September 2020 (WU2020)'),
#  ('W',
#   'CME_W',
#   'CME_WZ2020',
#   datetime.datetime(2018, 7, 13, 0, 0),
#   datetime.datetime(2020, 12, 14, 0, 0),
#   '2020-12-18 3:37',
#   'Wheat Futures, December 2020 (WZ2020)'),
#  ('W',
#   'CME_W',
#   'CME_WH2021',
#   datetime.datetime(2018, 7, 13, 0, 0),
#   datetime.datetime(2021, 3, 12, 0, 0),
#   '2021-03-16 3:38',
#   'Wheat Futures, March 2021 (WH2021)'),
#  ('W',
#   'CME_W',
#   'CME_WK2021',
#   datetime.datetime(2018, 7, 13, 0, 0),
#   datetime.datetime(2021, 5, 14, 0, 0),
#   '2021-05-18 23:37',
#   'Wheat Futures, May 2021 (WK2021)'),
#  ('W',
#   'CME_W',
#   'CME_WN2021',
#   datetime.datetime(2018, 7, 13, 0, 0),
#   datetime.datetime(2021, 7, 14, 0, 0),
#   '2021-07-17 2:37',
#   'Wheat Futures, July 2021 (WN2021)'),
#  ('W',
#   'CME_W',
#   'CME_WU2021',
#   datetime.datetime(2019, 7, 12, 0, 0),
#   datetime.datetime(2021, 9, 14, 0, 0),
#   '2021-09-18 2:37',
#   'Wheat Futures, September 2021 (WU2021)'),
#  ('W',
#   'CME_W',
#   'CME_WZ2021',
#   datetime.datetime(2019, 7, 12, 0, 0),
#   datetime.datetime(2021, 12, 14, 0, 0),
#   '2021-12-18 3:38',
#   'Wheat Futures, December 2021 (WZ2021)'),
#  ('W',
#   'CME_W',
#   'CME_WH2022',
#   datetime.datetime(2019, 7, 12, 0, 0),
#   datetime.datetime(2022, 3, 14, 0, 0),
#   '2022-03-18 23:38',
#   'Wheat Futures, March 2022 (WH2022)'),
#  ('W',
#   'CME_W',
#   'CME_WK2022',
#   datetime.datetime(2019, 7, 12, 0, 0),
#   datetime.datetime(2022, 4, 19, 0, 0),
#   '2022-04-20 2:38',
#   'Wheat Futures, May 2022 (WK2022)'),
#  ('W',
#   'CME_W',
#   'CME_WN2022',
#   datetime.datetime(2019, 7, 12, 0, 0),
#   datetime.datetime(2022, 4, 19, 0, 0),
#   '2022-04-20 2:38',
#   'Wheat Futures, July 2022 (WN2022)'),
#  ('W',
#   'CME_W',
#   'CME_WU2022',
#   datetime.datetime(2020, 7, 14, 0, 0),
#   datetime.datetime(2022, 4, 19, 0, 0),
#   '2022-04-20 2:38',
#   'Wheat Futures, September 2022 (WU2022)'),
#  ('W',
#   'CME_W',
#   'CME_WZ2022',
#   datetime.datetime(2020, 7, 14, 0, 0),
#   datetime.datetime(2022, 4, 19, 0, 0),
#   '2022-04-20 2:38',
#   'Wheat Futures, December 2022 (WZ2022)'),
#  ('W',
#   'CME_W',
#   'CME_WH2023',
#   datetime.datetime(2020, 7, 14, 0, 0),
#   datetime.datetime(2022, 4, 19, 0, 0),
#   '2022-04-20 2:38',
#   'Wheat Futures, March 2023 (WH2023)'),
#  ('W',
#   'CME_W',
#   'CME_WK2023',
#   datetime.datetime(2020, 7, 14, 0, 0),
#   datetime.datetime(2022, 4, 19, 0, 0),
#   '2022-04-20 2:38',
#   'Wheat Futures, May 2023 (WK2023)'),
#  ('W',
#   'CME_W',
#   'CME_WN2023',
#   datetime.datetime(2020, 7, 14, 0, 0),
#   datetime.datetime(2022, 4, 19, 0, 0),
#   '2022-04-20 2:38',
#   'Wheat Futures, July 2023 (WN2023)'),
#  ('W',
#   'CME_W',
#   'CME_WU2023',
#   datetime.datetime(2021, 7, 15, 0, 0),
#   datetime.datetime(2022, 4, 19, 0, 0),
#   '2022-04-20 2:38',
#   'Wheat Futures, September 2023 (WU2023)'),
#  ('W',
#   'CME_W',
#   'CME_WZ2023',
#   datetime.datetime(2021, 7, 15, 0, 0),
#   datetime.datetime(2022, 4, 19, 0, 0),
#   '2022-04-20 2:38',
#   'Wheat Futures, December 2023 (WZ2023)'),
#  ('W',
#   'CME_W',
#   'CME_WH2024',
#   datetime.datetime(2021, 7, 15, 0, 0),
#   datetime.datetime(2022, 4, 19, 0, 0),
#   '2022-04-20 2:38',
#   'Wheat Futures, March 2024 (WH2024)'),
#  ('W',
#   'CME_W',
#   'CME_WK2024',
#   datetime.datetime(2021, 7, 15, 0, 0),
#   datetime.datetime(2022, 4, 19, 0, 0),
#   '2022-04-20 2:38',
#   'Wheat Futures, May 2024 (WK2024)'),
#  ('W',
#   'CME_W',
#   'CME_WN2024',
#   datetime.datetime(2021, 7, 15, 0, 0),
#   datetime.datetime(2022, 4, 19, 0, 0),
#   '2022-04-20 2:38',
#   'Wheat Futures, July 2024 (WN2024)')]

# %%
df = pd.DataFrame(file['W']['CME_WZ1973'][:])

# %%
df
# Out:
#      date    open    high     low   close  volume  open_interest
# 0    1097  239.25  240.00  233.75  234.75     320            275
# 1    1098  234.25  239.75  234.25  239.25     310            375
# 2    1099  240.00  241.50  236.25  236.50     410            705
# 3    1100  237.25  239.50  234.50  236.50      70            740
# 4    1103  235.75  237.25  235.50  236.50     185            665
# ..    ...     ...     ...     ...     ...     ...            ...
# 238  1441  572.00  578.00  547.00  550.50    3095           7250
# 239  1442  550.00  560.00  530.50  544.00    3565           5950
# 240  1443  547.00  547.00  527.00  528.50    1955           4805
# 241  1446  535.00  548.50  524.00  548.50    1835           3755
# 242  1447  560.00  565.00  529.00  533.00    2790           2115
#
# [243 rows x 7 columns]
