# %% [markdown]
# ### 종목별 증거금 업데이트
# * TradeStation 웹사이트 이용

# %%
import requests
from bs4 import BeautifulSoup
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_25704/852116523.py in <module>
#       1 import requests
# ----> 2 from bs4 import BeautifulSoup
#
# ModuleNotFoundError: No module named 'bs4'

# %%
url = "https://www.tradestation.com/pricing/futures-margin-requirements/"
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'}

# %%
res = requests.get(url, headers=headers)

# %%
print(res.content)
# Out:
# b'<!DOCTYPE html>\n<html lang="en-US">\n<head>\n\t<meta charset="UTF-8" />\n<meta http-equiv="X-UA-Compatible" content="IE=edge">\n\t<link rel="pingback" href="https://www.tradestation.com/xmlrpc.php" />\n\n\t<script type="text/javascript">\n\t\tdocument.documentElement.className = \'js\';\n\t</script>\n\t\n\t<!-- Google Tag Manager -->\n\t<script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({\'gtm.start\':\n\tnew Date().getTime(),event:\'gtm.js\'});var f=d.getElementsByTagName(s)[0],\n\tj=d.createElement(s),dl=l!=\'dataLayer\'?\'&l=\'+l:\'\';j.async=true;j.src=\n\t\'https://www.googletagmanager.com/gtm.js?id=\'+i+dl;f.parentNode.insertBefore(j,f);\n\t})(window,document,\'script\',\'dataLayer\',\'GTM-QFXN\');</script>\n\t<!-- End Google Tag Manager -->\n\n\t<meta name=\'robots\' content=\'index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1\' />\n\n\t<!-- This site is optimized with the Yoast SEO plugin v18.2 - https://yoast.com/wordpress/plugins/seo/ -->\n\t<title>Futures Margin Rates | TradeStation</title>\n\t<meta name="description" content="Get reduced intraday margin rates overnight on U.S. equity index futures." />\n\t<link rel="canonical" href="https://www.tradestation.com/pricing/futures-margin-requirements/" />\n\t<meta property="og:locale" content="en_US" />\n\t<meta property="og:type" content="article" />\n\t<meta property="og:title" content="Futures Margin Rates | TradeStation" />\n\t<meta property="og:description" content="Get reduced intraday margin rates overnight on U.S. equity index futures." />\n\t<meta property="og:url" content="https://www.tradestation.com/pricing/futures-margin-requirements/" />\n\t<meta property="og:site_name" content="TradeStation" />\n\t<meta property="article:publisher" content="https://www.facebook.com/TradeStation" />\n\t<meta property="article:modified_time" content="2022-04-08T13:52:13+00:00" />\n\t<meta name="twitter:card" content="summary_large_image" />\n\t<meta name="twitter:site" content="@TradeStation" />\n\t<meta name="twitter:label1" content="Est. reading time" />\n\t<meta name="twitter:data1" content="8 minutes" />\n\t<script type="application/ld+json" class="yoast-schema-graph">{"@context":"https://schema.org","@graph":[{"@type":"Organization","@id":"https://www.tradestation.com/#organization","name":"TradeStation","url":"https://www.tradestation.com/","sameAs":["https://www.facebook.com/TradeStation","https://www.instagram.com/tradestation","https://www.linkedin.com/company/tradestation","http://www.youtube.com/tradestation","https://en.wikipedia.org/wiki/TradeStation","https://twitter.com/TradeStation"],"logo":{"@type":"ImageObject","@id":"https://www.tradestation.com/#logo","inLanguage":"en-US","url":"https://uploads.tradestation.com/uploads/TS-Logo-Mark.png","contentUrl":"https://uploads.tradestation.com/uploads/TS-Logo-Mark.png","width":1000,"height":1333,"caption":"TradeStation"},"image":{"@id":"https://www.tradestation.com/#logo"}},{"@type":"WebSite","@id":"https://www.tradestation.com/#website","url":"https://www.tradestation.com/","name":"TradeStation","description":"Award-Winning Online Broker","publisher":{"@id":"https://www.tradestation.com/#organization"},"potentialAction":[{"@type":"SearchAction","target":{"@type":"EntryPoint","urlTemplate":"https://www.tradestation.com/?s={search_term_string}"},"query-input":"required name=search_term_string"}],"inLanguage":"en-US"},{"@type":"WebPage","@id":"https://www.tradestation.com/pricing/futures-margin-requirements/#webpage","url":"https://www.tradestation.com/pricing/futures-margin-requirements/","name":"Futures Margin Rates | TradeStation","isPartOf":{"@id":"https://www.tradestation.com/#website"},"datePublished":"2019-11-19T20:01:06+00:00","dateModified":"2022-04-08T13:52:13+00:00","description":"Get reduced intraday margin rates overnight on U.S. equity index futures.","breadcrumb":{"@id":"https://www.tradestation.com/pricing/futures-margin-requirements/#breadcrumb"},"inLanguage":"en-US"," ...

# %%
res.text
# Out:
# '<!DOCTYPE html>\n<html lang="en-US">\n<head>\n\t<meta charset="UTF-8" />\n<meta http-equiv="X-UA-Compatible" content="IE=edge">\n\t<link rel="pingback" href="https://www.tradestation.com/xmlrpc.php" />\n\n\t<script type="text/javascript">\n\t\tdocument.documentElement.className = \'js\';\n\t</script>\n\t\n\t<!-- Google Tag Manager -->\n\t<script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({\'gtm.start\':\n\tnew Date().getTime(),event:\'gtm.js\'});var f=d.getElementsByTagName(s)[0],\n\tj=d.createElement(s),dl=l!=\'dataLayer\'?\'&l=\'+l:\'\';j.async=true;j.src=\n\t\'https://www.googletagmanager.com/gtm.js?id=\'+i+dl;f.parentNode.insertBefore(j,f);\n\t})(window,document,\'script\',\'dataLayer\',\'GTM-QFXN\');</script>\n\t<!-- End Google Tag Manager -->\n\n\t<meta name=\'robots\' content=\'index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1\' />\n\n\t<!-- This site is optimized with the Yoast SEO plugin v18.2 - https://yoast.com/wordpress/plugins/seo/ -->\n\t<title>Futures Margin Rates | TradeStation</title>\n\t<meta name="description" content="Get reduced intraday margin rates overnight on U.S. equity index futures." />\n\t<link rel="canonical" href="https://www.tradestation.com/pricing/futures-margin-requirements/" />\n\t<meta property="og:locale" content="en_US" />\n\t<meta property="og:type" content="article" />\n\t<meta property="og:title" content="Futures Margin Rates | TradeStation" />\n\t<meta property="og:description" content="Get reduced intraday margin rates overnight on U.S. equity index futures." />\n\t<meta property="og:url" content="https://www.tradestation.com/pricing/futures-margin-requirements/" />\n\t<meta property="og:site_name" content="TradeStation" />\n\t<meta property="article:publisher" content="https://www.facebook.com/TradeStation" />\n\t<meta property="article:modified_time" content="2022-04-08T13:52:13+00:00" />\n\t<meta name="twitter:card" content="summary_large_image" />\n\t<meta name="twitter:site" content="@TradeStation" />\n\t<meta name="twitter:label1" content="Est. reading time" />\n\t<meta name="twitter:data1" content="8 minutes" />\n\t<script type="application/ld+json" class="yoast-schema-graph">{"@context":"https://schema.org","@graph":[{"@type":"Organization","@id":"https://www.tradestation.com/#organization","name":"TradeStation","url":"https://www.tradestation.com/","sameAs":["https://www.facebook.com/TradeStation","https://www.instagram.com/tradestation","https://www.linkedin.com/company/tradestation","http://www.youtube.com/tradestation","https://en.wikipedia.org/wiki/TradeStation","https://twitter.com/TradeStation"],"logo":{"@type":"ImageObject","@id":"https://www.tradestation.com/#logo","inLanguage":"en-US","url":"https://uploads.tradestation.com/uploads/TS-Logo-Mark.png","contentUrl":"https://uploads.tradestation.com/uploads/TS-Logo-Mark.png","width":1000,"height":1333,"caption":"TradeStation"},"image":{"@id":"https://www.tradestation.com/#logo"}},{"@type":"WebSite","@id":"https://www.tradestation.com/#website","url":"https://www.tradestation.com/","name":"TradeStation","description":"Award-Winning Online Broker","publisher":{"@id":"https://www.tradestation.com/#organization"},"potentialAction":[{"@type":"SearchAction","target":{"@type":"EntryPoint","urlTemplate":"https://www.tradestation.com/?s={search_term_string}"},"query-input":"required name=search_term_string"}],"inLanguage":"en-US"},{"@type":"WebPage","@id":"https://www.tradestation.com/pricing/futures-margin-requirements/#webpage","url":"https://www.tradestation.com/pricing/futures-margin-requirements/","name":"Futures Margin Rates | TradeStation","isPartOf":{"@id":"https://www.tradestation.com/#website"},"datePublished":"2019-11-19T20:01:06+00:00","dateModified":"2022-04-08T13:52:13+00:00","description":"Get reduced intraday margin rates overnight on U.S. equity index futures.","breadcrumb":{"@id":"https://www.tradestation.com/pricing/futures-margin-requirements/#breadcrumb"},"inLanguage":"en-US","p ...
