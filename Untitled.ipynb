# %%
from .tools import Instrument
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from .tools import Instrument
#
# ImportError: attempted relative import with no known parent package

# %%
from tools.instruments import Instruments

# %%
Instruments
# Out:
# tools.instruments.Instruments

# %%
from tools.instruments import instruments

# %%
instruments['AD'].rolldates(method='bo')
# Out:
# [['AD', 'CME_ADH1987', '1987-01-13', '1987-03-12', '58', '0'],
#  ['AD',
#   'CME_ADM1987',
#   '1987-03-13',
#   '1987-06-02',
#   '81',
#   '-0.01569998264312744'],
#  ['AD',
#   'CME_ADU1987',
#   '1987-06-03',
#   '1987-09-14',
#   '103',
#   '-0.011600017547607422'],
#  ['AD',
#   'CME_ADZ1987',
#   '1987-09-15',
#   '1987-12-14',
#   '90',
#   '-0.006399989128112793'],
#  ['AD',
#   'CME_ADH1988',
#   '1987-12-15',
#   '1988-03-14',
#   '90',
#   '-0.008400022983551025'],
#  ['AD',
#   'CME_ADM1988',
#   '1988-03-15',
#   '1988-06-13',
#   '90',
#   '-0.007200002670288086'],
#  ['AD',
#   'CME_ADU1988',
#   '1988-06-14',
#   '1988-09-19',
#   '97',
#   '-0.015899956226348877'],
#  ['AD',
#   'CME_ADZ1988',
#   '1988-09-20',
#   '1988-12-14',
#   '85',
#   '-0.009299993515014648'],
#  ['AD',
#   'CME_ADH1989',
#   '1988-12-15',
#   '1989-03-13',
#   '88',
#   '-0.010200023651123047'],
#  ['AD',
#   'CME_ADM1989',
#   '1989-03-14',
#   '1989-06-15',
#   '93',
# ...

# %%
instruments.filter(symbol='AD')
# Out:
# [[AD] CME Australian Dollar AUD]

# %%
list(instruments.keys())
# Out:
# ['AD',
#  'AL',
#  'ATW',
#  'B',
#  'BO',
#  'BP',
#  'C',
#  'CC',
#  'CD',
#  'CL',
#  'CT',
#  'CU',
#  'DA',
#  'DX',
#  'EC',
#  'ED',
#  'ES',
#  'FBTP',
#  'FDAX',
#  'FESX',
#  'FF',
#  'FGBL',
#  'FGBM',
#  'FGBS',
#  'FOAT',
#  'FV',
#  'G',
#  'GC',
#  'HG',
#  'HO',
#  'I',
#  'JY',
#  'KC',
#  'KW',
#  'L',
#  'LB',
#  'LC',
#  'LN',
#  'M',
#  'MD',
#  'MP',
#  'MW',
#  'NE',
#  'NG',
#  'NK',
#  'NQ',
#  'O',
#  'OJ',
#  'PA',
#  'PB',
#  'PL',
#  'R',
#  'RB',
#  'RF',
#  'RR',
#  'RS1',
#  'RTY',
#  'RU',
#  'S',
#  'SB',
#  'SF',
#  'SI',
#  'SM',
#  'SP',
#  'SXF',
#  'T',
#  'TF',
#  'TU',
#  'TY',
#  'US',
#  'VX',
#  'W',
#  'YM',
#  'Z',
#  'ZN',
#  'FC']
